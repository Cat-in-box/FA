# %% [markdown]
# # Классификация изображений

# %%
from sklearn.datasets import fetch_olivetti_faces
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import svm
import numpy as np
import seaborn as sns
import pandas as pd
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import learning_curve

# %% [markdown]
# ### 1. Загрузите датасет Olivetti faces;

# %%
faces = fetch_olivetti_faces()
print(faces.DESCR)
# Out:
# .. _olivetti_faces_dataset:
#
# The Olivetti faces dataset
# --------------------------
#
# `This dataset contains a set of face images`_ taken between April 1992 and
# April 1994 at AT&T Laboratories Cambridge. The
# :func:`sklearn.datasets.fetch_olivetti_faces` function is the data
# fetching / caching function that downloads the data
# archive from AT&T.
#
# .. _This dataset contains a set of face images: http://www.cl.cam.ac.uk/research/dtg/attarchive/facedatabase.html
#
# As described on the original website:
#
#     There are ten different images of each of 40 distinct subjects. For some
#     subjects, the images were taken at different times, varying the lighting,
#     facial expressions (open / closed eyes, smiling / not smiling) and facial
#     details (glasses / no glasses). All the images were taken against a dark
#     homogeneous background with the subjects in an upright, frontal position
#     (with tolerance for some side movement).
#
# ...

# %% [markdown]
# ### 3. Выведите информацию о количественных параметрах датасета;

# %%
print(faces.DESCR)
# Out:
# .. _olivetti_faces_dataset:
#
# The Olivetti faces dataset
# --------------------------
#
# `This dataset contains a set of face images`_ taken between April 1992 and
# April 1994 at AT&T Laboratories Cambridge. The
# :func:`sklearn.datasets.fetch_olivetti_faces` function is the data
# fetching / caching function that downloads the data
# archive from AT&T.
#
# .. _This dataset contains a set of face images: http://www.cl.cam.ac.uk/research/dtg/attarchive/facedatabase.html
#
# As described on the original website:
#
#     There are ten different images of each of 40 distinct subjects. For some
#     subjects, the images were taken at different times, varying the lighting,
#     facial expressions (open / closed eyes, smiling / not smiling) and facial
#     details (glasses / no glasses). All the images were taken against a dark
#     homogeneous background with the subjects in an upright, frontal position
#     (with tolerance for some side movement).
#
# ...

# %% [markdown]
# ### 4. Выведите несколько изображений на экран используя инструментарий библиотеки matplotlib;

# %%
_, axs = plt.subplots(1, 4, figsize=(22, 22)) # делим область вывода на 4 части, чтобы вывести в ряд
for i in range(4):
    axs[i].imshow(faces.images[i], cmap=plt.cm.bone) # отрисовываем изображения

# %% [markdown]
# ### 5. Разделите эти данные на тестовую и обучающую выборки;

# %%
X = faces.data # матрица пикселей
Y = faces.target # отношение данных к классу

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=True)

# %% [markdown]
# ### 6. Постройте модель классификатора метода опорных векторов для идентификации человека по изображению;

# %%
# строим модель классификатора метода опорных векторов
clf = svm.SVC()
clf.fit(X, Y)
y_pred = clf.predict(x_test) # обучаем ее

# %% [markdown]
# Матрица предсказаний:

# %%
# %matplotlib inline

class_names = [0, 1]
fig, ax = plt.subplots(figsize=(22, 22))
ticks = np.arange(len(class_names))

plt.xticks(ticks, class_names) # ось x
plt.yticks(ticks, class_names) # ось y

# Строим матрицу
sns.heatmap(pd.DataFrame(metrics.confusion_matrix(y_test, y_pred)), annot=True)
plt.ylabel('Действительные значения')
plt.xlabel('Предсказанные значения')
# Out:
# Text(0.5, 177.0, 'Предсказанные значения')

# %% [markdown]
# Слишком хороший результат, судя по матрице

# %% [markdown]
# ### 7. Оцените качество модели на тестовой выборке с помощью следующих метрик:

# %% [markdown]
# ##### a. достоверность предсказания (accuracy);
# ##### b. точность (precision);
# ##### c. полнота (recall);

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         1
#            5       1.00      1.00      1.00         1
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         1
#            8       1.00      1.00      1.00         3
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         1
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           16       1.00      1.00      1.00         1
#           17       1.00      1.00      1.00         3
#           18       1.00      1.00      1.00         2
# ...

# %% [markdown]
# Достоверность предсказания (accuracy) -> 1.0
#
# Точность (precision) -> 1.0
#
# Полнота (recall) -> 1.0
#
# Выглядит подозрительно

# %% [markdown]
# ### 8. Постройте кривую обучения - график зависимости тестовой и обучающей эффективности от размера обучающей выборки.

# %%
def plot_learning_curve(estimator, title, X, y, axes=None, ylim=None, cv=None, n_jobs=None, train_sizes=np.linspace(0.1, 1.0, 5)):
    
    # задаем параметры для отрисовки графиков
    if axes is None:
        _, axes = plt.subplots(1, 3, figsize=(20, 5))

    axes[0].set_title(title)
    if ylim is not None:
        axes[0].set_ylim(*ylim)
    
    axes[0].set_xlabel("Тренировочные примеры")
    axes[0].set_ylabel("Оценка")

    # подсчет характеристик (среднее и  стандартное отклонение для характеристик обучающей и тестовой выборок)
    train_sizes, train_scores, test_scores, fit_times, _ = learning_curve(estimator,X,y,cv=cv,n_jobs=n_jobs,train_sizes=train_sizes,return_times=True,)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    fit_times_mean = np.mean(fit_times, axis=1)
    fit_times_std = np.std(fit_times, axis=1)

    # отрисовываем
    # График кривой обучения
    axes[0].grid()
    axes[0].fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r",)
    axes[0].fill_between(
        train_sizes,
        test_scores_mean - test_scores_std,
        test_scores_mean + test_scores_std,
        alpha=0.1,
        color="g",
    )
    axes[0].plot(train_sizes, train_scores_mean, "o-", color="r", label="Тренировочная оценка")
    axes[0].plot(train_sizes, test_scores_mean, "o-", color="g", label="Оценка кросс-валидации")
    axes[0].legend(loc="best")

    # График n_samples / fit_times
    axes[1].grid()
    axes[1].plot(train_sizes, fit_times_mean, "o-")
    axes[1].fill_between(train_sizes,fit_times_mean - fit_times_std,fit_times_mean + fit_times_std,alpha=0.1,)
    axes[1].set_xlabel("Тренировочные данные")
    axes[1].set_ylabel("Успешность")
    axes[1].set_title("Scalability of the model")

    # График fit_time / score
    fit_time_argsort = fit_times_mean.argsort()
    fit_time_sorted = fit_times_mean[fit_time_argsort]
    test_scores_mean_sorted = test_scores_mean[fit_time_argsort]
    test_scores_std_sorted = test_scores_std[fit_time_argsort]
    axes[2].grid()
    axes[2].plot(fit_time_sorted, test_scores_mean_sorted, "o-")
    axes[2].fill_between(fit_time_sorted,test_scores_mean_sorted - test_scores_std_sorted,test_scores_mean_sorted + test_scores_std_sorted,alpha=0.1,)
    axes[2].set_xlabel("Успешность")
    axes[2].set_ylabel("Оценка")
    axes[2].set_title("Эффективность модели")

    return plt

# %%
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
plot_learning_curve(clf, "", X, Y, cv=cv)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\anast\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### 9. Сделайте вывод о применимости модели.

# %% [markdown]
# Модель применима, но лучше увеличить объем данных (400 - это мало, я считаю). Можно использовать изменения в угле наклона или отражение изображений.
