# %% [markdown]
# # Форматы данных (2)

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 5: Форматы данных (часть 2)"
# * https://docs.python.org/3/library/csv.html
# * https://docs.h5py.org/en/stable/
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Считайте данные из файла `open_pubs.csv`, используя `csv.reader`, и преобразуйте к структуре данных следующего вида:
#
# `{'fas_id': [24, 30, ...], 'name': ['Achor Inn', 'Angel Inn', ...], ... }`

# %%
with open('../data/open_pubs.csv') as fp:
    dictionary = []
    reader = csv.reader(fp)
    headers = next(reader)
    for _ in range(len(headers)):
        dictionary.append([])
    for row in reader:
        for i in range(len(headers)):
            dictionary[i].append(row[i])

dictionary = dict(zip(headers, dictionary))
dictionary
# Out:
# {'fas_id': ['24',
#   '30',
#   '63',
#   '64',
#   '65',
#   '85',
#   '101',
#   '126',
#   '140',
#   '153',
#   '154',
#   '197',
#   '230',
#   '240',
#   '252',
#   '261',
#   '272',
#   '281',
#   '294',
#   '307',
#   '308',
#   '396',
#   '397',
#   '429',
#   '441',
#   '498',
#   '500',
#   '516',
#   '535',
#   '553',
#   '561',
#   '562',
#   '569',
#   '574',
#   '577',
#   '578',
#   '601',
#   '606',
#   '665',
#   '679',
#   '698',
#   '699',
#   '700',
#   '703',
#   '704',
#   '705',
#   '708',
#   '709',
#   '713',
#   '714',
#   '716',
#   '718',
#   '722',
#   '723',
#   '724',
#   '725',
#   '726',
#   '729',
#   '733',
#   '734',
#   '735',
#   '736',
#   '739',
#   '743',
#   '744',
#   '745',
#   '749',
#   '751',
#   '752',
#   '757',
#   '758',
#   '760',
#   '763',
#   '771',
#   '775',
#   '776',
#   '778',
#   '780',
#   '781',
#   '785',
#   '788',
#   '789',
#   '791',
#   '792',
#   '793',
#   '794',
#   '796',
#   '797',
#   '799',
#   '800',
#   '805',
#   '824',
#   '843',
#   '852',
#   '853',
#   '855',
#   '933',
#   '940',
#   '947',
#   '956',
#   '958',
#   '959',
#   '961',
#   '971',
#   '975',
#   '977',
#   '981',
#   '982',
#   '1000',
#   '1012',
#   '1022',
#   '1024',
#   '1064',
#   '1082',
#   '1087',
#   '1106',
#   '1108',
#   '1143',
#   '1145',
#   '1153',
#   '1169',
#   '1183',
#   '1188',
#   '1241',
#   '1250',
#   '1251',
#   '1260',
#   '1283',
#   '1307',
#   '1308',
#   '1329',
#   '1345',
#   '1347',
#   '1360',
#   '1374',
#   '1383',
#   '1509',
#   '1573',
#   '1618',
#   '1642',
#   '1657',
#   '1658',
#   '1671',
#   '1730',
#   '1734',
#   '1747',
#   '1777',
#   '1840',
#   '1841',
#   '1847',
#   '1860',
#   '1862',
#   '1865',
#   '1866',
#   '1868',
#   '1873',
#   '1874',
#   '1885',
#   '1888',
#   '1893',
#   '1895',
#   '1903',
#   '1906',
#   '1907',
#   '1909',
#   '1911',
#   '1916',
#   '1920',
#   '1937',
#   '1942',
#   '1963',
#   '1969',
#   '1990',
#   '1992',
#   '2020',
#   '2021',
#   '2052',
#   '2072',
#   '2083',
#   '2092',
#   '2093',
#   '2099',
#   '2100',
#   '2102',
#   '2103',
#   '2104',
#   '2122',
#   '2123',
#   '2129',
#   '2130',
#   '2133',
#   '2148',
#   '2168',
#   '2169',
#   '2192',
#   '2284',
#   '2315',
#   '2325',
#   '2328',
#   '2356',
#   '2359',
#   '2392',
#   '2438',
#   '2445',
#   '2475',
#   '2476',
#   '2477',
#   '2478',
#   '2479',
#   '2488',
#   '2501',
#   '2504',
#   '2526',
#   '2543',
#   '2556',
#   '2578',
#   '2590',
#   '2643',
#   '2656',
#   '2664',
#   '2667',
#   '2682',
#   '2683',
#   '2684',
#   '2786',
#   '2792',
#   '2802',
#   '2835',
#   '2862',
#   '2863',
#   '2871',
#   '2908',
#   '2917',
#   '2929',
#   '2931',
#   '2933',
#   '2942',
#   '2962',
#   '2967',
#   '2975',
#   '3000',
#   '3001',
#   '3006',
#   '3041',
#   '3045',
#   '3052',
#   '3074',
#   '3075',
#   '3086',
#   '3100',
#   '3104',
#   '3125',
#   '3131',
#   '3166',
#   '3167',
#   '3168',
#   '3169',
#   '3173',
#   '3174',
#   '3175',
#   '3176',
#   '3179',
#   '3180',
#   '3182',
#   '3184',
#   '3189',
#   '3192',
#   '3193',
#   '3194',
#   '3199',
#   '3205',
#   '3206',
#   '3210',
#   '3212',
#   '3214',
#   '3216',
#   '3217',
#   '3218',
#   '3240',
#   '3241',
#   '3243',
#   '3244',
#   '3245',
#   '3248',
#   '3252',
#   '3255',
#   '3262',
#   '3263',
#   '3264',
#   '3267',
#   '3268',
#   '3270',
#   '3271',
#   '3272',
#   '3274',
#   '3275',
#   '3276',
#   '3277',
#   '3281',
#   '3285',
#   '3325',
#   '3329',
#   '3331',
#   '3337',
#   '3344',
#   '3360',
#   '3379',
#   '3380',
#   '3389',
#   '3429',
#   '3441',
#   '3446',
#   '3447',
#   '3462',
#   '3464',
#   '3465',
#   '3478',
#   '3479',
#   '3481',
#   '3489',
#   '3491',
#   '3492',
#   '3537',
#   '3577',
#   '3578',
#   '3579',
#   '3588',
#   '3592',
#   '3611',
#   '3619',
#   '3621',
#   '3638',
#   '3651',
#   '3652',
#   '3663',
#   '3709',
#   '3739',
#   '3756',
#   '3758',
#   '3763',
#   '3777',
#   '3788',
#   '3842',
#   '3843',
#   '3853',
#   '3875',
#   '3925',
#   '3930',
#   '3931',
#   '3984',
#   '3987',
#   '4019',
#   '4023',
#   '4057',
#   '4076',
#   '4093',
#   '4104',
#   '4108',
#   '4116',
#   '4162',
#   '4181',
#   '4194',
#   '4205',
#   '4207',
#   '4212',
#   '4214',
#   '4215',
#   '4216',
#   '4217',
#   '4218',
#   '4226',
#   '4227',
#   '4232',
#   '4233',
#   '4234',
#   '4247',
#   '4251',
#   '4252',
#   '4254',
#   '4255',
#   '4258',
#   '4260',
#   '4262',
#   '4265',
#   '4267',
#   '4270',
#   '4271',
#   '4272',
#   '4273',
#   '4274',
#   '4277',
#   '4283',
#   '4284',
#   '4287',
#   '4289',
#   '4295',
#   '4296',
#   '4301',
#   '4303',
#   '4311',
#   '4313',
#   '4316',
#   '4317',
#   '4319',
#   '4324',
#   '4325',
#   '4329',
#   '4330',
#   '4331',
#   '4332',
#   '4333',
#   '4335',
#   '4336',
#   '4340',
#   '4341',
#   '4343',
#   '4347',
#   '4348',
#   '4349',
#   '4351',
#   '4353',
#   '4355',
#   '4358',
#   '4359',
#   '4364',
#   '4367',
#   '4368',
#   '4369',
#   '4370',
#   '4374',
#   '4375',
#   '4378',
#   '4380',
#   '4381',
#   '4406',
#   '4417',
#   '4420',
#   '4425',
#   '4429',
#   '4430',
#   '4433',
#   '4438',
#   '4447',
#   '4450',
#   '4451',
#   '4452',
#   '4510',
#   '4528',
#   '4534',
#   '4542',
#   '4558',
#   '4596',
#   '4629',
#   '4632',
#   '4648',
#   '4690',
#   '4698',
#   '4712',
#   '4716',
#   '4720',
#   '4729',
#   '4791',
#   '4820',
#   '4843',
#   '4853',
#   '4867',
#   '4895',
#   '4897',
#   '4906',
#   '4915',
#   '4944',
#   '4947',
#   '4949',
#   '4950',
#   '5002',
#   '5036',
#   '5042',
#   '5058',
#   '5159',
#   '5168',
#   '5178',
#   '5200',
#   '5263',
#   '5295',
#   '5301',
#   '5304',
#   '5308',
#   '5330',
#   '5395',
#   '5398',
#   '5445',
#   '5446',
#   '5447',
#   '5448',
#   '5453',
#   '5454',
#   '5457',
#   '5460',
#   '5463',
#   '5464',
#   '5466',
#   '5467',
#   '5475',
#   '5476',
#   '5479',
#   '5481',
#   '5484',
#   '5488',
#   '5491',
#   '5492',
#   '5493',
#   '5494',
#   '5495',
#   '5496',
#   '5497',
#   '5500',
#   '5501',
#   '5504',
#   '5510',
#   '5513',
#   '5516',
#   '5519',
#   '5520',
#   '5521',
#   '5522',
#   '5525',
#   '5531',
#   '5533',
#   '5534',
#   '5537',
#   '5543',
#   '5544',
#   '5545',
#   '5546',
#   '5548',
#   '5549',
#   '5550',
#   '5551',
#   '5552',
#   '5554',
#   '5558',
#   '5560',
#   '5561',
#   '5562',
#   '5563',
#   '5573',
#   '5574',
#   '5577',
#   '5578',
#   '5579',
#   '5580',
#   '5581',
#   '5584',
#   '5588',
#   '5601',
#   '5602',
#   '5619',
#   '5635',
#   '5644',
#   '5652',
#   '5688',
#   '5691',
#   '5695',
#   '5729',
#   '5743',
#   '5750',
#   '5758',
#   '5763',
#   '5764',
#   '5765',
#   '5766',
#   '5767',
#   '5775',
#   '5776',
#   '5783',
#   '5787',
#   '5793',
#   '5799',
#   '5803',
#   '5805',
#   '5810',
#   '5815',
#   '5816',
#   '5823',
#   '5850',
#   '5890',
#   '5907',
#   '5908',
#   '5912',
#   '5931',
#   '5935',
#   '5936',
#   '5945',
#   '5952',
#   '5953',
#   '5958',
#   '5969',
#   '5970',
#   '5971',
#   '5972',
#   '5974',
#   '5984',
#   '5985',
#   '5998',
#   '6005',
#   '6009',
#   '6040',
#   '6042',
#   '6070',
#   '6074',
#   '6080',
#   '6086',
#   '6104',
#   '6121',
#   '6128',
#   '6130',
#   '6139',
#   '6160',
#   '6172',
#   '6173',
#   '6174',
#   '6175',
#   '6176',
#   '6180',
#   '6186',
#   '6192',
#   '6202',
#   '6205',
#   '6227',
#   '6232',
#   '6234',
#   '6239',
#   '6240',
#   '6241',
#   '6245',
#   '6246',
#   '6247',
#   '6248',
#   '6251',
#   '6252',
#   '6260',
#   '6261',
#   '6265',
#   '6266',
#   '6267',
#   '6269',
#   '6272',
#   '6275',
#   '6276',
#   '6278',
#   '6279',
#   '6281',
#   '6286',
#   '6287',
#   '6290',
#   '6291',
#   '6292',
#   '6294',
#   '6295',
#   '6297',
#   '6298',
#   '6299',
#   '6301',
#   '6303',
#   '6304',
#   '6307',
#   '6310',
#   '6311',
#   '6324',
#   '6328',
#   '6330',
#   '6331',
#   '6335',
#   '6360',
#   '6412',
#   '6448',
#   '6449',
#   '6450',
#   '6459',
#   '6460',
#   '6471',
#   '6472',
#   '6489',
#   '6567',
#   '6569',
#   '6585',
#   '6598',
#   '6621',
#   '6632',
#   '6661',
#   '6669',
#   '6673',
#   '6677',
#   '6700',
#   '6711',
#   '6746',
#   '6747',
#   '6749',
#   '6750',
#   '6751',
#   '6752',
#   '6789',
#   '6790',
#   '6796',
#   '6798',
#   '6806',
#   '6845',
#   '6920',
#   '6925',
#   '6951',
#   '6958',
#   '6959',
#   '6961',
#   '6962',
#   '6963',
#   '6968',
#   '6987',
#   '6989',
#   '6997',
#   '7020',
#   '7021',
#   '7032',
#   '7051',
#   '7060',
#   '7076',
#   '7094',
#   '7095',
#   '7098',
#   '7100',
#   '7101',
#   '7106',
#   '7107',
#   '7110',
#   '7112',
#   '7113',
#   '7117',
#   '7118',
#   '7120',
#   '7124',
#   '7128',
#   '7148',
#   '7151',
#   '7153',
#   '7155',
#   '7157',
#   '7158',
#   '7162',
#   '7166',
#   '7180',
#   '7187',
#   '7188',
#   '7201',
#   '7203',
#   '7205',
#   '7215',
#   '7217',
#   '7219',
#   '7276',
#   '7285',
#   '7287',
#   '7309',
#   '7323',
#   '7326',
#   '7329',
#   '7432',
#   '7438',
#   '7452',
#   '7479',
#   '7499',
#   '7506',
#   '7622',
#   '7644',
#   '7667',
#   '7674',
#   '7676',
#   '7714',
#   '7752',
#   '7753',
#   '7757',
#   '7762',
#   '7765',
#   '7767',
#   '7768',
#   '7770',
#   '7777',
#   '7778',
#   '7779',
#   '7782',
#   '7784',
#   '7785',
#   '7786',
#   '7788',
#   '7790',
#   '7791',
#   '7793',
#   '7794',
#   '7795',
#   '7799',
#   '7801',
#   '7803',
#   '7804',
#   '7805',
#   '7806',
#   '7807',
#   '7808',
#   '7822',
#   '7848',
#   '7914',
#   '7951',
#   '7952',
#   '7978',
#   '8134',
#   '8151',
#   '8178',
#   '8228',
#   '8259',
#   '8260',
#   '8331',
#   '8351',
#   '8375',
#   '8401',
#   '8430',
#   '8432',
#   '8436',
#   '8437',
#   '8462',
#   '8466',
#   '8473',
#   '8476',
#   '8583',
#   '8595',
#   '8628',
#   '8636',
#   '8649',
#   '8651',
#   '8688',
#   '8689',
#   '8722',
#   '8724',
#   '8769',
#   '8811',
#   '8837',
#   '8839',
#   '8841',
#   '8842',
#   '8846',
#   '8848',
#   '8851',
#   '8852',
#   '8859',
#   '8860',
#   '8869',
#   '8872',
#   '8873',
#   '8875',
#   '8876',
#   '8878',
#   '8882',
#   '8885',
#   '8887',
#   '8889',
#   '8890',
#   '8891',
#   '8892',
#   '8894',
#   '8896',
#   '8902',
#   '8905',
#   '8918',
#   '8919',
#   '8921',
#   '8922',
#   '8923',
#   '8935',
#   '8937',
#   '8938',
#   '8940',
#   '8942',
#   '8944',
#   '8945',
#   '8950',
#   '8952',
#   '8953',
#   '8955',
#   '8958',
#   '8959',
#   '8960',
#   '8980',
#   '8999',
#   '9065',
#   '9067',
#   '9076',
#   '9093',
#   '9098',
#   '9104',
#   '9106',
#   '9115',
#   '9118',
#   '9134',
#   '9135',
#   '9138',
#   '9139',
#   '9140',
#   '9142',
#   '9148',
#   '9149',
#   '9154',
#   '9211',
#   '9234',
#   '9237',
#   '9243',
#   '9245',
#   '9255',
#   '9263',
#   '9309',
#   '9360',
#   '9389',
#   '9390',
#   '9396',
#   '9409',
#   '9428',
#   '9430',
#   '9493',
#   '9502',
#   '9525',
#   '9528',
#   '9532',
#   '9549',
#   '9579',
#   '9585',
#   '9600',
#   '9614',
#   '9624',
#   '9631',
#   '9636',
#   '9661',
#   '9662',
#   '9663',
#   '9665',
#   '9728',
#   '9741',
#   '9785',
#   '9879',
#   '9881',
#   '9882',
#   '9883',
#   '9887',
#   '9900',
#   '9935',
#   '9936',
#   '9956',
#   '9979',
#   '10018',
#   '10057',
#   '10060',
#   '10107',
#   '10108',
#   '10129',
#   '10138',
#   '10166',
#   '10251',
#   '10298',
#   '10362',
#   '10379',
#   '10436',
#   '10464',
#   '10468',
#   '10469',
#   '10477',
#   '10517',
#   '10519',
#   '10520',
#   '10521',
#   '10522',
#   '10523',
#   '10524',
#   '10525',
#   '10526',
#   '10527',
#   '10528',
#   '10529',
#   '10530',
#   '10534',
#   '10535',
#   '10536',
#   '10537',
#   '10538',
#   '10542',
#   '10544',
#   '10545',
#   '10551',
#   '10552',
#   '10553',
#   '10554',
#   '10555',
#   '10556',
#   '10557',
#   '10560',
#   '10561',
#   '10563',
#   ...],
#  'name': ['Anchor Inn',
#   'Angel Inn',
#   'Black Boy Hotel',
#   'Black Horse',
#   'Black Lion',
#   'Bristol Arms',
#   'Butt and Oyster Inn',
#   'Carriers Arms',
#   'Chenery Catering Ltd',
#   'Clubhouse',
#   'Cock And Bell',
#   'Crown Inn',
#   'Eight Bells',
#   'Exclusive Inns Ltd',
#   'Five Bells Inn',
#   'Fox and Hounds',
#   'Gardeners Arms',
#   'Glemsford Social Club',
#   'Grover And Allen (J D Wetherspoon)',
#   'Hare and Hounds',
#   'Hare And Hounds',
#   'Kings Head',
#   'Kings Head Inn',
#   'Long Melford & District',
#   'Maldon Grey',
#   'North Street Tavern',
#   'Northcroft Social Club Ltd',
#   'Oyster Reach Beefeater',
#   'Plough And Fleece Inn',
#   'Prince Of Wales',
#   'Queens Head',
#   'Queens Head',
#   'Red Lion Inn',
#   'Rose and Crown',
#   'Royal Harwich Yacht Club',
#   'Royal Oak',
#   'Shipwreck Bar and Restaurant',
#   'Shoulder of Mutton',
#   'Sudbury Institute Club',
#   'Swan Inn',
#   'The Anchor Inn',
#   'The Angel Hotel',
#   'The Angel Inn',
#   'The Bay Horse',
#   'The Beagle',
#   'The Bell Inn Kersey Ltd',
#   'The Brewers Arms',
#   'The Brewery Tap',
#   'The Brook',
#   'The Brook Inn',
#   'The Bush Inn',
#   'The Case Is Altered',
#   'The Cock',
#   'The Cock Horse Inn',
#   'The Cock Inn',
#   'The Cock Inn',
#   'The Cock Inn',
#   'The Comfortable Cow',
#   'The Crown',
#   'The Crown',
#   'The Crown Inn',
#   'The Delphi Club',
#   'The Fleece PH',
#   'The George',
#   'The George & Dragon',
#   'The George Inn',
#   'The Greyhound',
#   'The Harkstead Bakers Arms Ltd',
#   'The Horseshoes Inn',
#   'The Kings Head',
#   'The Kings Head',
#   'The Lion',
#   'The Long Melford Inn',
#   'The Peacock Inn',
#   'The Red Lion',
#   'The Red Lion',
#   'The Rose Inn',
#   'The Royal British Legion',
#   'The Royal British Legion',
#   'The Saracens Head',
#   'The Silkworm Public House',
#   'The Six Bells',
#   'The Swan',
#   'The Swan',
#   'The Swan',
#   'The Swan Inn',
#   'The White Horse',
#   'The White Horse',
#   'The White Horse Inn',
#   'The Wild Man Sproughton Ltd',
#   'Three Horseshoes',
#   'United Services Club',
#   'Waggon And Horses',
#   'Wheatsheaf Inn',
#   'Wheelhouse',
#   'White Horse',
#   'Bar Zero',
#   'Barleylands Social Club',
#   'Basildon & Pitsea Cricket Club',
#   'Basildon Rugby Football Club',
#   'Basildon Snooker Centre',
#   'Basildon Sports & Leisure Club',
#   'Basildon United Football Club',
#   'Beehive',
#   'Benbow Club',
#   'Best Parties Ever',
#   'Billericay Constitutional Club',
#   'Billericay Cricket Club',
#   'Bluehouse Farm Community Ctr.',
#   'Bowers United Sports & Social',
#   'British Rail Social Association',
#   'Bromfords Sports Centre',
#   'Castle Mayne',
#   'Chequers',
#   'Chicago Rock Cafe',
#   'Club Kingswood',
#   'Coast to Coast',
#   'Cromwell Manor/Grand Events',
#   'Culpepper Club',
#   'David Lloyd Club',
#   'Dick Turpin',
#   'Downham Arms',
#   'Dunton Park Country Club',
#   'Ford Sports & Social Club',
#   'Fryerns Community Centre',
#   'Fryerns Social Club',
#   'Ghyllgrove Community Centre',
#   'Great Chalvedon Hall',
#   'Harvester Darby Digger',
#   'Harvester Langdon Hills',
#   'Holy Cross Recreation Ground',
#   'Inn on the Green',
#   'J D Wetherspoon',
#   'Jolly Friar Public House',
#   'Katz',
#   'Kings Head',
#   'Moon on the Square',
#   'Owl & Pussycat',
#   'Post Office Sports Club',
#   'Q Ball Snooker and Sports Bar',
#   'Red Lion',
#   'Reids Bar, Restaurant and Function Room',
#   'Royal British Legion Club',
#   'Social Club',
#   'South Essex Medical Club',
#   'Sportz Club Bar',
#   'Stock Brook Manor Golf Club',
#   'The Burstead Golf Club',
#   'The Cafe',
#   'The Coach and Horses',
#   'The Crane',
#   'The Crown Pub and Dining',
#   'The Duke Public House',
#   'The Dukes Head',
#   'The Edge',
#   'The Forge',
#   'The Four Seasons Public House',
#   'The Honey Pot',
#   'The Joker',
#   'The Mall Social Club',
#   'The Noak Bridge',
#   'The Plough and Tractor',
#   'The Quays',
#   'The Railway Hotel',
#   'The Rare Cow',
#   'The Swan',
#   'The Watermill',
#   'The Woodlands Club',
#   'Unit 7',
#   'Vange & Pitsea Social Club',
#   'Wick Bar',
#   'Wickford Cricket Club',
#   'Winged Horse',
#   'Winston Social Club',
#   'Addison Howard Centre',
#   'AFC Kempston Rovers Football Club',
#   'Angel Domino Team',
#   'Auction Room Ltd',
#   'Badlands',
#   'Bar Citrus',
#   'Barley Mow',
#   'Bedford & County Golf Club',
#   'Bedford & County Golf Club Bar',
#   'Bedford Arms',
#   'Bedford Athletic Rugby Club Bar',
#   'Bedford Borough Bowling Club Bar',
#   'Bedford Rowing Club',
#   'Bedford Rugby (Ground, Bar & Marquee)',
#   'Bedford Standard',
#   'Bedford Town Football Club',
#   'Bedfordshire Golf Club',
#   'Biddenham Pavilion',
#   'Brewhouse And Kitchen',
#   'Briar Bank Club',
#   'Burnaby Arms',
#   'Chequers Inn',
#   'Club Italia',
#   'Colmworth Golf Club',
#   'Colworth Club',
#   'Cross Keys',
#   'Crown Inn',
#   'Devonshire Arms',
#   'Euro Bar',
#   'Executive Snooker Club',
#   'Fox & Duck',
#   'Fox & Hounds',
#   'Fox & Hounds',
#   'Fox & Hounds',
#   'Fox Inn',
#   'Fuelers Bar',
#   'Gardeners Arms',
#   'George & Dragon',
#   'Gordon Arms PH',
#   'Greyfriars Snooker Centre',
#   'Half Moon',
#   'Hi-Fi',
#   'Horse & Jockey',
#   'Kalooki Club',
#   'Kempston Constitutional Club',
#   'Kempston Park Indoor Bowls Club',
#   'Kent Arms',
#   'King William IV',
#   'Kings Arms',
#   'Kings Arms PH',
#   'Mecca Bingo Ltd',
#   'Meltis Sports and Social Club',
#   'Mile Road Club',
#   'Mulberry Bush',
#   'North End Club',
#   'Number 13',
#   'Oakley Sports and Social Club',
#   'Pavenham Park Golf Club',
#   'Pilgrims Progress',
#   'Podington Cricket Club',
#   'Podington United Services Club',
#   'Polhill Arms',
#   'Prince Of Wales',
#   'Queens Tavern',
#   'RAFA Club',
#   'Red Lion',
#   'Royal Oak',
#   'Royal Oak',
#   'Russell Park Social Club',
#   'Ship',
#   'Shortstown Village Hall',
#   'Smiths Arms',
#   'Sport for Bedford Ltd',
#   'Sporting Targets Ltd',
#   'St Johns Arms',
#   'Star Rowing Club',
#   'Stewartby Sports & Social Club',
#   'Swan Inn',
#   'T Bar',
#   'The Anchor',
#   'The Anchor Inn',
#   'The Anchor Inn',
#   'The Artisan Tap',
#   'The Balloon',
#   'The Bedford Arms',
#   'The Bedford Club',
#   'The Bedford Golf Clubhouse',
#   'The Bell',
#   'The Bell',
#   'The Bluebell',
#   'The Bull',
#   'The Castle',
#   'The Chequers Inn',
#   'The Chequers of Yelden',
#   'The Chimney Corner',
#   'The Cock Inn',
#   'The Crown',
#   'The Crown Inn',
#   'The Duke Inn',
#   'The Falcon Inn',
#   'The Five Bells',
#   'The Flowerpot',
#   'The Flute',
#   'The Foresters Arms',
#   'The Mill',
#   'The Muntjac',
#   'The New Inn',
#   'The New Sportsman',
#   'The Oakley Arms',
#   'The Pad',
#   'The Park',
#   'The Pheasant',
#   'The Rose',
#   'The Royal George',
#   'The Royal Oak',
#   'The Ship',
#   'The Star Inn',
#   'The Sun Inn',
#   'The Swan With Two Nicks',
#   'The Tavistock Pub & Carvery',
#   'The Three Compasses',
#   'The Three Cranes',
#   'The Three Cups',
#   'The Tiger Moth',
#   'The Woolpack',
#   'Three Tuns',
#   'Victoria Arms',
#   'Vogue',
#   'Wait For The Wagon',
#   'Wellington Arms PH',
#   'White Horse',
#   'Wodka Live',
#   'Yates',
#   'Ye three Fyshes PH',
#   '47 Bar \\\\& Restaurant',
#   'Bar Sport',
#   'Bespoke Catering @ Parklands Restaurant',
#   'Bird In Hand',
#   'Bird In Hand PH',
#   'Bocking Arts Theatre',
#   'Bocking Sports Club',
#   'Bocking United Services Club',
#   'Bradwell Village Hall',
#   'Braintree And Bocking Constitutional Club',
#   'Braintree Bowls Club',
#   'Braintree Rugby Club',
#   'Braintree Town Football Club',
#   'Braintree Youth Project',
#   'Castle Hedingham Bowls Club',
#   'Coggeshall Conservative Club',
#   'Coggeshall Cricket Club',
#   'Coggeshall Town Football Club',
#   'Colne Valley Golf Club',
#   'Colne Working Mens Constitutional Club',
#   'Courtauld Bowls Club',
#   'Crittall Social Club',
#   'Cross Keys',
#   'Dolphin Public House',
#   'Earls Colne Recreation Club',
#   'Earls Colne Social Club',
#   'Easterford Lodge Masonic Hall',
#   'Fox And Hounds',
#   'Gosfield Social Club',
#   'Halstead Conservative Club',
#   'Halstead Cricket Club',
#   'Halstead Masonic Hall',
#   'Haver Arms',
#   'Hold The Anchovies',
#   'Kelvedon Conservative Club',
#   'Kelvedon Labour Club',
#   'King William IV PH',
#   'Little Elms PH',
#   'MDP Wethersfield Amenities',
#   'Memorial Hall',
#   'Memories Of Chinatown',
#   'Oaklands Inn',
#   "O'Grady's",
#   'Phoenix Hockey Club',
#   'Pinkuah Arms',
#   'RAF Association Headquarters',
#   'Rose And Crown PH',
#   'Scenarios',
#   'Sible Hedingham Social Club',
#   'Silver End Bowling Club',
#   'Sir Charlie Lockrams Drinking Parlour',
#   'Stepfield Snooker Club',
#   'Swan Inn PH',
#   'Terling Cricket Club',
#   'The Angel PH',
#   'The Angel PH',
#   'The Battesford Court',
#   'The Bell',
#   'The Bell',
#   'The Bell Inn',
#   'The Bell Inn',
#   'The Benson Bar And Bistro',
#   'The Bull',
#   'The Bull PH',
#   'The Castle PH',
#   'The Chapel Inn',
#   'The Cherry Tree',
#   'The Compasses',
#   'The Co-operative Food',
#   'The Cross Keys PH',
#   'The Drum Inn',
#   'The Duke Of Wellington',
#   'The Eight Bells PH',
#   'The Five Bells PH',
#   'The Fox Inn',
#   'The George',
#   'The George Inn',
#   'The Green Dragon',
#   'The Green Man',
#   'The Green Man',
#   'The Griffin',
#   'The Half Moon',
#   'The Henny Swan',
#   'The Horse And Groom',
#   'The Horse And Groom PH',
#   'The Kings Head',
#   'The Lion PH',
#   'The Locomotive',
#   'The Lounge',
#   'The Mulberry Tree',
#   'The Nags Head',
#   'The Onley',
#   'The Orange Tree',
#   'The Pheasant PH',
#   'The Picture Palace',
#   'The Plough',
#   'The Railway',
#   'The Railway Tavern',
#   'The Red Lion',
#   'The Red Lion',
#   'The Red Lion Inn',
#   'The Red Lion PH',
#   'The Red Lion PH',
#   'The Retreat PH',
#   'The Royal Oak',
#   'The Sportsman',
#   'The Spread Eagle Public House',
#   'The Square And Compasses',
#   'The Sun Inn',
#   'The Swan',
#   'The Swan',
#   'The Swiss Bell',
#   'The Three Bottles',
#   'The Three Tuns Inn',
#   'The Victoria PH',
#   'The Victory Inn',
#   'The Warrens',
#   'The Welsh Princess',
#   'The Wheatsheaf',
#   'The White Hart',
#   'The White Hart',
#   'The White Horse Inn',
#   'The White Horse PH',
#   "The Willow's Inn",
#   'The Woolpack',
#   'The Woolpack Inn',
#   'Twinstead Cricket Club',
#   'Vine End Gastro Pub Ltd',
#   'Wagon And Horses PH',
#   'Western Arms',
#   "Wethersfield Village Hall Men's Club",
#   'Wheatsheaf',
#   'Whispers Wine Bar',
#   'White Notley Football Club',
#   'Witham Bowls Club',
#   'Witham Rugby Club',
#   'Witham Town Football And Social Club',
#   'Witham Town Luncheon Club',
#   'Applewood Hall',
#   'Attleborough Football Club',
#   'Attleborough Snooker Centre',
#   'Banham Barrell',
#   'Bedingfeld Arms',
#   'Breckland Lodge (The Stag)',
#   'Carbrooke Village Social Club',
#   'Carnegie Rooms',
#   'Cherry Tree Public House',
#   'Crown Hotel',
#   "Darby's",
#   'Dereham Golf Club',
#   'Dereham Masonic Club',
#   'Dereham Snooker Club',
#   'Dog & Partridge',
#   'Fox & Hounds',
#   'Gemini Public House',
#   'Green Dragon',
#   'Greyhound Inn',
#   'Harling Recreation Bowls Club',
#   'Horse & Groom',
#   'ICE',
#   'Inn on the Green',
#   'J D Wetherspoon',
#   'Kings Arms',
#   'Kings Head',
#   'Kings Head Hotel',
#   "King's Head Public House",
#   'London Tavern',
#   'Mattishall Sports & Social Club',
#   'McTaggarts Freehouse Ltd',
#   'Millwrights Arms',
#   'Norfolk Terrier Ltd',
#   'Number 40',
#   'Old Bell Public House',
#   'Ox & Plough',
#   'Railway Tavern',
#   'Royal British Legion',
#   "Ry's Bar and Grill",
#   'Saham Toney Football Club',
#   "Saity's Bar",
#   'Ship Inn',
#   'Swaffham Conservative Club',
#   'Swaffham Golf Club',
#   'The  Bell Inn',
#   'The Albion',
#   'The Angel',
#   'The Angel Inn',
#   'The Black Horse',
#   'The Black Swan',
#   'The Bull',
#   'The Canary & Linnet',
#   'The Chase',
#   'The Chequers Inn',
#   'The Coachmakers Arms',
#   'The Cock Inn',
#   'The Crown',
#   'The Crown',
#   'The Deers Leap',
#   'The Dolphin',
#   'The Eagle',
#   'The Flying Fish',
#   'The Fox',
#   'The Fox Inn',
#   'The Gamekeeper Freehouse',
#   'The Garden House Public House',
#   'The George and Dragon',
#   'The George Hotel',
#   'The Golden Dog',
#   'The Great Danes Country Inn',
#   'The Greenstone',
#   'The Heart of Norfolk',
#   'The Kings Head',
#   'The Litcham Bull',
#   'The Lodge',
#   'The Masonic Hall',
#   'The Mermaid Inn',
#   'The Metro',
#   'The Mill Cafe Bar and Restaurant',
#   'The New Inn',
#   'The Old Railway Tavern',
#   'The Old Workhouse Bar',
#   'The Olde Windmill Inn',
#   'The Peddars Inn',
#   'The Red Lion',
#   'The Red Lion',
#   'The Red Lion',
#   'The Red Lion',
#   'The Romany Rye',
#   'The Rose And Crown',
#   'The Royal Naval Association',
#   'The Royal Oak',
#   'The Royal Standard',
#   'The Saxon Public House',
#   'The Station',
#   'The Swan',
#   'The Swan',
#   'The Swan Inn',
#   'The Swan Inn',
#   'The Warrener',
#   'The Watton Masonic Association',
#   'The White Hart',
#   'The White Hart',
#   'The White Horse',
#   'The Willow House',
#   'The Windmill',
#   'Thetford & District Ex-Service & Social Club',
#   'Thetford Conservative Club',
#   'Thetford Snooker Centre',
#   'Thetford Town Football Club',
#   'Toftwood Social Centre',
#   'Twenty Churchwardens',
#   'Victoria Inn',
#   'Waggon & Horses Public House',
#   'Whispers/Rumours',
#   'White Horse Inn',
#   'White Lodge Public House',
#   '124 (Essex) Transport Squadron Rlc Army Reserve Centre',
#   'Above Par Catering Ltd (At Thorndon Park)',
#   'Alma Arms Freehouse',
#   'Ashwells Sports & Country Club Ltd',
#   'Baptist Church',
#   'Baptist Church',
#   'Bar 28 Trading As Sticky Rice',
#   'Bar West One',
#   'Bardswell Social Club',
#   'Bentley Cricket Club',
#   'Bentley District Village Club',
#   'Blackmore Sports And Social Club',
#   'Boars Head',
#   'Brave Nelson',
#   'Brentwood County Cricket Club',
#   'Brentwood Golf Club',
#   'Brentwood Hard Court Tennis Club',
#   'Brentwood Rugby Club',
#   'Brentwood Tennis Club',
#   'Brentwood Theatre',
#   'Brookweald Cricket Club',
#   'Charlies Bar Ltd',
#   'Dairyman',
#   'East & West Horndon Village Hall',
#   'Eclipse (Brentwood) Ltd',
#   'Essex Arms',
#   'George Inns Ltd',
#   'Great & Little Warley Cricket Club',
#   'Great Danes Youth Football Club',
#   'Hartswood Golf Club',
#   'Herongate Cricket Club',
#   'Herongate Football & Athletic Club',
#   'Hollands Wine Bar',
#   'Hutton All Saints Scout Group',
#   'Hutton Cricket Club',
#   'Hutton Football Club',
#   'Hutton Free Church',
#   'Hutton Poplars Lodge',
#   'Ingatestone & Fryerning Community Association',
#   'Ingatestone Bowling Club',
#   'K H Village Hall Charitable Trust',
#   'Kelvedon Hatch Senior Citizen Lunch Club',
#   'Kings Chase Sports And Social Club Ltd',
#   'Lot 75',
#   'Luncheon Club',
#   'Mill Green Gospel Hall',
#   'Mount Avenue Banqueting Suite',
#   "Murphy's Sports Bar",
#   'Navestock Cricket Club',
#   "O'Neills",
#   'Poplars Hall',
#   'Prince Of Wales',
#   'Quennell Way Club',
#   'Rendezvous At Pilgrims Hall',
#   'Shenfield Cricket Club',
#   'Slug & Lettuce',
#   'Society Of Old Brentwood Sports Club',
#   'South Essex Golf & Country Club',
#   'South Weald Cricket Club',
#   'South Weald Parish Hall',
#   'Spread Eagle (Pub - Wetside)',
#   'St Johns Ambulance',
#   'St Peters Church',
#   'Stonyhill Bowls Club',
#   'Sugar Hut',
#   'Thatchers Arms',
#   'The Bell',
#   'The Black Horse',
#   'The Brewery Tap',
#   'The Bricklayers Arms',
#   'The Bull',
#   'The Chequers',
#   'The Cherry Tree',
#   'The Chough Public House',
#   'The Cricketers',
#   'The Eagle',
#   'The Eagle And Child',
#   'The Gardeners Arms',
#   'The George And Dragon',
#   'The Green Man',
#   'The Greyhound',
#   'The Halfway House',
#   'The Hermit Club',
#   'The Hutton Public House',
#   'The Leather Bottle (wet Side)',
#   'The Lounge Bar',
#   'The Merchant',
#   'The Nags Head',
#   'The Olde Dog Inn',
#   'The Plough',
#   'The Plough',
#   'The Rising Sun',
#   'The Robin',
#   'The Rose',
#   'The Shepherd',
#   'The Sports Lounge',
#   'The Star Inn',
#   'The Swan',
#   'The Teriss Bar',
#   'The Vine Brentwood',
#   'The White Horse',
#   'The Willow',
#   'Thriftwood Scout Campsite',
#   'Tipps Cross Remembrance Hall',
#   'Toby Carvery',
#   'Victoria Arms',
#   'Village Hall',
#   'Viper Inn',
#   'Virgin Active Clearview',
#   'Warley Park Golf Club',
#   'Ye Olde Green Dragon',
#   'Aylsham Ex Service & Social C',
#   'Black Boys Public House',
#   'Black Lion Public House',
#   'Black Swan Public House',
#   'Blue Boar Inn',
#   'Bob Carter Leisure Centre Trust',
#   'Brick Kilns Public House',
#   'Brickmakers Arms',
#   'Buckinghamshire Arms',
#   'County Arts Bowls Club',
#   'Crown Public House',
#   'Dog Public House (wet sales only)',
#   'Earle Arms Inn',
#   'Embrujo',
#   "Fatso's",
#   'Gordon Public House',
#   'Great Witchingham Lunch Club',
#   'Griffin Inn',
#   'Hainford Country Inn Ltd - The Chequers',
#   'Honingham Bowls Club',
#   'Huntsman Public House',
#   'Kings Arms Chinese and Thai',
#   'Kings Arms Public House',
#   'Kings Head Public House',
#   'Kings Head Public House',
#   'Kings Head Public House',
#   'Kings Head Public House',
#   'Longe Arms Public House',
#   'Lord Nelson Public House',
#   'Maids Head Public House',
#   'Maltsters Public House',
#   'Marsham Arms Inn',
#   'Norfolk Broads Yacht Club',
#   'Otter Public House',
#   'Parson Woodforde Public House',
#   'Racecourse Castle Carvery',
#   'Ram Snacks',
#   'Rampant Horse Public House',
#   'Recruiting Sergeant',
#   'Red Lion Public House',
#   'Red Lion Public House',
#   'Reedcutter Public House',
#   'Rising Sun Public House',
#   'Rose & Crown (Wet Sales Only)',
#   'Rushcutters Arms',
#   'Shoulder of Mutton Public House',
#   'Silver Fox Public House',
#   'Sole & Heel',
#   'St Andrews Hospital Staff Social Club',
#   'STB Getley Trading Ltd T/A The Red Lion Public House',
#   'Tamarind Indian Restaurant',
#   'The Acle Bridge Inn',
#   'The Bell Inn',
#   'The Bridge Inn',
#   'The Buck Inn',
#   'The Bull Inn',
#   'The Cock Inn',
#   'The Cock Tavern',
#   'The Cottage Public House',
#   'The Dial House',
#   'The Feathers Public House',
#   'The Fox Public House',
#   'The Fur & Feather Inn',
#   'The Gas Social Club',
#   'The Honingham Buck Ltd',
#   'The Jefferson Partnership t/a Green Man Public House',
#   'The Plough Inn',
#   'The Queens Head Pub',
#   'The Ram Public House',
#   'The Rivergarden',
#   'The Ship Inn',
#   'The Ship Public House',
#   'The Swan Inn',
#   'The Yare Public House',
#   'Town House Hotel',
#   'Unicorn Public House',
#   'United Business & Leisure (Roundwood)',
#   'Weston Park Golf Club & Restaurant',
#   'Whiffler Public House',
#   'White Horse',
#   'Woodman Public House',
#   'Woodside Snooker Centre',
#   'Wroxham Football Club',
#   'British Legion',
#   'Broxbourne Sports Club',
#   'Broxbourne Youth Football Club',
#   'Catering',
#   'Cheshunt Football Club',
#   'Cheshunt Park Golf Club(Private)',
#   'Cheshunt Royal British Legion Club',
#   'Galley Hall',
#   'Goffs Oak Comrades Club',
#   'Halsey Masonic Hall',
#   'Hoddesdon Labour Club',
#   'J D Wetherspoon \\"The Star\\","105 High Street, Hoddesdon, Hertfordshire',
#   'JJ & SM Catering',
#   "O'Shea Irish Bar",
#   'Prince Of Wales Public House',
#   'Rosedale Sports Club',
#   'Rye Park & Hoddesdon United Services',
#   'Rye Park Conservative Club',
#   'Stanboroughs Conservative Club',
#   'The Bull',
#   'The Bulls Head',
#   'The Cheshunt Sports Club',
#   'The Crocodile',
#   'The George',
#   'The Goffs Oak',
#   'The Golden Lion',
#   'The Green Dragon',
#   'The Jolly Bricklayers (no food prep)',
#   'The King James',
#   'The King William IV',
#   'The Maltsters Public House',
#   'The Moon and Cross',
#   'The Old Anchor Public House',
#   'The Old English Gentleman',
#   'The Old Star',
#   'The Plough',
#   'The Plough',
#   'The Queens Head Public House',
#   'The Red Cow',
#   'The Roman Urn(no food prepared)',
#   'The Sun',
#   'The Venue',
#   'The Vine Public House',
#   'The Wheatsheaf PH and Accomodation',
#   'The Wheelwrights',
#   'The White Bear Public House',
#   'The White Swan',
#   'The Windmill Public House',
#   'Ukranian Social Club',
#   'Wormley Sports Club',
#   'Architect',
#   'Baron Of Beef',
#   'Baroosh',
#   'Boathouse Public House',
#   'Champion Of The Thames',
#   'Chesterton Mens Club',
#   'Clarendon Arms',
#   "D'Arry's Wine Shop, Bar & Dining",
#   'Earl of Beaconsfield',
#   'Earl Of Derby',
#   'Green Dragon Public House',
#   'Hidden Rooms',
#   "Hudson's Ale House",
#   'Jenny Wren',
#   'Kingston Arms',
#   'Kitchen',
#   'Kuda',
#   'Kudos Hospitality',
#   'Little Red Kitchen Company Ltd',
#   'Live And Let Live',
#   'Lola Lo',
#   'Lord Byron Inn',
#   'Old Spring Public House',
#   'Panton Arms',
#   'Prince Regent',
#   'Queen Edith Public House',
#   'Red Bull',
#   'Red Lion',
#   'Salisbury Arms',
#   'Salisbury Conservative Club',
#   'Sir Isaac Newton',
#   'Six Bells',
#   'St Radegund',
#   'Ta Bouche',
#   'The Alma',
#   'The Anchor Public House',
#   'The Bath House',
#   'The Blue Moon',
#   'The Brook Public House',
#   'The Burleigh Arms',
#   'The Cambridge Blue',
#   'The Cambridge Brew House',
#   'The Carlton Arms Public House',
#   'The Carpenters Arms',
#   'The Corner House',
#   'The Dobblers Inn',
#   'The Duke Of Cambridge',
#   'The Eagle Public House',
#   'The Elm Tree',
#   'The Empress',
#   'The Flying Pig',
#   'The Geldart',
#   'The Golden Hind',
#   'The Grain and Hop Store',
#   'The Granta',
#   'The Grapes',
#   'The Great Northern',
#   'The Green Man',
#   'The Hawks Club',
#   'The Hopbine',
#   'The Junction',
#   'The Maypole P.H.',
#   'The Med',
#   'The Mill (new)',
#   'The Milton Arms',
#   'The Mitre Public House',
#   'The Pickerel Inn',
#   'The Portland Arms',
#   'The Punter',
#   'The Rathmore Club',
#   'The Regal',
#   'The Rock',
#   'The Royal Standard',
#   'The Ship',
#   'The Snug',
#   'The Snug',
#   'The Tram Depot',
#   'The Waterman',
#   'The White Swan',
#   'The Wrestlers',
#   'Traveller Rest',
#   'University Pitt Club',
#   'Admiral Jellicoe',
#   'Alfies',
#   'Anchor Inn',
#   'Bar One',
#   'Benfleet Conservative Club',
#   'Benfleet Tavern',
#   'Benfleet Yacht Club',
#   'Boyce Hill Golf & Country Club',
#   'Bread And Cheese',
#   'Canvey Club',
#   'Canvey Cricket Club',
#   'Canvey Island Conservative Club',
#   'Canvey Island Football Club',
#   'Canvey Island Rugby Union FC',
#   'Canvey Island Social Club',
#   'Castle Hotel Public House',
#   'Castle Point Golf Club',
#   'Chapman Sands Sailing Club',
#   "Fatty's Bar",
#   'Hadleigh & Thundersley Cricket Club',
#   'Hadleigh Conservative Club',
#   'Half Crown Public House',
#   'Haystack',
#   'Hoy And Helmet',
#   'Island Yacht Club',
#   'Lobster Smack',
#   'Oyster Bay Sports & Wine Bar',
#   'Rileys Sports Bar',
#   'Rio Bingo Club',
#   'Royal British Legion',
#   'Saks Cafe Bar',
#   'South Benfleet & Canvey Bowling Club',
#   'South Benfleet Social Club',
#   'The Monico',
#   'Thorney Bay Bar & Restaurant',
#   'Western Dance Centre',
#   'White Hart Public House',
#   "Windjammer's Upper Deck",
#   'Zach Wilsher',
#   'Ampthill & District Rugby Union Football Club',
#   'Ampthill Town Cricket Club',
#   'Arlesey Town Football Club',
#   'B & G Catering Ltd',
#   'Baldock Town Football Club',
#   'Barton Bowls Club',
#   'Barton Rovers Football Club',
#   'Biggleswade RUF & Associated Clubs',
#   'Biggleswade United Football Club',
#   'Biggleswade United Working Mens Club',
#   'Bird in Hand',
#   'Carpenters Arms',
#   'Chalgrave Manor Golf Club',
#   'Club Cookies',
#   "Drover's Arms",
#   'Dunstable Conservative Club',
#   'Dunstable Rugby Union Football Club',
#   'Dunstable Snooker Club',
#   'Dunstable Town Cricket Club',
#   'Elza Catering',
#   'Flutters Leisure Ltd',
#   'Flying Fox',
#   'Go Houghton',
#   'H Q Sports Bar',
#   'Houghton Regis Memorial Hall',
#   "John O'Gaunt Golf Club",
#   'Jolly Coopers',
#   'Leighton Buzzard Golf Club',
#   'Leighton Buzzard Rugby Club Ltd',
#   'Live and Let Live (Hertfordshire) LLP',
#   'Longs Inn',
#   'Marston Club',
#   "Noah's Ark",
#   'Pembroke Arms',
#   'Rising Sun',
#   'Royal Oak',
#   'South Bedfordshire Golf Club',
#   'Stewartby Water Sports Club Ltd',
#   'Stotfold Conservative Club',
#   'Stotfold Football Club',
#   'Studham Sports & Social Club',
#   'The Admiral',
#   'The Anchor',
#   'The Anchor',
#   'The Angel',
#   'The Ashwell Arms',
#   'The Axe & Compass',
#   'The Bald Buzzard',
#   'The Bank Bar & Kitchen',
#   'The Bell',
#   'The Bell',
#   'The Bell',
#   'The Bell',
#   'The Bell',
#   'The Bird in Hand',
#   'The Black Horse',
#   'The Black Horse',
#   'The Black Lion',
#   'The Blackbirds',
#   'The Brewery Tap',
#   'The Bull',
#   'The Bumble Bee',
#   'The Chequers',
#   'The Chequers',
#   'The Chequers',
#   'The Chequers',
#   'The Chequers',
#   'The Chequers',
#   'The Chequers',
#   'The Clay Pipe',
#   'The Cock Inn (Broom) Ltd',
#   'The College Arms',
#   ...],
#  'address': ['Upper Street, Stratford St Mary, COLCHESTER, Essex',
#   'Egremont Street, Glemsford, SUDBURY, Suffolk',
#   '7 Market Hill, SUDBURY, Suffolk',
#   'Lower Street, Stratford St Mary, COLCHESTER, Essex',
#   'Lion Road, Glemsford, SUDBURY, Suffolk',
#   'Bristol Hill, Shotley, IPSWICH, Suffolk',
#   'Pin Mill Road, Chelmondiston, IPSWICH, Suffolk',
#   'Heath Road, East Bergholt, COLCHESTER, Essex',
#   'The Bull Inn, The Street, Brantham, MANNINGTREE',
#   'The Grange Caravan Park, Straight Road, East Bergholt, COLCHESTER',
#   'Hall Street, Long Melford, SUDBURY, Suffolk',
#   'Cattawade Street, Brantham, MANNINGTREE, Essex',
#   'Eight Bells Public House, 90-92 Angel Street, Hadleigh, IPSWICH',
#   'The Swan Inn, The Street, Monks Eleigh, IPSWICH',
#   '63 Bures Road, Great Cornard, SUDBURY, Suffolk',
#   'Church Street, Groton, SUDBURY, Suffolk',
#   'Manningtree Road, Stutton, IPSWICH, Suffolk',
#   '25-27 Hunts Hill, Glemsford, SUDBURY, Suffolk',
#   'The Grover and Allen, 67-70 North Street, SUDBURY, Suffolk',
#   'Harrow Street, Leavenheath, COLCHESTER, Essex',
#   'Heath Road, East Bergholt, COLCHESTER, Essex',
#   '132 High Street, Bildeston, IPSWICH, Suffolk',
#   '115 Bures Road, Great Cornard, SUDBURY, Suffolk',
#   'Ex-Service & Social Club, Hall Street, Long Melford, SUDBURY',
#   'Cats Lane, Great Cornard, SUDBURY, Suffolk',
#   'North Street, SUDBURY, Suffolk',
#   'Flat 1, Croft Road, SUDBURY, Suffolk',
#   'Bourne Hill, Wherstead, IPSWICH, Suffolk',
#   'Great Green, Cockfield, BURY ST EDMUNDS, Suffolk',
#   'New Street, SUDBURY, Suffolk',
#   'The Row, Wenham Magna, COLCHESTER, Essex',
#   'The Street, Layham, IPSWICH, Suffolk',
#   'Main Road, Chelmondiston, IPSWICH, Suffolk',
#   'The Street, Elmsett, IPSWICH, Suffolk',
#   'Cat House Lane, Woolverstone, IPSWICH, Suffolk',
#   'East End Lane, East Bergholt, COLCHESTER, Essex',
#   'Shotley Marina, Shotley, IPSWICH, Suffolk',
#   'The Street, Assington, SUDBURY, Suffolk',
#   '54 Station Road, SUDBURY, Suffolk',
#   'Lower Street, Stratford St Mary, COLCHESTER, Essex',
#   '26 Court Street, Nayland with Wissington, COLCHESTER, Essex',
#   'The Angel, Market Place, Lavenham, SUDBURY',
#   'Polstead Street, Stoke by Nayland, COLCHESTER, Essex',
#   '61-65 Melford Road, SUDBURY, Suffolk',
#   'Hadleigh Road, Sproughton, IPSWICH, Suffolk',
#   'The Bell Inn, The Street, Kersey, IPSWICH',
#   'Bower House Tye, Polstead, COLCHESTER, Essex',
#   'East Street, SUDBURY, Suffolk',
#   'The Brook Inn, 241 Bures Road, Great Cornard, SUDBURY',
#   'The Street, Copdock And Washbrook, IPSWICH, Suffolk',
#   'The Bush, The Street, Shimpling, BURY ST EDMUNDS',
#   'Capel Road, Bentley, IPSWICH, Suffolk',
#   'Lavenham Road, Brent Eleigh, SUDBURY, Suffolk',
#   'The Cock Inn, Church Street, Lavenham, SUDBURY',
#   '89 George Street, Hadleigh, IPSWICH, Suffolk',
#   'Egremont Street, Glemsford, SUDBURY, Suffolk',
#   'Polstead Green, Polstead, COLCHESTER, Essex',
#   'Unit 3, The Pied Cow, 12 King Street, SUDBURY, Suffolk',
#   'High Street, Acton, SUDBURY, Suffolk',
#   'Park Street, Stoke by Nayland, COLCHESTER, Essex',
#   'The Green, Hartest, BURY ST EDMUNDS, Suffolk',
#   'Delphi Diesel Systems Ltd, Newton Road, SUDBURY, Suffolk',
#   'The Fleece, 8-10 Broad Street, Boxford, SUDBURY',
#   '52 High Street, Hadleigh, IPSWICH, Suffolk',
#   'The George and Dragon Public House, Hall Street, Long Melford, SUDBURY',
#   'George Street, Hintlesham, IPSWICH, Suffolk',
#   'High Street, Lavenham, SUDBURY, Suffolk',
#   'The Bakers Arms, The Street, Harkstead, IPSWICH',
#   'Three Horseshoes, Stows Hill, Cockfield, BURY ST EDMUNDS',
#   '90 High Street, Hadleigh, IPSWICH, Suffolk',
#   'Kings Head, Manningtree Road, Stutton, IPSWICH',
#   'Honey Tye, Leavenheath, COLCHESTER, Essex',
#   'Station Road, Long Melford, SUDBURY, Suffolk',
#   '37 The Street, Chelsworth, IPSWICH, Suffolk',
#   'High Street, Bildeston, IPSWICH, Suffolk',
#   'The Street, East Bergholt, COLCHESTER, Essex',
#   'The Street, Shotley, IPSWICH, Suffolk',
#   'Cordell Road, Long Melford, SUDBURY, Suffolk',
#   'George Street, Hadleigh, IPSWICH, Suffolk',
#   'Sudbury Road, Newton, SUDBURY, Suffolk',
#   'East Street, SUDBURY, Suffolk',
#   'The Street, Preston St Mary, SUDBURY, Suffolk',
#   'Hall Street, Long Melford, SUDBURY, Suffolk',
#   'Swan Inn, The Street, Holbrook, IPSWICH',
#   'The Street, Lawshall, BURY ST EDMUNDS, Suffolk',
#   'The Swan, The Street, Little Waldingfield, SUDBURY',
#   'Lavenham Road, The Heath, Great Waldingfield, SUDBURY, Suffolk',
#   'London Road, Capel St Mary, IPSWICH, Suffolk',
#   'White Horse Inn, Mill Green, Edwardstone, SUDBURY',
#   'Wild Man Inn, Bramford Road, Sproughton, IPSWICH',
#   'Church Square, Bures St Mary, BURES, Suffolk',
#   'White Horse Road, East Bergholt, COLCHESTER, Essex',
#   'Church Walk, SUDBURY, Suffolk',
#   'Church Road, Tattingstone, IPSWICH, Suffolk',
#   'Whatfield Road, Nedging with Naughton, IPSWICH, Suffolk',
#   'North Street, SUDBURY, Suffolk',
#   'Vitro Bars Ltd, 2 Western Road, Billericay, Essex',
#   'Barleylands Road, Basildon, Essex',
#   'The Clubhouse,Mopsies Park, Timberlog Close, Basildon, Essex',
#   'Gardiners Close, Basildon, Essex',
#   '5 High Pavement, Basildon, Essex',
#   'Gardiners Way, Basildon, Essex',
#   'Gardiners Close, Basildon, Essex',
#   'Southernhay, Basildon, Essex',
#   '77 Pound Lane, Bowers Gifford, Pitsea,Essex.',
#   'Barleylands Farm, Barleylands Road, Billericay, Essex',
#   '1a High Street, Billericay, Essex',
#   'The Toby Howe Cricket Ground, Blunts Wall Road, Billericay, Essex.',
#   'Laindon Link, Laindon, Basildon,Essex.',
#   'Bowers United Sports And Social Club, Crown Avenue, Pitsea, Basildon',
#   'Market Avenue, Wickford, Essex',
#   'Bromford Sports Centre, Grange Avenue, Wickford, Essex.',
#   'Castle Mayne, The Knares, Basildon, Essex',
#   '44 High Street, Billericay, Essex',
#   'Festival Leisure Park, Cranes Farm Road, Basildon, Essex',
#   'Club Kingswood, Clay Hill Lane, Basildon, Essex',
#   'Luminar Unit 1, Festival Way, Basildon, Essex',
#   'Cromwell Manor, Pitsea Hall Lane, Pitsea, Essex',
#   'Gardiners Lane South, Basildon, Essex',
#   'Festival Way, Basildon, Essex',
#   'Dick Turpin, Southend Arterial Road, Wickford, Essex',
#   '130 London Road, Wickford, Essex',
#   'Lower Dunton Road, Dunton, Basildon,Essex.',
#   'Gardiners Close, Basildon, Essex',
#   'Whitmore Way, Basildon, Essex',
#   'Fryerns Social Club, Fryerns Community Centre, Whitmore Way, Basildon, Essex',
#   'The Barnett Centre, Butneys, Basildon, Essex',
#   'Great Chalvedon Hall, Rectory Road, Pitsea, Basildon',
#   'Darby Digger, Radwinter Avenue, Wickford, Essex',
#   'High Road, Langdon Hills, Basildon,Essex.',
#   'Holy Cross Recreation Ground Pavilion, Church Road, Basildon, Essex',
#   'Mountnessing Road, Billericay, Essex',
#   '39 High Street, Billericay, Essex',
#   'Whitmore Way, Basildon, Essex',
#   'Southernhay, Basildon, Essex',
#   'Southend Road, Billericay, Essex',
#   '1-15 Market Square, Basildon, Essex',
#   '164 Clay Hill Road, Basildon, Essex',
#   'Gardiners Way, Basildon, Essex',
#   'Time Square, Basildon, Essex',
#   '113 High Street, Billericay, Essex',
#   '66-68 Laindon Road, Billericay, Essex',
#   '73-77 Runwell Road, Wickford, Essex',
#   'S Wernick & Sons Ltd, Russell Gardens, Shotgate, Wickford',
#   'Nether Mayne, Basildon, Essex',
#   'Wickford Community Centre, Market Road, Wickford, Essex',
#   'Queens Park Avenue, Billericay, Essex',
#   'Tye Common Road, Little Burstead, Billericay,Essex.',
#   'Bowers United Sports And Social Club, Crown Avenue, Pitsea, Basildon',
#   'The Coach and Horses, 36 Chapel Street, Billericay, Essex',
#   'The Crane, Denys Drive, Basildon, Essex',
#   '2 High Street, Billericay, Essex',
#   '80 High Street, Wickford, Essex',
#   'The Dukes Head, Laindon Common Road, Little Burstead, Billericay',
#   'The Edge, 6-8 High Pavement, Basildon, Essex',
#   'The Forge, 1-2 The Pantiles, Billericay, Essex',
#   'Victoria Road, Laindon, Basildon,Essex.',
#   'Festival Leisure Park, Cranes Farm Road, Basildon, Essex.',
#   '25 Laindon Centre, Basildon, Essex',
#   'Burnt Mills Road, Pitsea, Essex.',
#   'Noak Bridge Public House, 45 Wash Road, Laindon, Basildon',
#   '186 Great Knightleys, Basildon, Essex',
#   'Festival Leisure Park, Cranes Farm Road, Basildon, Essex.',
#   '1 High Street, Billericay, Essex',
#   'The New Mayflower, Jacksons Lane, Billericay, Essex',
#   'The Swan, The Broadway, Wickford, Essex',
#   'East Mayne, Basildon, Essex',
#   '35 Kingswood Road, Basildon, Essex',
#   'Unit 7, Festival Way, Basildon, Essex',
#   'Vange And Pitsea Working Mens Club, High Road, Vange, Basildon',
#   'Wick Community Centre, Salcott Crescent, Wickford, Essex',
#   'Runwell Road, Wickford, Essex',
#   'Luncies Road, Basildon, Essex',
#   '1 Northumberland Avenue, Laindon, Basildon',
#   'Addison Howard Park, Bedford Road, Kempston, Bedford',
#   'Kempston Rovers Football Club, Hillgrounds Road, Kempston, Bedford',
#   '30 The Broadway, Bedford',
#   '1 Duke Street, Bedford',
#   'Palace Chambers, Silver Street, Bedford',
#   '29 Harpur Street, Bedford',
#   '72 St Loyes Street, Bedford',
#   'Bedford And County Golf Club, Green Lane, Clapham, Bedford',
#   'Bedford And County Golf Club, Green Lane, Clapham, Bedford',
#   'Bedford Arms, High Street, Souldrop, Bedford',
#   'Bedford Athletic Rugby Club, Wentworth Drive, Bedford',
#   'Bedford Borough Bowling Club, Goldington Road, Bedford',
#   'Bedford Rowing Club, Duckmill Lane, Bedford',
#   'Bedford Rugby Union F C, Goldington Road, Bedford',
#   'The Standard, 26-28 High Street, Bedford',
#   'Bedford Town Football Club, Meadow Lane, Bedford',
#   'Bedfordshire Golf Club, Spring Lane, Stagsden, Bedford',
#   'Pavillion, Deep Spinney, Biddenham, Bedford',
#   '115-117 High Street, Bedford',
#   'Briar Bank Club, Hawthorn Drive, Wilstead, Bedford',
#   'Burnaby Arms, 66 Stanley Street, Bedford',
#   'The Chequers Inn, 47 Hall End Road, Wootton, Bedfordshire',
#   '32a Alexandra Road, Bedford',
#   'Colmworth Golf Club, New Road, Colmworth, Bedford',
#   'Unilever Sports & Social Club,, Colworth Estate, Sharnbrook, Bedford',
#   'The Cross Keys, 69 High Street, Bedford',
#   'The Crown Inn, Green End, Little Staughton, Bedford',
#   'Devonshire Arms, 32 Dudley Street, Bedford',
#   '13 St Johns Street, Bedford',
#   '3a Lurke Street, Bedford',
#   'Fox & Duck, 13 Bedford Road, Wootton, Bedford',
#   'Fox And Hounds, High Street, Riseley, Bedford',
#   'Fox And Hounds, 1 Milton Road, Clapham, Bedford',
#   'The Fox And Hounds, 178 Goldington Road, Bedford',
#   'Fox Inn, 35 High Street, Carlton, Bedford',
#   'Santa Pod Raceway, Podington Airfield, Airfield Road, Podington, Bedford',
#   'Gardeners Arms, 12 Sandhurst Road, Bedford',
#   'George And Dragon, 39 Mill Street, Bedford',
#   'Gordon Arms, 118 Castle Road, Bedford',
#   'Greyfriars Snooker Centre, Greyfriars, Bedford',
#   'The Half Moon, 108 High Street, Kempston, Bedford',
#   '30-32 High Street, Bedford',
#   'Horse & Jockey, Church End, Ravensden, Bedford',
#   '2 Spenser Road, Bedford',
#   '196a Bedford Road, Kempston, Bedford',
#   '290 Hillgrounds Road, Kempston, Bedford',
#   'Kent Arms, 54 Salisbury Street, Bedford',
#   'King William Iv, 56 High Street, Kempston, Bedford',
#   'Kings Arms, The Green, Cardington, Bedford',
#   'The Kings Arms, 24 St Marys Street, Bedford',
#   '57 London Road, Bedford',
#   'Meltis Sports And Social Club, Miller Road, Bedford',
#   '91 Mile Road, Bedford',
#   'Mulberry Bush, Springfield Centre, Kempston, Bedford',
#   'The North End Working Mens Social Club, 60 Roff Avenue, Bedford',
#   '13 St Pauls Square, Bedford',
#   'Oakley Sport And Social Club, Church Lane, Oakley, Bedford',
#   'Pavenham Park Golf Club, High Street, Pavenham, Bedford',
#   '42 Midland Road, Bedford',
#   'Podington Cricket Club, Hinwick Road, Podington, Bedford',
#   'United Services Club, Gold Street, Podington, Bedford',
#   'The Polhill Arms, 25 Wilden Road, Renhold, Bedford',
#   'The Prince Of Wales, 8 Northampton Road, Bromham, Bedford',
#   'Queens Tavern, 120 Queens Drive, Bedford',
#   '93 Ashburnham Road, Bedford',
#   'Red Lion, Bedford Road, Wilstead, Bedford',
#   'Royal Oak, 33 High Street, Roxton, Bedford',
#   'The Royal Oak, 91 Woburn Road, Kempston, Bedford',
#   'Russell Park Social Club, 69 Goldington Road, Bedford',
#   'The Ship, 7 St Cuthberts Street, Bedford',
#   'Shortstown Village Hall, Shorts Avenue, Shortstown, Bedford',
#   'The Smiths Arms, 15 Margetts Road, Kempston, Bedford',
#   'The Pavilion, Chester Road, Bedford',
#   'Sporting Targets Ltd, Knotting Lane, Riseley, Bedford',
#   'St Johns Arms, Knotting Road, Melchbourne, Bedford',
#   'Star Rowing Club, Commercial Road, Bedford',
#   'The Club House, Stewartby Way, Stewartby, Bedford',
#   'Swan Inn, 21 Bridge End, Bromham, Bedford',
#   'The Keep, Bedford Road, Kempston, Bedford',
#   'The Anchor, 397 Goldington Road, Bedford',
#   'The Anchor Inn, Cardington Road, Bedford',
#   'The Anchor Inn, 85 High Street, Great Barford, Bedford',
#   'The Artisan Tap, 92 High Street, Bedford',
#   '52 Foster Hill Road, Bedford',
#   'Bedford Arms, 57 High Street, Oakley, Bedford',
#   '11 De Parys Avenue, Bedford',
#   'The Bedford Golf Clubhouse, 10 Carnoustie Drive, Great Denham, Bedford',
#   'The Bell, 61 High Road, Cotton End, Bedford',
#   'The Bell, 81 High Street, Odell, Bedford',
#   '115 Putnoe Lane, Bedford',
#   'The Bull, 259 London Road, Bedford',
#   'The Castle, 17 Newnham Street, Bedford',
#   'The Chequers Inn, Pertenhall Road, Keysoe, Bedford',
#   'The Chequers Inn, High Street, Yielden, Bedford',
#   'The Chimney Corner Public House, Ampthill Road, Kempston Hardwick, Bedford',
#   'The Cock Inn, 2 Bedford Road, Wootton, Bedfordshire',
#   'The Crown, 17 Station Road, Willington, Bedford',
#   'Crown Inn Public House, Phoenix Park, Wyboston, Bedford',
#   'The Duke Inn, 10 Woburn Road, Kempston, Bedford',
#   'The Falcon Inn, Rushden Road, Bletsoe, Bedford',
#   'The Five Bells, 1-3 Northill Road, Cople, Bedford',
#   'The Flowerpot, 25 Tavistock Street, Bedford',
#   '2 Ram Yard, Bedford',
#   'The Foresters Arms, 41 Union Street, Bedford',
#   '32-34 Mill Street, Bedford',
#   'The Muntjac, 71 High Street, Harrold, Bedford',
#   'The New Inn, 1 Rushden Road, Wymington, Bedford',
#   'The Sportsman, 58 The Boundary, Bedford',
#   'The Oakley Arms, 98 High Street, Harrold, Bedford',
#   '2 Lurke Street, Bedford',
#   'The Park Public House, 98 Kimbolton Road, Bedford',
#   'The Pheasant, 300 Kimbolton Road, Bedford',
#   'The Rose, 45 High Street, Bedford',
#   'The Royal George, 8-10 Silver Street, Stevington, Bedford',
#   '23 Bridgend, Carlton, Bedford',
#   'The Ship, 102 Bromham Road, Bedford',
#   'The Star Inn, 42 High Street, Clapham, Bedfordshire',
# ...
#   '-0.215662',
#   '-0.427532',
#   '-0.424482',
#   '-0.525337',
#   '-0.227132',
#   '-0.225845',
#   '-0.511507',
#   '-0.30303',
#   '-0.575198',
#   '-0.628005',
#   '-0.530552',
#   '-0.662385',
#   '-0.655003',
#   '-0.657622',
#   '-0.522284',
#   '-0.282006',
#   '-0.549556',
#   '-0.531615',
#   '-0.516543',
#   '-0.495139',
#   '-0.531984',
#   '-0.619578',
#   '-0.348397',
#   '-0.663279',
#   '-0.498449',
#   '-0.33422',
#   '-0.42752',
#   '-0.498586',
#   '-0.454702',
#   '-0.441781',
#   '-0.222473',
#   '-0.164521',
#   '-0.489105',
#   '-0.514721',
#   '-0.498041',
#   '-0.643404',
#   '-0.291127',
#   '-0.628768',
#   ...],
#  'local_authority': ['Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Babergh',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Basildon',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Huntingdonshire',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Bedford',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Babergh',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Braintree',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Breckland',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Brentwood',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broadland',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   '',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Broxbourne',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Cambridge',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Castle Point',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Luton',
#   'Bedford',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   'Central Bedfordshire',
#   ...]}

# %% [markdown]
# 2. Сгенерируйте 2 случайные матрицы размера 10_000 x 10_000 и вычислите их произведение. Сколько времени занимают три этих операции? Сохраните 3 полученных матрицы в файл .npz с соответствующими названиями

# %%
A = np.random.randint(0, 100, size=(10_000, 10_000))
B = np.random.randint(0, 100, size=(10_000, 10_000))

# %%
np.save("./out/A.npy", A)
np.savez("./out/AB.npz", arr1=A, arr2=B)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-31fddaecadc3> in <module>
# ----> 1 np.save("./out/A.npy", A)
#       2 np.savez("./out/AB.npz", arr1=A, arr2=B)
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\numpy\lib\npyio.py in save(file, arr, allow_pickle, fix_imports)
#     539         if not file.endswith('.npy'):
#     540             file = file + '.npy'
# --> 541         fid = open(file, "wb")
#     542         own_fid = True
#     543
#
# FileNotFoundError: [Errno 2] No such file or directory: './out/A.npy'

# %%
r = np.load("./out/AB.npz")
r

# %%
r.files
# Out:
# ['arr1', 'arr2']

# %% [markdown]
# 3. Создайте 2 матрицы размера 1000x1000, используя различные параметризируемые распределения из numpy (https://docs.scipy.org/doc/numpy-1.15.0/reference/routines.random.html#distributions)
#
# После этого сохраните получившиеся матрицы в hdf5-файл в виде двух различных датасетов. В качестве описания каждого датасета укажите параметры используемых распределений

# %%
import h5py

# %%
with h5py.File("./out/test.h5", 'w') as hdf:
    ds1 = hdf.create_dataset("arrA", data=A)
    ds2 = hdf.create_dataset("arrB", data=B)
    
    ds1.attrs["Description"] = "Здесь лежит массив А"
    ds2.attrs["Description"] = "Здесь лежит массив B"

# %%
with h5py.File("./out/test.h5","r") as hdf:
    ds1 = hdf['arrA']
    print(type(ds1))
    #Только в этот момент появляются данные
    arr = ds1[:1000]
# Out:
# <class 'h5py._hl.dataset.Dataset'>

# %% [markdown]
# ## Лабораторная работа 5

# %% [markdown]
# ### csv

# %% [markdown]
# 1.1 В файле `tags_sample.csv` находится информация о тэгах, приписываемых рецептам. Воспользовавшись `csv.reader`, считайте этот файл и создайте словарь вида `id_рецепта: [список тэгов]`. Сохраните этот словарь в файл `tags_sample.json`.

# %%
import csv
import json
import pandas as pd

# %%
dictionary_1 = {}

with open('../data/tags_sample.csv') as file:
    reader = csv.reader(file)
    next(reader)
    for row in reader:
        row_id = int(row[0])
        if row_id not in dictionary_1:
            dictionary_1[row_id] = []
        dictionary_1[row_id].append(row[1])
        
dictionary_1
# Out:
# {44123: ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'soups-stews',
#   'beans',
#   'poultry',
#   'american',
#   'chicken',
#   'stove-top',
#   'dietary',
#   'gluten-free',
#   'comfort-food',
#   'californian',
#   'black-beans',
#   'free-of-something',
#   'meat',
#   'taste-mood',
#   'equipment',
#   'grilling',
#   '4-hours-or-less'],
#  67664: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'desserts',
#   'lunch',
#   'snacks',
#   'easy',
#   'kid-friendly',
#   'low-fat',
#   'summer',
#   'frozen-desserts',
#   'freezer',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'low-saturated-fat',
#   'inexpensive',
#   'healthy-2',
#   'toddler-friendly',
#   'low-in-something',
#   'equipment',
#   'small-appliance',
#   'mixer',
#   'number-of-servings',
#   '3-steps-or-less'],
#  38798: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'appetizers',
#   'side-dishes',
#   'vegetables',
#   'oven',
#   'refrigerator',
#   'freezer',
#   'dietary',
#   'oamc-freezer-make-ahead',
#   'low-carb',
#   'low-in-something',
#   'equipment',
#   'number-of-servings'],
#  35173: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'lunch',
#   'main-dish',
#   'oven',
#   'easy',
#   'dietary',
#   'sandwiches',
#   'equipment'],
#  84797: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'sauces',
#   'appetizers',
#   'main-dish',
#   'condiments-etc',
#   'beef',
#   'dinner-party',
#   'holiday-event',
#   'dietary',
#   'valentines-day',
#   'savory-sauces',
#   'meat',
#   'number-of-servings'],
#  44045: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'side-dishes',
#   'vegetables',
#   'american',
#   'easy',
#   'diabetic',
#   'dinner-party',
#   'heirloom-historical',
#   'holiday-event',
#   'kid-friendly',
#   'vegetarian',
#   'stove-top',
#   'dietary',
#   'christmas',
#   'thanksgiving',
#   'comfort-food',
#   'amish-mennonite',
#   'northeastern-united-states',
#   'corn',
#   'taste-mood',
#   'equipment',
#   'number-of-servings'],
#  107229: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'main-dish',
#   'asian',
#   'easy',
#   'diabetic',
#   'kosher',
#   'dietary',
#   'pasta-rice-and-grains'],
#  95926: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   '5-ingredients-or-less',
#   'lunch',
#   'fruit',
#   'american',
#   'southern-united-states',
#   'easy',
#   'european',
#   'beginner-cook',
#   'finger-food',
#   'kid-friendly',
#   'vegetarian',
#   'dietary',
#   'sandwiches',
#   'inexpensive',
#   'toddler-friendly',
#   'tropical-fruit',
#   'bananas',
#   'brunch',
#   'taste-mood',
#   'sweet',
#   'to-go',
#   'presentation'],
#  453467: ['60-minutes-or-less',
#   'time-to-make',
#   'cuisine',
#   'preparation',
#   'north-american',
#   'for-large-groups',
#   'canadian',
#   'british-columbian',
#   'number-of-servings'],
#  306168: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'side-dishes',
#   'vegetables',
#   'easy',
#   'beginner-cook',
#   'broccoli'],
#  50662: ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'casseroles',
#   'main-dish',
#   'beef',
#   'oven',
#   'one-dish-meal',
#   'comfort-food',
#   'meat',
#   'taste-mood',
#   'equipment',
#   '4-hours-or-less'],
#  118843: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'drop-cookies',
#   'desserts',
#   'easy',
#   'cookies-and-brownies',
#   '3-steps-or-less'],
#  69190: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'low-protein',
#   'healthy',
#   'soups-stews',
#   'potatoes',
#   'vegetables',
#   'kid-friendly',
#   'dietary',
#   'low-cholesterol',
#   'low-calorie',
#   'comfort-food',
#   'low-carb',
#   'healthy-2',
#   'low-in-something',
#   'taste-mood',
#   'presentation',
#   'served-hot',
#   '4-hours-or-less'],
#  503475: ['danish',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'pancakes-and-waffles',
#   'breakfast',
#   'scandinavian',
#   'european'],
#  149593: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'breads',
#   'lunch',
#   'eggs-dairy',
#   'oven',
#   'easy',
#   'beginner-cook',
#   'holiday-event',
#   'muffins',
#   'christmas',
#   'thanksgiving',
#   'quick-breads',
#   'brunch',
#   'taste-mood',
#   'sweet',
#   'equipment'],
#  200148: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'desserts',
#   'beans',
#   'vegan',
#   'vegetarian',
#   'cheesecake',
#   'dietary',
#   'soy-tofu',
#   '4-hours-or-less'],
#  310570: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'savory-pies',
#   'main-dish',
#   'eggs-dairy',
#   'easy',
#   'european',
#   'cheese',
#   '4-hours-or-less'],
#  95534: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'very-low-carbs',
#   'lunch',
#   'main-dish',
#   'beef',
#   'american',
#   'oven',
#   'easy',
#   'kid-friendly',
#   'dietary',
#   'low-sodium',
#   'sandwiches',
#   'high-protein',
#   'low-carb',
#   'midwestern',
#   'high-in-something',
#   'low-in-something',
#   'meat',
#   'roast-beef',
#   'taste-mood',
#   'savory',
#   'equipment'],
#  109818: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   '5-ingredients-or-less',
#   'side-dishes',
#   'vegetables',
#   'easy',
#   'dietary'],
#  66932: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'side-dishes',
#   'rice',
#   'asian',
#   'microwave',
#   'stove-top',
#   'dietary',
#   'low-sodium',
#   'low-in-something',
#   'pasta-rice-and-grains',
#   'brown-rice',
#   'equipment'],
#  226001: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'desserts',
#   'inexpensive'],
#  125195: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'north-american',
#   'salads',
#   'side-dishes',
#   'american',
#   'easy',
#   'midwestern',
#   '3-steps-or-less'],
#  141939: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'eggs-dairy',
#   'poultry',
#   'vegetables',
#   'oven',
#   'easy',
#   'refrigerator',
#   'dinner-party',
#   'holiday-event',
#   'chicken',
#   'dietary',
#   'spicy',
#   'comfort-food',
#   'meat',
#   'onions',
#   'taste-mood',
#   'equipment'],
#  250883: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-large-groups',
#   '5-ingredients-or-less',
#   'appetizers',
#   'lunch',
#   'snacks',
#   'eggs-dairy',
#   'easy',
#   'beginner-cook',
#   'finger-food',
#   'dips',
#   'cheese',
#   'dietary',
#   'number-of-servings',
#   'presentation',
#   'served-cold',
#   '4-hours-or-less'],
#  120297: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'healthy',
#   'side-dishes',
#   'potatoes',
#   'vegetables',
#   'asian',
#   'middle-eastern',
#   'dinner-party',
#   'low-fat',
#   'vegetarian',
#   'lebanese',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'low-in-something',
#   '4-hours-or-less'],
#  147477: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'appetizers',
#   'eggs-dairy',
#   'seafood',
#   'easy',
#   'dips',
#   'spreads',
#   'cheese',
#   'dietary',
#   'high-calcium',
#   'high-protein',
#   'low-carb',
#   'high-in-something',
#   'low-in-something',
#   'shellfish',
#   'clams',
#   '3-steps-or-less'],
#  223349: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'seafood',
#   'vegetables',
#   'easy',
#   'diabetic',
#   'shrimp',
#   'dietary',
#   'low-sodium',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'low-in-something',
#   'shellfish'],
#  60938: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'appetizers',
#   'lunch',
#   'side-dishes',
#   'snacks',
#   'eggs-dairy',
#   'potatoes',
#   'vegetables',
#   'oven',
#   'dinner-party',
#   'finger-food',
#   'cheese',
#   'deep-fry',
#   'stove-top',
#   'dietary',
#   'comfort-food',
#   'taste-mood',
#   'equipment',
#   'presentation',
#   'served-hot',
#   'technique'],
#  302399: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   '5-ingredients-or-less',
#   'breads',
#   'easy'],
#  342620: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'main-dish',
#   'beef',
#   'american',
#   'southern-united-states',
#   'oven',
#   'easy',
#   'beginner-cook',
#   'comfort-food',
#   'ground-beef',
#   'meat',
#   'taste-mood',
#   'equipment',
#   '4-hours-or-less'],
#  296983: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'for-1-or-2',
#   'appetizers',
#   'salads',
#   'potatoes',
#   'vegetables',
#   'greek',
#   'easy',
#   'european',
#   'vegan',
#   'vegetarian',
#   'dips',
#   'dietary',
#   'number-of-servings'],
#  166089: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'north-american',
#   '5-ingredients-or-less',
#   'main-dish',
#   'poultry',
#   'american',
#   'easy',
#   'kid-friendly',
#   'chicken',
#   'dietary',
#   'oamc-freezer-make-ahead',
#   'high-protein',
#   'low-carb',
#   'inexpensive',
#   'high-in-something',
#   'low-in-something',
#   'meat',
#   'number-of-servings'],
#  129581: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'desserts',
#   'cakes',
#   'chocolate',
#   'dietary',
#   'low-in-something',
#   '4-hours-or-less'],
#  116741: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'beverages',
#   'breakfast',
#   'vegetables',
#   'easy',
#   'low-fat',
#   'vegetarian',
#   'dietary',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   'brunch',
#   '3-steps-or-less'],
#  325714: ['time-to-make',
#   'course',
#   'preparation',
#   'desserts',
#   '1-day-or-more',
#   'cakes'],
#  276594: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'healthy',
#   'appetizers',
#   'main-dish',
#   'beef',
#   'dietary',
#   'ground-beef',
#   'meat',
#   'brunch',
#   'novelty'],
#  487173: ['weeknight',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'eggs-dairy',
#   'easy',
#   'european',
#   'italian',
#   'cheese',
#   'dietary',
#   'low-carb',
#   'low-in-something',
#   'meat',
#   'from-scratch'],
#  289671: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'low-protein',
#   'beverages',
#   'eggs-dairy',
#   'easy',
#   'refrigerator',
#   'beginner-cook',
#   'summer',
#   'chocolate',
#   'smoothies',
#   'food-processor-blender',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'shakes',
#   'low-calorie',
#   'low-carb',
#   'low-in-something',
#   'equipment',
#   'small-appliance',
#   'number-of-servings'],
#  44050: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'low-protein',
#   '5-ingredients-or-less',
#   'desserts',
#   'american',
#   'easy',
#   'heirloom-historical',
#   'holiday-event',
#   'cakes',
#   'dietary',
#   'cake-fillings-and-frostings',
#   'amish-mennonite',
#   'northeastern-united-states',
#   'low-in-something',
#   'number-of-servings',
#   '3-steps-or-less'],
#  447429: ['weeknight',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'soups-stews',
#   'beef',
#   'american',
#   'kid-friendly',
#   'dietary',
#   'low-calorie',
#   'comfort-food',
#   'low-carb',
#   'ground-beef',
#   'low-in-something',
#   'meat',
#   'taste-mood'],
#  137701: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'eggs-dairy',
#   'rice',
#   'european',
#   'winter',
#   'italian',
#   'cheese',
#   'dietary',
#   'one-dish-meal',
#   'seasonal',
#   'comfort-food',
#   'pasta-rice-and-grains',
#   'taste-mood',
#   'savory',
#   'presentation',
#   'served-hot'],
#  292568: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   '5-ingredients-or-less',
#   'desserts',
#   'easy',
#   'cakes',
#   'dietary',
#   'high-calcium',
#   'high-in-something',
#   '3-steps-or-less'],
#  299989: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'main-dish',
#   'salads',
#   'beans',
#   'poultry',
#   'rice',
#   'mexican',
#   'easy',
#   'dinner-party',
#   'kid-friendly',
#   'spring',
#   'summer',
#   'chicken',
#   'stove-top',
#   'dietary',
#   'copycat',
#   'one-dish-meal',
#   'seasonal',
#   'inexpensive',
#   'black-beans',
#   'meat',
#   'pasta-rice-and-grains',
#   'novelty',
#   'equipment'],
#  63346: ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'desserts',
#   'vegetables',
#   'oven',
#   'potluck',
#   'dinner-party',
#   'kid-friendly',
#   'cakes',
#   'dietary',
#   'to-go',
#   'equipment',
#   'small-appliance',
#   'mixer',
#   'presentation',
#   'served-cold',
#   '4-hours-or-less'],
#  342619: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'beverages',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'low-fat',
#   'vegan',
#   'vegetarian',
#   'smoothies',
#   'food-processor-blender',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'infant-baby-friendly',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'toddler-friendly',
#   'low-in-something',
#   'taste-mood',
#   'sweet',
#   'equipment',
#   'small-appliance',
#   '3-steps-or-less'],
#  383120: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'lunch',
#   'main-dish',
#   'snacks',
#   'potluck',
#   'one-dish-meal',
#   'inexpensive',
#   'pasta-rice-and-grains',
#   'taste-mood',
#   'savory',
#   'to-go'],
#  367987: ['lactose',
#   '15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'salads',
#   'canadian',
#   'easy',
#   'no-cook',
#   'beginner-cook',
#   'salad-dressings',
#   'dietary',
#   'gluten-free',
#   'inexpensive',
#   'egg-free',
#   'quebec',
#   'free-of-something',
#   'taste-mood',
#   'savory',
#   '3-steps-or-less',
#   'technique'],
#  463219: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'lunch',
#   'main-dish',
#   'eggs-dairy',
#   'pasta',
#   'vegetables',
#   'easy',
#   'kid-friendly',
#   'cheese',
#   'stove-top',
#   'dietary',
#   'pasta-rice-and-grains',
#   'onions',
#   'equipment',
#   '3-steps-or-less'],
#  39172: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'breads',
#   'fruit',
#   'muffins',
#   'dietary',
#   'quick-breads',
#   'tropical-fruit',
#   'pineapple',
#   'number-of-servings'],
#  216068: ['course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'beef',
#   'easy',
#   'stews',
#   'crock-pot-slow-cooker',
#   'meat',
#   'equipment',
#   '3-steps-or-less'],
#  173730: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'soups-stews',
#   'potatoes',
#   'poultry',
#   'vegetables',
#   'easy',
#   'european',
#   'beginner-cook',
#   'winter',
#   'chicken',
#   'stove-top',
#   'seasonal',
#   'inexpensive',
#   'meat',
#   'equipment',
#   'small-appliance',
#   'mixer',
#   'presentation',
#   'served-hot',
#   '4-hours-or-less'],
#  287778: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'appetizers',
#   'lunch',
#   'snacks',
#   'easy',
#   'kid-friendly',
#   'dietary'],
#  437637: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'cobblers-and-crisps',
#   'desserts',
#   'fruit',
#   'dietary',
#   'comfort-food',
#   'low-in-something',
#   'taste-mood',
#   'sweet',
#   '4-hours-or-less'],
#  123115: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'salads',
#   'dietary'],
#  371549: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'poultry',
#   'easy',
#   'summer',
#   'turkey',
#   'seasonal',
#   'meat',
#   'equipment',
#   'grilling',
#   '3-steps-or-less',
#   'burgers',
#   'turkey-burgers'],
#  376813: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'soups-stews',
#   'pasta',
#   'poultry',
#   'vegetables',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'winter',
#   'chicken',
#   'dietary',
#   'seasonal',
#   'comfort-food',
#   'inexpensive',
#   'meat',
#   'pasta-rice-and-grains',
#   'carrots',
#   'taste-mood',
#   'savory'],
#  134085: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'pancakes-and-waffles',
#   'breakfast',
#   'lunch',
#   'american',
#   'kid-friendly',
#   'dietary',
#   'copycat',
#   'sandwiches',
#   'meat',
#   'novelty'],
#  390230: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-large-groups',
#   'main-dish',
#   'soups-stews',
#   'poultry',
#   'holiday-event',
#   'chili',
#   'chicken',
#   'meat',
#   'superbowl',
#   'number-of-servings',
#   '4-hours-or-less'],
#  401605: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'yams-sweet-potatoes',
#   'low-protein',
#   'side-dishes',
#   'potatoes',
#   'vegetables',
#   'holiday-event',
#   'dietary',
#   'christmas',
#   'thanksgiving',
#   'low-sodium',
#   'low-in-something'],
#  306590: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'side-dishes',
#   'potatoes',
#   'vegetables',
#   'easy',
#   '3-steps-or-less'],
#  303944: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'side-dishes',
#   'vegetables',
#   'dinner-party',
#   'holiday-event',
#   'dietary',
#   'low-carb',
#   'low-in-something'],
#  299968: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'beans',
#   'vegan',
#   'vegetarian',
#   'dietary',
#   '4-hours-or-less'],
#  192542: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'poultry',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'chicken',
#   'dietary',
#   'high-protein',
#   'inexpensive',
#   'high-in-something',
#   'toddler-friendly',
#   'meat',
#   'chicken-breasts'],
#  147563: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'potatoes',
#   'poultry',
#   'vegetables',
#   'easy',
#   'chicken',
#   'dietary',
#   'meat',
#   'chicken-breasts'],
#  193719: ['time-to-make',
#   'course',
#   'preparation',
#   'low-protein',
#   'healthy',
#   'main-dish',
#   'side-dishes',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-calorie',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   '4-hours-or-less'],
#  38852: ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'beef',
#   'oven',
#   'kid-friendly',
#   'dietary',
#   'comfort-food',
#   'ground-beef',
#   'meat',
#   'taste-mood',
#   'equipment',
#   '4-hours-or-less'],
#  250232: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'north-american',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'side-dishes',
#   'potatoes',
#   'vegetables',
#   'american',
#   'oven',
#   'easy',
#   'beginner-cook',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'low-in-something',
#   'equipment'],
#  134787: ['30-minutes-or-less',
#   'time-to-make',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'very-low-carbs',
#   'canning',
#   'vegetables',
#   'easy',
#   'no-cook',
#   'holiday-event',
#   'low-fat',
#   'dietary',
#   'gifts',
#   'christmas',
#   'thanksgiving',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'inexpensive',
#   'low-in-something',
#   'technique'],
#  437219: ['time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'snacks',
#   'american',
#   'dinner-party',
#   'dietary',
#   '4-hours-or-less'],
#  77380: ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'appetizers',
#   'eggs-dairy',
#   'holiday-event',
#   'spreads',
#   'cheese',
#   'dietary',
#   'new-years',
#   'high-calcium',
#   'high-protein',
#   'low-carb',
#   'high-in-something',
#   'low-in-something',
#   'superbowl',
#   'number-of-servings',
#   'presentation',
#   'served-cold'],
#  21357: ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'very-low-carbs',
#   'main-dish',
#   'pork',
#   'oven',
#   'easy',
#   'dinner-party',
#   'dietary',
#   'comfort-food',
#   'low-carb',
#   'low-in-something',
#   'meat',
#   'pork-chops',
#   'taste-mood',
#   'equipment',
#   '4-hours-or-less'],
#  198343: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-large-groups',
#   'breads',
#   'fruit',
#   'easy',
#   'beginner-cook',
#   'quick-breads',
#   'tropical-fruit',
#   'bananas',
#   'number-of-servings',
#   '4-hours-or-less'],
#  129919: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'casseroles',
#   'main-dish',
#   'eggs-dairy',
#   'pasta',
#   'american',
#   'southwestern-united-states',
#   'oven',
#   'potluck',
#   'kid-friendly',
#   'cheese',
#   'dietary',
#   'comfort-food',
#   'egg-free',
#   'free-of-something',
#   'toddler-friendly',
#   'pasta-rice-and-grains',
#   'elbow-macaroni',
#   'taste-mood',
#   'savory',
#   'to-go',
#   'equipment',
#   'number-of-servings',
#   'presentation',
#   'served-hot',
#   '4-hours-or-less'],
#  375376: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'breads',
#   'breakfast',
#   'eggs-dairy',
#   'easy',
#   'eggs',
#   'dietary',
#   'gluten-free',
#   'comfort-food',
#   'inexpensive',
#   'yeast',
#   'free-of-something',
#   'brunch',
#   'taste-mood',
#   '3-steps-or-less',
#   '4-hours-or-less'],
#  152534: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'appetizers',
#   'main-dish',
#   'oven',
#   'pizza',
#   'equipment'],
#  63131: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'for-large-groups',
#   'breakfast',
#   'desserts',
#   'easy',
#   'beginner-cook',
#   'kosher',
#   'picnic',
#   'vegan',
#   'vegetarian',
#   'cookies-and-brownies',
#   'bar-cookies',
#   'stove-top',
#   'dietary',
#   'brown-bag',
#   'to-go',
#   'camping',
#   'equipment',
#   'number-of-servings'],
#  24760: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'main-dish',
#   'beans',
#   'vegetables',
#   'asian',
#   'middle-eastern',
#   'easy',
#   'low-fat',
#   'vegetarian',
#   'stove-top',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   'equipment',
#   'number-of-servings'],
#  327979: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'beverages',
#   'fruit',
#   'easy',
#   'low-fat',
#   'vegan',
#   'vegetarian',
#   'smoothies',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'low-in-something',
#   'melons',
#   'tropical-fruit',
#   'papaya',
#   'pineapple',
#   'number-of-servings',
#   '3-steps-or-less'],
#  375362: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   '5-ingredients-or-less',
#   'side-dishes',
#   'easy',
#   'copycat',
#   'novelty',
#   '3-steps-or-less'],
#  217296: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'healthy',
#   'breads',
#   'european',
#   'holiday-event',
#   'irish',
#   'rolls-biscuits',
#   'grains',
#   'dietary',
#   'st-patricks-day',
#   'pasta-rice-and-grains',
#   '4-hours-or-less'],
#  121107: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   '5-ingredients-or-less',
#   'main-dish',
#   'pasta',
#   'vegetables',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'vegetarian',
#   'dietary',
#   'inexpensive',
#   'pasta-rice-and-grains',
#   'spaghetti',
#   'presentation',
#   'served-hot'],
#  435816: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'breads',
#   'eggs-dairy',
#   'american',
#   'oven',
#   'rolls-biscuits',
#   'nuts',
#   'eggs',
#   'midwestern',
#   'inexpensive',
#   'brunch',
#   'taste-mood',
#   'sweet',
#   'equipment',
#   '4-hours-or-less',
#   'baking',
#   'from-scratch'],
#  198073: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-large-groups',
#   '5-ingredients-or-less',
#   'appetizers',
#   'pork',
#   'easy',
#   'holiday-event',
#   'spicy',
#   'oamc-freezer-make-ahead',
#   'meat',
#   'pork-sausage',
#   'taste-mood',
#   'number-of-servings'],
#  202949: ['30-minutes-or-less',
#   'time-to-make',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'vegetables',
#   'spicy',
#   'comfort-food',
#   'taste-mood'],
#  26420: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'healthy',
#   'sauces',
#   'condiments-etc',
#   'seafood',
#   'easy',
#   'no-cook',
#   'low-fat',
#   'shrimp',
#   'dietary',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'savory-sauces',
#   'low-in-something',
#   'shellfish',
#   'number-of-servings',
#   '3-steps-or-less',
#   'technique'],
#  367828: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'side-dishes',
#   'rice',
#   'easy',
#   'low-fat',
#   'dietary',
#   'copycat',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-in-something',
#   'pasta-rice-and-grains',
#   'white-rice',
#   'novelty',
#   '3-steps-or-less'],
#  140610: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'breads',
#   'breakfast',
#   'fruit',
#   'vegetables',
#   'american',
#   'fall',
#   'holiday-event',
#   'muffins',
#   'grains',
#   'food-processor-blender',
#   'christmas',
#   'thanksgiving',
#   'seasonal',
#   'quick-breads',
#   'apples',
#   'pasta-rice-and-grains',
#   'carrots',
#   'brunch',
#   'equipment',
#   'small-appliance'],
#  392181: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'desserts',
#   'dinner-party',
#   'cakes',
#   'chocolate',
#   'dietary',
#   'copycat',
#   'novelty',
#   '4-hours-or-less'],
#  468143: ['weeknight',
#   '30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-large-groups',
#   '5-ingredients-or-less',
#   'desserts',
#   'easy',
#   'no-cook',
#   'dinner-party',
#   'finger-food',
#   'romantic',
#   'chocolate',
#   'inexpensive',
#   'taste-mood',
#   'sweet',
#   'number-of-servings',
#   'presentation',
#   'served-cold',
#   'technique'],
#  374703: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'salads',
#   'vegetables',
#   'spring',
#   'summer',
#   'vegan',
#   'vegetarian',
#   'dietary',
#   'seasonal',
#   'number-of-servings'],
#  100837: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'beverages',
#   'fruit',
#   'american',
#   'easy',
#   'no-cook',
#   'dinner-party',
#   'holiday-event',
#   'low-fat',
#   'romantic',
#   'cocktails',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-in-something',
#   'tropical-fruit',
#   'pineapple',
#   'brunch',
#   'taste-mood',
#   'presentation',
#   'served-cold',
#   'technique'],
#  286484: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'breakfast',
#   'lunch',
#   'eggs-dairy',
#   'fruit',
#   'easy',
#   'kid-friendly',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'infant-baby-friendly',
#   'low-saturated-fat',
#   'low-calorie',
#   'toddler-friendly',
#   'low-in-something',
#   'tropical-fruit',
#   'bananas',
#   'number-of-servings',
#   '3-steps-or-less'],
#  176996: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'sauces',
#   'condiments-etc',
#   'fruit',
#   'vegetables',
#   'easy',
#   'refrigerator',
#   'beginner-cook',
#   'dinner-party',
#   'holiday-event',
#   'low-fat',
#   'summer',
#   'vegetarian',
#   'salsas',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'healthy-2',
#   'low-in-something',
#   'melons',
#   'taste-mood',
#   'savory',
#   'equipment'],
#  290187: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'healthy',
#   'desserts',
#   'easy',
#   'microwave',
#   'kid-friendly',
#   'cakes',
#   'chocolate',
#   'dietary',
#   'low-cholesterol',
#   'healthy-2',
#   'low-in-something',
#   'taste-mood',
#   'sweet',
#   'equipment',
#   'number-of-servings'],
#  11361: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   '5-ingredients-or-less',
#   'very-low-carbs',
#   'appetizers',
#   'breakfast',
#   'lunch',
#   'main-dish',
#   'side-dishes',
#   'beef',
#   'pork',
#   'easy',
#   'dinner-party',
#   'finger-food',
#   'stove-top',
#   'dietary',
#   'low-carb',
#   'low-in-something',
#   'meat',
#   'equipment',
#   'presentation',
#   '3-steps-or-less'],
#  459738: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'appetizers',
#   'easy',
#   'taste-mood',
#   'savory'],
#  111198: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'desserts',
#   'eggs-dairy',
#   'fruit',
#   'african',
#   'oven',
#   'easy',
#   'holiday-event',
#   'kid-friendly',
#   'romantic',
#   'cakes',
#   'nuts',
#   'eggs',
#   'dietary',
#   'valentines-day',
#   'inexpensive',
#   'taste-mood',
#   'sweet',
#   'equipment'],
#  164636: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'healthy',
#   '5-ingredients-or-less',
#   'appetizers',
#   'easy',
#   'beginner-cook',
#   'low-fat',
#   'deep-fry',
#   'dietary',
#   'low-sodium',
#   'low-saturated-fat',
#   'inexpensive',
#   'low-in-something',
#   'number-of-servings',
#   '3-steps-or-less',
#   'technique'],
#  33246: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'healthy',
#   '5-ingredients-or-less',
#   'breads',
#   'easy',
#   'low-fat',
#   'dietary',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'quick-breads',
#   'low-in-something',
#   'number-of-servings',
#   '3-steps-or-less'],
#  302498: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-large-groups',
#   'main-dish',
#   'dietary',
#   'gluten-free',
#   'free-of-something',
#   'meat',
#   'number-of-servings'],
#  378067: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   '5-ingredients-or-less',
#   'main-dish',
#   'easy'],
#  165438: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-large-groups',
#   'desserts',
#   'cakes',
#   'number-of-servings'],
#  267159: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'healthy',
#   'desserts',
#   'cakes',
#   'chocolate',
#   'dietary'],
#  401283: ['weeknight',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'breads',
#   'main-dish',
#   'eggs-dairy',
#   'american',
#   'european',
#   'holiday-event',
#   'vegetarian',
#   'italian',
#   'grains',
#   'cheese',
#   'dietary',
#   'northeastern-united-states',
#   'yeast',
#   'pasta-rice-and-grains',
#   'taste-mood',
#   'savory'],
#  428566: ['weeknight',
#   '15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'healthy',
#   '5-ingredients-or-less',
#   'breakfast',
#   'lunch',
#   'snacks',
#   'fruit',
#   'easy',
#   'beginner-cook',
#   'diabetic',
#   'low-fat',
#   'vegetarian',
#   'dietary',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   'berries',
#   'blueberries',
#   'taste-mood',
#   'sweet',
#   'to-go',
#   'number-of-servings',
#   '3-steps-or-less'],
#  533190: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'breakfast',
#   'number-of-servings'],
#  478546: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'drop-cookies',
#   'desserts',
#   'american',
#   'easy',
#   'cookies-and-brownies',
#   'chocolate',
#   'taste-mood'],
#  40228: ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'very-low-carbs',
#   'main-dish',
#   'beef',
#   'american',
#   'easy',
#   'european',
#   'dinner-party',
#   'heirloom-historical',
#   'holiday-event',
#   'italian',
#   'stove-top',
#   'dietary',
#   'low-sodium',
#   'high-protein',
#   'low-carb',
#   'high-in-something',
#   'low-in-something',
#   'meat',
#   'roast-beef',
#   'equipment',
#   '4-hours-or-less'],
#  255985: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'pasta',
#   'easy',
#   'lasagna',
#   'dietary',
#   'one-dish-meal',
#   'low-carb',
#   'low-in-something',
#   'pasta-rice-and-grains',
#   '4-hours-or-less'],
#  402246: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'healthy',
#   'desserts',
#   'puddings-and-mousses',
#   'chocolate',
#   'dietary',
#   'low-in-something'],
#  180817: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-large-groups',
#   'breads',
#   'lunch',
#   'sandwiches',
#   'yeast',
#   'number-of-servings',
#   '4-hours-or-less'],
#  133326: ['time-to-make',
#   'course',
#   'preparation',
#   'casseroles',
#   'main-dish',
#   'oven',
#   'dietary',
#   'one-dish-meal',
#   'equipment',
#   '4-hours-or-less'],
#  513963: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   '5-ingredients-or-less',
#   'pies-and-tarts',
#   'desserts',
#   'easy',
#   'no-cook',
#   'pies',
#   'technique'],
#  213395: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'bisques-cream-soups',
#   'soups-stews',
#   'vegetables',
#   'easy',
#   'dietary',
#   'comfort-food',
#   'peppers',
#   'tomatoes',
#   'taste-mood',
#   'number-of-servings'],
#  27060: ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'breads',
#   'bread-machine',
#   'easy',
#   'grains',
#   'dietary',
#   'yeast',
#   'pasta-rice-and-grains',
#   'equipment',
#   'small-appliance',
#   'number-of-servings',
#   '3-steps-or-less'],
#  334201: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'pancakes-and-waffles',
#   'breakfast',
#   'eggs-dairy',
#   'easy',
#   'beginner-cook',
#   'grains',
#   'eggs',
#   'stove-top',
#   'comfort-food',
#   'pasta-rice-and-grains',
#   'taste-mood',
#   'equipment',
#   'presentation',
#   'served-hot'],
#  482111: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'beverages',
#   'eggs-dairy',
#   'easy',
#   'dinner-party',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'low-in-something',
#   'brunch',
#   'taste-mood',
#   'number-of-servings',
#   '3-steps-or-less',
#   'non-alcoholic',
#   'from-scratch'],
#  126072: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   '5-ingredients-or-less',
#   'pies-and-tarts',
#   'desserts',
#   'easy',
#   'crusts-pastry-dough-2',
#   'dietary',
#   'low-sodium',
#   'low-in-something',
#   'number-of-servings',
#   '3-steps-or-less'],
#  292147: ['time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'breads',
#   'bread-machine',
#   'easy',
#   'beginner-cook',
#   'yeast',
#   'equipment',
#   'small-appliance',
#   'number-of-servings',
#   '4-hours-or-less'],
#  221429: ['course',
#   'preparation',
#   'healthy',
#   'breads',
#   'bread-machine',
#   'dietary',
#   'low-cholesterol',
#   'healthy-2',
#   'low-in-something',
#   'equipment',
#   'small-appliance'],
#  218671: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'pancakes-and-waffles',
#   'breakfast',
#   'easy',
#   'kid-friendly',
#   'vegetarian',
#   'dietary',
#   'low-cholesterol',
#   'oamc-freezer-make-ahead',
#   'healthy-2',
#   'low-in-something',
#   'number-of-servings'],
#  121712: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   '5-ingredients-or-less',
#   'appetizers',
#   'easy',
#   'dietary',
#   'low-carb',
#   'low-in-something',
#   '3-steps-or-less'],
#  235003: ['course',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'beverages',
#   'easy',
#   'beginner-cook',
#   'low-fat',
#   'summer',
#   'cocktails',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'low-in-something',
#   'novelty',
#   '3-steps-or-less'],
#  43669: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'soups-stews',
#   'vegetables',
#   'easy',
#   'fall',
#   'vegetarian',
#   'winter',
#   'chowders',
#   'stove-top',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'low-calorie',
#   'comfort-food',
#   'inexpensive',
#   'low-in-something',
#   'corn',
#   'taste-mood',
#   'equipment'],
#  449768: ['course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   '5-ingredients-or-less',
#   'condiments-etc',
#   'vegetables',
#   'easy',
#   'vegetarian',
#   'dietary',
#   'gifts',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'healthy-2',
#   'low-in-something',
#   'tomatoes',
#   'novelty',
#   'technique'],
#  257696: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'low-protein',
#   'desserts',
#   'easy',
#   'cakes',
#   'dietary',
#   'low-cholesterol',
#   'low-in-something'],
#  53353: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'low-protein',
#   '5-ingredients-or-less',
#   'desserts',
#   'easy',
#   'holiday-event',
#   'kid-friendly',
#   'candy',
#   'dietary',
#   'low-sodium',
#   'comfort-food',
#   'low-in-something',
#   'taste-mood',
#   'number-of-servings',
#   '3-steps-or-less'],
#  115160: ['time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'for-large-groups',
#   'desserts',
#   'oven',
#   'european',
#   'cakes',
#   'russian',
#   'stove-top',
#   'equipment',
#   'number-of-servings',
#   '4-hours-or-less'],
#  140172: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'main-dish',
#   'easy',
#   'stews',
#   'dietary',
#   'number-of-servings',
#   '3-steps-or-less'],
#  392598: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'healthy',
#   'main-dish',
#   'low-fat',
#   'dietary',
#   'low-saturated-fat',
#   'low-in-something'],
#  356163: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'healthy',
#   'main-dish',
#   'beef',
#   'pasta',
#   'easy',
#   'dietary',
#   'one-dish-meal',
#   'low-calorie',
#   'low-in-something',
#   'meat',
#   'pasta-rice-and-grains'],
#  140173: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'pasta',
#   'seafood',
#   'easy',
#   'shrimp',
#   'dietary',
#   'pasta-rice-and-grains',
#   'shellfish',
#   '3-steps-or-less'],
#  289025: ['15-minutes-or-less',
#   'time-to-make',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'vegetables',
#   'easy',
#   'dietary',
#   'asparagus',
#   'number-of-servings'],
#  291409: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'healthy',
#   'main-dish',
#   'soups-stews',
#   'beans',
#   'easy',
#   'beginner-cook',
#   'low-fat',
#   'vegan',
#   'vegetarian',
#   'chili',
#   'dietary',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   '3-steps-or-less'],
#  282812: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'granola-and-porridge',
#   'breakfast',
#   'easy',
#   'number-of-servings'],
#  489337: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'casseroles',
#   'main-dish',
#   'easy',
#   'dietary',
#   '3-steps-or-less'],
#  250900: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'pies-and-tarts',
#   'desserts',
#   'fruit',
#   'pies',
#   'dietary',
#   'low-sodium',
#   'low-in-something',
#   'apples',
#   '4-hours-or-less'],
#  160494: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'desserts',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'cakes',
#   'dietary',
#   'inexpensive',
#   'egg-free',
#   'free-of-something',
#   'number-of-servings',
#   '3-steps-or-less'],
#  245950: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'low-protein',
#   'sauces',
#   'main-dish',
#   'condiments-etc',
#   'vegetables',
#   'canadian',
#   'easy',
#   'dietary',
#   'low-calorie',
#   'comfort-food',
#   'low-carb',
#   'savory-sauces',
#   'low-in-something',
#   'tomatoes',
#   'taste-mood'],
#  388578: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-large-groups',
#   'breads',
#   'fruit',
#   'kid-friendly',
#   'vegetarian',
#   'dietary',
#   'quick-breads',
#   'toddler-friendly',
#   'tropical-fruit',
#   'bananas',
#   'number-of-servings',
#   '4-hours-or-less'],
#  360881: ['time-to-make',
#   'course',
#   'preparation',
#   'breads',
#   'easy',
#   'beginner-cook',
#   'quick-breads',
#   '4-hours-or-less'],
#  453243: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   '5-ingredients-or-less',
#   'lunch',
#   'soups-stews',
#   'beans',
#   'beef',
#   'american',
#   'southwestern-united-states',
#   'tex-mex',
#   'easy',
#   'beginner-cook',
#   'comfort-food',
#   'inexpensive',
#   'chick-peas-garbanzos',
#   'meat',
#   'taste-mood'],
#  101260: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'appetizers',
#   'condiments-etc',
#   'dinner-party',
#   'dietary',
#   'number-of-servings'],
#  256464: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'very-low-carbs',
#   'side-dishes',
#   'vegetables',
#   'easy',
#   'beginner-cook',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'healthy-2',
#   'low-in-something',
#   'broccoli',
#   'number-of-servings'],
#  122791: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'desserts',
#   'lunch',
#   'snacks',
#   'eggs-dairy',
#   'fruit',
#   'easy',
#   'european',
#   'microwave',
#   'beginner-cook',
#   'kid-friendly',
#   'kosher',
#   'puddings-and-mousses',
#   'english',
#   'dietary',
#   'comfort-food',
#   'inexpensive',
#   'toddler-friendly',
#   'berries',
#   'strawberries',
#   'tropical-fruit',
#   'bananas',
#   'brunch',
#   'taste-mood',
#   'sweet',
#   'equipment',
#   'number-of-servings'],
#  214264: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'healthy',
#   'beverages',
#   'easy',
#   'low-fat',
#   'smoothies',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'shakes',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'low-in-something',
#   'number-of-servings',
#   '3-steps-or-less'],
#  416599: ['weeknight',
#   '15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'healthy',
#   'beverages',
#   'breakfast',
#   'microwave',
#   'low-fat',
#   'chocolate',
#   'dietary',
#   'gluten-free',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'high-calcium',
#   'comfort-food',
#   'inexpensive',
#   'egg-free',
#   'free-of-something',
#   'high-in-something',
#   'low-in-something',
#   'taste-mood',
#   'sweet',
#   'equipment',
#   'number-of-servings'],
#  162657: ['lactose',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'side-dishes',
#   'potatoes',
#   'vegetables',
#   'easy',
#   'beginner-cook',
#   'dinner-party',
#   'holiday-event',
#   'spring',
#   'dietary',
#   'seasonal',
#   'high-fiber',
#   'inexpensive',
#   'egg-free',
#   'free-of-something',
#   'high-in-something',
#   'number-of-servings'],
#  166483: ['course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'poultry',
#   'rice',
#   'vegetables',
#   'easy',
#   'beginner-cook',
#   'diabetic',
#   'kid-friendly',
#   'chicken',
#   'dietary',
#   'one-dish-meal',
#   'comfort-food',
#   'brown-bag',
#   'inexpensive',
#   'egg-free',
#   'free-of-something',
#   'toddler-friendly',
#   'meat',
#   'pasta-rice-and-grains',
#   'white-rice',
#   'broccoli',
#   'brunch',
#   'taste-mood',
#   'to-go'],
#  385415: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'sauces',
#   'appetizers',
#   'canning',
#   'condiments-etc',
#   'vegetables',
#   'american',
#   'mexican',
#   'southwestern-united-states',
#   'tex-mex',
#   'summer',
#   'vegan',
#   'vegetarian',
#   'salsas',
#   'stove-top',
#   'dietary',
#   'seasonal',
#   'squash',
#   'tomatoes',
#   'taste-mood',
#   'savory',
#   'equipment',
#   'technique',
#   'water-bath'],
#  120462: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'eggs-dairy',
#   'pasta',
#   'easy',
#   'vegetarian',
#   'cheese',
#   'dietary',
#   'high-calcium',
#   'comfort-food',
#   'high-in-something',
#   'pasta-rice-and-grains',
#   'penne',
#   'taste-mood',
#   '3-steps-or-less'],
#  128544: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'desserts',
#   'eggs-dairy',
#   'dinner-party',
#   'cakes',
#   'chocolate',
#   'eggs',
#   'dietary',
#   'gluten-free',
#   'free-of-something',
#   '4-hours-or-less'],
#  257111: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'breads',
#   'lunch',
#   'snacks',
#   'eggs-dairy',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'cheese',
#   'dietary',
#   'gifts',
#   'low-sodium',
#   'comfort-food',
#   'inexpensive',
#   'low-in-something',
#   'taste-mood',
#   '4-hours-or-less'],
#  274469: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'desserts',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'frozen-desserts',
#   'dietary',
#   'comfort-food',
#   'taste-mood',
#   'number-of-servings',
#   '3-steps-or-less'],
#  432661: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'condiments-etc',
#   'easy',
#   'herb-and-spice-mixes',
#   'dietary',
#   'low-sodium',
#   'cooking-mixes',
#   'low-in-something',
#   'peanut-butter'],
#  388488: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'chili',
#   'spicy',
#   'meat',
#   'taste-mood',
#   '4-hours-or-less'],
#  353419: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'healthy',
#   'main-dish',
#   'side-dishes',
#   'dietary'],
#  296654: ['15-minutes-or-less',
# ...
#   'low-in-something',
#   'apples',
#   'taste-mood',
#   'sweet',
#   'number-of-servings',
#   '3-steps-or-less'],
#  39402: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'for-1-or-2',
#   'beverages',
#   'fruit',
#   'american',
#   'easy',
#   'no-cook',
#   'kid-friendly',
#   'smoothies',
#   'food-processor-blender',
#   'dietary',
#   'seasonal',
#   'comfort-food',
#   'apples',
#   'taste-mood',
#   'equipment',
#   'small-appliance',
#   'number-of-servings',
#   '3-steps-or-less',
#   'technique'],
#  57771: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'north-american',
#   'for-large-groups',
#   'desserts',
#   'fruit',
#   'american',
#   'cakes',
#   'northeastern-united-states',
#   'apples',
#   'number-of-servings'],
#  127637: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'breads',
#   'fruit',
#   'easy',
#   'potluck',
#   'coffee-cakes',
#   'dietary',
#   'comfort-food',
#   'apples',
#   'brunch',
#   'taste-mood',
#   'to-go'],
#  140850: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-large-groups',
#   'breads',
#   'breakfast',
#   'eggs-dairy',
#   'fruit',
#   'oven',
#   'fall',
#   'kid-friendly',
#   'coffee-cakes',
#   'nuts',
#   'eggs',
#   'dietary',
#   'gifts',
#   'seasonal',
#   'comfort-food',
#   'apples',
#   'brunch',
#   'taste-mood',
#   'equipment',
#   'number-of-servings',
#   '4-hours-or-less'],
#  190858: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'breakfast',
#   'lunch',
#   'snacks',
#   'fruit',
#   'easy',
#   'no-cook',
#   'kid-friendly',
#   'vegan',
#   'vegetarian',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'toddler-friendly',
#   'low-in-something',
#   'apples',
#   'tropical-fruit',
#   'bananas',
#   'number-of-servings',
#   'technique'],
#  388465: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'cobblers-and-crisps',
#   'breakfast',
#   'desserts',
#   'fruit',
#   'dietary',
#   'low-in-something',
#   'apples',
#   'brunch'],
#  102670: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'breads',
#   'desserts',
#   'fruit',
#   'cakes',
#   'coffee-cakes',
#   'apples',
#   '4-hours-or-less'],
#  78210: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'breads',
#   'eggs-dairy',
#   'fruit',
#   'muffins',
#   'cheese',
#   'quick-breads',
#   'apples',
#   'number-of-servings'],
#  338725: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'cupcakes',
#   'desserts',
#   'fruit',
#   'cakes',
#   'apples'],
#  175891: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'desserts',
#   'fruit',
#   'french',
#   'oven',
#   'european',
#   'stove-top',
#   'dietary',
#   'low-sodium',
#   'low-in-something',
#   'apples',
#   'brunch',
#   'equipment'],
#  75960: ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'stuffings-dressings',
#   'side-dishes',
#   'fruit',
#   'dietary',
#   'apples',
#   '4-hours-or-less'],
#  399189: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'low-protein',
#   'healthy',
#   'beverages',
#   'low-fat',
#   'punch',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'low-in-something'],
#  142852: ['lactose',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'yams-sweet-potatoes',
#   'side-dishes',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'dinner-party',
#   'fall',
#   'holiday-event',
#   'vegetarian',
#   'dietary',
#   'thanksgiving',
#   'seasonal',
#   'comfort-food',
#   'free-of-something',
#   'apples',
#   'taste-mood',
#   '4-hours-or-less'],
#  71833: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'stuffings-dressings',
#   'side-dishes',
#   'fruit',
#   'oven',
#   'easy',
#   'dinner-party',
#   'stove-top',
#   'dietary',
#   'apples',
#   'equipment',
#   'number-of-servings',
#   '3-steps-or-less'],
#  40478: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   '5-ingredients-or-less',
#   'desserts',
#   'fruit',
#   'oven',
#   'easy',
#   'dinner-party',
#   'fall',
#   'holiday-event',
#   'kid-friendly',
#   'summer',
#   'easter',
#   'dietary',
#   'christmas',
#   'new-years',
#   'thanksgiving',
#   'low-sodium',
#   'seasonal',
#   'valentines-day',
#   'low-in-something',
#   'apples',
#   'equipment',
#   'number-of-servings'],
#  54095: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'lunch',
#   'main-dish',
#   'fruit',
#   'poultry',
#   'oven',
#   'broil',
#   'turkey',
#   'dietary',
#   'sandwiches',
#   'brown-bag',
#   'apples',
#   'meat',
#   'to-go',
#   'equipment'],
#  12672: ['60-minutes-or-less',
#   'time-to-make',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'low-protein',
#   'casseroles',
#   'fruit',
#   'vegetables',
#   'canadian',
#   'oven',
#   'easy',
#   'dinner-party',
#   'dietary',
#   'low-sodium',
#   'gluten-free',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'free-of-something',
#   'low-in-something',
#   'apples',
#   'equipment'],
#  50936: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'for-1-or-2',
#   'low-protein',
#   'desserts',
#   'fruit',
#   'american',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'comfort-food',
#   'low-in-something',
#   'apples',
#   'taste-mood',
#   'number-of-servings'],
#  93365: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'appetizers',
#   'soups-stews',
#   'eggs-dairy',
#   'fruit',
#   'dinner-party',
#   'holiday-event',
#   'cheese',
#   'dietary',
#   'low-sodium',
#   'low-carb',
#   'inexpensive',
#   'low-in-something',
#   'apples',
#   'brunch',
#   'presentation',
#   'served-cold'],
#  272034: ['30-minutes-or-less',
#   'time-to-make',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'fruit',
#   'easy',
#   'beginner-cook',
#   'dietary',
#   'low-cholesterol',
#   'low-in-something',
#   'apples',
#   '3-steps-or-less'],
#  40589: ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'desserts',
#   'fruit',
#   'oven',
#   'cookies-and-brownies',
#   'bar-cookies',
#   'dietary',
#   'apples',
#   'equipment',
#   'number-of-servings',
#   '4-hours-or-less'],
#  224452: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'healthy',
#   'granola-and-porridge',
#   'breakfast',
#   'fruit',
#   'easy',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   'apples'],
#  400912: ['time-to-make', 'preparation', '4-hours-or-less'],
#  378468: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'low-protein',
#   'healthy',
#   'desserts',
#   'salads',
#   'fruit',
#   'vegetables',
#   'easy',
#   'european',
#   'dinner-party',
#   'spring',
#   'summer',
#   'vegetarian',
#   'english',
#   'nuts',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'healthy-2',
#   'low-in-something',
#   'apples',
#   'presentation',
#   'served-cold',
#   '3-steps-or-less',
#   '4-hours-or-less'],
#  146444: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'breads',
#   'fruit',
#   'american',
#   'nuts',
#   'grains',
#   'gifts',
#   'midwestern',
#   'northeastern-united-states',
#   'quick-breads',
#   'apples',
#   'pasta-rice-and-grains',
#   'taste-mood',
#   'sweet',
#   '4-hours-or-less'],
#  456852: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'soups-stews',
#   'european',
#   'swiss'],
#  107851: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'pies-and-tarts',
#   'desserts',
#   'fruit',
#   'canadian',
#   'oven',
#   'dinner-party',
#   'holiday-event',
#   'pies',
#   'british-columbian',
#   'ontario',
#   'apples',
#   'equipment'],
#  89021: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'salads',
#   'fruit',
#   'vegetables',
#   'easy',
#   'no-cook',
#   'potluck',
#   'low-fat',
#   'picnic',
#   'summer',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'low-saturated-fat',
#   'low-calorie',
#   'brown-bag',
#   'healthy-2',
#   'low-in-something',
#   'apples',
#   'squash',
#   'to-go',
#   '3-steps-or-less',
#   'technique'],
#  330040: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'healthy',
#   'lunch',
#   'snacks',
#   'eggs-dairy',
#   'fruit',
#   'easy',
#   'beginner-cook',
#   'low-fat',
#   'cheese',
#   'dietary',
#   'low-cholesterol',
#   'sandwiches',
#   'low-saturated-fat',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   'apples',
#   'number-of-servings'],
#  452590: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'poultry',
#   'chicken',
#   'dietary',
#   'low-sodium',
#   'low-calorie',
#   'low-carb',
#   'low-in-something',
#   'meat',
#   'chicken-breasts'],
#  403819: ['occasion', 'holiday-event', 'christmas'],
#  420689: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'breakfast',
#   'eggs-dairy',
#   'eggs',
#   'brunch',
#   '4-hours-or-less'],
#  191150: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'appetizers',
#   'lunch',
#   'fruit',
#   'easy',
#   'dinner-party',
#   'finger-food',
#   'vegetarian',
#   'dietary',
#   'apples',
#   'brunch',
#   'presentation'],
#  74520: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'jams-and-preserves',
#   'sauces',
#   'chutneys',
#   'appetizers',
#   'canning',
#   'lunch',
#   'condiments-etc',
#   'snacks',
#   'fruit',
#   'easy',
#   'potluck',
#   'dinner-party',
#   'holiday-event',
#   'kosher',
#   'vegan',
#   'vegetarian',
#   'spreads',
#   'stove-top',
#   'dietary',
#   'spicy',
#   'sandwiches',
#   'savory-sauces',
#   'apples',
#   'brunch',
#   'taste-mood',
#   'savory',
#   'to-go',
#   'equipment',
#   'number-of-servings',
#   'technique',
#   'unprocessed-freezer'],
#  460292: ['bacon',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'north-american',
#   'for-1-or-2',
#   'pancakes-and-waffles',
#   'breakfast',
#   'pork',
#   'diabetic',
#   'dietary',
#   'meat',
#   'number-of-servings',
#   'presentation',
#   'served-hot',
#   'from-scratch'],
#  130992: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'jams-and-preserves',
#   'condiments-etc',
#   'fruit',
#   'easy',
#   'european',
#   'beginner-cook',
#   'kid-friendly',
#   'low-fat',
#   'dietary',
#   'gifts',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'inexpensive',
#   'toddler-friendly',
#   'low-in-something',
#   'apples',
#   'tropical-fruit',
#   'bananas'],
#  346687: ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'healthy',
#   'jams-and-preserves',
#   'condiments-etc',
#   'fruit',
#   'easy',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-in-something',
#   'apples',
#   'berries',
#   'raspberries'],
#  169993: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'pies-and-tarts',
#   'desserts',
#   'fruit',
#   'oven',
#   'dinner-party',
#   'vegetarian',
#   'pies',
#   'dietary',
#   'low-sodium',
#   'low-in-something',
#   'apples',
#   'berries',
#   'blueberries',
#   'taste-mood',
#   'sweet',
#   'equipment',
#   '4-hours-or-less'],
#  260352: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'for-1-or-2',
#   'omelets-and-frittatas',
#   'breakfast',
#   'eggs-dairy',
#   'fruit',
#   'french',
#   'european',
#   'diabetic',
#   'vegetarian',
#   'cheese',
#   'eggs',
#   'dietary',
#   'low-carb',
#   'low-in-something',
#   'apples',
#   'number-of-servings'],
#  158382: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'healthy',
#   'condiments-etc',
#   'fruit',
#   'european',
#   'holiday-event',
#   'kid-friendly',
#   'kosher',
#   'nuts',
#   'food-processor-blender',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'passover',
#   'healthy-2',
#   'low-in-something',
#   'apples',
#   'pitted-fruit',
#   'cherries',
#   'equipment',
#   'small-appliance'],
#  449725: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   '5-ingredients-or-less',
#   'main-dish',
#   'poultry',
#   'easy',
#   'chicken',
#   'meat',
#   'burgers'],
#  50851: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'breads',
#   'fruit',
#   'american',
#   'oven',
#   'easy',
#   'finger-food',
#   'muffins',
#   'dietary',
#   'quick-breads',
#   'apples',
#   'equipment',
#   'presentation'],
#  521251: ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'breakfast',
#   'desserts',
#   'fruit',
#   'easy',
#   'microwave',
#   'beginner-cook',
#   'cakes',
#   'dietary',
#   'low-cholesterol',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   'apples',
#   'equipment',
#   'small-appliance',
#   'number-of-servings'],
#  205500: ['lactose',
#   '30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'pancakes-and-waffles',
#   'breakfast',
#   'fruit',
#   'vegan',
#   'vegetarian',
#   'dietary',
#   'egg-free',
#   'free-of-something',
#   'apples',
#   'brunch'],
#  331846: ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'cobblers-and-crisps',
#   'desserts',
#   'fruit',
#   'fall',
#   'winter',
#   'dietary',
#   'low-sodium',
#   'seasonal',
#   'low-in-something',
#   'apples',
#   'berries',
#   '4-hours-or-less'],
#  69045: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'lunch',
#   'snacks',
#   'fruit',
#   'seafood',
#   'oven',
#   'easy',
#   'fish',
#   'broil',
#   'dietary',
#   'sandwiches',
#   'tuna',
#   'apples',
#   'saltwater-fish',
#   'equipment'],
#  31748: ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'beef',
#   'fruit',
#   'vegetables',
#   'oven',
#   'refrigerator',
#   'dinner-party',
#   'dietary',
#   'apples',
#   'meat',
#   'equipment',
#   '4-hours-or-less'],
#  20143: ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'very-low-carbs',
#   'main-dish',
#   'fruit',
#   'pork',
#   'german',
#   'oven',
#   'european',
#   'roast',
#   'dinner-party',
#   'dietary',
#   'low-sodium',
#   'high-protein',
#   'low-carb',
#   'high-in-something',
#   'low-in-something',
#   'apples',
#   'meat',
#   'equipment'],
#  524289: ['bacon',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'north-american',
#   'main-dish',
#   'pork',
#   'american',
#   'easy',
#   'dietary',
#   'low-sodium',
#   'high-protein',
#   'low-carb',
#   'high-in-something',
#   'low-in-something',
#   'meat',
#   'pork-chops',
#   'pork-loins',
#   '3-steps-or-less'],
#  203930: ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'appetizers',
#   'fruit',
#   'finger-food',
#   'apples',
#   'presentation'],
#  ...}

# %%
with open("./tags_sample.json", "w") as file:
    json.dump(dictionary_1, file)

# %%
with open("./tags_sample.json", "r") as file:
    data = json.load(file)
data
# Out:
# {'44123': ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'soups-stews',
#   'beans',
#   'poultry',
#   'american',
#   'chicken',
#   'stove-top',
#   'dietary',
#   'gluten-free',
#   'comfort-food',
#   'californian',
#   'black-beans',
#   'free-of-something',
#   'meat',
#   'taste-mood',
#   'equipment',
#   'grilling',
#   '4-hours-or-less'],
#  '67664': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'desserts',
#   'lunch',
#   'snacks',
#   'easy',
#   'kid-friendly',
#   'low-fat',
#   'summer',
#   'frozen-desserts',
#   'freezer',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'low-saturated-fat',
#   'inexpensive',
#   'healthy-2',
#   'toddler-friendly',
#   'low-in-something',
#   'equipment',
#   'small-appliance',
#   'mixer',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '38798': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'appetizers',
#   'side-dishes',
#   'vegetables',
#   'oven',
#   'refrigerator',
#   'freezer',
#   'dietary',
#   'oamc-freezer-make-ahead',
#   'low-carb',
#   'low-in-something',
#   'equipment',
#   'number-of-servings'],
#  '35173': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'lunch',
#   'main-dish',
#   'oven',
#   'easy',
#   'dietary',
#   'sandwiches',
#   'equipment'],
#  '84797': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'sauces',
#   'appetizers',
#   'main-dish',
#   'condiments-etc',
#   'beef',
#   'dinner-party',
#   'holiday-event',
#   'dietary',
#   'valentines-day',
#   'savory-sauces',
#   'meat',
#   'number-of-servings'],
#  '44045': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'side-dishes',
#   'vegetables',
#   'american',
#   'easy',
#   'diabetic',
#   'dinner-party',
#   'heirloom-historical',
#   'holiday-event',
#   'kid-friendly',
#   'vegetarian',
#   'stove-top',
#   'dietary',
#   'christmas',
#   'thanksgiving',
#   'comfort-food',
#   'amish-mennonite',
#   'northeastern-united-states',
#   'corn',
#   'taste-mood',
#   'equipment',
#   'number-of-servings'],
#  '107229': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'main-dish',
#   'asian',
#   'easy',
#   'diabetic',
#   'kosher',
#   'dietary',
#   'pasta-rice-and-grains'],
#  '95926': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   '5-ingredients-or-less',
#   'lunch',
#   'fruit',
#   'american',
#   'southern-united-states',
#   'easy',
#   'european',
#   'beginner-cook',
#   'finger-food',
#   'kid-friendly',
#   'vegetarian',
#   'dietary',
#   'sandwiches',
#   'inexpensive',
#   'toddler-friendly',
#   'tropical-fruit',
#   'bananas',
#   'brunch',
#   'taste-mood',
#   'sweet',
#   'to-go',
#   'presentation'],
#  '453467': ['60-minutes-or-less',
#   'time-to-make',
#   'cuisine',
#   'preparation',
#   'north-american',
#   'for-large-groups',
#   'canadian',
#   'british-columbian',
#   'number-of-servings'],
#  '306168': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'side-dishes',
#   'vegetables',
#   'easy',
#   'beginner-cook',
#   'broccoli'],
#  '50662': ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'casseroles',
#   'main-dish',
#   'beef',
#   'oven',
#   'one-dish-meal',
#   'comfort-food',
#   'meat',
#   'taste-mood',
#   'equipment',
#   '4-hours-or-less'],
#  '118843': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'drop-cookies',
#   'desserts',
#   'easy',
#   'cookies-and-brownies',
#   '3-steps-or-less'],
#  '69190': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'low-protein',
#   'healthy',
#   'soups-stews',
#   'potatoes',
#   'vegetables',
#   'kid-friendly',
#   'dietary',
#   'low-cholesterol',
#   'low-calorie',
#   'comfort-food',
#   'low-carb',
#   'healthy-2',
#   'low-in-something',
#   'taste-mood',
#   'presentation',
#   'served-hot',
#   '4-hours-or-less'],
#  '503475': ['danish',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'pancakes-and-waffles',
#   'breakfast',
#   'scandinavian',
#   'european'],
#  '149593': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'breads',
#   'lunch',
#   'eggs-dairy',
#   'oven',
#   'easy',
#   'beginner-cook',
#   'holiday-event',
#   'muffins',
#   'christmas',
#   'thanksgiving',
#   'quick-breads',
#   'brunch',
#   'taste-mood',
#   'sweet',
#   'equipment'],
#  '200148': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'desserts',
#   'beans',
#   'vegan',
#   'vegetarian',
#   'cheesecake',
#   'dietary',
#   'soy-tofu',
#   '4-hours-or-less'],
#  '310570': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'savory-pies',
#   'main-dish',
#   'eggs-dairy',
#   'easy',
#   'european',
#   'cheese',
#   '4-hours-or-less'],
#  '95534': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'very-low-carbs',
#   'lunch',
#   'main-dish',
#   'beef',
#   'american',
#   'oven',
#   'easy',
#   'kid-friendly',
#   'dietary',
#   'low-sodium',
#   'sandwiches',
#   'high-protein',
#   'low-carb',
#   'midwestern',
#   'high-in-something',
#   'low-in-something',
#   'meat',
#   'roast-beef',
#   'taste-mood',
#   'savory',
#   'equipment'],
#  '109818': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   '5-ingredients-or-less',
#   'side-dishes',
#   'vegetables',
#   'easy',
#   'dietary'],
#  '66932': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'side-dishes',
#   'rice',
#   'asian',
#   'microwave',
#   'stove-top',
#   'dietary',
#   'low-sodium',
#   'low-in-something',
#   'pasta-rice-and-grains',
#   'brown-rice',
#   'equipment'],
#  '226001': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'desserts',
#   'inexpensive'],
#  '125195': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'north-american',
#   'salads',
#   'side-dishes',
#   'american',
#   'easy',
#   'midwestern',
#   '3-steps-or-less'],
#  '141939': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'eggs-dairy',
#   'poultry',
#   'vegetables',
#   'oven',
#   'easy',
#   'refrigerator',
#   'dinner-party',
#   'holiday-event',
#   'chicken',
#   'dietary',
#   'spicy',
#   'comfort-food',
#   'meat',
#   'onions',
#   'taste-mood',
#   'equipment'],
#  '250883': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-large-groups',
#   '5-ingredients-or-less',
#   'appetizers',
#   'lunch',
#   'snacks',
#   'eggs-dairy',
#   'easy',
#   'beginner-cook',
#   'finger-food',
#   'dips',
#   'cheese',
#   'dietary',
#   'number-of-servings',
#   'presentation',
#   'served-cold',
#   '4-hours-or-less'],
#  '120297': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'healthy',
#   'side-dishes',
#   'potatoes',
#   'vegetables',
#   'asian',
#   'middle-eastern',
#   'dinner-party',
#   'low-fat',
#   'vegetarian',
#   'lebanese',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'low-in-something',
#   '4-hours-or-less'],
#  '147477': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'appetizers',
#   'eggs-dairy',
#   'seafood',
#   'easy',
#   'dips',
#   'spreads',
#   'cheese',
#   'dietary',
#   'high-calcium',
#   'high-protein',
#   'low-carb',
#   'high-in-something',
#   'low-in-something',
#   'shellfish',
#   'clams',
#   '3-steps-or-less'],
#  '223349': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'seafood',
#   'vegetables',
#   'easy',
#   'diabetic',
#   'shrimp',
#   'dietary',
#   'low-sodium',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'low-in-something',
#   'shellfish'],
#  '60938': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'appetizers',
#   'lunch',
#   'side-dishes',
#   'snacks',
#   'eggs-dairy',
#   'potatoes',
#   'vegetables',
#   'oven',
#   'dinner-party',
#   'finger-food',
#   'cheese',
#   'deep-fry',
#   'stove-top',
#   'dietary',
#   'comfort-food',
#   'taste-mood',
#   'equipment',
#   'presentation',
#   'served-hot',
#   'technique'],
#  '302399': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   '5-ingredients-or-less',
#   'breads',
#   'easy'],
#  '342620': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'main-dish',
#   'beef',
#   'american',
#   'southern-united-states',
#   'oven',
#   'easy',
#   'beginner-cook',
#   'comfort-food',
#   'ground-beef',
#   'meat',
#   'taste-mood',
#   'equipment',
#   '4-hours-or-less'],
#  '296983': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'for-1-or-2',
#   'appetizers',
#   'salads',
#   'potatoes',
#   'vegetables',
#   'greek',
#   'easy',
#   'european',
#   'vegan',
#   'vegetarian',
#   'dips',
#   'dietary',
#   'number-of-servings'],
#  '166089': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'north-american',
#   '5-ingredients-or-less',
#   'main-dish',
#   'poultry',
#   'american',
#   'easy',
#   'kid-friendly',
#   'chicken',
#   'dietary',
#   'oamc-freezer-make-ahead',
#   'high-protein',
#   'low-carb',
#   'inexpensive',
#   'high-in-something',
#   'low-in-something',
#   'meat',
#   'number-of-servings'],
#  '129581': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'desserts',
#   'cakes',
#   'chocolate',
#   'dietary',
#   'low-in-something',
#   '4-hours-or-less'],
#  '116741': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'beverages',
#   'breakfast',
#   'vegetables',
#   'easy',
#   'low-fat',
#   'vegetarian',
#   'dietary',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   'brunch',
#   '3-steps-or-less'],
#  '325714': ['time-to-make',
#   'course',
#   'preparation',
#   'desserts',
#   '1-day-or-more',
#   'cakes'],
#  '276594': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'healthy',
#   'appetizers',
#   'main-dish',
#   'beef',
#   'dietary',
#   'ground-beef',
#   'meat',
#   'brunch',
#   'novelty'],
#  '487173': ['weeknight',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'eggs-dairy',
#   'easy',
#   'european',
#   'italian',
#   'cheese',
#   'dietary',
#   'low-carb',
#   'low-in-something',
#   'meat',
#   'from-scratch'],
#  '289671': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'low-protein',
#   'beverages',
#   'eggs-dairy',
#   'easy',
#   'refrigerator',
#   'beginner-cook',
#   'summer',
#   'chocolate',
#   'smoothies',
#   'food-processor-blender',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'shakes',
#   'low-calorie',
#   'low-carb',
#   'low-in-something',
#   'equipment',
#   'small-appliance',
#   'number-of-servings'],
#  '44050': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'low-protein',
#   '5-ingredients-or-less',
#   'desserts',
#   'american',
#   'easy',
#   'heirloom-historical',
#   'holiday-event',
#   'cakes',
#   'dietary',
#   'cake-fillings-and-frostings',
#   'amish-mennonite',
#   'northeastern-united-states',
#   'low-in-something',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '447429': ['weeknight',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'soups-stews',
#   'beef',
#   'american',
#   'kid-friendly',
#   'dietary',
#   'low-calorie',
#   'comfort-food',
#   'low-carb',
#   'ground-beef',
#   'low-in-something',
#   'meat',
#   'taste-mood'],
#  '137701': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'eggs-dairy',
#   'rice',
#   'european',
#   'winter',
#   'italian',
#   'cheese',
#   'dietary',
#   'one-dish-meal',
#   'seasonal',
#   'comfort-food',
#   'pasta-rice-and-grains',
#   'taste-mood',
#   'savory',
#   'presentation',
#   'served-hot'],
#  '292568': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   '5-ingredients-or-less',
#   'desserts',
#   'easy',
#   'cakes',
#   'dietary',
#   'high-calcium',
#   'high-in-something',
#   '3-steps-or-less'],
#  '299989': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'main-dish',
#   'salads',
#   'beans',
#   'poultry',
#   'rice',
#   'mexican',
#   'easy',
#   'dinner-party',
#   'kid-friendly',
#   'spring',
#   'summer',
#   'chicken',
#   'stove-top',
#   'dietary',
#   'copycat',
#   'one-dish-meal',
#   'seasonal',
#   'inexpensive',
#   'black-beans',
#   'meat',
#   'pasta-rice-and-grains',
#   'novelty',
#   'equipment'],
#  '63346': ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'desserts',
#   'vegetables',
#   'oven',
#   'potluck',
#   'dinner-party',
#   'kid-friendly',
#   'cakes',
#   'dietary',
#   'to-go',
#   'equipment',
#   'small-appliance',
#   'mixer',
#   'presentation',
#   'served-cold',
#   '4-hours-or-less'],
#  '342619': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'beverages',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'low-fat',
#   'vegan',
#   'vegetarian',
#   'smoothies',
#   'food-processor-blender',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'infant-baby-friendly',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'toddler-friendly',
#   'low-in-something',
#   'taste-mood',
#   'sweet',
#   'equipment',
#   'small-appliance',
#   '3-steps-or-less'],
#  '383120': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'lunch',
#   'main-dish',
#   'snacks',
#   'potluck',
#   'one-dish-meal',
#   'inexpensive',
#   'pasta-rice-and-grains',
#   'taste-mood',
#   'savory',
#   'to-go'],
#  '367987': ['lactose',
#   '15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'salads',
#   'canadian',
#   'easy',
#   'no-cook',
#   'beginner-cook',
#   'salad-dressings',
#   'dietary',
#   'gluten-free',
#   'inexpensive',
#   'egg-free',
#   'quebec',
#   'free-of-something',
#   'taste-mood',
#   'savory',
#   '3-steps-or-less',
#   'technique'],
#  '463219': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'lunch',
#   'main-dish',
#   'eggs-dairy',
#   'pasta',
#   'vegetables',
#   'easy',
#   'kid-friendly',
#   'cheese',
#   'stove-top',
#   'dietary',
#   'pasta-rice-and-grains',
#   'onions',
#   'equipment',
#   '3-steps-or-less'],
#  '39172': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'breads',
#   'fruit',
#   'muffins',
#   'dietary',
#   'quick-breads',
#   'tropical-fruit',
#   'pineapple',
#   'number-of-servings'],
#  '216068': ['course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'beef',
#   'easy',
#   'stews',
#   'crock-pot-slow-cooker',
#   'meat',
#   'equipment',
#   '3-steps-or-less'],
#  '173730': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'soups-stews',
#   'potatoes',
#   'poultry',
#   'vegetables',
#   'easy',
#   'european',
#   'beginner-cook',
#   'winter',
#   'chicken',
#   'stove-top',
#   'seasonal',
#   'inexpensive',
#   'meat',
#   'equipment',
#   'small-appliance',
#   'mixer',
#   'presentation',
#   'served-hot',
#   '4-hours-or-less'],
#  '287778': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'appetizers',
#   'lunch',
#   'snacks',
#   'easy',
#   'kid-friendly',
#   'dietary'],
#  '437637': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'cobblers-and-crisps',
#   'desserts',
#   'fruit',
#   'dietary',
#   'comfort-food',
#   'low-in-something',
#   'taste-mood',
#   'sweet',
#   '4-hours-or-less'],
#  '123115': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'salads',
#   'dietary'],
#  '371549': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'poultry',
#   'easy',
#   'summer',
#   'turkey',
#   'seasonal',
#   'meat',
#   'equipment',
#   'grilling',
#   '3-steps-or-less',
#   'burgers',
#   'turkey-burgers'],
#  '376813': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'soups-stews',
#   'pasta',
#   'poultry',
#   'vegetables',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'winter',
#   'chicken',
#   'dietary',
#   'seasonal',
#   'comfort-food',
#   'inexpensive',
#   'meat',
#   'pasta-rice-and-grains',
#   'carrots',
#   'taste-mood',
#   'savory'],
#  '134085': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'pancakes-and-waffles',
#   'breakfast',
#   'lunch',
#   'american',
#   'kid-friendly',
#   'dietary',
#   'copycat',
#   'sandwiches',
#   'meat',
#   'novelty'],
#  '390230': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-large-groups',
#   'main-dish',
#   'soups-stews',
#   'poultry',
#   'holiday-event',
#   'chili',
#   'chicken',
#   'meat',
#   'superbowl',
#   'number-of-servings',
#   '4-hours-or-less'],
#  '401605': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'yams-sweet-potatoes',
#   'low-protein',
#   'side-dishes',
#   'potatoes',
#   'vegetables',
#   'holiday-event',
#   'dietary',
#   'christmas',
#   'thanksgiving',
#   'low-sodium',
#   'low-in-something'],
#  '306590': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'side-dishes',
#   'potatoes',
#   'vegetables',
#   'easy',
#   '3-steps-or-less'],
#  '303944': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'side-dishes',
#   'vegetables',
#   'dinner-party',
#   'holiday-event',
#   'dietary',
#   'low-carb',
#   'low-in-something'],
#  '299968': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'beans',
#   'vegan',
#   'vegetarian',
#   'dietary',
#   '4-hours-or-less'],
#  '192542': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'poultry',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'chicken',
#   'dietary',
#   'high-protein',
#   'inexpensive',
#   'high-in-something',
#   'toddler-friendly',
#   'meat',
#   'chicken-breasts'],
#  '147563': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'potatoes',
#   'poultry',
#   'vegetables',
#   'easy',
#   'chicken',
#   'dietary',
#   'meat',
#   'chicken-breasts'],
#  '193719': ['time-to-make',
#   'course',
#   'preparation',
#   'low-protein',
#   'healthy',
#   'main-dish',
#   'side-dishes',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-calorie',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   '4-hours-or-less'],
#  '38852': ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'beef',
#   'oven',
#   'kid-friendly',
#   'dietary',
#   'comfort-food',
#   'ground-beef',
#   'meat',
#   'taste-mood',
#   'equipment',
#   '4-hours-or-less'],
#  '250232': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'north-american',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'side-dishes',
#   'potatoes',
#   'vegetables',
#   'american',
#   'oven',
#   'easy',
#   'beginner-cook',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'low-in-something',
#   'equipment'],
#  '134787': ['30-minutes-or-less',
#   'time-to-make',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'very-low-carbs',
#   'canning',
#   'vegetables',
#   'easy',
#   'no-cook',
#   'holiday-event',
#   'low-fat',
#   'dietary',
#   'gifts',
#   'christmas',
#   'thanksgiving',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'inexpensive',
#   'low-in-something',
#   'technique'],
#  '437219': ['time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'snacks',
#   'american',
#   'dinner-party',
#   'dietary',
#   '4-hours-or-less'],
#  '77380': ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'appetizers',
#   'eggs-dairy',
#   'holiday-event',
#   'spreads',
#   'cheese',
#   'dietary',
#   'new-years',
#   'high-calcium',
#   'high-protein',
#   'low-carb',
#   'high-in-something',
#   'low-in-something',
#   'superbowl',
#   'number-of-servings',
#   'presentation',
#   'served-cold'],
#  '21357': ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'very-low-carbs',
#   'main-dish',
#   'pork',
#   'oven',
#   'easy',
#   'dinner-party',
#   'dietary',
#   'comfort-food',
#   'low-carb',
#   'low-in-something',
#   'meat',
#   'pork-chops',
#   'taste-mood',
#   'equipment',
#   '4-hours-or-less'],
#  '198343': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-large-groups',
#   'breads',
#   'fruit',
#   'easy',
#   'beginner-cook',
#   'quick-breads',
#   'tropical-fruit',
#   'bananas',
#   'number-of-servings',
#   '4-hours-or-less'],
#  '129919': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'casseroles',
#   'main-dish',
#   'eggs-dairy',
#   'pasta',
#   'american',
#   'southwestern-united-states',
#   'oven',
#   'potluck',
#   'kid-friendly',
#   'cheese',
#   'dietary',
#   'comfort-food',
#   'egg-free',
#   'free-of-something',
#   'toddler-friendly',
#   'pasta-rice-and-grains',
#   'elbow-macaroni',
#   'taste-mood',
#   'savory',
#   'to-go',
#   'equipment',
#   'number-of-servings',
#   'presentation',
#   'served-hot',
#   '4-hours-or-less'],
#  '375376': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'breads',
#   'breakfast',
#   'eggs-dairy',
#   'easy',
#   'eggs',
#   'dietary',
#   'gluten-free',
#   'comfort-food',
#   'inexpensive',
#   'yeast',
#   'free-of-something',
#   'brunch',
#   'taste-mood',
#   '3-steps-or-less',
#   '4-hours-or-less'],
#  '152534': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'appetizers',
#   'main-dish',
#   'oven',
#   'pizza',
#   'equipment'],
#  '63131': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'for-large-groups',
#   'breakfast',
#   'desserts',
#   'easy',
#   'beginner-cook',
#   'kosher',
#   'picnic',
#   'vegan',
#   'vegetarian',
#   'cookies-and-brownies',
#   'bar-cookies',
#   'stove-top',
#   'dietary',
#   'brown-bag',
#   'to-go',
#   'camping',
#   'equipment',
#   'number-of-servings'],
#  '24760': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'main-dish',
#   'beans',
#   'vegetables',
#   'asian',
#   'middle-eastern',
#   'easy',
#   'low-fat',
#   'vegetarian',
#   'stove-top',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   'equipment',
#   'number-of-servings'],
#  '327979': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'beverages',
#   'fruit',
#   'easy',
#   'low-fat',
#   'vegan',
#   'vegetarian',
#   'smoothies',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'low-in-something',
#   'melons',
#   'tropical-fruit',
#   'papaya',
#   'pineapple',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '375362': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   '5-ingredients-or-less',
#   'side-dishes',
#   'easy',
#   'copycat',
#   'novelty',
#   '3-steps-or-less'],
#  '217296': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'healthy',
#   'breads',
#   'european',
#   'holiday-event',
#   'irish',
#   'rolls-biscuits',
#   'grains',
#   'dietary',
#   'st-patricks-day',
#   'pasta-rice-and-grains',
#   '4-hours-or-less'],
#  '121107': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   '5-ingredients-or-less',
#   'main-dish',
#   'pasta',
#   'vegetables',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'vegetarian',
#   'dietary',
#   'inexpensive',
#   'pasta-rice-and-grains',
#   'spaghetti',
#   'presentation',
#   'served-hot'],
#  '435816': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'breads',
#   'eggs-dairy',
#   'american',
#   'oven',
#   'rolls-biscuits',
#   'nuts',
#   'eggs',
#   'midwestern',
#   'inexpensive',
#   'brunch',
#   'taste-mood',
#   'sweet',
#   'equipment',
#   '4-hours-or-less',
#   'baking',
#   'from-scratch'],
#  '198073': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-large-groups',
#   '5-ingredients-or-less',
#   'appetizers',
#   'pork',
#   'easy',
#   'holiday-event',
#   'spicy',
#   'oamc-freezer-make-ahead',
#   'meat',
#   'pork-sausage',
#   'taste-mood',
#   'number-of-servings'],
#  '202949': ['30-minutes-or-less',
#   'time-to-make',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'vegetables',
#   'spicy',
#   'comfort-food',
#   'taste-mood'],
#  '26420': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'healthy',
#   'sauces',
#   'condiments-etc',
#   'seafood',
#   'easy',
#   'no-cook',
#   'low-fat',
#   'shrimp',
#   'dietary',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'savory-sauces',
#   'low-in-something',
#   'shellfish',
#   'number-of-servings',
#   '3-steps-or-less',
#   'technique'],
#  '367828': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'side-dishes',
#   'rice',
#   'easy',
#   'low-fat',
#   'dietary',
#   'copycat',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-in-something',
#   'pasta-rice-and-grains',
#   'white-rice',
#   'novelty',
#   '3-steps-or-less'],
#  '140610': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'breads',
#   'breakfast',
#   'fruit',
#   'vegetables',
#   'american',
#   'fall',
#   'holiday-event',
#   'muffins',
#   'grains',
#   'food-processor-blender',
#   'christmas',
#   'thanksgiving',
#   'seasonal',
#   'quick-breads',
#   'apples',
#   'pasta-rice-and-grains',
#   'carrots',
#   'brunch',
#   'equipment',
#   'small-appliance'],
#  '392181': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'desserts',
#   'dinner-party',
#   'cakes',
#   'chocolate',
#   'dietary',
#   'copycat',
#   'novelty',
#   '4-hours-or-less'],
#  '468143': ['weeknight',
#   '30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-large-groups',
#   '5-ingredients-or-less',
#   'desserts',
#   'easy',
#   'no-cook',
#   'dinner-party',
#   'finger-food',
#   'romantic',
#   'chocolate',
#   'inexpensive',
#   'taste-mood',
#   'sweet',
#   'number-of-servings',
#   'presentation',
#   'served-cold',
#   'technique'],
#  '374703': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'salads',
#   'vegetables',
#   'spring',
#   'summer',
#   'vegan',
#   'vegetarian',
#   'dietary',
#   'seasonal',
#   'number-of-servings'],
#  '100837': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'beverages',
#   'fruit',
#   'american',
#   'easy',
#   'no-cook',
#   'dinner-party',
#   'holiday-event',
#   'low-fat',
#   'romantic',
#   'cocktails',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-in-something',
#   'tropical-fruit',
#   'pineapple',
#   'brunch',
#   'taste-mood',
#   'presentation',
#   'served-cold',
#   'technique'],
#  '286484': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'breakfast',
#   'lunch',
#   'eggs-dairy',
#   'fruit',
#   'easy',
#   'kid-friendly',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'infant-baby-friendly',
#   'low-saturated-fat',
#   'low-calorie',
#   'toddler-friendly',
#   'low-in-something',
#   'tropical-fruit',
#   'bananas',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '176996': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'sauces',
#   'condiments-etc',
#   'fruit',
#   'vegetables',
#   'easy',
#   'refrigerator',
#   'beginner-cook',
#   'dinner-party',
#   'holiday-event',
#   'low-fat',
#   'summer',
#   'vegetarian',
#   'salsas',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'healthy-2',
#   'low-in-something',
#   'melons',
#   'taste-mood',
#   'savory',
#   'equipment'],
#  '290187': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'healthy',
#   'desserts',
#   'easy',
#   'microwave',
#   'kid-friendly',
#   'cakes',
#   'chocolate',
#   'dietary',
#   'low-cholesterol',
#   'healthy-2',
#   'low-in-something',
#   'taste-mood',
#   'sweet',
#   'equipment',
#   'number-of-servings'],
#  '11361': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   '5-ingredients-or-less',
#   'very-low-carbs',
#   'appetizers',
#   'breakfast',
#   'lunch',
#   'main-dish',
#   'side-dishes',
#   'beef',
#   'pork',
#   'easy',
#   'dinner-party',
#   'finger-food',
#   'stove-top',
#   'dietary',
#   'low-carb',
#   'low-in-something',
#   'meat',
#   'equipment',
#   'presentation',
#   '3-steps-or-less'],
#  '459738': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'appetizers',
#   'easy',
#   'taste-mood',
#   'savory'],
#  '111198': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'desserts',
#   'eggs-dairy',
#   'fruit',
#   'african',
#   'oven',
#   'easy',
#   'holiday-event',
#   'kid-friendly',
#   'romantic',
#   'cakes',
#   'nuts',
#   'eggs',
#   'dietary',
#   'valentines-day',
#   'inexpensive',
#   'taste-mood',
#   'sweet',
#   'equipment'],
#  '164636': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'healthy',
#   '5-ingredients-or-less',
#   'appetizers',
#   'easy',
#   'beginner-cook',
#   'low-fat',
#   'deep-fry',
#   'dietary',
#   'low-sodium',
#   'low-saturated-fat',
#   'inexpensive',
#   'low-in-something',
#   'number-of-servings',
#   '3-steps-or-less',
#   'technique'],
#  '33246': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'healthy',
#   '5-ingredients-or-less',
#   'breads',
#   'easy',
#   'low-fat',
#   'dietary',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'quick-breads',
#   'low-in-something',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '302498': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-large-groups',
#   'main-dish',
#   'dietary',
#   'gluten-free',
#   'free-of-something',
#   'meat',
#   'number-of-servings'],
#  '378067': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   '5-ingredients-or-less',
#   'main-dish',
#   'easy'],
#  '165438': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-large-groups',
#   'desserts',
#   'cakes',
#   'number-of-servings'],
#  '267159': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'healthy',
#   'desserts',
#   'cakes',
#   'chocolate',
#   'dietary'],
#  '401283': ['weeknight',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'breads',
#   'main-dish',
#   'eggs-dairy',
#   'american',
#   'european',
#   'holiday-event',
#   'vegetarian',
#   'italian',
#   'grains',
#   'cheese',
#   'dietary',
#   'northeastern-united-states',
#   'yeast',
#   'pasta-rice-and-grains',
#   'taste-mood',
#   'savory'],
#  '428566': ['weeknight',
#   '15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'healthy',
#   '5-ingredients-or-less',
#   'breakfast',
#   'lunch',
#   'snacks',
#   'fruit',
#   'easy',
#   'beginner-cook',
#   'diabetic',
#   'low-fat',
#   'vegetarian',
#   'dietary',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   'berries',
#   'blueberries',
#   'taste-mood',
#   'sweet',
#   'to-go',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '533190': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'breakfast',
#   'number-of-servings'],
#  '478546': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'drop-cookies',
#   'desserts',
#   'american',
#   'easy',
#   'cookies-and-brownies',
#   'chocolate',
#   'taste-mood'],
#  '40228': ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'very-low-carbs',
#   'main-dish',
#   'beef',
#   'american',
#   'easy',
#   'european',
#   'dinner-party',
#   'heirloom-historical',
#   'holiday-event',
#   'italian',
#   'stove-top',
#   'dietary',
#   'low-sodium',
#   'high-protein',
#   'low-carb',
#   'high-in-something',
#   'low-in-something',
#   'meat',
#   'roast-beef',
#   'equipment',
#   '4-hours-or-less'],
#  '255985': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'pasta',
#   'easy',
#   'lasagna',
#   'dietary',
#   'one-dish-meal',
#   'low-carb',
#   'low-in-something',
#   'pasta-rice-and-grains',
#   '4-hours-or-less'],
#  '402246': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'healthy',
#   'desserts',
#   'puddings-and-mousses',
#   'chocolate',
#   'dietary',
#   'low-in-something'],
#  '180817': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-large-groups',
#   'breads',
#   'lunch',
#   'sandwiches',
#   'yeast',
#   'number-of-servings',
#   '4-hours-or-less'],
#  '133326': ['time-to-make',
#   'course',
#   'preparation',
#   'casseroles',
#   'main-dish',
#   'oven',
#   'dietary',
#   'one-dish-meal',
#   'equipment',
#   '4-hours-or-less'],
#  '513963': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   '5-ingredients-or-less',
#   'pies-and-tarts',
#   'desserts',
#   'easy',
#   'no-cook',
#   'pies',
#   'technique'],
#  '213395': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'bisques-cream-soups',
#   'soups-stews',
#   'vegetables',
#   'easy',
#   'dietary',
#   'comfort-food',
#   'peppers',
#   'tomatoes',
#   'taste-mood',
#   'number-of-servings'],
#  '27060': ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'breads',
#   'bread-machine',
#   'easy',
#   'grains',
#   'dietary',
#   'yeast',
#   'pasta-rice-and-grains',
#   'equipment',
#   'small-appliance',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '334201': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'pancakes-and-waffles',
#   'breakfast',
#   'eggs-dairy',
#   'easy',
#   'beginner-cook',
#   'grains',
#   'eggs',
#   'stove-top',
#   'comfort-food',
#   'pasta-rice-and-grains',
#   'taste-mood',
#   'equipment',
#   'presentation',
#   'served-hot'],
#  '482111': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'beverages',
#   'eggs-dairy',
#   'easy',
#   'dinner-party',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'low-in-something',
#   'brunch',
#   'taste-mood',
#   'number-of-servings',
#   '3-steps-or-less',
#   'non-alcoholic',
#   'from-scratch'],
#  '126072': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   '5-ingredients-or-less',
#   'pies-and-tarts',
#   'desserts',
#   'easy',
#   'crusts-pastry-dough-2',
#   'dietary',
#   'low-sodium',
#   'low-in-something',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '292147': ['time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'breads',
#   'bread-machine',
#   'easy',
#   'beginner-cook',
#   'yeast',
#   'equipment',
#   'small-appliance',
#   'number-of-servings',
#   '4-hours-or-less'],
#  '221429': ['course',
#   'preparation',
#   'healthy',
#   'breads',
#   'bread-machine',
#   'dietary',
#   'low-cholesterol',
#   'healthy-2',
#   'low-in-something',
#   'equipment',
#   'small-appliance'],
#  '218671': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'pancakes-and-waffles',
#   'breakfast',
#   'easy',
#   'kid-friendly',
#   'vegetarian',
#   'dietary',
#   'low-cholesterol',
#   'oamc-freezer-make-ahead',
#   'healthy-2',
#   'low-in-something',
#   'number-of-servings'],
#  '121712': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   '5-ingredients-or-less',
#   'appetizers',
#   'easy',
#   'dietary',
#   'low-carb',
#   'low-in-something',
#   '3-steps-or-less'],
#  '235003': ['course',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'beverages',
#   'easy',
#   'beginner-cook',
#   'low-fat',
#   'summer',
#   'cocktails',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'low-in-something',
#   'novelty',
#   '3-steps-or-less'],
#  '43669': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'soups-stews',
#   'vegetables',
#   'easy',
#   'fall',
#   'vegetarian',
#   'winter',
#   'chowders',
#   'stove-top',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'low-calorie',
#   'comfort-food',
#   'inexpensive',
#   'low-in-something',
#   'corn',
#   'taste-mood',
#   'equipment'],
#  '449768': ['course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   '5-ingredients-or-less',
#   'condiments-etc',
#   'vegetables',
#   'easy',
#   'vegetarian',
#   'dietary',
#   'gifts',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'healthy-2',
#   'low-in-something',
#   'tomatoes',
#   'novelty',
#   'technique'],
#  '257696': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'low-protein',
#   'desserts',
#   'easy',
#   'cakes',
#   'dietary',
#   'low-cholesterol',
#   'low-in-something'],
#  '53353': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'low-protein',
#   '5-ingredients-or-less',
#   'desserts',
#   'easy',
#   'holiday-event',
#   'kid-friendly',
#   'candy',
#   'dietary',
#   'low-sodium',
#   'comfort-food',
#   'low-in-something',
#   'taste-mood',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '115160': ['time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'for-large-groups',
#   'desserts',
#   'oven',
#   'european',
#   'cakes',
#   'russian',
#   'stove-top',
#   'equipment',
#   'number-of-servings',
#   '4-hours-or-less'],
#  '140172': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'main-dish',
#   'easy',
#   'stews',
#   'dietary',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '392598': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'healthy',
#   'main-dish',
#   'low-fat',
#   'dietary',
#   'low-saturated-fat',
#   'low-in-something'],
#  '356163': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'healthy',
#   'main-dish',
#   'beef',
#   'pasta',
#   'easy',
#   'dietary',
#   'one-dish-meal',
#   'low-calorie',
#   'low-in-something',
#   'meat',
#   'pasta-rice-and-grains'],
#  '140173': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'pasta',
#   'seafood',
#   'easy',
#   'shrimp',
#   'dietary',
#   'pasta-rice-and-grains',
#   'shellfish',
#   '3-steps-or-less'],
#  '289025': ['15-minutes-or-less',
#   'time-to-make',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'vegetables',
#   'easy',
#   'dietary',
#   'asparagus',
#   'number-of-servings'],
#  '291409': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'healthy',
#   'main-dish',
#   'soups-stews',
#   'beans',
#   'easy',
#   'beginner-cook',
#   'low-fat',
#   'vegan',
#   'vegetarian',
#   'chili',
#   'dietary',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   '3-steps-or-less'],
#  '282812': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'granola-and-porridge',
#   'breakfast',
#   'easy',
#   'number-of-servings'],
#  '489337': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'casseroles',
#   'main-dish',
#   'easy',
#   'dietary',
#   '3-steps-or-less'],
#  '250900': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'pies-and-tarts',
#   'desserts',
#   'fruit',
#   'pies',
#   'dietary',
#   'low-sodium',
#   'low-in-something',
#   'apples',
#   '4-hours-or-less'],
#  '160494': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'desserts',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'cakes',
#   'dietary',
#   'inexpensive',
#   'egg-free',
#   'free-of-something',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '245950': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'low-protein',
#   'sauces',
#   'main-dish',
#   'condiments-etc',
#   'vegetables',
#   'canadian',
#   'easy',
#   'dietary',
#   'low-calorie',
#   'comfort-food',
#   'low-carb',
#   'savory-sauces',
#   'low-in-something',
#   'tomatoes',
#   'taste-mood'],
#  '388578': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-large-groups',
#   'breads',
#   'fruit',
#   'kid-friendly',
#   'vegetarian',
#   'dietary',
#   'quick-breads',
#   'toddler-friendly',
#   'tropical-fruit',
#   'bananas',
#   'number-of-servings',
#   '4-hours-or-less'],
#  '360881': ['time-to-make',
#   'course',
#   'preparation',
#   'breads',
#   'easy',
#   'beginner-cook',
#   'quick-breads',
#   '4-hours-or-less'],
#  '453243': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   '5-ingredients-or-less',
#   'lunch',
#   'soups-stews',
#   'beans',
#   'beef',
#   'american',
#   'southwestern-united-states',
#   'tex-mex',
#   'easy',
#   'beginner-cook',
#   'comfort-food',
#   'inexpensive',
#   'chick-peas-garbanzos',
#   'meat',
#   'taste-mood'],
#  '101260': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'appetizers',
#   'condiments-etc',
#   'dinner-party',
#   'dietary',
#   'number-of-servings'],
#  '256464': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'very-low-carbs',
#   'side-dishes',
#   'vegetables',
#   'easy',
#   'beginner-cook',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'healthy-2',
#   'low-in-something',
#   'broccoli',
#   'number-of-servings'],
#  '122791': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'desserts',
#   'lunch',
#   'snacks',
#   'eggs-dairy',
#   'fruit',
#   'easy',
#   'european',
#   'microwave',
#   'beginner-cook',
#   'kid-friendly',
#   'kosher',
#   'puddings-and-mousses',
#   'english',
#   'dietary',
#   'comfort-food',
#   'inexpensive',
#   'toddler-friendly',
#   'berries',
#   'strawberries',
#   'tropical-fruit',
#   'bananas',
#   'brunch',
#   'taste-mood',
#   'sweet',
#   'equipment',
#   'number-of-servings'],
#  '214264': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'for-1-or-2',
#   'healthy',
#   'beverages',
#   'easy',
#   'low-fat',
#   'smoothies',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'shakes',
#   'low-saturated-fat',
#   'low-calorie',
#   'low-carb',
#   'low-in-something',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '416599': ['weeknight',
#   '15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'healthy',
#   'beverages',
#   'breakfast',
#   'microwave',
#   'low-fat',
#   'chocolate',
#   'dietary',
#   'gluten-free',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'high-calcium',
#   'comfort-food',
#   'inexpensive',
#   'egg-free',
#   'free-of-something',
#   'high-in-something',
#   'low-in-something',
#   'taste-mood',
#   'sweet',
#   'equipment',
#   'number-of-servings'],
#  '162657': ['lactose',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'side-dishes',
#   'potatoes',
#   'vegetables',
#   'easy',
#   'beginner-cook',
#   'dinner-party',
#   'holiday-event',
#   'spring',
#   'dietary',
#   'seasonal',
#   'high-fiber',
#   'inexpensive',
#   'egg-free',
#   'free-of-something',
#   'high-in-something',
#   'number-of-servings'],
#  '166483': ['course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'poultry',
#   'rice',
#   'vegetables',
#   'easy',
#   'beginner-cook',
#   'diabetic',
#   'kid-friendly',
#   'chicken',
#   'dietary',
#   'one-dish-meal',
#   'comfort-food',
#   'brown-bag',
#   'inexpensive',
#   'egg-free',
#   'free-of-something',
#   'toddler-friendly',
#   'meat',
#   'pasta-rice-and-grains',
#   'white-rice',
#   'broccoli',
#   'brunch',
#   'taste-mood',
#   'to-go'],
#  '385415': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'sauces',
#   'appetizers',
#   'canning',
#   'condiments-etc',
#   'vegetables',
#   'american',
#   'mexican',
#   'southwestern-united-states',
#   'tex-mex',
#   'summer',
#   'vegan',
#   'vegetarian',
#   'salsas',
#   'stove-top',
#   'dietary',
#   'seasonal',
#   'squash',
#   'tomatoes',
#   'taste-mood',
#   'savory',
#   'equipment',
#   'technique',
#   'water-bath'],
#  '120462': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'eggs-dairy',
#   'pasta',
#   'easy',
#   'vegetarian',
#   'cheese',
#   'dietary',
#   'high-calcium',
#   'comfort-food',
#   'high-in-something',
#   'pasta-rice-and-grains',
#   'penne',
#   'taste-mood',
#   '3-steps-or-less'],
#  '128544': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'desserts',
#   'eggs-dairy',
#   'dinner-party',
#   'cakes',
#   'chocolate',
#   'eggs',
#   'dietary',
#   'gluten-free',
#   'free-of-something',
#   '4-hours-or-less'],
#  '257111': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'breads',
#   'lunch',
#   'snacks',
#   'eggs-dairy',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'cheese',
#   'dietary',
#   'gifts',
#   'low-sodium',
#   'comfort-food',
#   'inexpensive',
#   'low-in-something',
#   'taste-mood',
#   '4-hours-or-less'],
#  '274469': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'occasion',
#   'for-1-or-2',
#   'desserts',
#   'easy',
#   'beginner-cook',
#   'kid-friendly',
#   'frozen-desserts',
#   'dietary',
#   'comfort-food',
#   'taste-mood',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '432661': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'condiments-etc',
#   'easy',
#   'herb-and-spice-mixes',
#   'dietary',
#   'low-sodium',
#   'cooking-mixes',
#   'low-in-something',
#   'peanut-butter'],
#  '388488': ['time-to-make',
# ...
#  '39402': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'for-1-or-2',
#   'beverages',
#   'fruit',
#   'american',
#   'easy',
#   'no-cook',
#   'kid-friendly',
#   'smoothies',
#   'food-processor-blender',
#   'dietary',
#   'seasonal',
#   'comfort-food',
#   'apples',
#   'taste-mood',
#   'equipment',
#   'small-appliance',
#   'number-of-servings',
#   '3-steps-or-less',
#   'technique'],
#  '57771': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'north-american',
#   'for-large-groups',
#   'desserts',
#   'fruit',
#   'american',
#   'cakes',
#   'northeastern-united-states',
#   'apples',
#   'number-of-servings'],
#  '127637': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'breads',
#   'fruit',
#   'easy',
#   'potluck',
#   'coffee-cakes',
#   'dietary',
#   'comfort-food',
#   'apples',
#   'brunch',
#   'taste-mood',
#   'to-go'],
#  '140850': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'for-large-groups',
#   'breads',
#   'breakfast',
#   'eggs-dairy',
#   'fruit',
#   'oven',
#   'fall',
#   'kid-friendly',
#   'coffee-cakes',
#   'nuts',
#   'eggs',
#   'dietary',
#   'gifts',
#   'seasonal',
#   'comfort-food',
#   'apples',
#   'brunch',
#   'taste-mood',
#   'equipment',
#   'number-of-servings',
#   '4-hours-or-less'],
#  '190858': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'breakfast',
#   'lunch',
#   'snacks',
#   'fruit',
#   'easy',
#   'no-cook',
#   'kid-friendly',
#   'vegan',
#   'vegetarian',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'toddler-friendly',
#   'low-in-something',
#   'apples',
#   'tropical-fruit',
#   'bananas',
#   'number-of-servings',
#   'technique'],
#  '388465': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'cobblers-and-crisps',
#   'breakfast',
#   'desserts',
#   'fruit',
#   'dietary',
#   'low-in-something',
#   'apples',
#   'brunch'],
#  '102670': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'breads',
#   'desserts',
#   'fruit',
#   'cakes',
#   'coffee-cakes',
#   'apples',
#   '4-hours-or-less'],
#  '78210': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'breads',
#   'eggs-dairy',
#   'fruit',
#   'muffins',
#   'cheese',
#   'quick-breads',
#   'apples',
#   'number-of-servings'],
#  '338725': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'cupcakes',
#   'desserts',
#   'fruit',
#   'cakes',
#   'apples'],
#  '175891': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'desserts',
#   'fruit',
#   'french',
#   'oven',
#   'european',
#   'stove-top',
#   'dietary',
#   'low-sodium',
#   'low-in-something',
#   'apples',
#   'brunch',
#   'equipment'],
#  '75960': ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'stuffings-dressings',
#   'side-dishes',
#   'fruit',
#   'dietary',
#   'apples',
#   '4-hours-or-less'],
#  '399189': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'preparation',
#   'low-protein',
#   'healthy',
#   'beverages',
#   'low-fat',
#   'punch',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'low-in-something'],
#  '142852': ['lactose',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'yams-sweet-potatoes',
#   'side-dishes',
#   'fruit',
#   'potatoes',
#   'vegetables',
#   'dinner-party',
#   'fall',
#   'holiday-event',
#   'vegetarian',
#   'dietary',
#   'thanksgiving',
#   'seasonal',
#   'comfort-food',
#   'free-of-something',
#   'apples',
#   'taste-mood',
#   '4-hours-or-less'],
#  '71833': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'stuffings-dressings',
#   'side-dishes',
#   'fruit',
#   'oven',
#   'easy',
#   'dinner-party',
#   'stove-top',
#   'dietary',
#   'apples',
#   'equipment',
#   'number-of-servings',
#   '3-steps-or-less'],
#  '40478': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   '5-ingredients-or-less',
#   'desserts',
#   'fruit',
#   'oven',
#   'easy',
#   'dinner-party',
#   'fall',
#   'holiday-event',
#   'kid-friendly',
#   'summer',
#   'easter',
#   'dietary',
#   'christmas',
#   'new-years',
#   'thanksgiving',
#   'low-sodium',
#   'seasonal',
#   'valentines-day',
#   'low-in-something',
#   'apples',
#   'equipment',
#   'number-of-servings'],
#  '54095': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'lunch',
#   'main-dish',
#   'fruit',
#   'poultry',
#   'oven',
#   'broil',
#   'turkey',
#   'dietary',
#   'sandwiches',
#   'brown-bag',
#   'apples',
#   'meat',
#   'to-go',
#   'equipment'],
#  '12672': ['60-minutes-or-less',
#   'time-to-make',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'low-protein',
#   'casseroles',
#   'fruit',
#   'vegetables',
#   'canadian',
#   'oven',
#   'easy',
#   'dinner-party',
#   'dietary',
#   'low-sodium',
#   'gluten-free',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'healthy-2',
#   'free-of-something',
#   'low-in-something',
#   'apples',
#   'equipment'],
#  '50936': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'for-1-or-2',
#   'low-protein',
#   'desserts',
#   'fruit',
#   'american',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'comfort-food',
#   'low-in-something',
#   'apples',
#   'taste-mood',
#   'number-of-servings'],
#  '93365': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'appetizers',
#   'soups-stews',
#   'eggs-dairy',
#   'fruit',
#   'dinner-party',
#   'holiday-event',
#   'cheese',
#   'dietary',
#   'low-sodium',
#   'low-carb',
#   'inexpensive',
#   'low-in-something',
#   'apples',
#   'brunch',
#   'presentation',
#   'served-cold'],
#  '272034': ['30-minutes-or-less',
#   'time-to-make',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'fruit',
#   'easy',
#   'beginner-cook',
#   'dietary',
#   'low-cholesterol',
#   'low-in-something',
#   'apples',
#   '3-steps-or-less'],
#  '40589': ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'desserts',
#   'fruit',
#   'oven',
#   'cookies-and-brownies',
#   'bar-cookies',
#   'dietary',
#   'apples',
#   'equipment',
#   'number-of-servings',
#   '4-hours-or-less'],
#  '224452': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'healthy',
#   'granola-and-porridge',
#   'breakfast',
#   'fruit',
#   'easy',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-calorie',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   'apples'],
#  '400912': ['time-to-make', 'preparation', '4-hours-or-less'],
#  '378468': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'low-protein',
#   'healthy',
#   'desserts',
#   'salads',
#   'fruit',
#   'vegetables',
#   'easy',
#   'european',
#   'dinner-party',
#   'spring',
#   'summer',
#   'vegetarian',
#   'english',
#   'nuts',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'healthy-2',
#   'low-in-something',
#   'apples',
#   'presentation',
#   'served-cold',
#   '3-steps-or-less',
#   '4-hours-or-less'],
#  '146444': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'breads',
#   'fruit',
#   'american',
#   'nuts',
#   'grains',
#   'gifts',
#   'midwestern',
#   'northeastern-united-states',
#   'quick-breads',
#   'apples',
#   'pasta-rice-and-grains',
#   'taste-mood',
#   'sweet',
#   '4-hours-or-less'],
#  '456852': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'cuisine',
#   'preparation',
#   'soups-stews',
#   'european',
#   'swiss'],
#  '107851': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'pies-and-tarts',
#   'desserts',
#   'fruit',
#   'canadian',
#   'oven',
#   'dinner-party',
#   'holiday-event',
#   'pies',
#   'british-columbian',
#   'ontario',
#   'apples',
#   'equipment'],
#  '89021': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'salads',
#   'fruit',
#   'vegetables',
#   'easy',
#   'no-cook',
#   'potluck',
#   'low-fat',
#   'picnic',
#   'summer',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'seasonal',
#   'low-saturated-fat',
#   'low-calorie',
#   'brown-bag',
#   'healthy-2',
#   'low-in-something',
#   'apples',
#   'squash',
#   'to-go',
#   '3-steps-or-less',
#   'technique'],
#  '330040': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'healthy',
#   'lunch',
#   'snacks',
#   'eggs-dairy',
#   'fruit',
#   'easy',
#   'beginner-cook',
#   'low-fat',
#   'cheese',
#   'dietary',
#   'low-cholesterol',
#   'sandwiches',
#   'low-saturated-fat',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   'apples',
#   'number-of-servings'],
#  '452590': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'main-dish',
#   'poultry',
#   'chicken',
#   'dietary',
#   'low-sodium',
#   'low-calorie',
#   'low-carb',
#   'low-in-something',
#   'meat',
#   'chicken-breasts'],
#  '403819': ['occasion', 'holiday-event', 'christmas'],
#  '420689': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'breakfast',
#   'eggs-dairy',
#   'eggs',
#   'brunch',
#   '4-hours-or-less'],
#  '191150': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'appetizers',
#   'lunch',
#   'fruit',
#   'easy',
#   'dinner-party',
#   'finger-food',
#   'vegetarian',
#   'dietary',
#   'apples',
#   'brunch',
#   'presentation'],
#  '74520': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'jams-and-preserves',
#   'sauces',
#   'chutneys',
#   'appetizers',
#   'canning',
#   'lunch',
#   'condiments-etc',
#   'snacks',
#   'fruit',
#   'easy',
#   'potluck',
#   'dinner-party',
#   'holiday-event',
#   'kosher',
#   'vegan',
#   'vegetarian',
#   'spreads',
#   'stove-top',
#   'dietary',
#   'spicy',
#   'sandwiches',
#   'savory-sauces',
#   'apples',
#   'brunch',
#   'taste-mood',
#   'savory',
#   'to-go',
#   'equipment',
#   'number-of-servings',
#   'technique',
#   'unprocessed-freezer'],
#  '460292': ['bacon',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'north-american',
#   'for-1-or-2',
#   'pancakes-and-waffles',
#   'breakfast',
#   'pork',
#   'diabetic',
#   'dietary',
#   'meat',
#   'number-of-servings',
#   'presentation',
#   'served-hot',
#   'from-scratch'],
#  '130992': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   '5-ingredients-or-less',
#   'jams-and-preserves',
#   'condiments-etc',
#   'fruit',
#   'easy',
#   'european',
#   'beginner-cook',
#   'kid-friendly',
#   'low-fat',
#   'dietary',
#   'gifts',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'inexpensive',
#   'toddler-friendly',
#   'low-in-something',
#   'apples',
#   'tropical-fruit',
#   'bananas'],
#  '346687': ['60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'low-protein',
#   'healthy',
#   'jams-and-preserves',
#   'condiments-etc',
#   'fruit',
#   'easy',
#   'low-fat',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'low-in-something',
#   'apples',
#   'berries',
#   'raspberries'],
#  '169993': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'pies-and-tarts',
#   'desserts',
#   'fruit',
#   'oven',
#   'dinner-party',
#   'vegetarian',
#   'pies',
#   'dietary',
#   'low-sodium',
#   'low-in-something',
#   'apples',
#   'berries',
#   'blueberries',
#   'taste-mood',
#   'sweet',
#   'equipment',
#   '4-hours-or-less'],
#  '260352': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'for-1-or-2',
#   'omelets-and-frittatas',
#   'breakfast',
#   'eggs-dairy',
#   'fruit',
#   'french',
#   'european',
#   'diabetic',
#   'vegetarian',
#   'cheese',
#   'eggs',
#   'dietary',
#   'low-carb',
#   'low-in-something',
#   'apples',
#   'number-of-servings'],
#  '158382': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'healthy',
#   'condiments-etc',
#   'fruit',
#   'european',
#   'holiday-event',
#   'kid-friendly',
#   'kosher',
#   'nuts',
#   'food-processor-blender',
#   'dietary',
#   'low-sodium',
#   'low-cholesterol',
#   'low-saturated-fat',
#   'passover',
#   'healthy-2',
#   'low-in-something',
#   'apples',
#   'pitted-fruit',
#   'cherries',
#   'equipment',
#   'small-appliance'],
#  '449725': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   '5-ingredients-or-less',
#   'main-dish',
#   'poultry',
#   'easy',
#   'chicken',
#   'meat',
#   'burgers'],
#  '50851': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'north-american',
#   'breads',
#   'fruit',
#   'american',
#   'oven',
#   'easy',
#   'finger-food',
#   'muffins',
#   'dietary',
#   'quick-breads',
#   'apples',
#   'equipment',
#   'presentation'],
#  '521251': ['15-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'for-1-or-2',
#   'breakfast',
#   'desserts',
#   'fruit',
#   'easy',
#   'microwave',
#   'beginner-cook',
#   'cakes',
#   'dietary',
#   'low-cholesterol',
#   'inexpensive',
#   'healthy-2',
#   'low-in-something',
#   'apples',
#   'equipment',
#   'small-appliance',
#   'number-of-servings'],
#  '205500': ['lactose',
#   '30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'pancakes-and-waffles',
#   'breakfast',
#   'fruit',
#   'vegan',
#   'vegetarian',
#   'dietary',
#   'egg-free',
#   'free-of-something',
#   'apples',
#   'brunch'],
#  '331846': ['time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'low-protein',
#   'healthy',
#   'cobblers-and-crisps',
#   'desserts',
#   'fruit',
#   'fall',
#   'winter',
#   'dietary',
#   'low-sodium',
#   'seasonal',
#   'low-in-something',
#   'apples',
#   'berries',
#   '4-hours-or-less'],
#  '69045': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'lunch',
#   'snacks',
#   'fruit',
#   'seafood',
#   'oven',
#   'easy',
#   'fish',
#   'broil',
#   'dietary',
#   'sandwiches',
#   'tuna',
#   'apples',
#   'saltwater-fish',
#   'equipment'],
#  '31748': ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'occasion',
#   'main-dish',
#   'beef',
#   'fruit',
#   'vegetables',
#   'oven',
#   'refrigerator',
#   'dinner-party',
#   'dietary',
#   'apples',
#   'meat',
#   'equipment',
#   '4-hours-or-less'],
#  '20143': ['weeknight',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'occasion',
#   'very-low-carbs',
#   'main-dish',
#   'fruit',
#   'pork',
#   'german',
#   'oven',
#   'european',
#   'roast',
#   'dinner-party',
#   'dietary',
#   'low-sodium',
#   'high-protein',
#   'low-carb',
#   'high-in-something',
#   'low-in-something',
#   'apples',
#   'meat',
#   'equipment'],
#  '524289': ['bacon',
#   '60-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'cuisine',
#   'preparation',
#   'north-american',
#   'main-dish',
#   'pork',
#   'american',
#   'easy',
#   'dietary',
#   'low-sodium',
#   'high-protein',
#   'low-carb',
#   'high-in-something',
#   'low-in-something',
#   'meat',
#   'pork-chops',
#   'pork-loins',
#   '3-steps-or-less'],
#  '203930': ['30-minutes-or-less',
#   'time-to-make',
#   'course',
#   'main-ingredient',
#   'preparation',
#   'appetizers',
#   'fruit',
#   'finger-food',
#   'apples',
#   'presentation'],
#  ...}

# %% [markdown]
# 1.2 Считайте файл `recipes_sample_with_filled_nsteps.csv` (__ЛР4__) в виде `pd.DataFrame`. Добавьте к таблице 2 столбца: `n_tags`, содержащий количество тэгов у этого рецепта; и `tags`, содержащий набор тэгов в виде строки (тэги внутри строки разделяются символом `;`)

# %%
import pandas as pd

# %%
recipes_filled = pd.read_csv("../Lab4/recipes_sample_with_filled_nsteps.csv")
recipes_filled
# Out:
#        Unnamed: 0                                          name      id  \
# 0               0         george s at the cove  black bean soup   44123
# 1               1            healthy for them  yogurt popsicles   67664
# 2               2                  i can t believe it s spinach   38798
# 3               3                          italian  gut busters   35173
# 4               4      love is in the air  beef fondue   sauces   84797
# ...           ...                                           ...     ...
# 29995       29995  zurie s holey rustic olive and cheddar bread  267661
# 29996       29996          zwetschgenkuchen  bavarian plum cake  386977
# 29997       29997   zwiebelkuchen   southwest german onion cake  103312
# 29998       29998                                   zydeco soup  486161
# 29999       29999        cookies by design   cookies on a stick  298512
#
#        minutes  contributor_id   submitted  n_steps  \
# 0           90           35193  2002-10-25       11
# 1           10           91970  2003-07-26        3
# 2           30            1533  2002-08-29        5
# 3           45           22724  2002-07-27        7
# 4           25            4470  2004-02-23        4
# ...        ...             ...         ...      ...
# 29995       80          200862  2007-11-25       16
# 29996      240          177443  2009-08-24       22
# 29997       75          161745  2004-11-03       10
# 29998       60          227978  2012-08-29        7
# 29999       29          506822  2008-04-15        9
#
#                                              description  n_ingredients
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
# [30000 rows x 9 columns]

# %%
buf_list = []

for _, row in recipes_filled.iterrows():
    if row['id'] in dictionary_1:
        buf_list.append(len(dictionary_1[row['id']]))
    else:
        buf_list.append(float("nan"))

recipes_filled['n_tags'] = buf_list
recipes_filled
# Out:
#        Unnamed: 0                                          name      id  \
# 0               0         george s at the cove  black bean soup   44123
# 1               1            healthy for them  yogurt popsicles   67664
# 2               2                  i can t believe it s spinach   38798
# 3               3                          italian  gut busters   35173
# 4               4      love is in the air  beef fondue   sauces   84797
# ...           ...                                           ...     ...
# 29995       29995  zurie s holey rustic olive and cheddar bread  267661
# 29996       29996          zwetschgenkuchen  bavarian plum cake  386977
# 29997       29997   zwiebelkuchen   southwest german onion cake  103312
# 29998       29998                                   zydeco soup  486161
# 29999       29999        cookies by design   cookies on a stick  298512
#
#        minutes  contributor_id   submitted  n_steps  \
# 0           90           35193  2002-10-25       11
# 1           10           91970  2003-07-26        3
# 2           30            1533  2002-08-29        5
# 3           45           22724  2002-07-27        7
# 4           25            4470  2004-02-23        4
# ...        ...             ...         ...      ...
# 29995       80          200862  2007-11-25       16
# 29996      240          177443  2009-08-24       22
# 29997       75          161745  2004-11-03       10
# 29998       60          227978  2012-08-29        7
# 29999       29          506822  2008-04-15        9
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
#        n_tags
# 0          25
# 1          31
# 2          17
# 3          11
# 4          19
# ...       ...
# 29995      18
# 29996      19
# 29997      20
# 29998      20
# 29999      12
#
# [30000 rows x 10 columns]

# %%
buf_list = []

for _, row in recipes_filled.iterrows():
    if row['id'] in dictionary_1:
        buf_list.append(';'.join(dictionary_1[row['id']]))
    else:
        buf_list.append(float("nan"))

recipes_filled['tags'] = buf_list
recipes_filled
# Out:
#        Unnamed: 0                                          name      id  \
# 0               0         george s at the cove  black bean soup   44123
# 1               1            healthy for them  yogurt popsicles   67664
# 2               2                  i can t believe it s spinach   38798
# 3               3                          italian  gut busters   35173
# 4               4      love is in the air  beef fondue   sauces   84797
# ...           ...                                           ...     ...
# 29995       29995  zurie s holey rustic olive and cheddar bread  267661
# 29996       29996          zwetschgenkuchen  bavarian plum cake  386977
# 29997       29997   zwiebelkuchen   southwest german onion cake  103312
# 29998       29998                                   zydeco soup  486161
# 29999       29999        cookies by design   cookies on a stick  298512
#
#        minutes  contributor_id   submitted  n_steps  \
# 0           90           35193  2002-10-25       11
# 1           10           91970  2003-07-26        3
# 2           30            1533  2002-08-29        5
# 3           45           22724  2002-07-27        7
# 4           25            4470  2004-02-23        4
# ...        ...             ...         ...      ...
# 29995       80          200862  2007-11-25       16
# 29996      240          177443  2009-08-24       22
# 29997       75          161745  2004-11-03       10
# 29998       60          227978  2012-08-29        7
# 29999       29          506822  2008-04-15        9
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
#        n_tags                                               tags
# 0          25  weeknight;time-to-make;course;main-ingredient;...
# 1          31  15-minutes-or-less;time-to-make;course;prepara...
# 2          17  30-minutes-or-less;time-to-make;course;main-in...
# 3          11  60-minutes-or-less;time-to-make;course;prepara...
# 4          19  30-minutes-or-less;time-to-make;course;main-in...
# ...       ...                                                ...
# 29995      18  time-to-make;course;main-ingredient;cuisine;pr...
# 29996      19  time-to-make;course;main-ingredient;cuisine;pr...
# 29997      20  time-to-make;course;main-ingredient;cuisine;pr...
# 29998      20  ham;60-minutes-or-less;time-to-make;course;mai...
# 29999      12  30-minutes-or-less;time-to-make;course;prepara...
#
# [30000 rows x 11 columns]

# %%
recipes_filled[recipes_filled['n_tags'].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, id, minutes, contributor_id, submitted, n_steps, description, n_ingredients, n_tags, tags]
# Index: []

# %% [markdown]
# 1.3 В файле `ingredients_sample.csv` находится информация о ингредиентах, необходимых для рецепта. Воспользовавшись `csv.DictReader`, считайте этот файл и создайте словарь вида `id_рецепта: [список ингредиентов]`.

# %%
dictionary_2 = {}

with open('../data/ingredients_sample.csv') as file:
    reader = csv.DictReader(file)
    for item in reader:
        recipe_id = int(item["recipe_id"])
        if recipe_id not in dictionary_2:
            dictionary_2[recipe_id] = []
        dictionary_2[recipe_id].append(item["ingredient"])
        
dictionary_2
# Out:
# {44123: ['unsalted butter',
#   'carrot',
#   'onion',
#   'celery',
#   'broccoli stem',
#   'dried thyme',
#   'dried oregano',
#   'dried sweet basil leaves',
#   'dry white wine',
#   'chicken stock',
#   'worcestershire sauce',
#   'tabasco sauce',
#   'smoked chicken',
#   'black beans',
#   'broccoli floret',
#   'heavy cream',
#   'salt & fresh ground pepper',
#   'cornstarch'],
#  250900: ['unsalted butter',
#   'all-purpose flour',
#   'walnuts',
#   'light brown sugar',
#   'refrigerated pie crust',
#   'granny smith apples'],
#  120462: ['unsalted butter',
#   'onion',
#   'milk',
#   'salt',
#   'egg',
#   'cream cheese',
#   'extra-sharp cheddar cheese',
#   'fresh ground black pepper',
#   'garlic clove',
#   'penne pasta',
#   'gruyere cheese',
#   'hot red pepper flakes',
#   'sweet hungarian paprika',
#   'saltines'],
#  257111: ['unsalted butter',
#   'milk',
#   'eggs',
#   'honey',
#   'white bread',
#   'vanilla',
#   'ground cinnamon',
#   'hot water'],
#  148114: ['unsalted butter',
#   'nuts',
#   'granulated sugar',
#   'semi-sweet chocolate chips'],
#  15646: ['unsalted butter',
#   'eggs',
#   'flour',
#   'vanilla extract',
#   'light brown sugar',
#   'light corn syrup',
#   'pecan halves',
#   'pie shell'],
#  494527: ['unsalted butter',
#   'ground cumin',
#   'coconut milk',
#   'whole tomatoes',
#   'chili flakes',
#   'sea salt',
#   'ground coriander',
#   'vegetable broth',
#   'yellow onions',
#   'curry powder'],
#  532656: ['unsalted butter',
#   'flour',
#   'salt',
#   'cayenne pepper',
#   'egg yolks',
#   'cheese',
#   'egg whites',
#   'nigella seeds'],
#  277764: ['unsalted butter',
#   'celery',
#   'dried oregano',
#   'garlic cloves',
#   'parmesan cheese',
#   'salt & freshly ground black pepper',
#   'ground beef',
#   'tomato sauce',
#   'yellow onion',
#   'acorn squash',
#   'russet potato'],
#  336627: ['unsalted butter',
#   'eggs',
#   'sour cream',
#   'vanilla',
#   'sugar',
#   'cinnamon',
#   'graham cracker crumbs',
#   'cream cheese',
#   'ground nutmeg',
#   'allspice',
#   'canned pumpkin',
#   'gingersnap crumbs',
#   'caramel sauce'],
#  403180: ['unsalted butter',
#   'brown sugar',
#   'coconut milk',
#   'whipped cream',
#   'mini marshmallows',
#   'pretzels',
#   'pumpkin spice',
#   'low-fat sour cream',
#   'low-fat milk',
#   'chocolate flavor instant pudding and pie filling mix',
#   'coconut flakes',
#   'cool whip lite'],
#  435173: ['unsalted butter',
#   'dried thyme',
#   'worcestershire sauce',
#   'salt',
#   'all-purpose flour',
#   'olive oil',
#   'fresh ground black pepper',
#   'roast',
#   'beef broth',
#   'sweet onions',
#   'yukon gold potatoes'],
#  490199: ['unsalted butter',
#   'eggs',
#   'salt',
#   'baking powder',
#   'granulated sugar',
#   'almond extract',
#   'almond paste',
#   'kirsch',
#   'cake flour'],
#  456968: ['unsalted butter',
#   'salt',
#   'light brown sugar',
#   'ground cardamom',
#   'ground almonds',
#   'whole milk',
#   'dried coconut',
#   'long-grain rice',
#   'oranges, zest of'],
#  429293: ['unsalted butter',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'lemon juice',
#   'vanilla extract',
#   'light brown sugar',
#   'egg yolks',
#   'cream of tartar',
#   'egg whites',
#   'ground almonds',
#   "confectioners' sugar",
#   'lemon zest'],
#  339697: ['unsalted butter',
#   'all-purpose flour',
#   'almond extract',
#   "confectioners' sugar",
#   'blanched slivered almond'],
#  106417: ['unsalted butter',
#   'vanilla extract',
#   'granulated sugar',
#   'sea salt',
#   'chocolate',
#   'almonds'],
#  333740: ['unsalted butter',
#   'water',
#   'baking soda',
#   'vanilla extract',
#   'pecans',
#   'granulated sugar',
#   'flaked coconut',
#   'light corn syrup',
#   'macadamia nuts'],
#  242952: ['unsalted butter',
#   'salt',
#   'baking powder',
#   'sugar',
#   'vanilla extract',
#   'coconut milk',
#   'cream of tartar',
#   'egg whites',
#   'kosher salt',
#   'cake flour',
#   'coconut extract',
#   'coconut cream',
#   'coconut water',
#   'sweetened flaked coconut'],
#  338907: ['unsalted butter',
#   'celery',
#   'milk',
#   'eggs',
#   'sage',
#   'butter',
#   'salt',
#   'whole wheat flour',
#   'poultry seasoning',
#   'onions',
#   'sugar',
#   'garlic cloves',
#   'rosemary',
#   'chicken broth',
#   'parsley',
#   'walnuts',
#   'active dry yeast',
#   'fresh coarse ground black pepper',
#   'thyme',
#   'white flour',
#   'savory'],
#  21019: ['unsalted butter', 'water', 'all-purpose flour', 'lard'],
#  395016: ['unsalted butter',
#   'salt',
#   'water',
#   'ground black pepper',
#   'garlic cloves',
#   'cheese',
#   'baguette'],
#  499403: ['unsalted butter',
#   'eggs',
#   'salt',
#   'black pepper',
#   'portabella mushrooms',
#   'gruyere cheese',
#   'shallot',
#   'fresh tarragon'],
#  116061: ['unsalted butter',
#   'chicken stock',
#   'bay leaves',
#   'red onions',
#   'fresh oregano',
#   'port wine',
#   'stale bread',
#   'jarlsberg cheese'],
#  187678: ['unsalted butter',
#   'milk',
#   'flour',
#   'salt',
#   'sugar',
#   'egg',
#   'lemon rind'],
#  65729: ['unsalted butter',
#   'onion',
#   'worcestershire sauce',
#   'ketchup',
#   'water',
#   'paprika',
#   'garlic cloves',
#   'cayenne pepper',
#   'plum tomatoes',
#   'dark brown sugar',
#   'tamarind paste',
#   'dried ancho chile powder',
#   'english mustard',
#   'treacle'],
#  484063: ['unsalted butter',
#   'eggs',
#   'baking soda',
#   'chocolate chips',
#   'vanilla extract',
#   'granulated sugar',
#   'light brown sugar',
#   'light corn syrup',
#   'crunchy peanut butter',
#   'old fashioned oats',
#   "m&m'"],
#  81945: ['unsalted butter',
#   'milk',
#   'eggs',
#   'sour cream',
#   'bananas',
#   'all-purpose flour',
#   'baking soda',
#   'bittersweet chocolate',
#   'granulated sugar',
#   'pure vanilla extract',
#   'cocoa',
#   'icing sugar'],
#  293253: ['unsalted butter',
#   'brown sugar',
#   'vanilla extract',
#   'caster sugar',
#   'hazelnuts',
#   'tart green apples',
#   'plain white flour'],
#  403981: ['unsalted butter',
#   'fresh lemon juice',
#   'honey',
#   'sour cream',
#   'salt',
#   'water',
#   'all-purpose flour',
#   'sugar',
#   'ground cinnamon',
#   'granny smith apples',
#   'white cornmeal',
#   'ice water',
#   'fresh cranberries'],
#  141762: ['unsalted butter',
#   'water',
#   'all-purpose flour',
#   'cinnamon',
#   'powdered sugar',
#   'light brown sugar',
#   'rolled oats',
#   'apple pie filling'],
#  194654: ['unsalted butter',
#   'heavy cream',
#   'cornstarch',
#   'milk',
#   'eggs',
#   'brown sugar',
#   'salt',
#   'vanilla',
#   'sugar',
#   'ground cinnamon',
#   'ground nutmeg',
#   'half-and-half',
#   'granulated sugar',
#   'raisins',
#   'egg yolks',
#   '2% low-fat milk',
#   'tart apples',
#   'croissants'],
#  28745: ['unsalted butter',
#   'ground cinnamon',
#   'light brown sugar',
#   'lemon',
#   'cooking apples',
#   'brown bread'],
#  400101: ['unsalted butter',
#   'carrot',
#   'onion',
#   'celery',
#   'vegetable oil',
#   'salt',
#   'water',
#   'all-purpose flour',
#   'sugar',
#   'black pepper',
#   'garlic cloves',
#   'ice',
#   'chicken broth',
#   'bay leaves',
#   'ginger',
#   'bay leaf',
#   'yellow onion',
#   'thyme',
#   'oranges',
#   'kosher salt',
#   'turkey',
#   'apple cider',
#   'black peppercorns',
#   'whole allspice',
#   'whole cloves',
#   'sage leaves',
#   'parsley sprigs',
#   'turkey neck',
#   'fresh thyme sprigs',
#   'turkey drippings'],
#  459131: ['unsalted butter',
#   'brown sugar',
#   'all-purpose flour',
#   'cinnamon',
#   'lemon juice',
#   'maple syrup',
#   'granny smith apples',
#   'vanilla ice cream',
#   'peanut brittle',
#   'peanuts'],
#  308056: ['unsalted butter',
#   'eggs',
#   'sour cream',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'baking soda',
#   'sugar',
#   'ground cinnamon',
#   'ground nutmeg',
#   'walnuts',
#   'tart apple',
#   'ground allspice'],
#  331337: ['unsalted butter',
#   'milk',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'egg',
#   'vanilla extract',
#   'apple',
#   'molasses',
#   'dark brown sugar',
#   'old fashioned oats',
#   'pitted dates'],
#  302640: ['unsalted butter',
#   'flour',
#   'salt',
#   'sugar',
#   'cinnamon',
#   'lemon, juice and zest of',
#   'light brown sugar',
#   'ground allspice',
#   'nutmeg',
#   'pecan pieces',
#   'tart apples'],
#  398095: ['unsalted butter',
#   'onion',
#   'honey',
#   'sour cream',
#   'ground nutmeg',
#   'chicken broth',
#   'white pepper',
#   'apple cider vinegar',
#   'gingerroot',
#   'dried red chili pepper',
#   'cinnamon stick',
#   'unsweetened applesauce',
#   'pumpkin puree'],
#  338725: ['unsalted butter',
#   'eggs',
#   'salt',
#   'baking soda',
#   'sugar',
#   'vanilla extract',
#   'ground cinnamon',
#   'apple',
#   'canola oil',
#   'unbleached all-purpose flour',
#   'cinnamon sugar'],
#  331846: ['unsalted butter',
#   'water',
#   'all-purpose flour',
#   'ground cinnamon',
#   'granulated sugar',
#   'light brown sugar',
#   'granny smith apples',
#   'cranberries',
#   'crystallized ginger',
#   'old fashioned oats',
#   'dried sweetened cranberries',
#   'cranberry wine',
#   'braeburn apples',
#   'minute tapioca'],
#  43792: ['unsalted butter',
#   'salt',
#   'all-purpose flour',
#   'sugar',
#   'ground cinnamon',
#   'granny smith apples',
#   'vanilla ice cream',
#   'old fashioned oats',
#   'hazelnuts',
#   'golden brown sugar',
#   'prune'],
#  125300: ['unsalted butter',
#   'honey',
#   'brown sugar',
#   'vanilla',
#   'whole wheat flour',
#   'cinnamon',
#   'walnuts',
#   'allspice',
#   'oats',
#   'ginger',
#   'fresh strawberries',
#   'rhubarb',
#   'baking apple'],
#  189486: ['unsalted butter',
#   'salt',
#   'baking powder',
#   'vanilla',
#   'all-purpose flour',
#   'granulated sugar',
#   'light brown sugar',
#   'almond extract',
#   'apricots',
#   'almond paste',
#   'orange, zest of',
#   'extra-large eggs'],
#  116397: ['unsalted butter',
#   'brown sugar',
#   'salt',
#   'baking powder',
#   'vanilla',
#   'all-purpose flour',
#   'sugar',
#   'cinnamon',
#   'raisins',
#   'egg yolks',
#   'egg whites',
#   'hot water',
#   'caster sugar',
#   'fresh lime juice',
#   'brandy',
#   'dried apricots',
#   'cake flour',
#   'cashews',
#   'low-fat plain yogurt'],
#  144773: ['unsalted butter',
#   'milk',
#   'eggs',
#   'sour cream',
#   'baking powder',
#   'granulated sugar',
#   'light brown sugar',
#   'ground allspice',
#   'ground cardamom',
#   'unbleached all-purpose flour',
#   'fresh orange juice',
#   'dried apricots',
#   'whole wheat pastry flour',
#   'fresh cranberries',
#   'old fashioned oats',
#   'orange, zest of'],
#  42845: ['unsalted butter',
#   'honey',
#   'salt',
#   'fresh ginger',
#   'ground black pepper',
#   'onions',
#   'fresh sage',
#   'shallots',
#   'fresh thyme',
#   'turkey',
#   'low sodium chicken broth',
#   'apricot nectar',
#   'apricot preserves'],
#  456699: ['unsalted butter',
#   'worcestershire sauce',
#   'ketchup',
#   'salt',
#   'carrots',
#   'garlic cloves',
#   'peas',
#   'red bell pepper',
#   'chicken broth',
#   'adobo seasoning',
#   'light beer',
#   'chicken',
#   'green bell pepper',
#   'yellow onion',
#   'green beans',
#   'white rice',
#   'pimento stuffed olive',
#   'cilantro leaf'],
#  256185: ['unsalted butter', 'salt', 'lemon juice', 'asparagus', 'lemon zest'],
#  492732: ['unsalted butter',
#   'salt',
#   'hard-boiled eggs',
#   'fresh ground black pepper',
#   'unbleached all-purpose flour',
#   'asparagus',
#   'whole milk',
#   'fresh dill',
#   'country ham'],
#  61350: ['unsalted butter',
#   'heavy cream',
#   'salt',
#   'parmesan cheese',
#   'asparagus',
#   'fontina cheese'],
#  426187: ['unsalted butter',
#   'heavy cream',
#   'eggs',
#   'salt',
#   'all-purpose flour',
#   'egg',
#   'black pepper',
#   'leek',
#   'asparagus',
#   'fresh tarragon'],
#  360752: ['unsalted butter',
#   'onion',
#   'heavy cream',
#   'frozen chopped spinach',
#   'salt',
#   'chicken broth',
#   'fresh ground black pepper',
#   'garlic',
#   'nutmeg'],
#  113839: ['unsalted butter',
#   'heavy cream',
#   'milk',
#   'sugar',
#   'powdered sugar',
#   'egg yolks',
#   'slivered almonds',
#   'ground almonds',
#   'rum',
#   'ladyfingers'],
#  54968: ['unsalted butter',
#   'eggs',
#   'salt',
#   'vanilla',
#   'all-purpose flour',
#   'baking soda',
#   'sugar',
#   'cinnamon',
#   'cream cheese',
#   'powdered sugar',
#   'nutmeg',
#   'granny smith apple',
#   'cognac',
#   'clove',
#   'corn oil'],
#  354868: ['unsalted butter',
#   'fresh lemon juice',
#   'sugar',
#   'vanilla extract',
#   'whipping cream',
#   'ground cinnamon',
#   'egg yolks',
#   'heavy whipping cream',
#   'whole milk',
#   'dry sherry',
#   'cake flour',
#   'bosc pears',
#   'ladyfingers',
#   'canned pumpkin puree',
#   'fuji apples'],
#  510837: ['unsalted butter',
#   'eggs',
#   'salt',
#   'bacon',
#   'fresh ground black pepper',
#   'shallots',
#   'nutmeg',
#   'gruyere cheese',
#   'parmigiano-reggiano cheese',
#   'whole milk',
#   'french bread cubes'],
#  454498: ['unsalted butter',
#   'eggs',
#   'vanilla extract',
#   'caster sugar',
#   'chocolate',
#   'irish cream',
#   'self raising flour'],
#  2056: ['unsalted butter',
#   'cinnamon',
#   'nutmeg',
#   'acorn squash',
#   'pure maple syrup'],
#  189716: ['unsalted butter',
#   'creme fraiche',
#   'golden delicious apples',
#   'blackberry jam'],
#  476032: ['unsalted butter',
#   'cornstarch',
#   'milk',
#   'fresh lemon juice',
#   'sour cream',
#   'baking powder',
#   'all-purpose flour',
#   'sugar',
#   'lemon juice',
#   'vanilla extract',
#   'orange juice',
#   'ricotta cheese',
#   'kosher salt',
#   'lemon zest',
#   'fresh blueberries',
#   'extra-large eggs',
#   'mascarpone cheese'],
#  382060: ['unsalted butter',
#   'carrot',
#   'onion',
#   'celery',
#   'garlic powder',
#   'water',
#   'ground black pepper',
#   'onions',
#   'brown rice',
#   'kosher salt'],
#  479742: ['unsalted butter',
#   'celery',
#   'dried thyme',
#   'cornstarch',
#   'fresh parsley',
#   'salt',
#   'onions',
#   'black pepper',
#   'chicken broth',
#   'dried marjoram'],
#  48861: ['unsalted butter',
#   'chicken stock',
#   'sour cream',
#   'rosemary',
#   'chicken',
#   'salt and pepper'],
#  369627: ['unsalted butter',
#   'onion',
#   'dried thyme',
#   'heavy cream',
#   'milk',
#   'eggs',
#   'salt',
#   'hot pepper sauce',
#   'ground cumin',
#   'red bell pepper',
#   'green bell pepper',
#   'fresh ground pepper',
#   'mushrooms',
#   'colby cheese'],
#  185257: ['unsalted butter',
#   'eggs',
#   'brown sugar',
#   'vanilla',
#   'maple syrup',
#   'ground cinnamon',
#   'pecans',
#   'light cream',
#   'challah'],
#  157276: ['unsalted butter',
#   'dried thyme',
#   'fresh parsley',
#   'onions',
#   'chicken broth',
#   'half-and-half',
#   'fresh ground pepper',
#   'garlic',
#   'sea salt'],
#  419300: ['unsalted butter',
#   'milk',
#   'cheddar cheese',
#   'salt',
#   'pepper',
#   'water',
#   'all-purpose flour',
#   'paprika',
#   'macaroni'],
#  272706: ['unsalted butter',
#   'heavy cream',
#   'parmesan cheese',
#   'salt & freshly ground black pepper',
#   'fresh spinach',
#   'tomato puree',
#   'pancetta',
#   'medium pasta shell'],
#  150400: ['unsalted butter',
#   'worcestershire sauce',
#   'salt',
#   'adobo sauce',
#   'dry red wine',
#   'garlic clove',
#   'chipotle chile in adobo',
#   'medium shrimp'],
#  323783: ['unsalted butter',
#   'fresh ground black pepper',
#   'lime, juice of',
#   'lime, zest of',
#   'tilapia fillets',
#   'crazy salt'],
#  498924: ['unsalted butter',
#   'fresh parsley',
#   'orange juice',
#   'nutmeg',
#   'orange',
#   'grand marnier',
#   'yam',
#   'orange slices'],
#  237054: ['unsalted butter',
#   'eggs',
#   'water',
#   'oil',
#   'vanilla extract',
#   'buttermilk',
#   "devil's food cake mix",
#   "confectioners' sugar",
#   'table salt',
#   'marshmallow cream'],
#  20505: ['unsalted butter',
#   'honey',
#   'balsamic vinegar',
#   'goat cheese',
#   'bosc pears'],
#  183463: ['unsalted butter',
#   'honey',
#   'black pepper',
#   'balsamic vinegar',
#   'pears',
#   'manchego cheese'],
#  301370: ['unsalted butter',
#   'heavy cream',
#   'milk',
#   'eggs',
#   'salt',
#   'baking powder',
#   'sugar',
#   'vanilla extract',
#   'light corn syrup',
#   'semi-sweet chocolate chips',
#   'unbleached all-purpose flour',
#   'unsweetened baking chocolate'],
#  196320: ['unsalted butter',
#   'flour',
#   'salt',
#   'baking powder',
#   'vanilla',
#   'egg',
#   'banana',
#   'granulated sugar',
#   'light brown sugar',
#   'semi-sweet chocolate chips',
#   'walnut pieces'],
#  99580: ['unsalted butter',
#   'eggs',
#   'butter',
#   'fresh lemon juice',
#   'honey',
#   'brown sugar',
#   'salt',
#   'baking powder',
#   'white sugar',
#   'all-purpose flour',
#   'baking soda',
#   'cinnamon',
#   'walnuts',
#   'banana',
#   'allspice',
#   'nutmeg',
#   'pure vanilla extract',
#   'banana granola',
#   'chocolate-covered english toffee bars'],
#  58002: ['unsalted butter',
#   'salt',
#   'baking powder',
#   'bananas',
#   'all-purpose flour',
#   'baking soda',
#   'sugar',
#   'egg',
#   'buttermilk',
#   'ground cinnamon',
#   'walnuts',
#   'semi-sweet chocolate chips',
#   'golden brown sugar'],
#  89417: ['unsalted butter',
#   'eggs',
#   'brown sugar',
#   'flour',
#   'salt',
#   'baking powder',
#   'bananas',
#   'water',
#   'vanilla extract',
#   'powdered sugar',
#   'walnuts',
#   'unsweetened cocoa powder',
#   'mini chocolate chip'],
#  440156: ['unsalted butter',
#   'onion',
#   'all-purpose flour',
#   'nutmeg',
#   'ginger',
#   'vegetable broth',
#   'banana squash',
#   'dry vermouth'],
#  97569: ['unsalted butter',
#   'bananas',
#   'whole milk',
#   'dark brown sugar',
#   'bread',
#   'double cream',
#   'clear honey'],
#  359581: ['unsalted butter',
#   'heavy cream',
#   'eggs',
#   'butter',
#   'salt',
#   'baking powder',
#   'baking soda',
#   'lemon juice',
#   'vanilla extract',
#   'buttermilk',
#   'granulated sugar',
#   'light brown sugar',
#   'cake flour',
#   'mashed banana',
#   'caramel icing'],
#  414513: ['unsalted butter',
#   'milk',
#   'eggs',
#   'honey',
#   'salt',
#   'baking powder',
#   'bananas',
#   'pecans',
#   'self-raising flour',
#   'vanilla essence',
#   'caster sugar',
#   'almond essence',
#   'demerara sugar'],
#  307156: ['unsalted butter',
#   'eggs',
#   'butter',
#   'brown sugar',
#   'sour cream',
#   'salt',
#   'vanilla',
#   'all-purpose flour',
#   'baking soda',
#   'cinnamon',
#   'vanilla extract',
#   'cream cheese',
#   'ground cinnamon',
#   'powdered sugar',
#   'granulated sugar',
#   'dark rum',
#   'firm bananas'],
#  104428: ['unsalted butter',
#   'flour',
#   'salt',
#   'baking powder',
#   'sugar',
#   'egg',
#   'walnuts',
#   'fresh orange juice',
#   'orange zest',
#   'unsweetened dutch cocoa'],
#  204963: ['unsalted butter',
#   'milk',
#   'sour cream',
#   'baking powder',
#   'bananas',
#   'all-purpose flour',
#   'sugar',
#   'pure vanilla extract',
#   'kosher salt',
#   'pure maple syrup',
#   'lemon zest',
#   'extra-large eggs'],
#  208643: ['unsalted butter',
#   'heavy cream',
#   'cornstarch',
#   'milk',
#   'salt',
#   'sugar',
#   'pure vanilla extract',
#   'cocoa powder',
#   'semisweet chocolate',
#   'extra-large egg yolks'],
#  217440: ['unsalted butter',
#   'cornstarch',
#   'sour cream',
#   'flour',
#   'baking soda',
#   'sugar',
#   'cream cheese',
#   'pure vanilla extract',
#   'kosher salt',
#   'blueberries',
#   "confectioners' sugar",
#   'raspberries',
#   'extra-large eggs'],
#  208412: ['unsalted butter',
#   'sour cream',
#   'baking powder',
#   'all-purpose flour',
#   'baking soda',
#   'ground cinnamon',
#   'walnuts',
#   'granulated sugar',
#   'light brown sugar',
#   'pure vanilla extract',
#   'kosher salt',
#   "confectioners' sugar",
#   'cake flour',
#   'extra-large eggs',
#   'real maple syrup'],
#  48475: ['unsalted butter',
#   'onion',
#   'potatoes',
#   'carrots',
#   'olive oil',
#   'parmesan cheese',
#   'chicken broth',
#   'parsley',
#   'dried basil',
#   'red pepper flakes',
#   'garlic',
#   'fresh rosemary',
#   'barley',
#   'dried marjoram',
#   'celery rib'],
#  17782: ['unsalted butter', 'salt', 'water', 'all-purpose flour'],
#  262577: ['unsalted butter',
#   'fresh lemon juice',
#   'dry mustard',
#   'salt and pepper',
#   'garlic',
#   'fresh herbs'],
#  112973: ['unsalted butter',
#   'salt',
#   'half-and-half',
#   'white pepper',
#   'white potatoes'],
#  359497: ['unsalted butter',
#   'eggs',
#   'salt',
#   'baking powder',
#   'sugar',
#   'vanilla extract',
#   'whole milk',
#   'cake flour'],
#  74238: ['unsalted butter',
#   'olive oil',
#   'parmesan cheese',
#   'cream cheese',
#   'pine nuts',
#   'fresh basil leaves',
#   'cheesecloth'],
#  32311: ['unsalted butter', 'parmesan cheese', 'garlic', 'basil'],
#  349394: ['unsalted butter',
#   'dry white wine',
#   'fresh lemon juice',
#   'fresh parsley',
#   'garlic cloves',
#   'olive oil',
#   'fresh ground black pepper',
#   'shallots',
#   'panko breadcrumbs',
#   'kosher salt',
#   'lemon',
#   'bay scallops',
#   'prosciutto di parma',
#   'pernod'],
#  173134: ['unsalted butter',
#   'dry white wine',
#   'heavy cream',
#   'vegetable oil',
#   'salt',
#   'mayonnaise',
#   'lemon, juice of',
#   'bacon',
#   'shrimp',
#   'lettuce',
#   'tomatoes',
#   'white pepper',
#   'shallots',
#   'salt and pepper',
#   'sourdough bread',
#   'champagne vinegar'],
#  263056: ['unsalted butter',
#   'carrot',
#   'sliced mushrooms',
#   'chopped tomatoes',
#   'salt and pepper',
#   'cheese',
#   'canned tomatoes',
#   'green beans',
#   'plain flour',
#   'minced beef',
#   'instant oxo'],
#  190538: ['unsalted butter',
#   'sour cream',
#   'mayonnaise',
#   'dijon mustard',
#   'fresh ground black pepper',
#   'fresh coarse ground black pepper',
#   'kosher salt',
#   'arugula',
#   'bread',
#   'whole grain mustard',
#   'prepared horseradish',
#   'filet of beef'],
#  103833: ['unsalted butter',
#   'onion',
#   'flour',
#   'salt',
#   'baking powder',
#   'water',
#   'carrots',
#   'egg',
#   'olive oil',
#   'salt and pepper',
#   'bay leaf',
#   'egg yolk',
#   'ice water',
#   'fresh peas',
#   'yellow cornmeal',
#   'boiling potatoes',
#   'lean beef chuck'],
#  176441: ['unsalted butter',
#   'onion',
#   'dried oregano',
#   'worcestershire sauce',
#   'carrots',
#   'garlic cloves',
#   'parmesan cheese',
#   'ground beef',
#   'extra virgin olive oil',
#   'russet potatoes',
#   'fresh ground black pepper',
#   'tomato paste',
#   'kosher salt',
#   'whole milk',
#   'mashed potatoes',
#   'fresh flat-leaf parsley',
#   'celery rib',
#   'low sodium beef broth',
#   'cremini mushroom'],
#  370964: ['unsalted butter',
#   'milk',
#   'eggs',
#   'honey',
#   'vanilla extract',
#   'beer',
#   'self-rising flour'],
#  311108: ['unsalted butter',
#   'hot sauce',
#   'lemon juice',
#   'garlic cloves',
#   'old bay seasoning',
#   'beer',
#   'extra-large shrimp'],
#  422595: ['unsalted butter',
#   'caraway seed',
#   'mustard seeds',
#   'white onions',
#   'hoagie rolls',
#   'bratwursts',
#   'brown ale',
#   'sweet-hot mustard'],
#  196371: ['unsalted butter',
#   'salt',
#   'white sugar',
#   'beets',
#   'bosc pears',
#   'vidalia onions',
#   'raspberry vinegar'],
#  304615: ['unsalted butter',
#   'heavy cream',
#   'salt',
#   'ground black pepper',
#   'carrots',
#   'granulated sugar',
#   'nutmeg',
#   'dried parsley'],
#  271687: ['unsalted butter',
#   'eggs',
#   'slivered almonds',
#   'almond extract',
#   'light cream cheese',
#   'corn flake crumbs',
#   'sugar substitute',
#   'lemon cake mix',
#   'strawberry preserves'],
#  427488: ['unsalted butter',
#   'all-purpose flour',
#   'cinnamon',
#   'pecans',
#   'granulated sugar',
#   'oats',
#   'frozen blueberries',
#   'dark brown sugar',
#   'orange',
#   'frozen raspberries'],
#  265531: ['unsalted butter',
#   'sugar',
#   'pecans',
#   'blueberries',
#   'raspberries',
#   'blackberry',
#   'vanilla cake mix'],
#  434903: ['unsalted butter',
#   'baking powder',
#   'vanilla extract',
#   'granulated sugar',
#   'egg whites',
#   'nonstick cooking spray',
#   'almond extract',
#   'whole milk',
#   "confectioners' sugar",
#   'cake flour',
#   'blanched slivered almond',
#   'table salt',
#   'raspberry jam'],
#  429882: ['unsalted butter',
#   'eggs',
#   'salt',
#   'all-purpose flour',
#   'sugar',
#   'walnuts',
#   'pure vanilla extract',
#   'unsweetened cocoa powder'],
#  108281: ['unsalted butter',
#   'salt',
#   'all-purpose flour',
#   'sugar',
#   'white vinegar',
#   'shortening',
#   'ice water'],
#  384511: ['unsalted butter',
#   'onion',
#   'salt & fresh ground pepper',
#   'vegetable oil',
#   'ketchup',
#   'mayonnaise',
#   'ground black pepper',
#   'sugar',
#   'sweet pickle relish',
#   'white vinegar',
#   'american cheese',
#   'hamburger buns',
#   'sirloin steaks',
#   'boneless beef short ribs'],
#  503781: ['unsalted butter',
#   'eggs',
#   'sour cream',
#   'baking powder',
#   'vanilla',
#   'all-purpose flour',
#   'baking soda',
#   'sugar',
#   'cinnamon',
#   'nutmeg',
#   'cream of tartar'],
#  118183: ['unsalted butter',
#   'eggs',
#   'flour',
#   'salt',
#   'vanilla',
#   'baking soda',
#   'pecans',
#   'white chocolate chips',
#   'butterscotch chips',
#   'dark brown sugar',
#   'light molasses'],
#  239210: ['unsalted butter',
#   'dry white wine',
#   'olive oil',
#   'parmesan cheese',
#   'arborio rice',
#   'salt and pepper',
#   'garlic',
#   'fresh thyme',
#   'yellow onion',
#   'low sodium chicken broth',
#   'fresh chives',
#   'shiitake mushrooms'],
#  221275: ['unsalted butter',
#   'milk',
#   'all-purpose flour',
#   'nuts',
#   'instant vanilla pudding',
#   'cream cheese',
#   'instant chocolate pudding mix',
#   'walnuts',
#   "confectioners' sugar",
#   'frozen whipped topping',
#   'chocolate curls'],
#  266425: ['unsalted butter',
#   'salt',
#   'sugar',
#   'lemon juice',
#   'dry mustard',
#   'frozen lima beans'],
#  70637: ['unsalted butter',
#   'eggs',
#   'brown sugar',
#   'flour',
#   'vanilla',
#   'baking soda',
#   'chocolate chips',
#   'sugar',
#   'canola oil',
#   'vanilla instant pudding mix'],
#  162172: ['unsalted butter',
#   'salt',
#   'all-purpose flour',
#   'baking soda',
#   'sugar',
#   'ground cinnamon',
#   'raisins',
#   'rolled oats',
#   'pure vanilla extract',
#   'egg white'],
#  167665: ['unsalted butter',
#   'milk',
#   'pure vanilla extract',
#   "confectioners' sugar",
#   'semisweet chocolate'],
#  342877: ['unsalted butter',
#   'milk',
#   'pure vanilla extract',
#   "confectioners' sugar"],
#  250167: ['unsalted butter',
#   'eggs',
#   'salt',
#   'all-purpose flour',
#   'baking soda',
#   'walnuts',
#   'granulated sugar',
#   'semi-sweet chocolate chips',
#   'unsweetened cocoa powder',
#   "confectioners' sugar"],
#  155637: ['unsalted butter',
#   'eggs',
#   'salt',
#   'baking powder',
#   'sesame seeds',
#   'all-purpose flour',
#   'sugar',
#   'vanilla extract',
#   'orange zest'],
#  408642: ['unsalted butter',
#   'heavy cream',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'sugar',
#   'half-and-half'],
#  374312: ['unsalted butter',
#   'heavy cream',
#   'water',
#   'vanilla extract',
#   'bittersweet chocolate',
#   'unsweetened cocoa powder',
#   'kosher salt',
#   'whole milk',
#   'corn syrup'],
#  170543: ['unsalted butter',
#   'heavy cream',
#   'eggs',
#   'salt',
#   'sugar',
#   'cinnamon',
#   'bittersweet chocolate',
#   'whole almonds',
#   'orange, zest of'],
#  41273: ['unsalted butter',
#   'fresh parsley',
#   'all-purpose flour',
#   'chicken broth',
#   'shallots',
#   'garlic',
#   'egg yolks',
#   'beef broth',
#   'mushroom',
#   'fresh chives',
#   'creme fraiche',
#   'anise seed',
#   'pernod',
#   'riesling wine',
#   'escargot'],
#  330225: ['unsalted butter',
#   'heavy cream',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'baking soda',
#   'buttermilk',
#   'fresh ground black pepper'],
#  244642: ['unsalted butter',
#   'milk',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'sugar',
#   'egg',
#   'cream cheese',
#   'ground cinnamon',
#   'pure vanilla extract',
#   'lemon zest',
#   'fresh blackberries'],
#  26059: ['unsalted butter',
#   'garlic powder',
#   'salt',
#   'paprika',
#   'dried basil',
#   'onion powder',
#   'ground pepper',
#   'thyme',
#   'lemon pepper',
#   'catfish fillets'],
#  35400: ['unsalted butter', 'olive oil', 'blue cheese', 'garlic'],
#  88190: ['unsalted butter',
#   'eggs',
#   'brown sugar',
#   'salt',
#   'all-purpose flour',
#   'baking soda',
#   'chocolate chips',
#   'vanilla extract',
#   'pecans',
#   'granulated sugar'],
#  99121: ['unsalted butter',
#   'milk',
#   'flour',
#   'parmesan cheese',
#   'blue cheese',
#   'dry mustard',
#   'salt and pepper',
#   'egg yolks',
#   'cream of tartar',
#   'egg whites'],
#  364629: ['unsalted butter',
#   'worcestershire sauce',
#   'eggs',
#   'butter',
#   'salt',
#   'all-purpose flour',
#   'fresh ground pepper',
#   'tomato sauce',
#   'yellow onion',
#   'button mushrooms',
#   'fresh thyme sprig',
#   'beef stock',
#   'old fashioned oats',
#   'ground pork',
#   'ground veal',
#   'ground beef round'],
#  98749: ['unsalted butter',
#   'cornstarch',
#   'fresh lemon juice',
#   'water',
#   'sugar',
#   'phyllo dough',
#   'whipping cream',
#   'nutmeg',
#   'blueberries',
#   "confectioners' sugar"],
#  86136: ['unsalted butter', 'powdered sugar', 'fresh blueberries'],
#  241803: ['unsalted butter',
#   'eggs',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'sugar',
#   'buttermilk',
#   'pure maple syrup',
#   'fresh blueberries'],
#  477272: ['unsalted butter',
#   'cornstarch',
#   'brown sugar',
#   'salt',
#   'all-purpose flour',
#   'baking soda',
#   'cinnamon',
#   'egg',
#   'lemon juice',
#   'cream cheese',
#   'walnuts',
#   'granulated sugar',
#   'pure vanilla extract',
#   'frozen blueberries',
#   'quick-cooking oats'],
#  29662: ['unsalted butter',
#   'all-purpose flour',
#   'sugar',
#   'nutmeg',
#   'coconut',
#   'limes, juice of',
#   'fresh blueberries',
#   'pie crust',
#   'quick-cooking tapioca',
#   'limes, zest of'],
#  199959: ['unsalted butter',
#   'milk',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'egg',
#   'dried blueberries',
#   'maple sugar'],
#  161111: ['unsalted butter',
#   'heavy cream',
#   'fresh lemon juice',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'sugar',
#   'lemon, zest of',
#   "confectioners' sugar",
#   'fresh blueberries'],
#  244646: ['unsalted butter',
#   'milk',
#   'brown sugar',
#   'salt',
#   'baking powder',
#   'cream',
#   'all-purpose flour',
#   'sugar',
#   'egg',
#   'ground cinnamon',
#   'pure vanilla extract',
#   'fresh blueberries'],
#  102738: ['unsalted butter',
#   'eggs',
#   'salt',
#   'all-purpose flour',
#   'sugar',
#   'buttermilk',
#   'lime zest',
#   'blueberries',
#   'sweetened flaked coconut'],
#  181334: ['unsalted butter',
#   'heavy cream',
#   'cornstarch',
#   'honey',
#   'brown sugar',
#   'flour',
#   'salt',
#   'baking powder',
#   'white sugar',
#   'cinnamon',
#   'cornmeal',
#   'vanilla ice cream',
#   'blueberries',
#   'fresh orange juice',
#   'lemon zest'],
#  460385: ['unsalted butter',
#   'salt',
#   'black pepper',
#   'rosemary',
#   'extra virgin olive oil',
#   'chicken breasts',
#   'shallots',
#   'blueberries',
#   'balsamic vinegar',
#   'sugar-free maple syrup'],
#  244328: ['unsalted butter',
#   'eggs',
#   'butter',
#   'salt',
#   'all-purpose flour',
#   'sugar',
#   'vanilla extract',
#   'whole milk',
#   'brandy',
#   'fruit filling'],
#  373136: ['unsalted butter',
#   'heavy cream',
#   'eggs',
#   'salt',
#   'water',
#   'all-purpose flour',
#   'vanilla extract',
#   'ground cinnamon',
#   'granulated sugar',
#   'light brown sugar',
#   'granny smith apples',
#   'calvados',
#   'whole milk',
#   'lemon zest',
#   'cinnamon stick'],
#  205903: ['unsalted butter',
#   'eggs',
#   'hot sauce',
#   'garlic salt',
#   'extra-sharp cheddar cheese',
#   'jalapenos',
#   'quick-cooking grits',
#   'diced green chilis'],
#  363935: ['unsalted butter',
#   'dry white wine',
#   'honey',
#   'salt',
#   'garlic cloves',
#   'olive oil',
#   'fresh ground black pepper',
#   'french bread',
#   'chipotle chile in adobo',
#   'kosher salt',
#   'flat leaf parsley',
#   'vegetables',
#   'roasted red pepper',
#   'idaho potatoes',
#   'fresh spinach leaves',
#   'spanish onion',
#   'unsweetened coconut milk',
#   'poblano chiles',
#   'mussels',
#   'clam broth',
#   'prepared mayonnaise'],
#  293515: ['unsalted butter',
#   'eggs',
#   'flour',
#   'sugar',
#   'bittersweet chocolate',
#   'whipping cream',
#   'white chocolate',
#   'bourbon'],
#  402259: ['unsalted butter',
#   'eggs',
#   'brown sugar',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'vanilla extract',
#   'granulated sugar',
#   "m&m's semi-sweet chocolate baking bits"],
#  331929: ['unsalted butter',
#   'onions',
#   'carrots',
#   'garlic cloves',
#   'extra virgin olive oil',
#   'fresh sage',
#   'sea salt',
#   'plum tomatoes',
#   'fresh ground white pepper',
#   'fresh thyme leaves',
#   'pork loin roast'],
#  366685: ['unsalted butter',
#   'heavy cream',
#   'cornstarch',
#   'milk',
#   'flour',
#   'salt',
#   'baking powder',
#   'water',
#   'sugar',
#   'vanilla extract',
#   'bittersweet chocolate',
#   'chocolate syrup',
#   'egg yolks',
#   'egg whites',
#   'whole milk',
#   'vanilla bean',
#   'creme fraiche',
#   'cake flour'],
#  195302: ['unsalted butter',
#   'maple syrup',
#   'ground nutmeg',
#   'ground cloves',
#   'shallots',
#   'apple cider',
#   'dried sage',
#   'golden delicious apples',
#   'bourbon'],
#  65204: ['unsalted butter',
#   'salt',
#   'garlic cloves',
#   'cream cheese',
#   'fresh ground black pepper',
#   'fresh basil',
#   'thyme',
#   'marjoram',
#   'dill weed',
#   'fresh chives'],
#  397909: ['unsalted butter',
#   'cornstarch',
#   'eggs',
#   'sour cream',
#   'salt',
#   'vanilla',
#   'water',
#   'sugar',
#   'cinnamon',
#   'cream cheese',
#   'brandy',
#   'cranberries',
#   'chocolate cookie crumbs'],
#  282964: ['unsalted butter',
#   'milk',
#   'eggs',
#   'butter',
#   'brown sugar',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'vanilla extract',
#   'pecans',
#   'powdered sugar',
#   'semi-sweet chocolate chips',
#   'brandy',
#   '2% low-fat milk',
#   'baking cocoa'],
#  148306: ['unsalted butter',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'baking soda',
#   'sugar',
#   'egg',
#   'boiling water',
#   'walnuts',
#   'cold water',
#   'pure vanilla extract',
#   'brandy',
#   'dates'],
#  93118: ['unsalted butter',
#   'salt',
#   'water',
#   'egg',
#   'orange juice',
#   'ground nutmeg',
#   'granulated sugar',
#   'bread flour',
#   'nonfat dry milk powder',
#   'dry yeast',
#   'orange zest',
#   'mashed potatoes',
#   'ground mace'],
#  501464: ['unsalted butter',
#   'heavy cream',
#   'milk',
#   'eggs',
#   'sour cream',
#   'sugar',
#   'vanilla extract',
#   'ground cinnamon',
#   'ground nutmeg',
#   'pecans',
#   'raisins',
#   'brandy',
#   'grand marnier',
#   'white bread cubes'],
#  51546: ['unsalted butter',
#   'eggs',
#   'sugar',
#   'egg',
#   'active dry yeast',
#   'unbleached all-purpose flour',
#   'kosher salt',
#   'whole milk'],
#  13632: ['unsalted butter',
#   'broccoli',
#   'lemon juice',
#   'dijon mustard',
#   'salt and pepper',
#   'cauliflower'],
#  124388: ['unsalted butter',
#   'broccoli',
#   'soy sauce',
#   'fresh ground black pepper',
#   'balsamic vinegar'],
#  91: ['unsalted butter',
#   'celery',
#   'broccoli floret',
#   'oregano',
#   'brown rice',
#   'chicken broth',
#   'green onion',
#   'coconut',
#   'marjoram',
#   'fresh gingerroot',
#   'lemons',
#   'summer savory',
#   'fresh snow pea'],
#  372902: ['unsalted butter',
#   'pineapple',
#   'dark brown sugar',
#   'dark rum',
#   'sweetened flaked coconut'],
#  473172: ['unsalted butter',
#   'flour',
#   'salt',
#   'baking powder',
#   'white sugar',
#   'baking soda',
#   'cinnamon',
#   'buttermilk',
#   'half-and-half',
#   'walnuts',
#   'dark brown sugar',
#   'golden raisin',
#   'cake flour'],
#  315823: ['unsalted butter',
#   'salt',
#   'fresh ground pepper',
#   'skim milk',
#   'sweet potatoes',
#   'scallions',
#   'fresh gingerroot',
#   'large scallop'],
#  58783: ['unsalted butter',
#   'fresh lemon juice',
#   'all-purpose flour',
#   'baking soda',
#   'ground cinnamon',
#   'vanilla ice cream',
#   'egg yolk',
#   'lemon, rind of',
#   'dark brown sugar',
#   'golden delicious apples'],
#  180648: ['unsalted butter',
#   'eggs',
#   'sour cream',
#   'flour',
#   'baking powder',
#   'vanilla',
#   'sugar',
#   'cream cheese',
#   'light brown sugar',
#   'creamy peanut butter',
#   'semisweet chocolate',
#   'unsweetened chocolate'],
#  187035: ['unsalted butter',
#   'eggs',
#   'baking powder',
#   'all-purpose flour',
#   'sugar',
#   'unsweetened chocolate'],
#  511255: ['unsalted butter',
#   'heavy cream',
#   'butter',
#   'all-purpose flour',
#   'sugar',
#   'fresh ground black pepper',
#   'gruyere cheese',
#   'shallot',
#   'kosher salt',
#   'parmigiano-reggiano cheese',
#   'red wine vinegar',
#   'ice water',
#   'lemon zest',
#   'fresh flat-leaf parsley',
#   'fresh breadcrumbs',
#   'brussels sprouts'],
#  364628: ['unsalted butter',
#   'flour',
#   'salt',
#   'olive oil',
#   'chicken breasts',
#   'white wine',
#   'capers',
#   'lemons'],
#  356948: ['unsalted butter',
#   'cornstarch',
#   'salt',
#   'sugar',
#   'granulated sugar',
#   'cake flour'],
#  266173: ['unsalted butter',
#   'eggs',
#   'salt',
#   'baking powder',
#   'sugar',
#   'vanilla extract',
#   'boiling water',
#   'bittersweet chocolate',
#   'walnuts',
#   'cake flour',
#   'unsweetened chocolate',
#   'instant coffee powder',
#   'bittersweet chocolate chips'],
#  175759: ['unsalted butter',
#   'salt',
#   'boiling water',
#   'garlic cloves',
#   'olive oil',
#   'red onion',
#   'fresh ground black pepper',
#   'frozen baby peas',
#   'cracked bulgur wheat'],
#  378226: ['unsalted butter',
#   'fresh ground black pepper',
#   'egg noodles',
#   'kosher salt',
#   'pecorino cheese'],
#  374057: ['unsalted butter',
#   'onion',
#   'pepper',
#   'bacon',
#   'white potatoes',
#   'herb-seasoned salt'],
#  75835: ['unsalted butter',
#   'eggs',
#   'flour',
#   'baking soda',
#   'sugar',
#   'buttermilk',
#   'blueberries'],
#  483392: ['unsalted butter',
#   'salt',
#   'baking powder',
#   'vanilla',
#   'all-purpose flour',
#   'baking soda',
#   'sugar',
#   'egg',
#   'buttermilk',
#   'blackberries'],
#  326191: ['unsalted butter',
#   'fresh parsley',
#   'buttermilk',
#   'dijon mustard',
#   'russet potatoes'],
#  66241: ['unsalted butter',
#   'eggs',
#   'vegetable oil',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'baking soda',
#   'sugar',
#   'vanilla extract',
#   'maple syrup',
#   'buttermilk'],
#  473988: ['unsalted butter',
#   'flour',
#   'baking powder',
#   'vanilla',
#   'sugar',
#   'egg',
#   'buttermilk',
#   'kosher salt',
#   'lemon zest',
#   'fresh blueberries'],
#  279809: ['unsalted butter',
#   'onion',
#   'butter',
#   'fresh lemon juice',
#   'salt',
#   'all-purpose flour',
#   'sugar',
#   'olive oil',
#   'fat free sour cream',
#   'cayenne',
#   'fontina cheese',
#   'fresh sage leaves',
#   'butternut squash',
#   'ice water'],
#  166955: ['unsalted butter',
#   'eggs',
#   'salt',
#   'all-purpose flour',
#   'parmesan cheese',
#   'salt and pepper',
#   'fresh sage leaves',
#   'butternut squash'],
#  153299: ['unsalted butter',
#   'water',
#   'fresh ground pepper',
#   'low sodium chicken broth',
#   'dark brown sugar',
#   'butternut squash',
#   'coarse salt'],
#  64574: ['unsalted butter',
#   'eggs',
#   'butter',
#   'brown sugar',
#   'salt',
#   'cream cheese',
#   'pecans',
#   'granulated sugar',
#   'raisins',
#   'ricotta cheese',
#   'butterscotch chips',
#   'cooked egg noodles',
#   'raw carrots',
#   'mild curry powder'],
#  514138: ['unsalted butter',
#   'baking powder',
#   'all-purpose flour',
#   'baking soda',
#   'sugar',
#   'egg',
#   'light brown sugar',
#   'pure vanilla extract',
#   'kosher salt',
#   'butterscotch chips',
#   'dried shredded coconut'],
#  403264: ['unsalted butter',
#   'milk',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'sugar',
#   'egg',
#   'vanilla extract',
#   'granulated sugar',
#   'ground ginger',
#   'cherry preserves'],
#  170601: ['unsalted butter',
#   'heavy cream',
#   'eggs',
#   'salt',
#   'vanilla',
#   'all-purpose flour',
#   'walnuts',
#   'granulated sugar',
#   'instant coffee crystals'],
#  40826: ['unsalted butter',
#   'salt',
#   'onions',
#   'sugar',
#   'cayenne pepper',
#   'red bell pepper',
#   'fresh ground black pepper',
#   'sweet corn',
#   'celery ribs',
#   'tomatoes',
#   'green bell pepper',
#   'evaporated milk'],
#  39392: ['unsalted butter',
#   'honey',
#   'salt',
#   'ground black pepper',
#   'lemon juice',
#   'olive oil',
#   'parsley',
#   'seasoning',
#   'crushed red pepper flakes',
#   'cayenne',
#   'garlic',
#   'dried whole thyme',
#   'prawns',
#   'dried rosemary leaves',
#   'gluten-free soy sauce',
#   'dry oregano'],
#  67252: ['unsalted butter',
#   'onion',
#   'celery',
#   'tabasco sauce',
#   'eggs',
#   'oregano',
#   'salt',
#   'chicken broth',
#   'bay leaves',
#   'white pepper',
#   'onion powder',
#   'garlic',
#   'evaporated milk',
#   'thyme',
#   'green pepper',
#   'red pepper',
#   'cornbread',
#   'andouille sausage'],
#  487398: ['unsalted butter',
#   'dried thyme',
#   'dried oregano',
#   'paprika',
#   'black pepper',
#   'cayenne pepper',
#   'garlic salt',
#   'tilapia fillets'],
#  191372: ['unsalted butter',
#   'hot sauce',
#   'fresh cilantro',
#   'celery seed',
#   'extra virgin olive oil',
#   'fresh ground black pepper',
#   'chili powder',
#   'coarse sea salt',
#   'chicken wings',
#   'sweet paprika',
#   'thai sweet chili sauce',
#   'wheat beer',
#   'wood chips'],
#  45188: ['unsalted butter',
#   'heavy cream',
#   'walnuts',
#   'shallots',
#   'fresh chives',
#   'raisin bread',
#   'camembert cheese',
#   'grapes',
#   'truffle butter',
#   'fresh pear'],
#  316496: ['unsalted butter',
#   'carrot',
#   'water',
#   'all-purpose flour',
#   'ground black pepper',
#   'celery seed',
#   'potatoes',
#   'onions',
#   'egg',
#   'lemon juice',
#   'garlic cloves',
#   'bay leaves',
#   'ground cloves',
#   'allspice',
#   'apple cider',
#   'vegetable shortening',
#   'ground pork',
#   'fine salt'],
#  74509: ['unsalted butter',
#   'honey',
#   'salt',
#   'onions',
#   'cayenne pepper',
#   'nutmeg',
#   'granny smith apple',
#   'yams'],
#  111596: ['unsalted butter',
#   'eggs',
#   'sour cream',
#   'all-purpose flour',
#   'sugar',
#   'vanilla extract',
#   'cream cheese',
#   'kahlua',
#   'bittersweet chocolate',
#   'whipping cream',
#   'ground nutmeg',
#   'dark brown sugar',
#   'dark rum',
#   'chocolate wafer cookies',
#   'light molasses',
#   'instant espresso powder',
#   'espresso beans'],
#  206967: ['unsalted butter',
#   'eggs',
#   'brown sugar',
#   'all-purpose flour',
#   'sugar',
#   'vanilla extract',
#   'cream cheese',
#   'ground cinnamon',
#   'nutmeg',
#   'granny smith apples',
#   'quick-cooking oats',
#   'caramel topping'],
#  208162: ['unsalted butter',
#   'sugar',
#   'ground cinnamon',
#   'powdered sugar',
#   'ground cardamom',
#   'egg yolks',
#   'unbleached all-purpose flour',
#   'kosher salt',
#   'heavy whipping cream',
#   'dark brown sugar',
#   'golden delicious apples'],
#  324055: ['unsalted butter',
#   'eggs',
#   'flour',
#   'salt',
#   'baking powder',
#   'banana',
#   'granulated sugar',
#   'caramels',
#   'whole milk',
#   "confectioners' sugar"],
#  404987: ['unsalted butter',
#   'flour',
#   'salt',
#   'sugar',
#   'vanilla extract',
#   'light corn syrup',
#   'sweetened condensed milk',
#   'dark brown sugar'],
#  187751: ['unsalted butter',
#   'heavy cream',
#   'eggs',
#   'salt',
#   'baking powder',
#   'pecans',
#   'granulated sugar',
#   'pure vanilla extract',
#   'unbleached all-purpose flour',
#   'dark brown sugar',
#   "confectioners' sugar"],
#  304912: ['unsalted butter',
#   'salt',
#   'all-purpose flour',
#   'sugar',
#   'egg yolks',
#   'golden delicious apples'],
#  115138: ['unsalted butter',
#   'dry white wine',
#   'garlic cloves',
#   'extra virgin olive oil',
#   'white pepper',
#   'sea salt',
#   'fresh thyme',
#   'vegetable stock',
#   'fennel bulbs',
#   'small white beans'],
#  281473: ['unsalted butter',
#   'eggs',
#   'honey',
#   'sour cream',
#   'flour',
#   'salt',
#   'baking powder',
#   'baking soda',
#   'powdered sugar',
#   'ground cardamom',
#   'pure vanilla extract',
#   'whole milk'],
#  74778: ['unsalted butter',
#   'bananas',
#   'maple syrup',
#   'ground cinnamon',
#   'papaya',
#   'pineapple',
#   'yogurt',
#   'mango',
#   'dark rum'],
#  156124: ['unsalted butter',
#   'milk',
#   'eggs',
#   'baking powder',
#   'vanilla',
#   'sugar',
#   'sweet rice flour'],
#  153361: ['unsalted butter',
#   'onion',
#   'worcestershire sauce',
#   'tabasco sauce',
#   'garlic powder',
#   'vegetable oil',
#   'honey',
#   'celery seed',
#   'bacon',
#   'dijon mustard',
#   'salt & freshly ground black pepper',
#   'onion powder',
#   'dark brown sugar',
#   'sandwich bread',
#   'cider vinegar',
#   'ground lean pork',
#   'sweet paprika',
#   'green cabbage',
#   'hot paprika',
#   'liquid smoke'],
#  228068: ['unsalted butter',
#   'plain yogurt',
#   'eggs',
#   'vegetable oil',
#   'flour',
#   'salt',
#   'baking powder',
#   'baking soda',
#   'carrots',
#   'sugar',
#   'vanilla extract',
#   'cream cheese',
#   'ground cinnamon',
#   'powdered sugar',
#   'ground allspice',
#   'nutmeg',
#   'dark brown sugar'],
#  375044: ['unsalted butter',
#   'eggs',
#   'vegetable oil',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'baking soda',
#   'carrots',
#   'cream cheese',
#   'ground cinnamon',
#   'ground nutmeg',
#   'walnuts',
#   'granulated sugar',
#   'ground cloves',
#   'pineapple',
#   'white chocolate chips',
#   'lemon zest'],
#  19461: ['unsalted butter',
#   'onion',
#   'chicken stock',
#   'all-purpose flour',
#   'carrots',
#   'sugar',
#   'ginger',
#   'orange rind',
#   'light cream',
#   'clarified butter'],
#  210600: ['unsalted butter',
#   'heavy cream',
#   'fresh lemon juice',
#   'salt',
#   'carrots',
#   'sugar',
#   'chives',
#   'fresh nutmeg'],
#  492725: ['unsalted butter',
#   'dried thyme',
#   'dry white wine',
#   'salt',
#   'cooked chicken',
#   'pecans',
#   'chicken broth',
#   'half-and-half',
#   'fresh ground black pepper',
#   'yellow onion',
#   'rubbed sage',
#   'converted rice',
#   'unsifted all-purpose flour',
#   'baby bella mushrooms'],
#  21723: ['unsalted butter',
#   'cornstarch',
#   'brown sugar',
#   'flour',
#   'salt',
#   'baking powder',
#   'vanilla',
#   'all-purpose flour',
#   'sugar',
#   'cinnamon',
#   'half-and-half',
#   'nutmeg',
#   'granny smith apples',
#   'golden delicious apples'],
#  295664: ['unsalted butter',
#   'honey',
#   'water',
#   'kosher salt',
#   'saffron thread',
#   'whole chickens'],
#  343376: ['unsalted butter',
#   'vegetable oil',
#   'salt',
#   'garlic cloves',
#   'shallots',
#   'pine nuts',
#   'dried chili',
#   'black currants',
#   'escarole'],
#  133105: ['unsalted butter',
#   'onion',
#   'all-purpose flour',
#   'paprika',
#   'half-and-half',
#   'fresh ground pepper',
#   'nutmeg',
#   'whole milk',
#   'cauliflower',
#   'almonds',
#   'manchego cheese'],
#  344303: ['unsalted butter',
#   'fresh parsley',
#   'black pepper',
#   'garlic',
#   'kosher salt',
#   'fresh breadcrumb',
#   'lemon wedge',
#   'head cauliflower'],
#  94580: ['unsalted butter',
#   'salt',
#   'leeks',
#   'fresh ground black pepper',
#   'sun-dried tomatoes packed in oil',
#   'cauliflower'],
#  337604: ['unsalted butter',
#   'heavy cream',
#   'fresh ground black pepper',
#   'kosher salt',
#   'apple cider',
#   'yukon gold potatoes',
#   'golden delicious apples',
#   'fennel bulb',
#   'celery root'],
#  422429: ['unsalted butter',
#   'salt',
#   'all-purpose flour',
#   'vanilla extract',
#   'ground cinnamon',
#   'powdered sugar',
#   'granulated sugar',
#   'ground cloves',
#   'ground ginger',
#   'ground cardamom'],
#  271025: ['unsalted butter',
#   'eggs',
#   'flour',
#   'salt',
#   'vanilla',
#   'sugar',
#   'dark chocolate',
#   'champagne'],
#  137911: ['unsalted butter',
#   'heavy cream',
#   'cornstarch',
#   'fresh parsley',
#   'salt',
#   'pepper',
#   'lemon juice',
#   'boiling water',
#   'olive oil',
#   'dijon mustard',
#   'cayenne pepper',
#   'shallots',
#   'instant rice',
#   'boneless chicken breasts',
#   'portabella mushroom',
#   'dried tarragon',
#   'shiitake mushroom',
#   'rich chicken broth',
#   'chardonnay wine',
#   'cremini mushroom',
#   'dried porcini mushrooms'],
#  45180: ['unsalted butter',
#   'dry white wine',
#   'cornstarch',
#   'cheddar cheese',
#   'garlic',
#   'french bread',
#   'canned tomato'],
#  266354: ['unsalted butter',
#   'heavy cream',
#   'flour',
#   'salt',
#   'sharp cheddar cheese',
#   'cayenne pepper'],
#  138924: ['unsalted butter',
#   'honey',
#   'salt',
#   'water',
#   'all-purpose flour',
#   'dijon mustard',
#   'cayenne pepper',
#   'extra-sharp cheddar cheese',
#   'yeast',
#   'nonfat dry milk powder'],
#  47939: ['unsalted butter',
#   'flour',
#   'sharp cheddar cheese',
#   'paprika',
#   'stuffed olives'],
#  441650: ['unsalted butter',
#   'milk',
#   'all-purpose flour',
#   'black pepper',
#   'sliced mushrooms',
#   'parmesan cheese',
#   'shallots',
#   'broccoli florets',
#   'kosher salt',
#   'fontina cheese',
#   'baby spinach',
#   'bow tie pasta'],
#  150913: ['unsalted butter',
#   'milk',
#   'salt',
#   'all-purpose flour',
#   'sharp cheddar cheese',
#   'hot pepper sauce',
#   'dijon mustard',
#   'diced green chilies',
#   'head cauliflower',
#   'head broccoli'],
#  62166: ['unsalted butter',
#   'dried oregano',
#   'dry white wine',
#   'ground black pepper',
#   'reduced-sodium chicken broth',
#   'boneless chicken breasts',
#   'plain flour',
#   'reduced-fat cheddar cheese'],
#  445568: ['unsalted butter',
#   'brown sugar',
#   'salt',
#   'cinnamon',
#   'vanilla extract',
#   'pecans',
#   'nutmeg',
#   'puff pastry sheets'],
#  413222: ['unsalted butter',
#   'milk',
#   'eggs',
#   'salt',
#   'all-purpose flour',
#   'baking soda',
#   'sugar',
#   'white chocolate chips',
#   'pure vanilla extract',
#   'cocoa',
#   'dried sour cherries'],
#  400257: ['unsalted butter',
#   'eggs',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'sugar',
#   'graham cracker crumbs',
#   'vanilla extract',
#   'cream cheese',
#   'cherry pie filling'],
#  197840: ['unsalted butter',
#   'baking powder',
#   'water',
#   'all-purpose flour',
#   'baking soda',
#   'sugar',
#   'egg',
#   'vanilla extract',
#   'ground nutmeg',
#   'table salt',
#   'dried cherries',
#   'dried pears'],
#  336955: ['unsalted butter', 'flour', 'salt', 'sugar', 'dried cherries'],
#  49511: ['unsalted butter',
#   'eggs',
#   'flour',
#   'salt',
#   'baking powder',
#   'vanilla',
#   'sugar',
#   'powdered sugar',
#   'almond extract',
#   'cherry pie filling'],
#  4893: ['unsalted butter',
#   'celery',
#   'onions',
#   'fresh sage',
#   'fresh thyme',
#   'fresh rosemary',
#   'fresh parsley leaves',
#   'homemade-style white bread',
#   'fresh savory',
#   'fresh chestnuts'],
#  398969: ['unsalted butter',
#   'chicken stock',
#   'onions',
#   'black pepper',
#   'rosemary',
#   'extra virgin olive oil',
#   'parsley',
#   'thyme',
#   'kosher salt',
#   'red pepper',
#   'white wine',
#   'bread',
#   'extra-large eggs',
#   'fennel bulbs',
#   'pancetta',
#   'fennel seeds',
#   'chestnuts'],
#  274036: ['unsalted butter',
#   'flour',
#   'salt',
#   'baking powder',
#   'sugar',
#   'vanilla extract',
#   'walnuts',
#   'egg whites',
#   'unsweetened cocoa'],
#  454832: ['unsalted butter',
#   'milk',
#   'vegetable oil',
#   'baking powder',
#   'baking soda',
#   'sugar',
#   'egg',
#   'vanilla extract',
#   'cream cheese',
#   'unbleached all-purpose flour',
#   'table salt'],
# ...
#   'kosher salt',
#   'sweet paprika'],
#  319963: ['unsalted butter',
#   'powdered sugar',
#   'mini marshmallows',
#   'semisweet chocolate',
#   'golden syrup',
#   'digestive biscuits'],
#  146886: ['unsalted butter',
#   'eggs',
#   'half-and-half',
#   'leeks',
#   'fresh ground black pepper',
#   'fresh thyme leave',
#   'roquefort cheese',
#   'pastry dough'],
#  401442: ['unsalted butter',
#   'salt',
#   'pine nuts',
#   'pecan halves',
#   'dark brown sugar',
#   'whole almonds',
#   'walnut halves',
#   'fresh rosemary leaf'],
#  418697: ['unsalted butter',
#   'green onions',
#   'sugar',
#   'frozen peas',
#   'fresh rosemary',
#   'pine nuts',
#   'salt & pepper',
#   'dried rosemary'],
#  14410: ['unsalted butter',
#   'onion',
#   'chicken stock',
#   'water',
#   'bacon',
#   'fresh ground pepper',
#   'garlic',
#   'fresh rosemary',
#   'kosher salt',
#   'dried white beans'],
#  147246: ['unsalted butter',
#   'fresh parsley',
#   'salt',
#   'olive oil',
#   'fresh sage',
#   'fresh coarse ground black pepper',
#   'pine nuts',
#   'part-skim ricotta cheese',
#   'parmigiano-reggiano cheese',
#   'fresh oregano',
#   'noodles'],
#  103573: ['unsalted butter',
#   'salt',
#   'all-purpose flour',
#   'nuts',
#   'cinnamon',
#   'egg',
#   'cream cheese',
#   'granulated sugar',
#   'raisins',
#   'icing sugar',
#   'apricot jam'],
#  413147: ['unsalted butter',
#   'all-purpose flour',
#   'baking soda',
#   'egg',
#   'vanilla extract',
#   'light brown sugar',
#   'semi-sweet chocolate chips',
#   'creamy peanut butter',
#   'marshmallow cream'],
#  351886: ['unsalted butter',
#   'all-purpose flour',
#   'baking soda',
#   'egg',
#   'vanilla extract',
#   'cooking spray',
#   'light brown sugar',
#   'creamy peanut butter',
#   'milk chocolate chips',
#   'marshmallow cream'],
#  56237: ['unsalted butter',
#   'salt',
#   'all-purpose flour',
#   'sugar',
#   'graham crackers',
#   'marshmallows',
#   'milk chocolate',
#   'extra large eggs'],
#  240766: ['unsalted butter',
#   'graham cracker crumbs',
#   'vanilla extract',
#   'light brown sugar',
#   'mini marshmallows',
#   'graham crackers',
#   '2% low-fat milk',
#   'semisweet chocolate chunks'],
#  56083: ['unsalted butter',
#   'graham cracker crumbs',
#   'whipping cream',
#   'chocolate ice cream',
#   'nonstick cooking spray',
#   'miniature marshmallows',
#   'milk chocolate',
#   'marshmallow creme',
#   'chocolate-covered graham cracker cookies'],
#  174710: ['unsalted butter',
#   'milk',
#   'flour',
#   'salt',
#   'vanilla',
#   'sugar',
#   'egg yolks'],
#  89802: ['unsalted butter',
#   'onion',
#   'sage leaves',
#   'double cream',
#   'streaky bacon',
#   'salad potatoes'],
#  115543: ['unsalted butter',
#   'milk',
#   'baking powder',
#   'all-purpose flour',
#   'egg',
#   'cayenne pepper',
#   'fresh sage',
#   'white pepper',
#   'sea salt'],
#  285359: ['unsalted butter',
#   'onion',
#   'dry white wine',
#   'fresh parsley',
#   'salt',
#   'pepper',
#   'cream',
#   'tomatoes',
#   'madeira wine',
#   'salmon fillets',
#   'white mushroom',
#   'dried wild mushrooms'],
#  58867: ['unsalted butter',
#   'fresh lemon juice',
#   'olive oil',
#   'garlic',
#   'fresh rosemary',
#   'salmon fillets'],
#  450834: ['unsalted butter', 'coarse sea salt', 'marshmallows', 'cereal'],
#  476092: ['unsalted butter',
#   'vanilla extract',
#   'sweetened condensed milk',
#   'caramels',
#   'miniature marshmallows',
#   'flaked sea salt',
#   'toasted rice cereal'],
#  444113: ['unsalted butter',
#   'heavy cream',
#   'vegetable oil',
#   'sugar',
#   'light corn syrup',
#   'pure vanilla extract',
#   'kosher salt'],
#  355907: ['unsalted butter',
#   'baking powder',
#   'baking soda',
#   'egg',
#   'vanilla extract',
#   'granulated sugar',
#   'light brown sugar',
#   'unbleached all-purpose flour',
#   'coarse sea salt',
#   'table salt',
#   'old fashioned oats'],
#  535312: ['unsalted butter',
#   'milk',
#   'eggs',
#   'flour',
#   'baking powder',
#   'chocolate chips',
#   'sugar',
#   'unsweetened cocoa powder',
#   'kosher salt',
#   "confectioners' sugar",
#   'caramel sauce',
#   'sweetened flaked coconut'],
#  345490: ['unsalted butter',
#   'dry white wine',
#   'chicken stock',
#   'hot sauce',
#   'salt',
#   'garlic cloves',
#   'extra virgin olive oil',
#   'fresh ground pepper',
#   'bay leaf',
#   'shallot',
#   'diced tomato',
#   'flat leaf parsley',
#   'medium shrimp',
#   'fresh thyme sprigs',
#   'sourdough bread',
#   'littleneck clams',
#   'bottled clam juice',
#   'red snapper fillet'],
#  459345: ['unsalted butter',
#   'eggs',
#   'sour cream',
#   'flour',
#   'salt',
#   'baking powder',
#   'sugar',
#   'ground cinnamon',
#   'ground ginger',
#   'nutmeg',
#   'cocoa powder',
#   'dark brown sugar'],
#  273069: ['unsalted butter',
#   'olive oil',
#   'garlic',
#   'kosher salt',
#   'cracked black pepper',
#   'flat leaf parsley',
#   'salt-packed anchovy fillet'],
#  202982: ['unsalted butter',
#   'eggs',
#   'water',
#   'all-purpose flour',
#   'parmesan cheese',
#   'fresh ground pepper',
#   'italian sausage',
#   'fresh thyme',
#   'fresh rosemary',
#   'gruyere cheese',
#   'kosher salt',
#   'egg yolk',
#   'yukon gold potato'],
#  194580: ['unsalted butter',
#   'onion',
#   'celery',
#   'dried thyme',
#   'fresh parsley',
#   'white bread',
#   'dried cranberries',
#   'whole wheat bread',
#   'dried rosemary',
#   'dried sage',
#   'golden delicious apple',
#   'turkey broth',
#   'turkey sausage',
#   'turkey liver'],
#  338305: ['unsalted butter',
#   'eggs',
#   'green onions',
#   'all-purpose flour',
#   'monterey jack cheese',
#   'salt and pepper',
#   'cold water',
#   'jalapeno',
#   'whole milk',
#   'english muffins',
#   'breakfast sausage',
#   'sage leaf'],
#  155741: ['unsalted butter',
#   'celery',
#   'heavy cream',
#   'fresh lemon juice',
#   'all-purpose flour',
#   'garlic cloves',
#   'olive oil',
#   'smoked paprika',
#   'fresh ground pepper',
#   'sea salt',
#   'skim milk',
#   'ground pepper',
#   'shallot',
#   'vegetable broth',
#   'vegetable stock',
#   'large shrimp',
#   'yellow cornmeal',
#   'manchego cheese'],
#  112547: ['unsalted butter',
#   'heavy cream',
#   'bananas',
#   'pecans',
#   'light brown sugar',
#   'ground cardamom',
#   'vanilla ice cream',
#   'fresh lime juice'],
#  332706: ['unsalted butter',
#   'garlic cloves',
#   'parmesan cheese',
#   'extra virgin olive oil',
#   'kosher salt',
#   'cracked black pepper',
#   'fresh green beans'],
#  84201: ['unsalted butter',
#   'soy sauce',
#   'sugar',
#   'portabella mushrooms',
#   'shallots',
#   'mushrooms',
#   'balsamic vinegar',
#   'scallions'],
#  81589: ['unsalted butter',
#   'sour cream',
#   'salt',
#   'olive oil',
#   'hot pepper sauce',
#   'avocado',
#   'crushed red pepper flakes',
#   'garlic',
#   'cilantro',
#   'lime, juice of',
#   'cabbage',
#   'large shrimp',
#   'sandwich buns'],
#  225283: ['unsalted butter',
#   'worcestershire sauce',
#   'garlic cloves',
#   'olive oil',
#   'sliced mushrooms',
#   'wine',
#   'thyme',
#   'dried onion flakes',
#   'mixed herbs'],
#  118923: ['unsalted butter',
#   'chicken stock',
#   'all-purpose flour',
#   'red onion',
#   'shrimp',
#   'whipping cream',
#   'brandy',
#   'beef stock',
#   'shiitake mushrooms',
#   'veal cutlets'],
#  300747: ['unsalted butter',
#   'fresh lemon juice',
#   'salt',
#   'fresh ground black pepper',
#   'garlic clove',
#   'zucchini',
#   'arugula',
#   'lemon zest'],
#  383929: ['unsalted butter',
#   'eggs',
#   'ground beef',
#   'extra virgin olive oil',
#   'fresh ground black pepper',
#   'lettuce',
#   'garlic clove',
#   'kosher salt',
#   'yellow onions',
#   'hamburger buns',
#   'red chili pepper flakes',
#   'beefsteak tomatoes',
#   'pineapple rings',
#   'pickled beets',
#   'aged white cheddar cheese'],
#  263317: ['unsalted butter',
#   'onion',
#   'fresh garlic',
#   'fresh parsley',
#   'water',
#   'bacon',
#   'fresh thyme',
#   'fresh rosemary',
#   'kosher salt',
#   'chicken bouillon cubes',
#   'cracked black pepper',
#   'acorn squash',
#   'fresh chives',
#   'creole seasoning',
#   'turnip',
#   'yam',
#   'cremini mushroom'],
#  327941: ['unsalted butter',
#   'eggs',
#   'salt',
#   'cinnamon',
#   'light brown sugar',
#   'nutmeg',
#   'evaporated milk',
#   'sweet potatoes'],
#  418779: ['unsalted butter',
#   'eggs',
#   'salt',
#   'water',
#   'all-purpose flour',
#   'black pepper',
#   'garlic cloves',
#   'olive oil',
#   'fresh thyme',
#   'fresh rosemary',
#   'whole milk',
#   'balsamic vinegar',
#   'scallion',
#   'wild rice',
#   'cremini mushrooms',
#   'red bell peppers',
#   'dried porcini mushrooms'],
#  222094: ['unsalted butter',
#   'dry white wine',
#   'salt',
#   'black pepper',
#   'olive oil',
#   'white wine vinegar',
#   'asparagus',
#   'large scallops'],
#  97514: ['unsalted butter',
#   'vegetable oil',
#   'fresh cilantro',
#   'water',
#   'onions',
#   'white wine vinegar',
#   'ground coriander',
#   'sea scallops'],
#  150375: ['unsalted butter',
#   'salt',
#   'all-purpose flour',
#   'fresh sage',
#   'fresh thyme',
#   'fresh rosemary',
#   'egg white',
#   'flat leaf parsley',
#   'fresh sage leaves',
#   'superfine sugar',
#   'fresh thyme sprigs',
#   'fresh parsley leaves',
#   'rosemary sprigs'],
#  33438: ['unsalted butter',
#   'flour',
#   'old bay seasoning',
#   'half-and-half',
#   'dry mustard',
#   'hot water',
#   'white wine',
#   'lobster meat'],
#  142715: ['unsalted butter',
#   'sour cream',
#   'salt',
#   'mayonnaise',
#   'sharp cheddar cheese',
#   'paprika',
#   'sugar',
#   'buttermilk',
#   'cream cheese',
#   'white vinegar',
#   'garbanzo beans',
#   'prepared horseradish',
#   'brown ale'],
#  405125: ['unsalted butter',
#   'heavy cream',
#   'honey',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'baking soda',
#   'sugar',
#   'buttermilk',
#   'orange zest',
#   'berries'],
#  482989: ['unsalted butter',
#   'onion',
#   'eggs',
#   'vegetable oil',
#   'fresh ginger',
#   'fresh cilantro',
#   'ground cumin',
#   'fresh ground black pepper',
#   'plum tomatoes',
#   'kosher salt',
#   'ground turmeric',
#   'serrano chili',
#   'low-fat greek yogurt'],
#  263642: ['unsalted butter',
#   'eggs',
#   'butter',
#   'fresh ground black pepper',
#   'tomatoes',
#   'fresh basil leaf',
#   'kosher salt',
#   'italian bread',
#   'whole milk ricotta cheese'],
#  379273: ['unsalted butter',
#   'fresh cilantro',
#   'crushed red pepper flakes',
#   'garlic',
#   'lime zest',
#   'fresh lime juice',
#   'coarse sea salt',
#   'coriander seed'],
#  444315: ['unsalted butter',
#   'vegetable oil',
#   'fresh ginger',
#   'soy sauce',
#   'black pepper',
#   'ground cumin',
#   'chicken broth',
#   'red pepper flakes',
#   'shallot',
#   'port wine',
#   'plums',
#   'boneless duck breast halves'],
#  160032: ['unsalted butter',
#   'graham cracker crumbs',
#   'lemon juice',
#   'lemon, zest of',
#   'ground cinnamon',
#   'whipped cream',
#   'egg yolks',
#   'sweetened condensed milk'],
#  196877: ['unsalted butter',
#   'onion',
#   'heavy cream',
#   'salt',
#   'all-purpose flour',
#   'ground black pepper',
#   'garlic cloves',
#   'green beans',
#   'low sodium chicken broth',
#   'sandwich bread',
#   'white button mushrooms',
#   'cremini mushrooms',
#   'fresh thyme leaves',
#   'dried porcini mushrooms',
#   'fried onions'],
#  216245: ['unsalted butter',
#   'ham',
#   'fresh parsley',
#   'onions',
#   'mushrooms',
#   'salt & pepper',
#   'fine breadcrumbs',
#   'puff pastry sheets',
#   'red bell peppers',
#   'egg wash',
#   'cream sherry'],
#  88875: ['unsalted butter',
#   'onion',
#   'salt and pepper',
#   'canola oil',
#   'green pepper',
#   'chopped pimiento',
#   'french-fried potatoes'],
#  144494: ['unsalted butter',
#   'heavy cream',
#   'eggs',
#   'salt',
#   'baking powder',
#   'water',
#   'all-purpose flour',
#   'baking soda',
#   'sugar',
#   'buttermilk',
#   'bittersweet chocolate',
#   'light corn syrup',
#   'pure vanilla extract',
#   'unsweetened cocoa powder',
#   'hot coffee'],
#  68264: ['unsalted butter',
#   'worcestershire sauce',
#   'tabasco sauce',
#   'milk',
#   'salt',
#   'pepper',
#   'all-purpose flour',
#   'medium shrimp',
#   'frozen peas and carrots',
#   'white button mushrooms'],
#  493510: ['unsalted butter',
#   'dry white wine',
#   'milk',
#   'salt',
#   'celery seed',
#   'onions',
#   'bacon',
#   'fresh ground black pepper',
#   'chicken breasts',
#   'garlic',
#   'broccoli florets',
#   'cooked rice',
#   'oysters',
#   'fresh tarragon',
#   'anise seed',
#   'fish stock',
#   'jumbo shrimp'],
#  278241: ['unsalted butter',
#   'heavy cream',
#   'salt',
#   'water',
#   'olive oil',
#   'seasoning salt',
#   'parmesan cheese',
#   'fresh ground black pepper',
#   'monterey jack pepper cheese',
#   'garlic',
#   'jalapeno',
#   'yellow onion',
#   'kosher salt',
#   'diced tomato',
#   'fresh basil leaves',
#   'linguine',
#   'fresh parsley leaves',
#   'large shrimp'],
#  151937: ['unsalted butter',
#   'onion',
#   'salt',
#   'pepper',
#   'all-purpose flour',
#   'paprika',
#   'garlic cloves',
#   'parmesan cheese',
#   'half-and-half',
#   'roasted red peppers',
#   'lasagna noodles',
#   'frozen green pea',
#   'romano cheese',
#   'vegetable oil cooking spray',
#   'medium shrimp',
#   'sea scallops'],
#  428669: ['unsalted butter',
#   'dry white wine',
#   'eggs',
#   'fresh lemon juice',
#   'all-purpose flour',
#   'garlic cloves',
#   'dijon mustard',
#   'parsley',
#   'canola oil',
#   'fine sea salt',
#   'lemon wedges',
#   'jumbo shrimp'],
#  321409: ['unsalted butter',
#   'garlic cloves',
#   'shrimp',
#   'cilantro',
#   'gingerroot',
#   'medium-dry sherry'],
#  25172: ['unsalted butter',
#   'eggs',
#   'sugar',
#   'vanilla extract',
#   'whipped cream',
#   'slivered almonds',
#   'pie shell',
#   'chocolate'],
#  367708: ['unsalted butter',
#   'cornstarch',
#   'salt',
#   'lemon juice',
#   'granulated sugar',
#   'egg yolks',
#   'whole milk',
#   'lemon zest'],
#  321751: ['unsalted butter', 'caster sugar', 'plain flour', 'demerara sugar'],
#  487192: ['unsalted butter',
#   'carrot',
#   'eggs',
#   'vegetable oil',
#   'sour cream',
#   'baking powder',
#   'baking soda',
#   'vanilla extract',
#   'cream cheese',
#   'ground cinnamon',
#   'ground nutmeg',
#   'granulated sugar',
#   'light brown sugar',
#   'ground cloves',
#   'unbleached all-purpose flour',
#   "confectioners' sugar",
#   'table salt',
#   'cream cheese frosting'],
#  66409: ['unsalted butter',
#   'milk',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'granulated sugar'],
#  107755: ['unsalted butter',
#   'ground cinnamon',
#   'orange',
#   'stale bread',
#   'eggnog'],
#  353990: ['unsalted butter',
#   'eggs',
#   'honey',
#   'brown sugar',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'baking soda',
#   'vanilla extract',
#   'ground cinnamon',
#   'pineapple chunk',
#   'powdered sugar',
#   'ground ginger',
#   'ground cardamom',
#   'pineapple juice',
#   'baby carrots',
#   'almonds',
#   'toasted almond',
#   'fat free cream cheese',
#   'old fashioned oats',
#   'black currants',
#   'vanilla bean paste'],
#  51007: ['unsalted butter',
#   'eggs',
#   'chocolate chips',
#   'whipping cream',
#   'powdered sugar',
#   'unflavored gelatin',
#   'egg yolks',
#   'egg whites',
#   'chocolate wafer crumbs'],
#  465115: ['unsalted butter',
#   'cornstarch',
#   'milk',
#   'eggs',
#   'brown sugar',
#   'flour',
#   'salt',
#   'baking powder',
#   'vanilla',
#   'water',
#   'baking soda',
#   'sugar',
#   'buttermilk',
#   'whipping cream',
#   'whipped cream',
#   'strawberries',
#   'cocoa',
#   'sweetened condensed milk',
#   'chocolate',
#   'strawberry',
#   'hot cocoa',
#   'unsweetened baking chocolate',
#   'chocolate pudding mix',
#   'strawberry jell-o gelatin dessert',
#   'strawberry extract'],
#  247987: ['unsalted butter',
#   'eggs',
#   'salt',
#   'baking powder',
#   'all-purpose flour',
#   'baking soda',
#   'cinnamon',
#   'vanilla extract',
#   'instant vanilla pudding',
#   'granulated sugar',
#   'pam cooking spray',
#   'whole milk',
#   'dark brown sugar'],
#  373600: ['unsalted butter',
#   'eggs',
#   'black pepper',
#   'kosher salt',
#   'fresh chives',
#   'goat cheese'],
#  208975: ['unsalted butter',
#   'salt',
#   'garlic cloves',
#   'extra virgin olive oil',
#   'fresh ground black pepper',
#   'fresh thyme leave',
#   'fresh rosemary leaf',
#   'beef rib roast'],
#  321032: ['unsalted butter',
#   'salt',
#   'monterey jack cheese',
#   'low-fat milk',
#   'small red potatoes'],
#  150441: ['unsalted butter',
#   'sharp cheddar cheese',
#   'potatoes',
#   'garlic cloves',
#   'salt and pepper',
#   'chorizo sausage',
#   'chives'],
#  111521: ['unsalted butter',
#   'heavy cream',
#   'all-purpose flour',
#   'paprika',
#   'salt & freshly ground black pepper',
#   'nutmeg',
#   'smoked gouda cheese',
#   'whole milk'],
#  146066: ['unsalted butter',
#   'eggs',
#   'vegetable oil',
#   'red onion',
#   'salt and pepper',
#   'half-and-half cream',
#   'green pepper',
#   'chives',
#   'flat leaf parsley',
#   'smoked salmon',
#   'lemon zest',
#   'puff pastry',
#   'fresh dill',
#   'white potatoes',
#   'hollandaise sauce',
#   'dill sprigs'],
#  461149: ['unsalted butter',
#   'cream cheese',
#   'smoked salmon',
#   'bread',
#   'fresh dill'],
#  ...}

# %% [markdown]
# 1.4 Добавьте к таблице из задания 1.2 столбец `ingredients`, содержащий набор ингредиентов в виде строки (ингредиенты внутри строки разделяются символом `*`)
#
# Для строк, которые содержат пропуски в столбце `n_ingredients`, заполните их на основе файла  `ingredients_sample.csv`

# %%
buf_list = []

for _, row in recipes_filled.iterrows():
    if row['id'] in dictionary_2:
        buf_list.append('*'.join(dictionary_2[row['id']]))
    else:
        buf_list.append(float("nan"))

recipes_filled['ingredients'] = buf_list
recipes_filled
# Out:
#        Unnamed: 0                                          name      id  \
# 0               0         george s at the cove  black bean soup   44123
# 1               1            healthy for them  yogurt popsicles   67664
# 2               2                  i can t believe it s spinach   38798
# 3               3                          italian  gut busters   35173
# 4               4      love is in the air  beef fondue   sauces   84797
# ...           ...                                           ...     ...
# 29995       29995  zurie s holey rustic olive and cheddar bread  267661
# 29996       29996          zwetschgenkuchen  bavarian plum cake  386977
# 29997       29997   zwiebelkuchen   southwest german onion cake  103312
# 29998       29998                                   zydeco soup  486161
# 29999       29999        cookies by design   cookies on a stick  298512
#
#        minutes  contributor_id   submitted  n_steps  \
# 0           90           35193  2002-10-25       11
# 1           10           91970  2003-07-26        3
# 2           30            1533  2002-08-29        5
# 3           45           22724  2002-07-27        7
# 4           25            4470  2004-02-23        4
# ...        ...             ...         ...      ...
# 29995       80          200862  2007-11-25       16
# 29996      240          177443  2009-08-24       22
# 29997       75          161745  2004-11-03       10
# 29998       60          227978  2012-08-29        7
# 29999       29          506822  2008-04-15        9
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
#        n_tags                                               tags  \
# 0          25  weeknight;time-to-make;course;main-ingredient;...
# 1          31  15-minutes-or-less;time-to-make;course;prepara...
# 2          17  30-minutes-or-less;time-to-make;course;main-in...
# 3          11  60-minutes-or-less;time-to-make;course;prepara...
# 4          19  30-minutes-or-less;time-to-make;course;main-in...
# ...       ...                                                ...
# 29995      18  time-to-make;course;main-ingredient;cuisine;pr...
# 29996      19  time-to-make;course;main-ingredient;cuisine;pr...
# 29997      20  time-to-make;course;main-ingredient;cuisine;pr...
# 29998      20  ham;60-minutes-or-less;time-to-make;course;mai...
# 29999      12  30-minutes-or-less;time-to-make;course;prepara...
#
#                                              ingredients
# 0      unsalted butter*carrot*onion*celery*broccoli s...
# 1             milk*frozen juice concentrate*plain yogurt
# 2      onion*frozen chopped spinach*eggs*garlic powde...
# 3      sandwich bun*good seasonings italian salad dre...
# 4      beef steaks*vegetable oil*spicy mustard*fresh ...
# ...                                                  ...
# 29995  dry white wine*eggs*cheddar cheese*baking powd...
# 29996  unsalted butter*milk*flour*salt*vanilla*all-pu...
# 29997  onion*milk*eggs*butter*flour*salt*pepper*sugar...
# 29998  onion*celery*dried thyme*dried oregano*fresh p...
# 29999  butter*sour cream*egg*bisquick*light brown sug...
#
# [30000 rows x 12 columns]

# %%
for index, row in recipes_filled.iterrows():
    if (row['id'] in dictionary_2) and (pd.isna(row['n_ingredients'])):
        recipes_filled['n_ingredients'][index] = len(dictionary_2[row['id']])

recipes_filled
# Out:
# <ipython-input-61-9cfb296b04c3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes_filled['n_ingredients'][index] = len(dictionary_2[row['id']])
#        Unnamed: 0                                          name      id  \
# 0               0         george s at the cove  black bean soup   44123
# 1               1            healthy for them  yogurt popsicles   67664
# 2               2                  i can t believe it s spinach   38798
# 3               3                          italian  gut busters   35173
# 4               4      love is in the air  beef fondue   sauces   84797
# ...           ...                                           ...     ...
# 29995       29995  zurie s holey rustic olive and cheddar bread  267661
# 29996       29996          zwetschgenkuchen  bavarian plum cake  386977
# 29997       29997   zwiebelkuchen   southwest german onion cake  103312
# 29998       29998                                   zydeco soup  486161
# 29999       29999        cookies by design   cookies on a stick  298512
#
#        minutes  contributor_id   submitted  n_steps  \
# 0           90           35193  2002-10-25       11
# 1           10           91970  2003-07-26        3
# 2           30            1533  2002-08-29        5
# 3           45           22724  2002-07-27        7
# 4           25            4470  2004-02-23        4
# ...        ...             ...         ...      ...
# 29995       80          200862  2007-11-25       16
# 29996      240          177443  2009-08-24       22
# 29997       75          161745  2004-11-03       10
# 29998       60          227978  2012-08-29        7
# 29999       29          506822  2008-04-15        9
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            3.0
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            9.0
# 4      i think a fondue is a very romantic casual din...           12.0
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...           13.0
# 29998  this is a delicious soup that i originally fou...           22.0
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
#        n_tags                                               tags  \
# 0          25  weeknight;time-to-make;course;main-ingredient;...
# 1          31  15-minutes-or-less;time-to-make;course;prepara...
# 2          17  30-minutes-or-less;time-to-make;course;main-in...
# 3          11  60-minutes-or-less;time-to-make;course;prepara...
# 4          19  30-minutes-or-less;time-to-make;course;main-in...
# ...       ...                                                ...
# 29995      18  time-to-make;course;main-ingredient;cuisine;pr...
# 29996      19  time-to-make;course;main-ingredient;cuisine;pr...
# 29997      20  time-to-make;course;main-ingredient;cuisine;pr...
# 29998      20  ham;60-minutes-or-less;time-to-make;course;mai...
# 29999      12  30-minutes-or-less;time-to-make;course;prepara...
#
#                                              ingredients
# 0      unsalted butter*carrot*onion*celery*broccoli s...
# 1             milk*frozen juice concentrate*plain yogurt
# 2      onion*frozen chopped spinach*eggs*garlic powde...
# 3      sandwich bun*good seasonings italian salad dre...
# 4      beef steaks*vegetable oil*spicy mustard*fresh ...
# ...                                                  ...
# 29995  dry white wine*eggs*cheddar cheese*baking powd...
# 29996  unsalted butter*milk*flour*salt*vanilla*all-pu...
# 29997  onion*milk*eggs*butter*flour*salt*pepper*sugar...
# 29998  onion*celery*dried thyme*dried oregano*fresh p...
# 29999  butter*sour cream*egg*bisquick*light brown sug...
#
# [30000 rows x 12 columns]

# %% [markdown]
# 1.5 Проверьте, содержит ли столбец `n_ingredients` пропуски. Если нет, преобразуйте его к целочисленному типу и сохраните результаты в файл `recipes_sample_with_tags_ingredients.csv`

# %%
recipes_filled[recipes_filled['n_ingredients'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, id, minutes, contributor_id, submitted, n_steps, description, n_ingredients, n_tags, tags, ingredients]
# Index: []

# %%
recipes_filled['n_ingredients'] = recipes_filled['n_ingredients'].astype(int)
recipes_filled.dtypes
# Out:
# Unnamed: 0         int64
# name              object
# id                 int64
# minutes            int64
# contributor_id     int64
# submitted         object
# n_steps            int64
# description       object
# n_ingredients      int32
# n_tags             int64
# tags              object
# ingredients       object
# dtype: object

# %%
recipes_filled.to_csv("./recipes_sample_with_tags_ingredients.csv")

# %% [markdown]
# ### npy

# %% [markdown]
# 2.1 Разделите таблицу, полученную в результате 1.5, на две таблицы: одна содержит рецепты, загруженные до 2000 года; вторая - все остальные. В полученных таблицах оставьте только числовые столбцы и преобразуйте их к `numpy.array`

# %%
recipes_filled["submitted"] = pd.to_datetime(recipes_filled["submitted"], format='%Y-%m-%d', errors='ignore')
recipes_filled
# Out:
#        Unnamed: 0                                          name      id  \
# 0               0         george s at the cove  black bean soup   44123
# 1               1            healthy for them  yogurt popsicles   67664
# 2               2                  i can t believe it s spinach   38798
# 3               3                          italian  gut busters   35173
# 4               4      love is in the air  beef fondue   sauces   84797
# ...           ...                                           ...     ...
# 29995       29995  zurie s holey rustic olive and cheddar bread  267661
# 29996       29996          zwetschgenkuchen  bavarian plum cake  386977
# 29997       29997   zwiebelkuchen   southwest german onion cake  103312
# 29998       29998                                   zydeco soup  486161
# 29999       29999        cookies by design   cookies on a stick  298512
#
#        minutes  contributor_id  submitted  n_steps  \
# 0           90           35193 2002-10-25       11
# 1           10           91970 2003-07-26        3
# 2           30            1533 2002-08-29        5
# 3           45           22724 2002-07-27        7
# 4           25            4470 2004-02-23        4
# ...        ...             ...        ...      ...
# 29995       80          200862 2007-11-25       16
# 29996      240          177443 2009-08-24       22
# 29997       75          161745 2004-11-03       10
# 29998       60          227978 2012-08-29        7
# 29999       29          506822 2008-04-15        9
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...             18
# 1      my children and their friends ask for my homem...              3
# 2                these were so go, it surprised even me.              8
# 3      my sister-in-law made these for us at a family...              9
# 4      i think a fondue is a very romantic casual din...             12
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...             10
# 29996  this is a traditional fresh plum cake, thought...             11
# 29997  this is a traditional late summer early fall s...             13
# 29998  this is a delicious soup that i originally fou...             22
# 29999  i've heard of the 'cookies by design' company,...             10
#
#        n_tags                                               tags  \
# 0          25  weeknight;time-to-make;course;main-ingredient;...
# 1          31  15-minutes-or-less;time-to-make;course;prepara...
# 2          17  30-minutes-or-less;time-to-make;course;main-in...
# 3          11  60-minutes-or-less;time-to-make;course;prepara...
# 4          19  30-minutes-or-less;time-to-make;course;main-in...
# ...       ...                                                ...
# 29995      18  time-to-make;course;main-ingredient;cuisine;pr...
# 29996      19  time-to-make;course;main-ingredient;cuisine;pr...
# 29997      20  time-to-make;course;main-ingredient;cuisine;pr...
# 29998      20  ham;60-minutes-or-less;time-to-make;course;mai...
# 29999      12  30-minutes-or-less;time-to-make;course;prepara...
#
#                                              ingredients
# 0      unsalted butter*carrot*onion*celery*broccoli s...
# 1             milk*frozen juice concentrate*plain yogurt
# 2      onion*frozen chopped spinach*eggs*garlic powde...
# 3      sandwich bun*good seasonings italian salad dre...
# 4      beef steaks*vegetable oil*spicy mustard*fresh ...
# ...                                                  ...
# 29995  dry white wine*eggs*cheddar cheese*baking powd...
# 29996  unsalted butter*milk*flour*salt*vanilla*all-pu...
# 29997  onion*milk*eggs*butter*flour*salt*pepper*sugar...
# 29998  onion*celery*dried thyme*dried oregano*fresh p...
# 29999  butter*sour cream*egg*bisquick*light brown sug...
#
# [30000 rows x 12 columns]

# %%
recipes_filled.dtypes
# Out:
# Unnamed: 0                 int64
# name                      object
# id                         int64
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                    int64
# description               object
# n_ingredients              int32
# n_tags                     int64
# tags                      object
# ingredients               object
# dtype: object

# %%
recipes_before = recipes_filled[recipes_filled['submitted'].dt.year < 2000]
recipes_before
# Out:
#        Unnamed: 0                                       name    id  minutes  \
# 189           189  30 minute smoked sausage and corn chowder  3441       30
# 434           434                         alfredo fettuccine  4205       25
# 439           439                   alfredo sauce with pasta  3258        0
# 669           669         amish friendship bread and starter   153       70
# 785           785                        anytime cheese ball  5197        0
# ...           ...                                        ...   ...      ...
# 29196       29196                         whipped cappuccino   465       25
# 29243       29243     white cake with coconut pecan frosting  2889      120
# 29463       29463                                 wine jelly  3752        0
# 29662       29662                             yellow rice ii  4801       20
# 29669       29669                    yellow squash casserole  2982        0
#
#        contributor_id  submitted  n_steps  \
# 189              1562 1999-10-18        8
# 434              1617 1999-11-09        3
# 439              1534 1999-10-10        8
# 669              1540 1999-09-06       19
# 785              1534 1999-12-15        3
# ...               ...        ...      ...
# 29196            1737 1999-08-30        6
# 29243            1646 1999-09-27        7
# 29463            1535 1999-10-30       13
# 29662            1598 1999-11-22        4
# 29669          124030 1999-08-18        6
#
#                                              description  n_ingredients  \
# 189    i love corn chowder, have a pot on now! recipe...              8
# 434                recipe from the olive garden cookbook              5
# 439                                                  NaN              6
# 669    many recipes have been posted for the amish br...             12
# 785                                                  NaN              5
# ...                                                  ...            ...
# 29196                                    the denver post              4
# 29243                                                NaN             11
# 29463  this make excellent gifts as it is quick and e...              4
# 29662  in south africa we have a rich heritage of amo...              7
# 29669                                                NaN              7
#
#        n_tags                                               tags  \
# 189        10  30-minutes-or-less;time-to-make;course;main-in...
# 434        14  30-minutes-or-less;time-to-make;course;main-in...
# 439        20  15-minutes-or-less;time-to-make;course;main-in...
# 669        16  time-to-make;course;cuisine;preparation;north-...
# 785        16  15-minutes-or-less;time-to-make;main-ingredien...
# ...       ...                                                ...
# 29196      19  30-minutes-or-less;time-to-make;course;prepara...
# 29243      18  weeknight;time-to-make;course;main-ingredient;...
# 29463       9  15-minutes-or-less;time-to-make;course;prepara...
# 29662      18  15-minutes-or-less;time-to-make;course;main-in...
# 29669      13  15-minutes-or-less;time-to-make;main-ingredien...
#
#                                              ingredients
# 189    heavy cream*vegetable oil*green onion*cream-st...
# 434    milk*butter*parmesan cheese*cream cheese*fettu...
# 439    heavy cream*butter*salt*pepper*parmesan cheese...
# 669    milk*eggs*flour*salt*baking powder*baking soda...
# 785    garlic powder*white vinegar*philadelphia cream...
# ...                                                  ...
# 29196  water*condensed milk*ice cubes*instant espress...
# 29243  eggs*butter*vegetable oil*flour*baking soda*su...
# 29463                      water*sugar*wine*liquid certo
# 29662  butter*salt*turmeric*cinnamon stick*seedless r...
# 29669  onion*butter*green peppers*cheese*yellow squas...
#
# [275 rows x 12 columns]

# %%
recipes_after = recipes_filled[recipes_filled['submitted'].dt.year >= 2000]
recipes_after
# Out:
#        Unnamed: 0                                          name      id  \
# 0               0         george s at the cove  black bean soup   44123
# 1               1            healthy for them  yogurt popsicles   67664
# 2               2                  i can t believe it s spinach   38798
# 3               3                          italian  gut busters   35173
# 4               4      love is in the air  beef fondue   sauces   84797
# ...           ...                                           ...     ...
# 29995       29995  zurie s holey rustic olive and cheddar bread  267661
# 29996       29996          zwetschgenkuchen  bavarian plum cake  386977
# 29997       29997   zwiebelkuchen   southwest german onion cake  103312
# 29998       29998                                   zydeco soup  486161
# 29999       29999        cookies by design   cookies on a stick  298512
#
#        minutes  contributor_id  submitted  n_steps  \
# 0           90           35193 2002-10-25       11
# 1           10           91970 2003-07-26        3
# 2           30            1533 2002-08-29        5
# 3           45           22724 2002-07-27        7
# 4           25            4470 2004-02-23        4
# ...        ...             ...        ...      ...
# 29995       80          200862 2007-11-25       16
# 29996      240          177443 2009-08-24       22
# 29997       75          161745 2004-11-03       10
# 29998       60          227978 2012-08-29        7
# 29999       29          506822 2008-04-15        9
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...             18
# 1      my children and their friends ask for my homem...              3
# 2                these were so go, it surprised even me.              8
# 3      my sister-in-law made these for us at a family...              9
# 4      i think a fondue is a very romantic casual din...             12
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...             10
# 29996  this is a traditional fresh plum cake, thought...             11
# 29997  this is a traditional late summer early fall s...             13
# 29998  this is a delicious soup that i originally fou...             22
# 29999  i've heard of the 'cookies by design' company,...             10
#
#        n_tags                                               tags  \
# 0          25  weeknight;time-to-make;course;main-ingredient;...
# 1          31  15-minutes-or-less;time-to-make;course;prepara...
# 2          17  30-minutes-or-less;time-to-make;course;main-in...
# 3          11  60-minutes-or-less;time-to-make;course;prepara...
# 4          19  30-minutes-or-less;time-to-make;course;main-in...
# ...       ...                                                ...
# 29995      18  time-to-make;course;main-ingredient;cuisine;pr...
# 29996      19  time-to-make;course;main-ingredient;cuisine;pr...
# 29997      20  time-to-make;course;main-ingredient;cuisine;pr...
# 29998      20  ham;60-minutes-or-less;time-to-make;course;mai...
# 29999      12  30-minutes-or-less;time-to-make;course;prepara...
#
#                                              ingredients
# 0      unsalted butter*carrot*onion*celery*broccoli s...
# 1             milk*frozen juice concentrate*plain yogurt
# 2      onion*frozen chopped spinach*eggs*garlic powde...
# 3      sandwich bun*good seasonings italian salad dre...
# 4      beef steaks*vegetable oil*spicy mustard*fresh ...
# ...                                                  ...
# 29995  dry white wine*eggs*cheddar cheese*baking powd...
# 29996  unsalted butter*milk*flour*salt*vanilla*all-pu...
# 29997  onion*milk*eggs*butter*flour*salt*pepper*sugar...
# 29998  onion*celery*dried thyme*dried oregano*fresh p...
# 29999  butter*sour cream*egg*bisquick*light brown sug...
#
# [29725 rows x 12 columns]

# %%
np_recipes_before = np.array([recipes_before[item] for item in ["id", "minutes", "contributor_id","n_steps","n_ingredients","n_tags"]])
np_recipes_before
# Out:
# array([[  3441,   4205,   3258, ...,   3752,   4801,   2982],
#        [    30,     25,      0, ...,      0,     20,      0],
#        [  1562,   1617,   1534, ...,   1535,   1598, 124030],
#        [     8,      3,      8, ...,     13,      4,      6],
#        [     8,      5,      6, ...,      4,      7,      7],
#        [    10,     14,     20, ...,      9,     18,     13]], dtype=int64)

# %%
np_recipes_after = np.array([recipes_after[item] for item in ["id", "minutes", "contributor_id","n_steps","n_ingredients","n_tags"]])
np_recipes_after
# Out:
# array([[ 44123,  67664,  38798, ..., 103312, 486161, 298512],
#        [    90,     10,     30, ...,     75,     60,     29],
#        [ 35193,  91970,   1533, ..., 161745, 227978, 506822],
#        [    11,      3,      5, ...,     10,      7,      9],
#        [    18,      3,      8, ...,     13,     22,     10],
#        [    25,     31,     17, ...,     20,     20,     12]], dtype=int64)

# %% [markdown]
# 2.2. Сохраните 2 полученных массива в архив `npz`. Дайте массивам читаемые имена.

# %%
np.savez('./task_2.2.npz', recipes_before_2000 = np_recipes_before, recipes_after_2000 = np_recipes_after)

# %% [markdown]
# 2.3 Считайте созданный архив и продемонстрируйте, что данные считались корректно.

# %%
data = np.load('./task_2.2.npz')
data.files
# Out:
# ['recipes_before_2000', 'recipes_after_2000']

# %%
data["recipes_before_2000"]
# Out:
# array([[  3441,   4205,   3258, ...,   3752,   4801,   2982],
#        [    30,     25,      0, ...,      0,     20,      0],
#        [  1562,   1617,   1534, ...,   1535,   1598, 124030],
#        [     8,      3,      8, ...,     13,      4,      6],
#        [     8,      5,      6, ...,      4,      7,      7],
#        [    10,     14,     20, ...,      9,     18,     13]], dtype=int64)

# %%
data["recipes_after_2000"]
# Out:
# array([[ 44123,  67664,  38798, ..., 103312, 486161, 298512],
#        [    90,     10,     30, ...,     75,     60,     29],
#        [ 35193,  91970,   1533, ..., 161745, 227978, 506822],
#        [    11,      3,      5, ...,     10,      7,      9],
#        [    18,      3,      8, ...,     13,     22,     10],
#        [    25,     31,     17, ...,     20,     20,     12]], dtype=int64)

# %% [markdown]
# ### hdf

# %% [markdown]
# 3.1 Выведите названия всех датасетов, находящихся в файле `nutrition_sample.h5`, а также размерность матриц, содержащихся в данных датасетах и их метаданные.
#
# Формат вывода:
# ```
# Dataset name=dataset_0, dataset size=(30000,), metadata={'info': 'calories (#)'}
# Dataset name=dataset_1, dataset size=(30000,), metadata={'info': 'total fat (PDV)'}
# ...
# ```

# %%
datasets_dict = {}
with h5py.File("./data/nutrition_sample.h5","r") as hdf:
    
    for key in hdf.keys():
        file = hdf[key]
        metadata = dict(file.attrs)
        print(f"Dataset name={key}, dataset size={file.shape}, metadata={metadata}")
        datasets_dict[key] = {"all" : {'data': file[:]}, 'attrs': metadata}
# Out:
# Dataset name=dataset_0, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'calories (#)'}
# Dataset name=dataset_1, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'total fat (PDV)'}
# Dataset name=dataset_2, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'sugar (PDV)'}
# Dataset name=dataset_3, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'sodium (PDV)'}
# Dataset name=dataset_4, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'protein (PDV)'}
# Dataset name=dataset_5, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'saturated fat (PDV)'}
# Dataset name=dataset_6, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'carbohydrates (PDV)'}

# %%
datasets_dict
# Out:
# {'dataset_0': {'all': {'data': array([[4.41230e+04, 8.04700e+02],
#           [6.76640e+04, 1.64600e+02],
#           [3.87980e+04, 5.38000e+01],
#           ...,
#           [1.03312e+05, 8.64100e+02],
#           [4.86161e+05, 4.15200e+02],
#           [2.98512e+05, 1.88000e+02]])},
#   'attrs': {'col_0': 'recipe_id', 'col_1': 'calories (#)'}},
#  'dataset_1': {'all': {'data': array([[4.41230e+04, 1.08000e+02],
#           [6.76640e+04, 3.00000e+00],
#           [3.87980e+04, 5.00000e+00],
#           ...,
#           [1.03312e+05, 8.70000e+01],
#           [4.86161e+05, 2.60000e+01],
#           [2.98512e+05, 1.10000e+01]])},
#   'attrs': {'col_0': 'recipe_id', 'col_1': 'total fat (PDV)'}},
#  'dataset_2': {'all': {'data': array([[4.41230e+04, 2.60000e+01],
#           [6.76640e+04, 5.00000e+00],
#           [3.87980e+04, 2.00000e+00],
#           ...,
#           [1.03312e+05, 3.00000e+01],
#           [4.86161e+05, 3.40000e+01],
#           [2.98512e+05, 5.70000e+01]])},
#   'attrs': {'col_0': 'recipe_id', 'col_1': 'sugar (PDV)'}},
#  'dataset_3': {'all': {'data': array([[4.41230e+04, 1.90000e+01],
#           [6.76640e+04, 1.00000e+00],
#           [3.87980e+04, 3.00000e+00],
#           ...,
#           [1.03312e+05, 1.80000e+01],
#           [4.86161e+05, 2.60000e+01],
#           [2.98512e+05, 1.10000e+01]])},
#   'attrs': {'col_0': 'recipe_id', 'col_1': 'sodium (PDV)'}},
#  'dataset_4': {'all': {'data': array([[4.41230e+04, 2.80000e+01],
#           [6.76640e+04, 4.00000e+00],
#           [3.87980e+04, 3.00000e+00],
#           ...,
#           [1.03312e+05, 4.00000e+01],
#           [4.86161e+05, 4.40000e+01],
#           [2.98512e+05, 7.00000e+00]])},
#   'attrs': {'col_0': 'recipe_id', 'col_1': 'protein (PDV)'}},
#  'dataset_5': {'all': {'data': array([[4.41230e+04, 2.14000e+02],
#           [6.76640e+04, 6.00000e+00],
#           [3.87980e+04, 3.00000e+00],
#           ...,
#           [1.03312e+05, 1.52000e+02],
#           [4.86161e+05, 2.10000e+01],
#           [2.98512e+05, 2.10000e+01]])},
#   'attrs': {'col_0': 'recipe_id', 'col_1': 'saturated fat (PDV)'}},
#  'dataset_6': {'all': {'data': array([[4.41230e+04, 1.00000e+01],
#           [6.76640e+04, 1.10000e+01],
#           [3.87980e+04, 1.00000e+00],
#           ...,
#           [1.03312e+05, 2.30000e+01],
#           [4.86161e+05, 1.50000e+01],
#           [2.98512e+05, 9.00000e+00]])},
#   'attrs': {'col_0': 'recipe_id', 'col_1': 'carbohydrates (PDV)'}}}

# %% [markdown]
# 3.2 Разбейте каждый из имеющихся датасетов на две части: 1 часть содержит только те строки, где PDV (Percent Daily Value) превышает 100%; 2 часть содержит те строки, где PDV не составляет не более 100%.<br>Создайте 2 группы в файле и разместите в них соответствующие части датасета c сохранением метаданных исходных датасетов. Итого должно получиться 2 группы, содержащие несколько датасетов. Сохраните результаты в файл `nutrition_grouped.h5`

# %%
datasets_dict = {k : v for k, v in datasets_dict.items() if "PDV" in v["attrs"]["col_1"]}

# %%
new_datasets_dict = {"PDV_more_100" : {}, "PDV_less_100": {}}
for dataset, values in datasets_dict.items():

    data = values["all"]["data"]
    mask = data[:,1] > 1
    
    new_datasets_dict["PDV_more_100"][dataset] = {"data" :  data[mask], "attrs" : values["attrs"], "name": dataset}

    mask = data[:,1] < 1
    new_datasets_dict["PDV_less_100"][dataset] = {"data" :  data[mask], "attrs" : values["attrs"], "name": dataset}

# %%
for dataset, data in new_datasets_dict.items():
    print(dataset)
    print(data)
# Out:
# PDV_more_100
# {'dataset_1': {'data': array([[4.41230e+04, 1.08000e+02],
#        [6.76640e+04, 3.00000e+00],
#        [3.87980e+04, 5.00000e+00],
#        ...,
#        [1.03312e+05, 8.70000e+01],
#        [4.86161e+05, 2.60000e+01],
#        [2.98512e+05, 1.10000e+01]]), 'attrs': {'col_0': 'recipe_id', 'col_1': 'total fat (PDV)'}, 'name': 'dataset_1'}, 'dataset_2': {'data': array([[4.41230e+04, 2.60000e+01],
#        [6.76640e+04, 5.00000e+00],
#        [3.87980e+04, 2.00000e+00],
#        ...,
#        [1.03312e+05, 3.00000e+01],
#        [4.86161e+05, 3.40000e+01],
#        [2.98512e+05, 5.70000e+01]]), 'attrs': {'col_0': 'recipe_id', 'col_1': 'sugar (PDV)'}, 'name': 'dataset_2'}, 'dataset_3': {'data': array([[4.41230e+04, 1.90000e+01],
#        [3.87980e+04, 3.00000e+00],
#        [3.51730e+04, 9.70000e+01],
#        ...,
#        [1.03312e+05, 1.80000e+01],
#        [4.86161e+05, 2.60000e+01],
#        [2.98512e+05, 1.10000e+01]]), 'attrs': {'col_0': 'recipe_id', 'col_1': 'sodium (PDV)'}, 'name': 'dataset_3'}, 'dataset_4': {'data': array([[4.41230e+04, 2.80000e+01],
#        [6.76640e+04, 4.00000e+00],
#        [3.87980e+04, 3.00000e+00],
#        ...,
#        [1.03312e+05, 4.00000e+01],
#        [4.86161e+05, 4.40000e+01],
#        [2.98512e+05, 7.00000e+00]]), 'attrs': {'col_0': 'recipe_id', 'col_1': 'protein (PDV)'}, 'name': 'dataset_4'}, 'dataset_5': {'data': array([[4.41230e+04, 2.14000e+02],
#        [6.76640e+04, 6.00000e+00],
#        [3.87980e+04, 3.00000e+00],
#        ...,
#        [1.03312e+05, 1.52000e+02],
#        [4.86161e+05, 2.10000e+01],
#        [2.98512e+05, 2.10000e+01]]), 'attrs': {'col_0': 'recipe_id', 'col_1': 'saturated fat (PDV)'}, 'name': 'dataset_5'}, 'dataset_6': {'data': array([[4.41230e+04, 1.00000e+01],
#        [6.76640e+04, 1.10000e+01],
#        [3.51730e+04, 2.00000e+00],
#        ...,
#        [1.03312e+05, 2.30000e+01],
#        [4.86161e+05, 1.50000e+01],
#        [2.98512e+05, 9.00000e+00]]), 'attrs': {'col_0': 'recipe_id', 'col_1': 'carbohydrates (PDV)'}, 'name': 'dataset_6'}}
# PDV_less_100
# {'dataset_1': {'data': array([[116741.,      0.],
#        [342619.,      0.],
#        [173730.,      0.],
#        ...,
#        [279769.,      0.],
#        [321224.,      0.],
#        [325574.,      0.]]), 'attrs': {'col_0': 'recipe_id', 'col_1': 'total fat (PDV)'}, 'name': 'dataset_1'}, 'dataset_2': {'data': array([[292568.,      0.],
#        [287778.,      0.],
#        [ 11361.,      0.],
#        ...,
#        [498523.,      0.],
#        [ 86286.,      0.],
#        [275655.,      0.]]), 'attrs': {'col_0': 'recipe_id', 'col_1': 'sugar (PDV)'}, 'name': 'dataset_2'}, 'dataset_3': {'data': array([[296983.,      0.],
#        [250232.,      0.],
#        [327979.,      0.],
#        ...,
#        [376373.,      0.],
#        [279769.,      0.],
#        [162411.,      0.]]), 'attrs': {'col_0': 'recipe_id', 'col_1': 'sodium (PDV)'}, 'name': 'dataset_3'}, 'dataset_4': {'data': array([[367987.,      0.],
#        [100837.,      0.],
#        [165096.,      0.],
#        ...,
#        [400519.,      0.],
#        [498523.,      0.],
#        [130433.,      0.]]), 'attrs': {'col_0': 'recipe_id', 'col_1': 'protein (PDV)'}, 'name': 'dataset_4'}, 'dataset_5': {'data': array([[116741.,      0.],
#        [342619.,      0.],
#        [173730.,      0.],
#        ...,
#        [321224.,      0.],
#        [325574.,      0.],
#        [316950.,      0.]]), 'attrs': {'col_0': 'recipe_id', 'col_1': 'saturated fat (PDV)'}, 'name': 'dataset_5'}, 'dataset_6': {'data': array([[147477.,      0.],
#        [383120.,      0.],
#        [367987.,      0.],
#        ...,
#        [269904.,      0.],
#        [205148.,      0.],
#        [505053.,      0.]]), 'attrs': {'col_0': 'recipe_id', 'col_1': 'carbohydrates (PDV)'}, 'name': 'dataset_6'}}

# %%
h5_path = "./out/nutrition_grouped.h5"
with h5py.File(h5_path, mode='w') as hdf:
    for group, data in new_datasets_dict.items():
        new_group = hdf.create_group(group)
        for d in data:
            item = new_group.create_dataset(name=data[d]['name'], data=data[d]['data'])
            item.attrs.update(data[d]['attrs'])

# %% [markdown]
# 3.3 Выведите названия всех групп и датасетов, находящихся в этих группах, из файла `nutrition_grouped.h5` а также размерность матриц, содержащихся в датасетах и их метаданные.

# %%
with h5py.File(h5_path) as hdf:
    
    for group_name, data in hdf.items():
        print(f'\nGroup: {group_name}')

        for key in data:
            file = data[key]
            metadata = dict(file.attrs)
            print(f"Dataset name={key}, dataset size={file.shape}, metadata={metadata}")
            datasets_dict[key] = {"all" : {'data': file[:]}, 'attrs': metadata}
# Out:
# Group: PDV_less_100
# Dataset name=dataset_1, dataset size=(2146, 2), metadata={'col_0': 'recipe_id', 'col_1': 'total fat (PDV)'}
# Dataset name=dataset_2, dataset size=(1371, 2), metadata={'col_0': 'recipe_id', 'col_1': 'sugar (PDV)'}
# Dataset name=dataset_3, dataset size=(2588, 2), metadata={'col_0': 'recipe_id', 'col_1': 'sodium (PDV)'}
# Dataset name=dataset_4, dataset size=(1274, 2), metadata={'col_0': 'recipe_id', 'col_1': 'protein (PDV)'}
# Dataset name=dataset_5, dataset size=(2569, 2), metadata={'col_0': 'recipe_id', 'col_1': 'saturated fat (PDV)'}
# Dataset name=dataset_6, dataset size=(1653, 2), metadata={'col_0': 'recipe_id', 'col_1': 'carbohydrates (PDV)'}
#
# Group: PDV_more_100
# Dataset name=dataset_1, dataset size=(27025, 2), metadata={'col_0': 'recipe_id', 'col_1': 'total fat (PDV)'}
# Dataset name=dataset_2, dataset size=(27822, 2), metadata={'col_0': 'recipe_id', 'col_1': 'sugar (PDV)'}
# Dataset name=dataset_3, dataset size=(26148, 2), metadata={'col_0': 'recipe_id', 'col_1': 'sodium (PDV)'}
# Dataset name=dataset_4, dataset size=(27748, 2), metadata={'col_0': 'recipe_id', 'col_1': 'protein (PDV)'}
# Dataset name=dataset_5, dataset size=(26559, 2), metadata={'col_0': 'recipe_id', 'col_1': 'saturated fat (PDV)'}
# Dataset name=dataset_6, dataset size=(26591, 2), metadata={'col_0': 'recipe_id', 'col_1': 'carbohydrates (PDV)'}

# %% [markdown]
# 3.4 Модифицируйте код из 3.3 таким образом, чтобы сохранить датасеты, используя сжатие. Сравните размер полученного файла с размерами файла из 3.3. Прокомментируйте результат.

# %%
h5_compressed_path = "./out/nutrition_grouped_compressed.h5"
with h5py.File(h5_compressed_path, mode='w') as hdf:
    for group, data in new_datasets_dict.items():
        new_group = hdf.create_group(group)
        for d in data:
            item = new_group.create_dataset(name=data[d]['name'], data=data[d]['data'], compression="gzip", compression_opts=9)
            item.attrs.update(data[d]['attrs'])

# %%
def get_file_size_2(file):
 
    stat = os.stat(file)
    print(stat)
    size = stat.st_size
    return size

def convert_bytes(size, unit=None):
    if unit == "KB":
        return print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        return print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    elif unit == "GB":
        return print('File size: ' + str(round(size / (1024 * 1024 * 1024), 3)) + ' Gigabytes')
    else:
        return print('File size: ' + str(size) + ' bytes')

# %%
import os

# %%
size = get_file_size_2(h5_path)
print('File size: ' + str(size) + ' bytes')
# Out:
# os.stat_result(st_mode=33188, st_ino=27995154, st_dev=16777234, st_nlink=1, st_uid=501, st_gid=20, st_size=2788576, st_atime=1633279255, st_mtime=1633279255, st_ctime=1633279255)
# File size: 2788576 bytes

# %%
size = get_file_size_2(h5_compressed_path)
print('File size: ' + str(size) + ' bytes')
# Out:
# os.stat_result(st_mode=33188, st_ino=27997350, st_dev=16777234, st_nlink=1, st_uid=501, st_gid=20, st_size=914789, st_atime=1633279205, st_mtime=1633279256, st_ctime=1633279256)
# File size: 914789 bytes
