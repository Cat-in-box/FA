# %% [markdown]
# # Dask Delayed

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 13: Dask Delayed
# * https://docs.dask.org/en/latest/delayed.html
# * Jesse C. Daniel. Data Science with Python and Dask.

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# ![](https://i.imgur.com/AwiN8y6.png)
# ![](https://i.imgur.com/ceY6guU.png)

# %% [markdown]
# 1. Напишите 2 функции, имитирующие CPU-bound задачу и IO-bound задачу:
#
# `cpu_task()`: генерирует 100 тыс. случайных чисел и возвращает их сумму (без использования `numpy`)
#
# `io_task()`: "спит" 0.1 сек, затем генерирует случайное число и возвращает его
#
# Замерьте время выполнения 100 последовательных вызовов каждой из этих функций. Распараллелив вычисления при помощи `dask.delayed`, сократите время выполнения. Исследуйте, как зависит время вычислений от выбранного планировщика `scheduler`.

# %%
import random
import time
import dask

def cpu_task():
    lst = [random.randint(0,10) for _ in range(100_000)]
    return sum(lst)

def io_task():
    time.sleep(0.1)
    return random.randint(0,10)

# %%
cpu_task()
# Out:
# 500279

# %%
# %%time
res = [cpu_task() for _ in range(100)]
# Out:
# Wall time: 6 s

# %%
# %%time
res = [io_task() for _ in range(100)]
# Out:
# Wall time: 10.9 s

# %%
from dask import delayed

# %%
cpu_task_delayed = delayed(cpu_task)

# %%
cpu_task_delayed().compute()
# Out:
# 500245

# %%
# %%time
res = [cpu_task_delayed() for _ in range(100)]
res_computed = dask.compute(res, scheduler="threading")
# Out:
# Wall time: 6.49 s

# %%
# %%time
res = [cpu_task_delayed() for _ in range(100)]
res_computed = dask.compute(res, scheduler="multiprocessing")
# Out:
# Wall time: 2.76 s

# %%
io_task_delayed = delayed(io_task)

# %%
# %%time
res = [io_task_delayed() for _ in range(100)]
res_computed = dask.compute(res, scheduler="threading")
# Out:
# Wall time: 997 ms

# %%
# %%time
res = [io_task_delayed() for _ in range(100)]
res_computed = dask.compute(res, scheduler="multiprocessing")
# Out:
# Wall time: 2.11 s

# %% [markdown]
# ## Лабораторная работа 14

# %%
from bs4 import BeautifulSoup
from datetime import datetime
import glob
import dask
import dask.bag as db
import json
import re

# %% [markdown]
# 1. Напишите функцию, которая считывает файл формата xml из каталога `reviewers_full` и по данным этого файла формирует список словарей, содержащих следующие ключи: `id`, `username`, `name`, `sex`, `country`, `mail`, `registered`, `birthdate`, `name_prefix`, `country_code`. Часть из этих значений в исходном файле хранится в виде тэгов, часть - в виде атрибутов тэгов. Для конкретного человека какие-то из этих ключей могут отсутствовать.

# %%
tag_list = ['id', 'username', 'name', 'sex', 'country', 'mail', 'registered', 'birthdate']

def reader(path):
    file = open(path,"r").read()
    data = BeautifulSoup(file,'xml')
    result_list = []
    
    for user in data.find_all('user'):
        user_dict = {}
        if user.get('prefix') is not None:
            user_dict['name_prefix'] = user.get('prefix')
        
        for tag in tag_list:
            user_tag = user.find(tag)
            if user_tag is not None:
                if tag == 'birthdate':
                    user_dict[tag] = datetime.strptime(user_tag.get_text(), '%Y-%m-%d')
                else:
                    user_dict[tag] = user_tag.get_text()

                if tag == 'country' and user.find(tag).get('code') is not None:
                    user_dict['country_code'] = user.find(tag).get('code')

        result_list.append(user_dict)
    
    return result_list

# %%
files_list = glob.glob("../data/reviewers_full/reviewers_full_*.xml")
result = []
for path in files_list:
    result.extend(reader(path))

result[:5]
# Out:
# [{'name_prefix': 'Mrs.',
#   'id': '556011',
#   'username': 'gabrielacalhoun',
#   'sex': 'F',
#   'birthdate': datetime.datetime(1988, 1, 25, 0, 0)},
#  {'id': '1251087',
#   'username': 'qbaxter',
#   'country': 'Norway',
#   'country_code': 'NO',
#   'mail': 'qware@gmail.com',
#   'birthdate': datetime.datetime(1985, 1, 19, 0, 0)},
#  {'id': '537188',
#   'username': 'crosschristopher',
#   'name': 'Dana Moore',
#   'mail': 'stephaniestrong@yahoo.com',
#   'registered': '2018-11-21',
#   'birthdate': datetime.datetime(1955, 7, 3, 0, 0)},
#  {'id': '250427',
#   'username': 'karen27',
#   'name': 'Jennifer Horne',
#   'country': 'Cuba',
#   'country_code': 'CU',
#   'mail': 'wjarvis@yahoo.com',
#   'registered': '2013-11-20',
#   'birthdate': datetime.datetime(2007, 4, 30, 0, 0)},
#  {'id': '2945188',
#   'username': 'gambledanielle',
#   'name': 'Henry Harris',
#   'country': 'Serbia',
#   'country_code': 'RS',
#   'registered': '2011-04-08'}]

# %% [markdown]
# 2. Измерьте время выполнения функции из задания 1 на всех файлах из каталога `reviewers_full`. Ускорьте время выполнения, используя `dask.delayed`.

# %%
# %%time
for path in files_list:
    reader(path)
# Out:
# Wall time: 1min 34s

# %%
delayed_reader = dask.delayed(reader)

# %%
# %%time
dask.compute([delayed_reader(path) for path in files_list], scheduler="processes")
# Out:
# Wall time: 1min 24s
# ([[{'name_prefix': 'Mrs.',
#     'id': '556011',
#     'username': 'gabrielacalhoun',
#     'sex': 'F',
#     'birthdate': datetime.datetime(1988, 1, 25, 0, 0)},
#    {'id': '1251087',
#     'username': 'qbaxter',
#     'country': 'Norway',
#     'country_code': 'NO',
#     'mail': 'qware@gmail.com',
#     'birthdate': datetime.datetime(1985, 1, 19, 0, 0)},
#    {'id': '537188',
#     'username': 'crosschristopher',
#     'name': 'Dana Moore',
#     'mail': 'stephaniestrong@yahoo.com',
#     'registered': '2018-11-21',
#     'birthdate': datetime.datetime(1955, 7, 3, 0, 0)},
#    {'id': '250427',
#     'username': 'karen27',
#     'name': 'Jennifer Horne',
#     'country': 'Cuba',
#     'country_code': 'CU',
#     'mail': 'wjarvis@yahoo.com',
#     'registered': '2013-11-20',
#     'birthdate': datetime.datetime(2007, 4, 30, 0, 0)},
#    {'id': '2945188',
#     'username': 'gambledanielle',
#     'name': 'Henry Harris',
#     'country': 'Serbia',
#     'country_code': 'RS',
#     'registered': '2011-04-08'},
#    {'name_prefix': 'Miss',
#     'id': '452355',
#     'username': 'smullen',
#     'name': 'Cynthia Johnson',
#     'sex': 'F',
#     'birthdate': datetime.datetime(2005, 3, 29, 0, 0)},
#    {'id': '382203',
#     'username': 'barrettmichael',
#     'name': 'Margaret Banks',
#     'mail': 'christinaday@hotmail.com',
#     'birthdate': datetime.datetime(1971, 11, 15, 0, 0)},
#    {'name_prefix': 'Mrs.',
#     'id': '81563',
#     'username': 'morrischarles',
#     'sex': 'F',
#     'country': 'Zambia',
#     'country_code': 'ZM',
#     'registered': '2014-09-28'},
#    {'name_prefix': 'Mrs.',
#     'id': '1355079',
#     'username': 'osalazar',
#     'sex': 'F',
#     'mail': 'justintyler@hotmail.com',
#     'registered': '2009-08-02'},
#    {'id': '185926',
#     'username': 'juanmontoya',
#     'sex': 'M',
#     'country': 'Aruba',
#     'country_code': 'AW',
#     'registered': '2016-07-16'},
#    {'id': '65936',
#     'username': 'villanuevafrank',
#     'name': 'Patrick Campos',
#     'country': 'Malaysia',
#     'country_code': 'MY',
#     'mail': 'stephanieshaw@gmail.com'},
#    {'id': '1047126',
#     'username': 'amorales',
#     'sex': 'M',
#     'country': 'Dominican Republic',
#     'country_code': 'DO',
#     'mail': 'briannatrujillo@gmail.com',
#     'registered': '2004-11-24'},
#    {'id': '27443',
#     'username': 'josephrush',
#     'country': 'Guam',
#     'country_code': 'GU',
#     'registered': '2015-07-18',
#     'birthdate': datetime.datetime(1976, 7, 5, 0, 0)},
#    {'id': '907374',
#     'username': 'gwheeler',
#     'sex': 'M',
#     'country': 'Solomon Islands',
#     'country_code': 'SB',
#     'mail': 'javery@hotmail.com'},
#    {'id': '287420',
#     'username': 'hughesabigail',
#     'name': 'Eric Garcia',
#     'mail': 'deborah17@yahoo.com',
#     'registered': '2006-04-02'},
#    {'id': '240344',
#     'username': 'ashleygrimes',
#     'name': 'Rebecca Bowers',
#     'country': 'Montserrat',
#     'country_code': 'MS',
#     'registered': '2001-08-26'},
#    {'name_prefix': 'Mr.',
#     'id': '849727',
#     'username': 'george76',
#     'name': 'Gregory Watts',
#     'sex': 'M'},
#    {'id': '2056668',
#     'username': 'franklinhancock',
#     'name': 'Michele Richards',
#     'country': 'Namibia',
#     'country_code': 'nan',
#     'mail': 'claudiamccoy@gmail.com',
#     'registered': '2009-08-12',
#     'birthdate': datetime.datetime(1983, 2, 20, 0, 0)},
#    {'id': '1030163',
#     'username': 'jennifer31',
#     'name': 'Amber Martin',
#     'sex': 'F',
#     'mail': 'austin68@yahoo.com'},
#    {'id': '329304',
#     'username': 'alisonbell',
#     'sex': 'F',
#     'mail': 'micheal05@hotmail.com',
#     'registered': '2008-10-25'},
#    {'id': '31499',
#     'username': 'lisa10',
#     'sex': 'M',
#     'country': 'American Samoa',
#     'country_code': 'AS',
#     'mail': 'newtonalexander@hotmail.com'},
#    {'id': '343188',
#     'username': 'lovepeter',
#     'sex': 'M',
#     'country': 'Sierra Leone',
#     'country_code': 'SL',
#     'registered': '2006-09-26'},
#    {'id': '46455',
#     'username': 'amy93',
#     'name': 'Patricia Fox',
#     'mail': 'wbrooks@hotmail.com'},
#    {'name_prefix': 'Dr.',
#     'id': '37779',
#     'username': 'fkhan',
#     'sex': 'F',
#     'country': 'Kazakhstan',
#     'country_code': 'KZ',
#     'registered': '2009-02-10'},
#    {'id': '356079',
#     'username': 'cdavis',
#     'country': 'Qatar',
#     'country_code': 'QA',
#     'birthdate': datetime.datetime(2015, 9, 29, 0, 0)},
#    {'name_prefix': 'Mrs.',
#     'id': '1515495',
#     'username': 'ronaldgrimes',
#     'name': 'Rita Hodge',
#     'sex': 'F',
#     'registered': '2003-07-03',
#     'birthdate': datetime.datetime(1996, 2, 7, 0, 0)},
#    {'id': '169166',
#     'username': 'shannonbender',
#     'name': 'Sandy Morales',
#     'sex': 'F',
#     'country': 'Yemen',
#     'country_code': 'YE',
#     'registered': '2019-06-23',
#     'birthdate': datetime.datetime(2009, 4, 21, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '97825',
#     'username': 'christinapeterson',
#     'sex': 'M',
#     'mail': 'rwoods@hotmail.com',
#     'registered': '2009-04-15'},
#    {'id': '133174',
#     'username': 'elizabethvaldez',
#     'name': 'Heather Jones',
#     'birthdate': datetime.datetime(1966, 4, 21, 0, 0)},
#    {'id': '581536',
#     'username': 'caseyjustin',
#     'name': 'Jose Taylor',
#     'mail': 'garretthaley@yahoo.com',
#     'registered': '2012-08-22',
#     'birthdate': datetime.datetime(2017, 12, 20, 0, 0)},
#    {'id': '227932',
#     'username': 'williamsonjacqueline',
#     'name': 'Edward Norton',
#     'sex': 'M',
#     'country': 'Mexico',
#     'country_code': 'MX',
#     'mail': 'katrina72@yahoo.com'},
#    {'id': '468627',
#     'username': 'dtaylor',
#     'country': 'Andorra',
#     'country_code': 'AD',
#     'mail': 'schaefercharles@hotmail.com',
#     'birthdate': datetime.datetime(2001, 12, 30, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '1072593',
#     'username': 'christian74',
#     'name': 'Danielle Webster',
#     'sex': 'F',
#     'birthdate': datetime.datetime(1984, 4, 14, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '1242867',
#     'username': 'christinegomez',
#     'sex': 'M',
#     'country': 'Netherlands',
#     'country_code': 'NL',
#     'mail': 'xcrosby@yahoo.com',
#     'registered': '2016-07-01',
#     'birthdate': datetime.datetime(1986, 11, 29, 0, 0)},
#    {'id': '137854',
#     'username': 'hwoods',
#     'name': 'Nichole Maynard',
#     'sex': 'F',
#     'mail': 'jamesgalloway@hotmail.com',
#     'birthdate': datetime.datetime(1990, 1, 3, 0, 0)},
#    {'id': '488441',
#     'username': 'longjacob',
#     'country': 'Costa Rica',
#     'country_code': 'CR',
#     'mail': 'brittney36@yahoo.com'},
#    {'id': '179133',
#     'username': 'zrodgers',
#     'name': 'Angelica Mcfarland',
#     'country': 'United Arab Emirates',
#     'country_code': 'AE',
#     'mail': 'coreyparker@hotmail.com',
#     'registered': '2017-07-18',
#     'birthdate': datetime.datetime(1955, 1, 13, 0, 0)},
#    {'id': '89240',
#     'username': 'elizabeth00',
#     'name': 'Edward Harper',
#     'mail': 'vrojas@hotmail.com'},
#    {'name_prefix': 'Dr.',
#     'id': '2000498330',
#     'username': 'jenna30',
#     'sex': 'M',
#     'country': 'Anguilla',
#     'country_code': 'AI',
#     'birthdate': datetime.datetime(1996, 9, 4, 0, 0)},
#    {'id': '171468',
#     'username': 'gallen',
#     'country': 'Turkey',
#     'country_code': 'TR',
#     'mail': 'charlesholland@yahoo.com',
#     'registered': '2016-01-13',
#     'birthdate': datetime.datetime(1963, 11, 29, 0, 0)},
#    {'id': '39835',
#     'username': 'stacykelly',
#     'name': 'Victor Owens',
#     'sex': 'M',
#     'country': 'Haiti',
#     'country_code': 'HT',
#     'mail': 'imccoy@yahoo.com',
#     'birthdate': datetime.datetime(1955, 6, 20, 0, 0)},
#    {'id': '1661670', 'username': 'beckricardo', 'registered': '2007-07-14'},
#    {'id': '163872',
#     'username': 'kristenchang',
#     'name': 'Ryan Washington',
#     'sex': 'M',
#     'country': 'Ethiopia',
#     'country_code': 'ET'},
#    {'id': '724631',
#     'username': 'abaldwin',
#     'mail': 'bridgesjanet@yahoo.com',
#     'registered': '2017-06-13'},
#    {'id': '129958',
#     'username': 'robert57',
#     'sex': 'M',
#     'country': 'Qatar',
#     'country_code': 'QA',
#     'registered': '2008-09-19',
#     'birthdate': datetime.datetime(2020, 3, 28, 0, 0)},
#    {'id': '545825',
#     'username': 'rosebrooke',
#     'name': 'Nathan Evans',
#     'sex': 'M',
#     'mail': 'collinsbrittany@hotmail.com',
#     'registered': '2010-02-19'},
#    {'name_prefix': 'Dr.',
#     'id': '19129',
#     'username': 'roberthoward',
#     'name': 'John Schaefer',
#     'sex': 'M',
#     'mail': 'connieyang@yahoo.com',
#     'registered': '2014-05-09',
#     'birthdate': datetime.datetime(2004, 9, 1, 0, 0)},
#    {'id': '1823125', 'username': 'kristygreen'},
#    {'name_prefix': 'Dr.',
#     'id': '704950',
#     'username': 'lorigreen',
#     'name': 'Edward Clark',
#     'sex': 'M',
#     'mail': 'eallen@gmail.com'},
#    {'id': '280422', 'username': 'tyler05', 'mail': 'michael31@gmail.com'},
#    {'name_prefix': 'Dr.',
#     'id': '1009166',
#     'username': 'rturner',
#     'name': 'Jason Williams',
#     'sex': 'M',
#     'country': 'Costa Rica',
#     'country_code': 'CR',
#     'registered': '2008-01-28'},
#    {'id': '215335',
#     'username': 'bryanfrazier',
#     'country': 'Kazakhstan',
#     'country_code': 'KZ',
#     'registered': '2011-02-01'},
#    {'id': '2549237',
#     'username': 'katherinemays',
#     'birthdate': datetime.datetime(1987, 11, 22, 0, 0)},
#    {'id': '748213',
#     'username': 'sheena36',
#     'sex': 'F',
#     'country': 'Mali',
#     'country_code': 'ML',
#     'mail': 'garzajill@hotmail.com',
#     'birthdate': datetime.datetime(1965, 5, 6, 0, 0)},
#    {'id': '2002026167',
#     'username': 'mramos',
#     'name': 'Laura Cooper',
#     'mail': 'chavezsydney@hotmail.com',
#     'registered': '2014-08-16'},
#    {'name_prefix': 'Mrs.',
#     'id': '40354',
#     'username': 'ocarey',
#     'sex': 'F',
#     'registered': '2017-02-14'},
#    {'id': '791238',
#     'username': 'clarkjennifer',
#     'country': 'Austria',
#     'country_code': 'AT',
#     'birthdate': datetime.datetime(2001, 8, 26, 0, 0)},
#    {'id': '22585',
#     'username': 'johnsonrachel',
#     'sex': 'F',
#     'mail': 'oschwartz@gmail.com',
#     'registered': '2001-05-03'},
#    {'id': '91392',
#     'username': 'jasmine70',
#     'name': 'Megan Powell',
#     'mail': 'bphillips@hotmail.com'},
#    {'id': '4470',
#     'username': 'susanhoward',
#     'mail': 'michaelhernandez@gmail.com',
#     'birthdate': datetime.datetime(1986, 10, 9, 0, 0)},
#    {'id': '25792',
#     'username': 'laurenjohnson',
#     'sex': 'M',
#     'mail': 'derrick15@hotmail.com',
#     'birthdate': datetime.datetime(1995, 12, 7, 0, 0)},
#    {'id': '359936',
#     'username': 'williambrooks',
#     'registered': '2017-09-23',
#     'birthdate': datetime.datetime(2004, 3, 15, 0, 0)},
#    {'id': '39992',
#     'username': 'carolyn39',
#     'sex': 'M',
#     'birthdate': datetime.datetime(2009, 5, 25, 0, 0)},
#    {'name_prefix': 'Mrs.',
#     'id': '853668',
#     'username': 'shawmiranda',
#     'name': 'Tara Chambers',
#     'sex': 'F',
#     'mail': 'biancamartin@hotmail.com',
#     'registered': '2018-08-07'},
#    {'name_prefix': 'Mr.', 'id': '196186', 'username': 'bvance', 'sex': 'M'},
#    {'id': '1607893',
#     'username': 'rodriguezstacey',
#     'sex': 'M',
#     'country': 'Ukraine',
#     'country_code': 'UA',
#     'mail': 'patrick12@yahoo.com'},
#    {'id': '706608',
#     'username': 'pwatts',
#     'name': 'Tasha Kennedy',
#     'birthdate': datetime.datetime(2008, 8, 3, 0, 0)},
#    {'id': '400708',
#     'username': 'christopher55',
#     'mail': 'michael57@gmail.com'},
#    {'id': '229850',
#     'username': 'johnstontimothy',
#     'name': 'Mark Drake',
#     'sex': 'M',
#     'registered': '2009-11-03',
#     'birthdate': datetime.datetime(1971, 10, 15, 0, 0)},
#    {'id': '2001157567',
#     'username': 'davidmckenzie',
#     'country': 'Isle of Man',
#     'country_code': 'IM'},
#    {'name_prefix': 'Mrs.',
#     'id': '766910',
#     'username': 'pdean',
#     'sex': 'F',
#     'country': 'Barbados',
#     'country_code': 'BB',
#     'mail': 'janet77@hotmail.com',
#     'birthdate': datetime.datetime(1993, 2, 5, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '1801324306',
#     'username': 'baileyrobert',
#     'sex': 'M',
#     'country': 'Czech Republic',
#     'country_code': 'CZ',
#     'registered': '2008-01-03'},
#    {'id': '421374',
#     'username': 'stephaniestevens',
#     'country': 'Antarctica (the territory South of 60 deg S)',
#     'registered': '2008-10-02'},
#    {'id': '88099',
#     'username': 'hunttrevor',
#     'name': 'Amber Bush',
#     'sex': 'F',
#     'country': 'Gambia',
#     'country_code': 'GM'},
#    {'id': '43574191',
#     'username': 'heatheric',
#     'name': 'Michael Bentley',
#     'country': 'Svalbard & Jan Mayen Islands',
#     'registered': '2016-12-28',
#     'birthdate': datetime.datetime(1998, 12, 21, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '274065',
#     'username': 'jwhite',
#     'sex': 'M',
#     'country': 'Estonia',
#     'country_code': 'EE',
#     'registered': '2002-07-05',
#     'birthdate': datetime.datetime(1950, 8, 26, 0, 0)},
#    {'id': '61569',
#     'username': 'james34',
#     'country': 'Uganda',
#     'country_code': 'UG'},
#    {'id': '1802530252',
#     'username': 'frankflores',
#     'name': 'Adam Contreras',
#     'mail': 'joneschristopher@yahoo.com',
#     'birthdate': datetime.datetime(1977, 10, 23, 0, 0)},
#    {'id': '460228',
#     'username': 'nfitzgerald',
#     'name': 'Tiffany Hamilton',
#     'birthdate': datetime.datetime(2016, 2, 19, 0, 0)},
#    {'name_prefix': 'Ms.',
#     'id': '409184',
#     'username': 'norma44',
#     'sex': 'F',
#     'registered': '2017-08-23',
#     'birthdate': datetime.datetime(1982, 5, 8, 0, 0)},
#    {'name_prefix': 'Mrs.',
#     'id': '1366053',
#     'username': 'audrey28',
#     'name': 'Jamie Harris',
#     'sex': 'F',
#     'mail': 'michelle59@hotmail.com',
#     'registered': '2018-01-03',
#     'birthdate': datetime.datetime(2003, 8, 1, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '206774',
#     'username': 'simsdan',
#     'name': 'Andrew Phillips',
#     'sex': 'M',
#     'registered': '2018-10-29',
#     'birthdate': datetime.datetime(2009, 3, 31, 0, 0)},
#    {'id': '137911',
#     'username': 'jsantana',
#     'name': 'Ian Valencia',
#     'sex': 'M',
#     'country': 'Oman',
#     'country_code': 'OM',
#     'mail': 'romeronicholas@gmail.com',
#     'registered': '2018-11-08'},
#    {'id': '520620',
#     'username': 'ptaylor',
#     'sex': 'F',
#     'country': 'United Kingdom',
#     'country_code': 'GB',
#     'mail': 'rcarr@gmail.com',
#     'registered': '2010-06-05',
#     'birthdate': datetime.datetime(1958, 9, 5, 0, 0)},
#    {'id': '1098259', 'username': 'hparker', 'name': 'Brian Gentry'},
#    {'name_prefix': 'Dr.',
#     'id': '512309',
#     'username': 'dbarnett',
#     'name': 'Stacey Gallagher',
#     'sex': 'F',
#     'country': 'Nepal',
#     'country_code': 'NP'},
#    {'id': '60716',
#     'username': 'mallory07',
#     'name': 'Matthew Farrell',
#     'country': 'Somalia',
#     'country_code': 'SO',
#     'registered': '2002-07-17'},
#    {'name_prefix': 'Mr.',
#     'id': '383346',
#     'username': 'williamhorn',
#     'name': 'Stephen Franco',
#     'sex': 'M',
#     'country': 'Liechtenstein',
#     'country_code': 'LI',
#     'mail': 'jeffreyfreeman@gmail.com',
#     'registered': '2011-09-16',
#     'birthdate': datetime.datetime(2021, 5, 28, 0, 0)},
#    {'id': '177226',
#     'username': 'woodsroy',
#     'sex': 'M',
#     'mail': 'fsmith@gmail.com',
#     'registered': '2019-10-30'},
#    {'id': '384041', 'username': 'kaylarobinson', 'registered': '2005-07-29'},
#    {'name_prefix': 'Dr.',
#     'id': '579298',
#     'username': 'karengutierrez',
#     'sex': 'F',
#     'country': 'Saint Barthelemy',
#     'mail': 'rhonda94@hotmail.com',
#     'registered': '2004-10-12',
#     'birthdate': datetime.datetime(1979, 4, 15, 0, 0)},
#    {'id': '926169', 'username': 'nreese', 'country': 'Pitcairn Islands'},
#    {'id': '308765',
#     'username': 'pfox',
#     'name': 'Amy Conley',
#     'sex': 'F',
#     'registered': '2016-09-03'},
#    {'id': '160974',
#     'username': 'aaron85',
#     'name': 'Katie Miller',
#     'birthdate': datetime.datetime(2018, 8, 8, 0, 0)},
#    {'id': '1368735',
#     'username': 'zmontes',
#     'name': 'Michelle Chapman',
#     'sex': 'F',
#     'country': 'Bermuda',
#     'country_code': 'BM',
#     'mail': 'lisa40@hotmail.com',
#     'birthdate': datetime.datetime(2005, 10, 29, 0, 0)},
#    {'id': '305531',
#     'username': 'katherinelopez',
#     'country': 'Indonesia',
#     'country_code': 'ID',
#     'registered': '2016-03-03',
#     'birthdate': datetime.datetime(2009, 5, 31, 0, 0)},
#    {'id': '577735',
#     'username': 'travis31',
#     'country': 'Slovakia (Slovak Republic)',
#     'registered': '2013-07-13'},
#    {'name_prefix': 'Mr.',
#     'id': '485109',
#     'username': 'matthew57',
#     'sex': 'M',
#     'country': 'Norfolk Island',
#     'country_code': 'NF',
#     'mail': 'johnbenton@gmail.com',
#     'birthdate': datetime.datetime(1968, 8, 14, 0, 0)},
#    {'id': '122235',
#     'username': 'amyadkins',
#     'name': 'Kim Kelly',
#     'country': 'Uruguay',
#     'country_code': 'UY',
#     'registered': '2012-10-11'},
#    {'id': '57101',
#     'username': 'dunnamanda',
#     'name': 'Yolanda Bailey',
#     'sex': 'F',
#     'country': 'Swaziland',
#     'country_code': 'SZ',
#     'birthdate': datetime.datetime(1957, 11, 20, 0, 0)},
#    {'id': '316717',
#     'username': 'jnichols',
#     'name': 'George Green',
#     'sex': 'M',
#     'registered': '2006-11-21',
#     'birthdate': datetime.datetime(1950, 1, 19, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '369715',
#     'username': 'mejiashannon',
#     'name': 'Chelsea Ortega',
#     'sex': 'F',
#     'mail': 'bentonbryan@gmail.com'},
#    {'id': '958072',
#     'username': 'andersonlaura',
#     'name': 'Scott Clay',
#     'country': 'Saint Martin',
#     'country_code': 'MF',
#     'mail': 'thaynes@yahoo.com'},
#    {'id': '537617',
#     'username': 'david09',
#     'sex': 'F',
#     'country': 'United States Minor Outlying Islands',
#     'country_code': 'UM',
#     'registered': '2005-05-03'},
#    {'name_prefix': 'Mr.',
#     'id': '233780',
#     'username': 'sean85',
#     'sex': 'M',
#     'country': 'Haiti',
#     'country_code': 'HT',
#     'mail': 'stephaniebradley@yahoo.com'},
#    {'id': '464624',
#     'username': 'jennifercarter',
#     'name': 'Brittany Smith',
#     'country': 'Djibouti',
#     'country_code': 'DJ',
#     'birthdate': datetime.datetime(1989, 8, 20, 0, 0)},
#    {'id': '1363533',
#     'username': 'coltoncarter',
#     'mail': 'donnamurphy@yahoo.com',
#     'registered': '2003-02-14',
#     'birthdate': datetime.datetime(1993, 8, 28, 0, 0)},
#    {'id': '182809',
#     'username': 'obuckley',
#     'name': 'Audrey Russell',
#     'mail': 'christopher36@hotmail.com',
#     'registered': '2001-02-25',
#     'birthdate': datetime.datetime(1967, 1, 24, 0, 0)},
#    {'id': '315055',
#     'username': 'amy70',
#     'sex': 'F',
#     'birthdate': datetime.datetime(1996, 5, 17, 0, 0)},
#    {'id': '362983',
#     'username': 'cvillarreal',
#     'name': 'Jose Shea',
#     'mail': 'mark86@yahoo.com',
#     'birthdate': datetime.datetime(2021, 7, 9, 0, 0)},
#    {'id': '67899',
#     'username': 'rhonda49',
#     'mail': 'james36@gmail.com',
#     'registered': '2017-01-06',
#     'birthdate': datetime.datetime(1961, 1, 24, 0, 0)},
#    {'id': '428885',
#     'username': 'mitchellabigail',
#     'country': 'Ireland',
#     'country_code': 'IE'},
#    {'name_prefix': 'Mrs.',
#     'id': '65720',
#     'username': 'matthewsmelissa',
#     'name': 'Michelle Mathews',
#     'sex': 'F',
#     'mail': 'bbaker@gmail.com',
#     'birthdate': datetime.datetime(1999, 2, 23, 0, 0)},
#    {'id': '49304',
#     'username': 'nataliecarroll',
#     'name': 'Ricardo Schroeder',
#     'mail': 'rmccarty@hotmail.com',
#     'registered': '2019-01-02',
#     'birthdate': datetime.datetime(1978, 9, 17, 0, 0)},
#    {'id': '342459',
#     'username': 'zperez',
#     'name': 'Amber Fisher',
#     'sex': 'F',
#     'mail': 'racheljarvis@gmail.com',
#     'birthdate': datetime.datetime(1977, 10, 31, 0, 0)},
#    {'id': '55875',
#     'username': 'erodriguez',
#     'country': 'Spain',
#     'country_code': 'ES',
#     'registered': '2018-02-09'},
#    {'name_prefix': 'Mrs.',
#     'id': '165933',
#     'username': 'youngoscar',
#     'name': 'Kayla Moreno',
#     'sex': 'F',
#     'country': 'Cape Verde',
#     'country_code': 'CV',
#     'registered': '2009-11-27',
#     'birthdate': datetime.datetime(2001, 1, 3, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '843107',
#     'username': 'josewagner',
#     'sex': 'M'},
#    {'id': '353313',
#     'username': 'montgomeryanthony',
#     'mail': 'jsolis@hotmail.com',
#     'birthdate': datetime.datetime(2016, 8, 26, 0, 0)},
#    {'id': '179827',
#     'username': 'mfischer',
#     'name': 'Craig Barnes',
#     'sex': 'M',
#     'mail': 'stephenwheeler@yahoo.com',
#     'registered': '2015-02-15'},
#    {'id': '2001119845',
#     'username': 'toddherrera',
#     'name': 'Nicholas King',
#     'country': 'India',
#     'country_code': 'IN'},
#    {'id': '74904',
#     'username': 'eroberts',
#     'country': 'Hungary',
#     'country_code': 'HU',
#     'registered': '2006-12-20'},
#    {'id': '80079',
#     'username': 'johnsonjennifer',
#     'mail': 'belinda89@yahoo.com'},
#    {'id': '384043',
#     'username': 'susan32',
#     'name': 'Heather Wilson',
#     'country': 'Northern Mariana Islands',
#     'country_code': 'MP',
#     'mail': 'yschultz@yahoo.com',
#     'registered': '2003-10-12',
#     'birthdate': datetime.datetime(1969, 7, 20, 0, 0)},
#    {'id': '642707',
#     'username': 'eric60',
#     'name': 'Anthony Perkins',
#     'birthdate': datetime.datetime(1967, 12, 19, 0, 0)},
#    {'id': '1634437',
#     'username': 'batesmichael',
#     'country': 'Cook Islands',
#     'country_code': 'CK',
#     'mail': 'johnbennett@yahoo.com',
#     'registered': '2008-02-18',
#     'birthdate': datetime.datetime(1996, 1, 25, 0, 0)},
#    {'id': '246844', 'username': 'kristin82', 'registered': '2017-09-30'},
#    {'id': '947380',
#     'username': 'justinlong',
#     'name': 'Jason Rasmussen',
#     'mail': 'jeffrey59@gmail.com',
#     'registered': '2011-09-30'},
#    {'id': '2000791497',
#     'username': 'kennethgregory',
#     'name': 'Melissa Frank',
#     'country': 'Uzbekistan',
#     'country_code': 'UZ',
#     'mail': 'hunter46@yahoo.com',
#     'birthdate': datetime.datetime(1995, 6, 8, 0, 0)},
#    {'id': '52074',
#     'username': 'brichard',
#     'mail': 'shellyalvarado@gmail.com',
#     'registered': '2007-03-31',
#     'birthdate': datetime.datetime(1976, 2, 8, 0, 0)},
#    {'id': '633221',
#     'username': 'james18',
#     'sex': 'F',
#     'mail': 'alex28@gmail.com',
#     'registered': '2015-08-08'},
#    {'id': '1269180',
#     'username': 'dillon44',
#     'name': 'Julie Pena',
#     'country': 'Botswana',
#     'country_code': 'BW',
#     'registered': '2007-08-11'},
#    {'id': '173314',
#     'username': 'harrisroger',
#     'name': 'Timothy Jones',
#     'sex': 'M',
#     'country': 'Isle of Man',
#     'country_code': 'IM',
#     'registered': '2008-08-18'},
#    {'name_prefix': 'Mr.',
#     'id': '373992',
#     'username': 'paul76',
#     'name': 'Vincent Baker',
#     'sex': 'M',
#     'birthdate': datetime.datetime(1977, 4, 23, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '104472',
#     'username': 'francesburke',
#     'name': 'Shawn Meyers',
#     'sex': 'M',
#     'country': 'Papua New Guinea',
#     'country_code': 'PG',
#     'mail': 'juliebailey@yahoo.com',
#     'registered': '2011-09-01',
#     'birthdate': datetime.datetime(1968, 12, 9, 0, 0)},
#    {'id': '1211488',
#     'username': 'stephen62',
#     'country': 'Lithuania',
#     'country_code': 'LT',
#     'mail': 'samuel54@gmail.com'},
#    {'id': '64631',
#     'username': 'katherine86',
#     'mail': 'matthew84@yahoo.com',
#     'birthdate': datetime.datetime(1960, 1, 20, 0, 0)},
#    {'id': '503743',
#     'username': 'sarahmiller',
#     'mail': 'salazaranthony@yahoo.com'},
#    {'id': '798070',
#     'username': 'lunaashley',
#     'birthdate': datetime.datetime(2019, 12, 2, 0, 0)},
#    {'id': '95743',
#     'username': 'gmorrow',
#     'sex': 'M',
#     'mail': 'brownjoseph@gmail.com',
#     'registered': '2014-05-14',
#     'birthdate': datetime.datetime(1988, 1, 17, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '993604',
#     'username': 'barnesmichael',
#     'sex': 'M',
#     'country': 'Cameroon',
#     'country_code': 'CM',
#     'mail': 'samuelbarnes@hotmail.com',
#     'birthdate': datetime.datetime(1978, 10, 23, 0, 0)},
#    {'id': '355702',
#     'username': 'williamayala',
#     'name': 'Casey Sullivan',
#     'sex': 'F'},
#    {'id': '341170',
#     'username': 'jerry48',
#     'name': 'David Schneider',
#     'mail': 'hullmichelle@gmail.com',
#     'registered': '2010-01-02'},
#    {'id': '2706705',
#     'username': 'hernandezhector',
#     'registered': '2016-11-20'},
#    {'name_prefix': 'Dr.',
#     'id': '357723',
#     'username': 'amber17',
#     'name': 'Keith Tran',
#     'sex': 'M',
#     'country': 'French Guiana',
#     'country_code': 'GF',
#     'birthdate': datetime.datetime(1951, 6, 5, 0, 0)},
#    {'name_prefix': 'Mrs.',
#     'id': '694088',
#     'username': 'andrew19',
#     'sex': 'F',
#     'registered': '2001-12-09'},
#    {'id': '1280137',
#     'username': 'michelledouglas',
#     'name': 'Cameron Fuller',
#     'sex': 'M',
#     'registered': '2010-01-09'},
#    {'id': '2001838097',
#     'username': 'manthony',
#     'sex': 'M',
#     'country': 'Guyana',
#     'country_code': 'GY',
#     'registered': '2011-01-07',
#     'birthdate': datetime.datetime(1963, 7, 30, 0, 0)},
#    {'id': '428644',
#     'username': 'ipope',
#     'country': 'Germany',
#     'country_code': 'DE',
#     'birthdate': datetime.datetime(1956, 5, 12, 0, 0)},
#    {'id': '936998',
#     'username': 'sean83',
#     'country': 'Bermuda',
#     'country_code': 'BM',
#     'mail': 'robert33@gmail.com',
#     'birthdate': datetime.datetime(1958, 11, 25, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '1264526',
#     'username': 'raymondcharles',
#     'name': 'Robert Martin',
#     'sex': 'M',
#     'country': 'Paraguay',
#     'country_code': 'PY',
#     'registered': '2011-01-13'},
#    {'id': '290298',
#     'username': 'powerssteven',
#     'mail': 'jamesfernandez@yahoo.com'},
#    {'name_prefix': 'Mrs.',
#     'id': '464185',
#     'username': 'williamgarcia',
#     'name': 'Margaret Lopez',
#     'sex': 'F',
#     'mail': 'jenningsamy@hotmail.com',
#     'birthdate': datetime.datetime(1988, 3, 19, 0, 0)},
#    {'id': '171303',
#     'username': 'bking',
#     'country': 'Niue',
#     'country_code': 'NU',
#     'mail': 'xjones@gmail.com',
#     'birthdate': datetime.datetime(2019, 3, 26, 0, 0)},
#    {'id': '452592',
#     'username': 'vcox',
#     'name': 'Cynthia Henderson PhD',
#     'sex': 'F',
#     'country': 'Liechtenstein',
#     'country_code': 'LI',
#     'registered': '2015-07-10',
#     'birthdate': datetime.datetime(1954, 5, 16, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '298791',
#     'username': 'nsweeney',
#     'sex': 'M',
#     'country': 'French Southern Territories',
#     'country_code': 'TF',
#     'mail': 'edwardgay@hotmail.com'},
#    {'id': '83316',
#     'username': 'ahurst',
#     'registered': '2012-05-12',
#     'birthdate': datetime.datetime(2011, 4, 8, 0, 0)},
#    {'id': '255186',
#     'username': 'davidgraham',
#     'name': 'Walter Mayer',
#     'sex': 'M',
#     'mail': 'blake27@hotmail.com',
#     'birthdate': datetime.datetime(1959, 4, 1, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '1610327',
#     'username': 'barbara83',
#     'name': 'Daniel Blair',
#     'sex': 'M',
#     'country': 'Saint Helena',
#     'mail': 'danielle55@gmail.com',
#     'registered': '2011-05-05'},
#    {'name_prefix': 'Mrs.',
#     'id': '223979',
#     'username': 'kmiller',
#     'name': 'Melissa Morrison',
#     'sex': 'F',
#     'country': 'Comoros',
#     'country_code': 'KM',
#     'mail': 'josephmiller@hotmail.com',
#     'registered': '2010-02-05'},
#    {'id': '53932',
#     'username': 'heidi86',
#     'name': 'Anthony Carson',
#     'country': 'United States Virgin Islands',
#     'registered': '2018-08-25'},
#    {'name_prefix': 'Mr.',
#     'id': '16863',
#     'username': 'sara99',
#     'name': 'Ralph Hunt',
#     'sex': 'M',
#     'registered': '2008-09-10'},
#    {'id': '2010064',
#     'username': 'collin85',
#     'registered': '2009-04-13',
#     'birthdate': datetime.datetime(2014, 1, 17, 0, 0)},
#    {'id': '2758236',
#     'username': 'parkerrichard',
#     'sex': 'M',
#     'mail': 'tonyabenjamin@gmail.com',
#     'birthdate': datetime.datetime(1962, 10, 28, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '763677',
#     'username': 'feliciahenry',
#     'sex': 'M',
#     'country': 'Greece',
#     'country_code': 'GR',
#     'registered': '2013-05-24',
#     'birthdate': datetime.datetime(2018, 11, 21, 0, 0)},
#    {'id': '147023',
#     'username': 'hboyle',
#     'country': 'Norway',
#     'country_code': 'NO',
#     'birthdate': datetime.datetime(1953, 1, 8, 0, 0)},
#    {'name_prefix': 'Ms.',
#     'id': '1012958',
#     'username': 'michaelcraig',
#     'name': 'Victoria Graham',
#     'sex': 'F',
#     'registered': '2013-12-12'},
#    {'id': '417104',
#     'username': 'vhopkins',
#     'mail': 'jonathon51@yahoo.com',
#     'registered': '2012-05-11'},
#    {'id': '17803',
#     'username': 'rogerstina',
#     'name': 'Caitlin West',
#     'country': 'Colombia',
#     'country_code': 'CO',
#     'mail': 'edwardhenry@gmail.com'},
#    {'id': '743937',
#     'username': 'pateljennifer',
#     'country': 'Mexico',
#     'country_code': 'MX',
#     'registered': '2017-02-03',
#     'birthdate': datetime.datetime(2013, 2, 2, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '193516',
#     'username': 'nicolelong',
#     'name': 'Colin Mccarty',
#     'sex': 'M',
#     'country': 'Bouvet Island (Bouvetoya)',
#     'mail': 'amandamonroe@yahoo.com',
#     'registered': '2019-05-18'},
#    {'id': '169430',
#     'username': 'christydavis',
#     'sex': 'M',
#     'mail': 'huntangela@hotmail.com',
#     'registered': '2012-05-26',
#     'birthdate': datetime.datetime(1995, 6, 14, 0, 0)},
#    {'id': '35635',
#     'username': 'johnwright',
#     'country': 'Iraq',
#     'country_code': 'IQ',
#     'birthdate': datetime.datetime(1994, 10, 4, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '379033',
#     'username': 'davidsonalexander',
#     'sex': 'M',
#     'mail': 'mark13@gmail.com'},
#    {'id': '890676', 'username': 'sblack', 'name': 'Dakota Reyes'},
#    {'id': '1833965',
#     'username': 'jerry71',
#     'country': 'Sao Tome and Principe',
#     'country_code': 'ST',
#     'mail': 'rbridges@yahoo.com',
#     'registered': '2015-04-18',
#     'birthdate': datetime.datetime(1971, 11, 8, 0, 0)},
#    {'id': '23510',
#     'username': 'theodore44',
#     'name': 'Samantha Harris',
#     'sex': 'F',
#     'country': 'Jamaica',
#     'country_code': 'JM',
#     'registered': '2013-05-19'},
#    {'name_prefix': 'Mrs.',
#     'id': '20517',
#     'username': 'hernandezzachary',
#     'name': 'Brenda Williams',
#     'sex': 'F',
#     'country': 'Holy See (Vatican City State)',
#     'country_code': 'VA',
#     'mail': 'morrisongail@hotmail.com',
#     'registered': '2002-02-11',
#     'birthdate': datetime.datetime(1995, 7, 30, 0, 0)},
#    {'id': '2001781588',
#     'username': 'nconley',
#     'name': 'Ronald Henry',
#     'mail': 'lewiswilliam@hotmail.com',
#     'registered': '2019-08-22'},
#    {'name_prefix': 'Dr.',
#     'id': '1085140',
#     'username': 'charles22',
#     'sex': 'M',
#     'country': 'Heard Island and McDonald Islands',
#     'country_code': 'HM',
#     'registered': '2008-11-23',
#     'birthdate': datetime.datetime(1983, 7, 6, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '68960',
#     'username': 'sharonmichael',
#     'sex': 'M',
#     'mail': 'jonathangardner@yahoo.com'},
#    {'name_prefix': 'Dr.',
#     'id': '781392',
#     'username': 'renee37',
#     'name': 'Rachel Johnson',
#     'sex': 'F',
#     'registered': '2012-02-24'},
#    {'id': '945545', 'username': 'ujones', 'mail': 'ggray@hotmail.com'},
#    {'name_prefix': 'Dr.', 'id': '57042', 'username': 'webbsamuel', 'sex': 'F'},
#    {'id': '1680722',
#     'username': 'martinezamber',
#     'country': 'New Caledonia',
#     'country_code': 'NC',
#     'mail': 'ggonzalez@gmail.com',
#     'registered': '2007-06-22'},
#    {'id': '1941672',
#     'username': 'kayla45',
#     'country': 'France',
#     'country_code': 'FR',
#     'mail': 'cheryl23@yahoo.com'},
#    {'name_prefix': 'Mr.',
#     'id': '15521',
#     'username': 'smiller',
#     'name': 'Zachary Hickman',
#     'sex': 'M',
#     'registered': '2016-11-21'},
#    {'id': '316578',
#     'username': 'elizabeth05',
#     'country': 'Uruguay',
#     'country_code': 'UY'},
#    {'name_prefix': 'Miss',
#     'id': '64583',
#     'username': 'hgreen',
#     'name': 'Lisa Pruitt',
#     'sex': 'F',
#     'country': 'Qatar',
#     'country_code': 'QA',
#     'mail': 'hudsonsusan@hotmail.com',
#     'registered': '2001-07-13'},
#    {'id': '2001624820',
#     'username': 'burgesschristopher',
#     'name': 'Natalie Harrell',
#     'birthdate': datetime.datetime(2019, 2, 3, 0, 0)},
#    {'id': '424680',
#     'username': 'kara39',
#     'country': 'Eritrea',
#     'country_code': 'ER',
#     'mail': 'myersmary@yahoo.com',
#     'registered': '2018-08-23'},
#    {'id': '142112',
#     'username': 'chelseaali',
#     'name': 'William Wang',
#     'sex': 'M',
#     'mail': 'clintonmccormick@yahoo.com'},
#    {'name_prefix': 'Mrs.',
#     'id': '104297',
#     'username': 'greeneshannon',
#     'sex': 'F',
#     'mail': 'yvette19@yahoo.com',
#     'registered': '2007-01-28',
#     'birthdate': datetime.datetime(2004, 10, 19, 0, 0)},
#    {'id': '47559',
#     'username': 'johnsonbrandon',
#     'sex': 'M',
#     'country': 'Guyana',
#     'country_code': 'GY',
#     'birthdate': datetime.datetime(2021, 2, 27, 0, 0)},
#    {'name_prefix': 'Mrs.',
#     'id': '651269',
#     'username': 'marksmith',
#     'name': 'Kristen Thomas',
#     'sex': 'F',
#     'country': 'Lebanon',
#     'country_code': 'LB',
#     'birthdate': datetime.datetime(1950, 11, 20, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '29196',
#     'username': 'pnavarro',
#     'name': 'Evan Elliott',
#     'sex': 'M',
#     'mail': 'jrussell@yahoo.com',
#     'registered': '2010-02-13',
#     'birthdate': datetime.datetime(1991, 9, 4, 0, 0)},
#    {'id': '2001677893',
#     'username': 'gina76',
#     'mail': 'stephenskatherine@gmail.com',
#     'birthdate': datetime.datetime(1980, 1, 21, 0, 0)},
#    {'id': '2002218566',
#     'username': 'rasmussencarrie',
#     'sex': 'M',
#     'registered': '2006-01-09'},
#    {'id': '62422',
#     'username': 'michealjones',
#     'name': 'Kristina Barnes',
#     'country': 'Sri Lanka',
#     'country_code': 'LK'},
#    {'name_prefix': 'Mr.',
#     'id': '301353',
#     'username': 'george64',
#     'name': 'George Mcbride',
#     'sex': 'M',
#     'country': 'Ghana',
#     'country_code': 'GH',
#     'birthdate': datetime.datetime(1968, 8, 23, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '293410',
#     'username': 'icox',
#     'name': 'Justin Smith',
#     'sex': 'M',
#     'registered': '2012-04-05',
#     'birthdate': datetime.datetime(1985, 5, 20, 0, 0)},
#    {'id': '364685',
#     'username': 'hollandrobert',
#     'country': 'Liberia',
#     'country_code': 'LR',
#     'mail': 'anita08@yahoo.com',
#     'birthdate': datetime.datetime(2011, 4, 30, 0, 0)},
#    {'id': '1639208',
#     'username': 'vterrell',
#     'birthdate': datetime.datetime(1971, 12, 26, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '485940',
#     'username': 'tamara09',
#     'name': 'Carol Stone',
#     'sex': 'F',
#     'country': 'Saint Helena',
#     'mail': 'greenashley@yahoo.com',
#     'birthdate': datetime.datetime(1981, 4, 12, 0, 0)},
#    {'id': '516926',
#     'username': 'melaniejensen',
#     'mail': 'amandajenkins@yahoo.com',
#     'registered': '2019-11-26'},
#    {'id': '196296',
#     'username': 'meltonmary',
#     'name': 'Russell Brown',
#     'country': 'Uzbekistan',
#     'country_code': 'UZ',
#     'mail': 'eric40@gmail.com'},
#    {'name_prefix': 'Miss',
#     'id': '2002153717',
#     'username': 'qlopez',
#     'name': 'Hannah Brown',
#     'sex': 'F',
#     'country': 'Cape Verde',
#     'country_code': 'CV',
#     'mail': 'gbutler@hotmail.com',
#     'birthdate': datetime.datetime(1979, 8, 1, 0, 0)},
#    {'id': '1527940',
#     'username': 'amandafox',
#     'name': 'Leslie Lewis',
#     'sex': 'F',
#     'birthdate': datetime.datetime(2000, 5, 26, 0, 0)},
#    {'id': '714468',
#     'username': 'debbiewhite',
#     'sex': 'F',
#     'mail': 'ldavis@yahoo.com',
#     'registered': '2011-05-09'},
#    {'name_prefix': 'Mrs.',
#     'id': '816162',
#     'username': 'kelleysherri',
#     'sex': 'F',
#     'mail': 'brownfelicia@yahoo.com',
#     'registered': '2004-11-09',
#     'birthdate': datetime.datetime(1961, 5, 14, 0, 0)},
#    {'id': '678366',
#     'username': 'zgreen',
#     'sex': 'M',
#     'country': 'Bhutan',
#     'country_code': 'BT',
#     'registered': '2006-12-19',
#     'birthdate': datetime.datetime(2009, 8, 7, 0, 0)},
#    {'id': '362202',
#     'username': 'jill67',
#     'country': 'South Africa',
#     'country_code': 'ZA',
#     'registered': '2001-02-27'},
#    {'id': '1630606',
#     'username': 'jesusbrown',
#     'name': 'Lisa Burgess',
#     'country': 'Zimbabwe',
#     'country_code': 'ZW',
#     'mail': 'ayersbrooke@yahoo.com'},
#    {'id': '981377',
#     'username': 'kelly99',
#     'country': 'Dominica',
#     'country_code': 'DM',
#     'mail': 'cabrerajames@yahoo.com'},
#    {'id': '814629',
#     'username': 'kpayne',
#     'name': 'Brian Cain',
#     'sex': 'M',
#     'mail': 'faith12@hotmail.com',
#     'birthdate': datetime.datetime(1971, 9, 22, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '103876',
#     'username': 'perezlaura',
#     'sex': 'M',
#     'registered': '2019-07-28',
#     'birthdate': datetime.datetime(1999, 11, 4, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '386585',
#     'username': 'knightdeanna',
#     'sex': 'M',
#     'mail': 'ortizisabel@gmail.com',
#     'registered': '2013-06-11',
#     'birthdate': datetime.datetime(1969, 7, 7, 0, 0)},
#    {'id': '173579',
#     'username': 'eburke',
#     'mail': 'vgibbs@hotmail.com',
#     'birthdate': datetime.datetime(2017, 7, 13, 0, 0)},
#    {'id': '953598',
#     'username': 'sherrymiller',
#     'name': 'Andrew Berg',
#     'country': 'Bahrain',
#     'country_code': 'BH',
#     'registered': '2011-04-23',
#     'birthdate': datetime.datetime(1996, 12, 10, 0, 0)},
#    {'id': '323186',
#     'username': 'richardbell',
#     'name': 'Mr. James Mclean DDS',
#     'sex': 'M',
#     'mail': 'martinezchristopher@gmail.com'},
#    {'id': '377581',
#     'username': 'martinezkendra',
#     'name': 'David Morrison',
#     'country': 'Tokelau',
#     'country_code': 'TK',
#     'mail': 'thomasthomas@yahoo.com',
#     'registered': '2003-07-20',
#     'birthdate': datetime.datetime(2017, 12, 8, 0, 0)},
#    {'id': '174706', 'username': 'johnny87', 'name': 'Allen Oconnell'},
#    {'id': '465829',
#     'username': 'devin80',
#     'name': 'Nancy Mcintosh',
#     'country': 'Croatia',
#     'country_code': 'HR',
#     'mail': 'kristymartin@yahoo.com',
#     'registered': '2010-11-16'},
#    {'id': '129190',
#     'username': 'dtaylor',
#     'name': 'Karen Clay',
#     'mail': 'chapmanaudrey@gmail.com',
#     'registered': '2011-02-24'},
#    {'name_prefix': 'Dr.',
#     'id': '1962',
#     'username': 'joshuamunoz',
#     'name': 'Bobby Cohen',
#     'sex': 'M',
#     'mail': 'xduncan@gmail.com',
#     'registered': '2005-05-28',
#     'birthdate': datetime.datetime(1965, 2, 22, 0, 0)},
#    {'id': '15851',
#     'username': 'deborah80',
#     'mail': 'ericmccormick@yahoo.com',
#     'registered': '2001-11-14',
#     'birthdate': datetime.datetime(1957, 5, 1, 0, 0)},
#    {'id': '130819',
#     'username': 'clarkkimberly',
#     'sex': 'M',
#     'country': 'Nicaragua',
#     'country_code': 'NI'},
#    {'id': '69695',
#     'username': 'angela19',
#     'sex': 'F',
#     'registered': '2013-11-29'},
#    {'name_prefix': 'Dr.',
#     'id': '135470',
#     'username': 'greenegabrielle',
#     'sex': 'M',
#     'birthdate': datetime.datetime(1999, 12, 25, 0, 0)},
#    {'id': '80980',
#     'username': 'manuel61',
#     'name': 'Melissa Richardson',
#     'country': 'Uruguay',
#     'country_code': 'UY',
#     'registered': '2015-07-05'},
#    {'id': '286566',
#     'username': 'mistyrice',
#     'name': 'Melanie Gonzalez',
#     'mail': 'kevin43@hotmail.com'},
#    {'id': '40114',
#     'username': 'jamessimpson',
#     'name': 'Randy Ruiz',
#     'sex': 'M',
#     'country': 'Dominican Republic',
#     'country_code': 'DO',
#     'mail': 'stonekevin@hotmail.com',
#     'registered': '2007-04-20'},
#    {'id': '131674',
#     'username': 'powersmark',
#     'name': 'Elizabeth Reed',
#     'mail': 'mjohnson@yahoo.com'},
#    {'id': '2074896',
#     'username': 'davidpearson',
#     'name': 'Andrew Price',
#     'sex': 'M'},
#    {'id': '398964', 'username': 'buckjennifer', 'name': 'Steven Wilson'},
#    {'id': '174991',
#     'username': 'nicolereynolds',
#     'name': 'Heather Cole',
#     'registered': '2017-06-03'},
#    {'id': '486648',
#     'username': 'deborah94',
#     'name': 'Kimberly Dunn',
#     'sex': 'F'},
#    {'id': '2001614553',
#     'username': 'juliacochran',
#     'name': 'Patricia King',
#     'mail': 'james67@yahoo.com',
#     'birthdate': datetime.datetime(2007, 12, 13, 0, 0)},
#    {'id': '2001495857',
#     'username': 'leecompton',
#     'registered': '2003-06-21',
#     'birthdate': datetime.datetime(2003, 3, 27, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '288146',
#     'username': 'christopher68',
#     'sex': 'M',
#     'birthdate': datetime.datetime(1952, 11, 10, 0, 0)},
#    {'id': '41218',
#     'username': 'kempandrea',
#     'name': 'Heather Cox',
#     'mail': 'david00@yahoo.com',
#     'registered': '2003-07-29'},
#    {'id': '1959496',
#     'username': 'fowlercarolyn',
#     'name': 'Michael Barnes',
#     'sex': 'M',
#     'country': 'Japan',
#     'country_code': 'JP',
#     'mail': 'khawkins@yahoo.com',
#     'birthdate': datetime.datetime(2020, 11, 6, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '1975307',
#     'username': 'maynardtracie',
#     'sex': 'F',
#     'mail': 'michaelwalker@hotmail.com'},
#    {'id': '29063',
#     'username': 'darrellwilliams',
#     'sex': 'F',
#     'registered': '2004-03-02'},
#    {'id': '811616',
#     'username': 'monica16',
#     'name': 'Julian Hernandez',
#     'country': 'Jordan',
#     'country_code': 'JO',
#     'mail': 'fostertimothy@gmail.com',
#     'birthdate': datetime.datetime(2004, 4, 18, 0, 0)},
#    {'id': '852439', 'username': 'fischermargaret'},
#    {'id': '2001672505',
#     'username': 'eric09',
#     'name': 'Stephen Soto',
#     'sex': 'M',
#     'country': 'Rwanda',
#     'country_code': 'RW',
#     'registered': '2002-11-17',
#     'birthdate': datetime.datetime(1978, 7, 24, 0, 0)},
#    {'id': '94243',
#     'username': 'harrisdeborah',
#     'country': 'Vietnam',
#     'country_code': 'VN',
#     'mail': 'george85@hotmail.com'},
#    {'name_prefix': 'Mr.',
#     'id': '352814',
#     'username': 'wjackson',
#     'name': 'Mr. Scott Kemp',
#     'sex': 'M',
#     'country': 'Pitcairn Islands',
#     'mail': 'rubioanne@yahoo.com',
#     'registered': '2010-12-25'},
#    {'id': '312142',
#     'username': 'qtucker',
#     'name': 'Charles Gates',
#     'sex': 'M',
#     'country': 'British Indian Ocean Territory (Chagos Archipelago)',
#     'mail': 'michelle52@yahoo.com',
#     'birthdate': datetime.datetime(1957, 1, 31, 0, 0)},
#    {'id': '449247', 'username': 'mathewslauren', 'name': 'Aaron Kelly'},
#    {'id': '144798',
#     'username': 'hvaldez',
#     'name': 'Michael Bailey',
#     'birthdate': datetime.datetime(1987, 5, 27, 0, 0)},
#    {'id': '102526',
#     'username': 'kmorales',
#     'name': 'Leslie Miller',
#     'mail': 'mckeemichael@hotmail.com'},
#    {'id': '985823',
#     'username': 'jeffrey90',
#     'mail': 'griffintrevor@gmail.com',
#     'birthdate': datetime.datetime(1973, 8, 8, 0, 0)},
#    {'id': '1402260',
#     'username': 'blakepatrick',
#     'mail': 'rwood@gmail.com',
#     'birthdate': datetime.datetime(1974, 11, 7, 0, 0)},
#    {'id': '2002217618',
#     'username': 'rhonda61',
#     'mail': 'manningjonathan@gmail.com',
#     'birthdate': datetime.datetime(1974, 6, 22, 0, 0)},
#    {'id': '227454',
#     'username': 'dananewton',
#     'name': 'Thomas Montes',
#     'country': 'Ecuador',
#     'country_code': 'EC',
#     'mail': 'istewart@yahoo.com',
#     'registered': '2006-09-25'},
#    {'id': '1020526',
#     'username': 'jeannesummers',
#     'name': 'Stephen Mckee',
#     'country': "Cote d'Ivoire",
#     'birthdate': datetime.datetime(2017, 2, 13, 0, 0)},
#    {'id': '1160514',
#     'username': 'nicholasthomas',
#     'sex': 'M',
#     'registered': '2018-05-06'},
#    {'id': '299566',
#     'username': 'taraalvarez',
#     'sex': 'M',
#     'country': 'Cambodia',
#     'country_code': 'KH',
#     'mail': 'gibsonnathan@yahoo.com',
#     'birthdate': datetime.datetime(1954, 11, 10, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '186979',
#     'username': 'wrichards',
#     'name': 'David Anderson',
#     'sex': 'M',
#     'birthdate': datetime.datetime(1970, 10, 9, 0, 0)},
#    {'id': '1182629',
#     'username': 'dominic41',
#     'name': 'Robert Butler',
#     'sex': 'M',
#     'mail': 'monicamolina@gmail.com'},
#    {'id': '187281',
#     'username': 'glewis',
#     'name': 'Samantha Flores',
#     'sex': 'F',
#     'mail': 'tjones@hotmail.com',
#     'birthdate': datetime.datetime(1970, 1, 1, 0, 0)},
#    {'id': '143318',
#     'username': 'hannahdelgado',
#     'mail': 'patricia57@yahoo.com'},
#    {'id': '37106',
#     'username': 'torrestammy',
#     'name': 'Michele House',
#     'birthdate': datetime.datetime(1997, 9, 9, 0, 0)},
#    {'id': '499271', 'username': 'natashalawrence', 'name': 'Kathleen Chapman'},
#    {'id': '115525',
#     'username': 'justinedwards',
#     'mail': 'charlesdavis@hotmail.com'},
#    {'id': '264198',
#     'username': 'thompsonjames',
#     'name': 'Michelle Gaines',
#     'country': 'Cayman Islands',
#     'country_code': 'KY',
#     'registered': '2017-07-08',
#     'birthdate': datetime.datetime(2008, 3, 10, 0, 0)},
#    {'id': '310237',
#     'username': 'stanleywright',
#     'country': 'United Arab Emirates',
#     'country_code': 'AE',
#     'registered': '2013-02-23',
#     'birthdate': datetime.datetime(2017, 4, 8, 0, 0)},
#    {'name_prefix': 'Ms.',
#     'id': '88378',
#     'username': 'gnelson',
#     'sex': 'F',
#     'mail': 'pattersonisaac@yahoo.com',
#     'birthdate': datetime.datetime(1952, 5, 2, 0, 0)},
#    {'id': '125388',
#     'username': 'marybrown',
#     'country': 'Hungary',
#     'country_code': 'HU',
#     'registered': '2014-04-30'},
#    {'id': '174096',
#     'username': 'hansonamy',
#     'sex': 'M',
#     'country': 'Turks and Caicos Islands',
#     'mail': 'sullivankaren@yahoo.com',
#     'birthdate': datetime.datetime(1960, 4, 6, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '430507',
#     'username': 'mcfarlandjoshua',
#     'name': 'Gerald Wilson',
#     'sex': 'M',
#     'mail': 'carlsonlaura@hotmail.com',
#     'birthdate': datetime.datetime(1965, 3, 28, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '59064',
#     'username': 'kevin41',
#     'sex': 'M',
#     'country': 'British Indian Ocean Territory (Chagos Archipelago)',
#     'registered': '2018-07-20'},
#    {'id': '2000317663',
#     'username': 'amanda76',
#     'sex': 'M',
#     'country': 'Korea',
#     'registered': '2006-07-01'},
#    {'id': '62839',
#     'username': 'xmurray',
#     'mail': 'patrickmelissa@hotmail.com',
#     'birthdate': datetime.datetime(1996, 5, 16, 0, 0)},
#    {'id': '949568',
#     'username': 'yangstacy',
#     'registered': '2012-05-14',
#     'birthdate': datetime.datetime(1977, 3, 9, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '1983947',
#     'username': 'kjones',
#     'sex': 'M',
#     'birthdate': datetime.datetime(2020, 9, 11, 0, 0)},
#    {'id': '1207345',
#     'username': 'pneal',
#     'sex': 'F',
#     'country': 'Chad',
#     'country_code': 'TD'},
#    {'name_prefix': 'Mr.',
#     'id': '279989',
#     'username': 'thomasdixon',
#     'sex': 'M',
#     'birthdate': datetime.datetime(1954, 8, 23, 0, 0)},
#    {'id': '107135',
#     'username': 'zmcdowell',
#     'country': 'Kyrgyz Republic',
#     'registered': '2001-02-14'},
#    {'id': '763912', 'username': 'david67', 'sex': 'M'},
#    {'name_prefix': 'Mrs.',
#     'id': '2001732094',
#     'username': 'samuel50',
#     'sex': 'F',
#     'country': 'Kuwait',
#     'country_code': 'KW',
#     'mail': 'perryamber@yahoo.com'},
#    {'id': '294705', 'username': 'meadowspriscilla', 'name': 'Laurie Delacruz'},
#    {'name_prefix': 'Mr.',
#     'id': '479499',
#     'username': 'rachelberry',
#     'sex': 'M',
#     'country': 'Saint Pierre and Miquelon',
#     'country_code': 'PM',
#     'mail': 'dtorres@gmail.com',
#     'registered': '2007-12-01'},
#    {'name_prefix': 'Mr.',
#     'id': '9717',
#     'username': 'mstrickland',
#     'sex': 'M',
#     'country': 'Malawi',
#     'country_code': 'MW',
#     'registered': '2017-01-11'},
#    {'name_prefix': 'Mrs.',
#     'id': '1321445',
#     'username': 'brianroberson',
#     'sex': 'F',
#     'country': 'Korea',
#     'mail': 'rclark@yahoo.com',
#     'registered': '2007-12-19',
#     'birthdate': datetime.datetime(1965, 10, 4, 0, 0)},
#    {'id': '131126',
#     'username': 'michael72',
#     'sex': 'M',
#     'mail': 'eparrish@yahoo.com',
#     'registered': '2006-08-06',
#     'birthdate': datetime.datetime(1984, 9, 17, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '201427',
#     'username': 'barbara14',
#     'name': 'Christopher Robbins',
#     'sex': 'M',
# ...
#     'username': 'garyfowler',
#     'name': 'Rebecca Baker',
#     'sex': 'F',
#     'registered': '2005-05-30'},
#    {'id': '2173582',
#     'username': 'padillaroger',
#     'name': 'Cheryl Hansen',
#     'registered': '2014-04-25'},
#    {'id': '2001923941',
#     'username': 'seththomas',
#     'name': 'Lucas Morgan',
#     'country': 'New Zealand',
#     'country_code': 'NZ',
#     'birthdate': datetime.datetime(1989, 12, 25, 0, 0)},
#    {'id': '2827429',
#     'username': 'kyle43',
#     'mail': 'nancy31@hotmail.com',
#     'birthdate': datetime.datetime(2000, 10, 31, 0, 0)},
#    {'name_prefix': 'Ms.',
#     'id': '1231311',
#     'username': 'pittmancatherine',
#     'name': 'Chelsea Martin',
#     'sex': 'F',
#     'mail': 'griffithmichael@yahoo.com',
#     'birthdate': datetime.datetime(1987, 11, 5, 0, 0)},
#    {'id': '1800355652',
#     'username': 'valdezdavid',
#     'sex': 'M',
#     'country': 'Faroe Islands',
#     'country_code': 'FO',
#     'birthdate': datetime.datetime(1960, 7, 30, 0, 0)},
#    {'id': '2000404937',
#     'username': 'lindseyclark',
#     'mail': 'sarah77@yahoo.com',
#     'registered': '2004-10-23',
#     'birthdate': datetime.datetime(1988, 10, 25, 0, 0)},
#    {'id': '1803542966',
#     'username': 'lindawatson',
#     'name': 'Bradley Neal',
#     'mail': 'zjones@hotmail.com',
#     'registered': '2015-08-11'},
#    {'id': '2295614',
#     'username': 'kristine40',
#     'country': 'Kuwait',
#     'country_code': 'KW',
#     'mail': 'ysmith@yahoo.com',
#     'birthdate': datetime.datetime(1959, 10, 31, 0, 0)},
#    {'id': '885544',
#     'username': 'moorejames',
#     'name': 'Ashley Conner',
#     'sex': 'F',
#     'registered': '2018-06-09'},
#    {'id': '1560451',
#     'username': 'brownryan',
#     'mail': 'jacquelinepace@gmail.com',
#     'registered': '2017-03-06',
#     'birthdate': datetime.datetime(2005, 11, 27, 0, 0)},
#    {'id': '8869',
#     'username': 'twoods',
#     'country': 'Saudi Arabia',
#     'country_code': 'SA',
#     'mail': 'aramos@yahoo.com',
#     'registered': '2009-04-02',
#     'birthdate': datetime.datetime(1969, 8, 20, 0, 0)},
#    {'id': '1802679869',
#     'username': 'campbellgabriel',
#     'sex': 'M',
#     'country': 'Suriname',
#     'country_code': 'SR',
#     'mail': 'madeline35@gmail.com',
#     'registered': '2012-06-01'},
#    {'name_prefix': 'Mr.',
#     'id': '2002088662',
#     'username': 'xbowen',
#     'name': 'Eric Davis',
#     'sex': 'M',
#     'country': 'Belarus',
#     'country_code': 'BY',
#     'birthdate': datetime.datetime(2019, 8, 29, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '2001609316',
#     'username': 'rrodriguez',
#     'name': 'Danielle Melton',
#     'sex': 'F',
#     'mail': 'njones@gmail.com',
#     'registered': '2009-10-19'},
#    {'id': '607610',
#     'username': 'williamsteresa',
#     'name': 'Laura Bird',
#     'sex': 'F',
#     'country': 'Niger',
#     'country_code': 'NE',
#     'mail': 'uthomas@hotmail.com',
#     'registered': '2007-08-03'},
#    {'name_prefix': 'Mrs.',
#     'id': '585457',
#     'username': 'markwoods',
#     'sex': 'F',
#     'country': 'Macao',
#     'country_code': 'MO',
#     'birthdate': datetime.datetime(1986, 1, 21, 0, 0)},
#    {'id': '1802939952',
#     'username': 'tyronekeller',
#     'name': 'Peter Kelley',
#     'country': 'Aruba',
#     'country_code': 'AW',
#     'registered': '2016-07-04',
#     'birthdate': datetime.datetime(1976, 4, 28, 0, 0)},
#    {'id': '2000377601',
#     'username': 'mckayjohn',
#     'birthdate': datetime.datetime(2002, 1, 4, 0, 0)},
#    {'name_prefix': 'Miss',
#     'id': '2001015503',
#     'username': 'richard18',
#     'sex': 'F',
#     'birthdate': datetime.datetime(2004, 10, 3, 0, 0)},
#    {'id': '2651054',
#     'username': 'ppowers',
#     'name': 'Donna West',
#     'registered': '2008-11-28'},
#    {'name_prefix': 'Mr.',
#     'id': '1802390922',
#     'username': 'katherine85',
#     'name': 'Robert Green',
#     'sex': 'M',
#     'mail': 'shelley74@hotmail.com',
#     'registered': '2019-05-10'},
#    {'id': '794341',
#     'username': 'maria78',
#     'name': 'Kerry Morris',
#     'sex': 'M',
#     'registered': '2004-01-09'},
#    {'id': '2000364220',
#     'username': 'onealjeremy',
#     'sex': 'F',
#     'country': 'Chile',
#     'country_code': 'CL',
#     'mail': 'melissa49@gmail.com'},
#    {'name_prefix': 'Dr.',
#     'id': '2000535017',
#     'username': 'msalazar',
#     'name': 'Jonathan Conrad',
#     'sex': 'M',
#     'country': 'Ghana',
#     'country_code': 'GH',
#     'registered': '2004-01-17'},
#    {'id': '338523',
#     'username': 'marystewart',
#     'name': 'Kendra Murphy',
#     'sex': 'F',
#     'country': 'Aruba',
#     'country_code': 'AW'},
#    {'id': '2002321970', 'username': 'teresa50', 'sex': 'M'},
#    {'id': '2000266492',
#     'username': 'casey39',
#     'name': 'Alejandro Foster',
#     'registered': '2001-05-26',
#     'birthdate': datetime.datetime(1952, 5, 24, 0, 0)},
#    {'id': '315579',
#     'username': 'martinezalicia',
#     'name': 'Melissa Bennett',
#     'sex': 'F',
#     'mail': 'jenniferwood@gmail.com',
#     'registered': '2002-01-25'},
#    {'id': '1681976',
#     'username': 'gperez',
#     'country': 'Azerbaijan',
#     'country_code': 'AZ',
#     'mail': 'sullivantimothy@hotmail.com',
#     'registered': '2019-08-23',
#     'birthdate': datetime.datetime(1963, 5, 10, 0, 0)},
#    {'id': '946597',
#     'username': 'kimberlygaines',
#     'sex': 'M',
#     'birthdate': datetime.datetime(2016, 2, 29, 0, 0)},
#    {'id': '1960622',
#     'username': 'murrayamber',
#     'country': 'French Guiana',
#     'country_code': 'GF',
#     'mail': 'bethanyhickman@yahoo.com',
#     'registered': '2002-09-25',
#     'birthdate': datetime.datetime(1989, 11, 18, 0, 0)},
#    {'id': '1461064',
#     'username': 'walkertara',
#     'sex': 'F',
#     'country': "Lao People's Democratic Republic",
#     'country_code': 'LA',
#     'registered': '2002-12-12'},
#    {'name_prefix': 'Mr.',
#     'id': '796003',
#     'username': 'david15',
#     'sex': 'M',
#     'mail': 'jturner@hotmail.com'},
#    {'name_prefix': 'Mr.',
#     'id': '463756',
#     'username': 'brian30',
#     'sex': 'M',
#     'country': 'American Samoa',
#     'country_code': 'AS',
#     'birthdate': datetime.datetime(1952, 5, 12, 0, 0)},
#    {'id': '364655',
#     'username': 'valerieharris',
#     'country': 'Brazil',
#     'country_code': 'BR',
#     'mail': 'pbrown@yahoo.com',
#     'registered': '2018-08-13',
#     'birthdate': datetime.datetime(1952, 3, 1, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '2002276763',
#     'username': 'xnorton',
#     'name': 'Joseph Rangel',
#     'sex': 'M',
#     'country': 'Kiribati',
#     'country_code': 'KI',
#     'mail': 'phillip13@gmail.com'},
#    {'name_prefix': 'Mrs.',
#     'id': '768565',
#     'username': 'lthompson',
#     'name': 'Shawna Soto',
#     'sex': 'F',
#     'birthdate': datetime.datetime(2010, 2, 21, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '2001730787',
#     'username': 'gkelley',
#     'sex': 'M',
#     'mail': 'anthonypadilla@gmail.com',
#     'registered': '2004-03-23',
#     'birthdate': datetime.datetime(2010, 12, 12, 0, 0)},
#    {'id': '2001165454',
#     'username': 'nhughes',
#     'country': 'Moldova',
#     'mail': 'mreyes@gmail.com',
#     'birthdate': datetime.datetime(1965, 9, 17, 0, 0)},
#    {'id': '412471',
#     'username': 'williamschristopher',
#     'sex': 'F',
#     'registered': '2010-11-12',
#     'birthdate': datetime.datetime(1985, 12, 13, 0, 0)},
#    {'id': '882329',
#     'username': 'jamesallen',
#     'name': 'Glen Keller',
#     'birthdate': datetime.datetime(2012, 4, 15, 0, 0)},
#    {'id': '2737118',
#     'username': 'nicolewilliams',
#     'name': 'Kevin West',
#     'mail': 'steven98@gmail.com',
#     'birthdate': datetime.datetime(1999, 3, 26, 0, 0)},
#    {'id': '2001833118',
#     'username': 'santanaalexa',
#     'birthdate': datetime.datetime(1955, 6, 18, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '1564621',
#     'username': 'hortonmartin',
#     'name': 'Alexander Jackson',
#     'sex': 'M',
#     'birthdate': datetime.datetime(1960, 3, 8, 0, 0)},
#    {'id': '2002053137',
#     'username': 'fsnyder',
#     'name': 'Kelly Perez',
#     'sex': 'F',
#     'country': 'Japan',
#     'country_code': 'JP',
#     'registered': '2014-09-16',
#     'birthdate': datetime.datetime(2012, 12, 20, 0, 0)},
#    {'id': '153270',
#     'username': 'leandrea',
#     'name': 'Douglas Nguyen',
#     'mail': 'sonyaroberts@hotmail.com',
#     'registered': '2013-09-28',
#     'birthdate': datetime.datetime(2020, 8, 25, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '1706378',
#     'username': 'agarcia',
#     'sex': 'M',
#     'registered': '2015-08-21',
#     'birthdate': datetime.datetime(1959, 8, 20, 0, 0)},
#    {'id': '2002045588', 'username': 'robertkim', 'registered': '2011-10-19'},
#    {'id': '747705',
#     'username': 'garciajeremy',
#     'name': 'Vicki Williams',
#     'registered': '2019-01-17',
#     'birthdate': datetime.datetime(1969, 10, 1, 0, 0)},
#    {'id': '2179227', 'username': 'avilataylor', 'name': 'Sherry Dillon'},
#    {'id': '2001362866',
#     'username': 'josephsmith',
#     'name': 'Tiffany Luna',
#     'sex': 'F',
#     'registered': '2017-06-27'},
#    {'id': '1488508', 'username': 'msmith', 'sex': 'M'},
#    {'id': '2001833026',
#     'username': 'vbishop',
#     'sex': 'F',
#     'country': 'Maldives',
#     'country_code': 'MV',
#     'registered': '2016-11-15',
#     'birthdate': datetime.datetime(1958, 10, 3, 0, 0)},
#    {'id': '1762143',
#     'username': 'michael41',
#     'country': 'Monaco',
#     'country_code': 'MC',
#     'birthdate': datetime.datetime(2013, 5, 1, 0, 0)},
#    {'id': '2525133',
#     'username': 'nicole55',
#     'name': 'Shannon Smith',
#     'country': 'Bolivia',
#     'country_code': 'BO',
#     'mail': 'patriciasullivan@gmail.com',
#     'birthdate': datetime.datetime(1980, 12, 5, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '27034',
#     'username': 'chandlertina',
#     'name': 'Rick Coleman',
#     'sex': 'M',
#     'country': 'Vietnam',
#     'country_code': 'VN',
#     'mail': 'johndelgado@hotmail.com',
#     'registered': '2015-10-04',
#     'birthdate': datetime.datetime(1963, 8, 4, 0, 0)},
#    {'id': '1877133',
#     'username': 'sueray',
#     'mail': 'cheryl64@yahoo.com',
#     'registered': '2019-01-31'},
#    {'id': '2000141963',
#     'username': 'timothybenson',
#     'name': 'Richard Townsend',
#     'sex': 'M',
#     'mail': 'clarkscott@hotmail.com',
#     'registered': '2011-04-14'},
#    {'id': '2408562',
#     'username': 'ybarrera',
#     'name': 'Willie Williams',
#     'sex': 'M',
#     'country': 'Haiti',
#     'country_code': 'HT',
#     'birthdate': datetime.datetime(2016, 12, 7, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '2001804074',
#     'username': 'frenchjulia',
#     'sex': 'M'},
#    {'id': '1802504698',
#     'username': 'kristincurtis',
#     'country': 'United States of America',
#     'mail': 'stephen69@hotmail.com',
#     'registered': '2009-12-12',
#     'birthdate': datetime.datetime(1962, 8, 23, 0, 0)},
#    {'id': '823664',
#     'username': 'ericdixon',
#     'name': 'Jerry Wade',
#     'country': 'Albania',
#     'country_code': 'AL',
#     'mail': 'tiffanypatterson@hotmail.com',
#     'registered': '2010-09-21'},
#    {'name_prefix': 'Mrs.',
#     'id': '388577',
#     'username': 'leslie82',
#     'sex': 'F',
#     'mail': 'tyler41@gmail.com'},
#    {'name_prefix': 'Mrs.',
#     'id': '153695',
#     'username': 'evanvillegas',
#     'sex': 'F',
#     'country': 'Mayotte',
#     'country_code': 'YT',
#     'mail': 'bbailey@yahoo.com',
#     'birthdate': datetime.datetime(1997, 1, 30, 0, 0)},
#    {'id': '2718108',
#     'username': 'kmercado',
#     'name': 'Katherine Baker',
#     'country': "Cote d'Ivoire",
#     'mail': 'smithjennifer@hotmail.com'},
#    {'id': '2001251106',
#     'username': 'kimberly15',
#     'country': 'Grenada',
#     'country_code': 'GD',
#     'birthdate': datetime.datetime(1964, 3, 3, 0, 0)},
#    {'id': '207104',
#     'username': 'fdean',
#     'name': 'Tammy Thompson',
#     'country': 'Poland',
#     'country_code': 'PL',
#     'birthdate': datetime.datetime(1964, 2, 4, 0, 0)},
#    {'id': '2001253391',
#     'username': 'annafleming',
#     'country': 'Andorra',
#     'country_code': 'AD',
#     'birthdate': datetime.datetime(1986, 1, 22, 0, 0)},
#    {'id': '2001074670',
#     'username': 'samantha01',
#     'mail': 'luis78@yahoo.com',
#     'birthdate': datetime.datetime(1975, 5, 22, 0, 0)},
#    {'id': '2000172054',
#     'username': 'joshuafernandez',
#     'name': 'Lucas Flores',
#     'country': 'Barbados',
#     'country_code': 'BB',
#     'mail': 'hayesmelissa@gmail.com'},
#    {'id': '2759970',
#     'username': 'spetersen',
#     'country': 'Holy See (Vatican City State)',
#     'country_code': 'VA',
#     'registered': '2012-05-24',
#     'birthdate': datetime.datetime(1978, 11, 7, 0, 0)},
#    {'id': '1762530',
#     'username': 'mholloway',
#     'birthdate': datetime.datetime(1963, 4, 14, 0, 0)},
#    {'id': '1802922978',
#     'username': 'ricejessica',
#     'name': 'Ariel Gilmore',
#     'mail': 'hector88@yahoo.com',
#     'registered': '2004-01-18',
#     'birthdate': datetime.datetime(2005, 8, 12, 0, 0)},
#    {'id': '1325841',
#     'username': 'crosscharles',
#     'name': 'Steven Miranda',
#     'sex': 'M',
#     'country': 'Saint Kitts and Nevis',
#     'country_code': 'KN',
#     'registered': '2001-11-23',
#     'birthdate': datetime.datetime(1994, 4, 21, 0, 0)},
#    {'name_prefix': 'Ms.',
#     'id': '1138259',
#     'username': 'jsmith',
#     'name': 'Amber Harrington',
#     'sex': 'F',
#     'mail': 'ydiaz@hotmail.com',
#     'birthdate': datetime.datetime(2010, 7, 27, 0, 0)},
#    {'id': '2001867356',
#     'username': 'beth31',
#     'name': 'Devin Wilson',
#     'mail': 'nperez@gmail.com'},
#    {'id': '176234',
#     'username': 'luisjimenez',
#     'name': 'Mrs. Ashley Holland',
#     'birthdate': datetime.datetime(1950, 3, 8, 0, 0)},
#    {'id': '295453',
#     'username': 'johnsonmelissa',
#     'name': 'Kimberly Collins',
#     'sex': 'F',
#     'mail': 'jennifer92@hotmail.com',
#     'birthdate': datetime.datetime(1984, 10, 12, 0, 0)},
#    {'name_prefix': 'Dr.',
#     'id': '195966',
#     'username': 'iperez',
#     'name': 'Jasmine Wood',
#     'sex': 'F',
#     'country': "Lao People's Democratic Republic",
#     'country_code': 'LA',
#     'mail': 'hbell@yahoo.com',
#     'registered': '2018-12-06',
#     'birthdate': datetime.datetime(2017, 3, 24, 0, 0)},
#    {'id': '278020',
#     'username': 'clintoncarpenter',
#     'name': 'Christopher Bowen',
#     'country': 'Egypt',
#     'country_code': 'EG',
#     'mail': 'glennbutler@gmail.com',
#     'registered': '2005-12-26',
#     'birthdate': datetime.datetime(2001, 11, 22, 0, 0)},
#    {'name_prefix': 'Mr.',
#     'id': '2001700146',
#     'username': 'troy70',
#     'sex': 'M',
#     'country': 'Marshall Islands',
#     'country_code': 'MH',
#     'mail': 'leslie55@yahoo.com',
#     'birthdate': datetime.datetime(1952, 9, 18, 0, 0)},
#    {'id': '2770874',
#     'username': 'browncarla',
#     'name': 'Jaime Ray',
#     'birthdate': datetime.datetime(1965, 10, 6, 0, 0)},
#    {'id': '13153793',
#     'username': 'collinsmichael',
#     'name': 'Douglas Morales',
#     'registered': '2017-12-25'},
#    {'id': '1477683',
#     'username': 'kelly68',
#     'name': 'Scott Cooper',
#     'country': 'Botswana',
#     'country_code': 'BW',
#     'registered': '2011-10-26'},
#    {'id': '2001105370',
#     'username': 'linda06',
#     'country': 'Saint Helena',
#     'birthdate': datetime.datetime(1971, 4, 26, 0, 0)},
#    {'id': '1082961',
#     'username': 'debra93',
#     'country': 'Saint Vincent and the Grenadines',
#     'country_code': 'VC',
#     'mail': 'james92@hotmail.com'},
#    {'id': '1800027635', 'username': 'michael28', 'sex': 'M'},
#    {'id': '2349333', 'username': 'castrojoseph', 'name': 'Manuel Price'},
#    {'id': '2002203670',
#     'username': 'marissawolf',
#     'country': 'El Salvador',
#     'country_code': 'SV',
#     'mail': 'cgeorge@hotmail.com'},
#    {'id': '553115',
#     'username': 'gleblanc',
#     'sex': 'F',
#     'mail': 'duncanadam@yahoo.com',
#     'registered': '2018-02-17'},
#    {'name_prefix': 'Mr.',
#     'id': '2002106714',
#     'username': 'lisa38',
#     'sex': 'M',
#     'registered': '2003-11-16'},
#    {'id': '709872',
#     'username': 'hoffmanjulie',
#     'name': 'Anthony Ellis',
#     'sex': 'M',
#     'country': 'Taiwan',
#     'country_code': 'TW',
#     'registered': '2012-11-11',
#     'birthdate': datetime.datetime(1960, 1, 18, 0, 0)},
#    {'id': '2000332934',
#     'username': 'mcdowellteresa',
#     'name': 'Taylor Mejia',
#     'sex': 'M',
#     'registered': '2011-02-06'},
#    ...]],)

# %% [markdown]
# 3. Задекорируйте функцию из задания 1 при помощи `dask.delayed` и создайте список `reviewers`, состоящий из 5 объектов `delayed` (по одному объекту на файл). Из списка объектов `delayed`, создайте `dask.bag` при помощи метода `db.from_delayed`. Добавьте ключ `birth_year`, в котором хранится год рождения человека. Оставьте в выборке только тех людей, которые __наверняка__ моложе 1980 года. Преобразуйте поле `id` к целому типу.

# %%
reviewers = [dask.delayed(reader)(path) for path in files_list]

# %%
reviewers_bag = db.from_delayed(reviewers)

# %%
def add_year(item):
    if item.get('birthdate') is not None:
        item['birth_year'] = item.get('birthdate').year
        
    item['id'] = int(item['id'])

    return item

reviewers_bag_new = reviewers_bag.map(add_year).filter(lambda x: x.get('birth_year') is not None and x['birth_year'] > 1980)
reviewers_bag_new.take(5)

# %% [markdown]
# 4. Из `dask.bag`, полученного в задании 3, создайте `dask.dataframe` при помощи метода `bag.to_dataframe`. Укажите столбец `id` в качестве индекса.

# %%
reviewers_df = reviewers_bag_new.to_dataframe().set_index('id')
reviewers_df.head(5)

# %% [markdown]
# 5. Назовем отзыв негативным, если оценка равна 0, 1 или 2. Загрузите данные о негативных отзывах из файлов архива `reviews_full` (__ЛР12__) в виде `dask.DataFrame`. Посчитайте количество отзывов с группировкой по пользователю, оставившему отзыв. Объедините результат с таблицей, полученной в задаче 4.

# %%
 def add_rating(data):
    string, path = data
    json_obj = json.loads(string)
    json_obj['rating'] = int(re.findall('reviews_([0-9]).json', path)[0])
    json_obj['date'] = datetime.strptime(json_obj['date'], '%Y-%m-%d')
    return json_obj

reviews = db.read_text(urlpath='../data/reviews_full/reviews_*.json', include_path=True).map(add_rating).to_dataframe()
reviews.head(5)
# Out:
#    user_id  recipe_id       date  \
# 0   452355     292657 2016-05-08
# 1   329304     433404 2006-06-14
# 2   227932    2008187 1985-11-19
# 3   171468     270716 2019-05-21
# 4    91392    1159916 1972-09-18
#
#                                               review  rating
# 0  WOW!!! This is the best. I have never been abl...       0
# 1  This was good but the dressing needed somethin...       0
# 2  Very good,it was a hit for my family. I used 6...       0
# 3  Made for ZWT-8 Family Picks after I saw these ...       0
# 4  Very nice slaw. I especially like that it does...       0

# %%
reviews_neg = reviews[(reviews['rating'] > -1) & (reviews['rating'] < 3)]
reviews_neg_count = reviews_neg.groupby(reviews_neg['user_id'])['recipe_id'].count().compute()
reviews_neg_count

# %%
reviewers_bad_count = reviewers_df.merge(reviews_neg_count, how='inner', left_index=True, right_on='user_id')
reviewers_bad_count

# %% [markdown]
# #### [версия 2]
# * Уточнена формулировка задачи 1
