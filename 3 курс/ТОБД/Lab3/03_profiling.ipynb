# %% [markdown]
# ## Оптимизация выполнения кода, векторизация, Numba

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 3: Оптимизация выполнения кода, векторизация, Numba
# * IPython Cookbook, Second Edition (2018), глава 4
# * https://numba.pydata.org/numba-doc/latest/user/5minguide.html

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Сгенерируйте массив `A` из `N=1млн` случайных целых чисел на отрезке от 0 до 1000. Пусть `B[i] = A[i] + 100`. Посчитайте среднее значение массива `B`.

# %%
import numpy as np

A = np.random.randint(0, 1000, size=(1000000, ))
A
# Out:
# array([128, 515, 132, ..., 510, 986, 765])

# %%
def f1(A):
    acc, cnt = 0, 0
    for ai in A:
        bi = ai + 100
        acc += bi
        cnt +=1
    return acc/cnt

# %timeit f1(A)
# Out:
# 1 loop, best of 5: 564 ms per loop

# %%
def f2(A):
    acc = 0
    for ai in A:
        bi = ai + 100
        acc += bi
    return acc/len(A)

# %timeit f2(A)
# Out:
# 1 loop, best of 5: 545 ms per loop

# %%
def f3(A):
    return sum(A)/len(A)+100

# %timeit f3(A)
# Out:
# 10 loops, best of 5: 167 ms per loop

# %%
def f4(A):
    return A.mean()+100

# %timeit f4(A)
# Out:
# The slowest run took 7.23 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000 loops, best of 5: 954 µs per loop

# %%
# %lprun -f f2 f2(A)

# %%
import numba

# %%
@numba.njit
def f5(A):
    acc, cnt = 0, 0
    for ai in A:
        bi = ai + 100
        acc += bi
        cnt +=1
    return acc/cnt

# %timeit f5(A)
# Out:
# The slowest run took 560.77 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1 loop, best of 5: 568 µs per loop

# %% [markdown]
# 2. Создайте таблицу 2млн строк и с 4 столбцами, заполненными случайными числами. Добавьте столбец `key`, которые содержит элементы из множества английских букв. Выберите из таблицы подмножество строк, для которых в столбце `key` указаны первые 5 английских букв.

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.randint(0, 1000, size=(2_000_000, 4)), columns=['col1', 'col2', 'col3', 'col4'])
letters = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
df['key'] = np.random.choice(letters, 2_000_000, replace=True)
df
# Out:
#          col1  col2  col3  col4 key
# 0         612   314   604   992   a
# 1         649   738   796   866   f
# 2         445   963    84   943   g
# 3         538   451   915   413   a
# 4         887   951   868   609   a
# ...       ...   ...   ...   ...  ..
# 1999995   843   243   396   572   d
# 1999996    66   574   787   995   b
# 1999997   923   493   998   494   c
# 1999998   821   385   736   984   g
# 1999999    87   512   462   761   c
#
# [2000000 rows x 5 columns]

# %%
def g(df):
    letters = ['a', 'b', 'c', 'd', 'e']
    dfs = []
    for letter in letters:
        q = df[df['key']==letter]
        dfs.append(q)
    return pd.concat(dfs, axis=0)

g(df)
# Out:
#          col1  col2  col3  col4 key
# 0         612   314   604   992   a
# 3         538   451   915   413   a
# 4         887   951   868   609   a
# 8          79   848   125   975   a
# 10        956   636   394    40   a
# ...       ...   ...   ...   ...  ..
# 1999954    57   213   746   915   e
# 1999958   501   428   703   862   e
# 1999982   282   479   524   731   e
# 1999984   106   650   690    10   e
# 1999993    35   973   975   941   e
#
# [1427142 rows x 5 columns]

# %%
# %timeit g(df)
# Out:
# 1 loop, best of 5: 685 ms per loop

# %%
def g1(df):
    letters = ['a', 'b', 'c', 'd', 'e']
    return df[df['key'].isin(letters)]

g1(df)
# Out:
#          col1  col2  col3  col4 key
# 0         612   314   604   992   a
# 3         538   451   915   413   a
# 4         887   951   868   609   a
# 5         174   218   158   438   b
# 6         965   371   963   985   c
# ...       ...   ...   ...   ...  ..
# 1999993    35   973   975   941   e
# 1999995   843   243   396   572   d
# 1999996    66   574   787   995   b
# 1999997   923   493   998   494   c
# 1999999    87   512   462   761   c
#
# [1427142 rows x 5 columns]

# %%
# %timeit g1(df)
# Out:
# 10 loops, best of 5: 157 ms per loop

# %% [markdown]
# ## Лабораторная работа 3

# %%
# !pip install line_profiler
# Out:
# Collecting line_profiler
#   Downloading line_profiler-3.3.0-cp37-cp37m-manylinux2010_x86_64.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Requirement already satisfied: IPython>=0.13 in /usr/local/lib/python3.7/dist-packages (from line_profiler) (5.5.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from IPython>=0.13->line_profiler) (1.0.18)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython>=0.13->line_profiler) (5.1.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython>=0.13->line_profiler) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython>=0.13->line_profiler) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython>=0.13->line_profiler) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython>=0.13->line_profiler) (4.4.2)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from IPython>=0.13->line_profiler) (0.8.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython>=0.13->line_profiler) (2.6.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython>=0.13->line_profiler) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython>=0.13->line_profiler) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython>=0.13->line_profiler) (0.7.0)
# Installing collected packages: line-profiler
# Successfully installed line-profiler-3.3.0

# %%
# %load_ext line_profiler

# %% [markdown]
# 1. В файлах `recipes_sample.csv` и `reviews_sample.csv` (__ЛР 2__) находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца(ов) с индексами. Приведите столбцы к нужным типам.
#
# Реализуйте несколько вариантов функции подсчета среднего значения столбца `rating` из таблицы `reviews` для отзывов, оставленных в 2010 году.
#
# A. С использованием метода `DataFrame.iterrows` и без использования срезов таблицы
#
# Б. С использованием метода `DataFrame.iterrows` и с использованием срезов таблицы
#
# В. С использованием метода `DataFrame.mean`
#
# Проверьте, что результаты работы всех написанных функций корректны и совпадают. Измерьте выполнения всех вариантов.

# %%
recipes = pd.read_csv(r"https://raw.githubusercontent.com/Cat-in-box/FA/main/3%20%D0%BA%D1%83%D1%80%D1%81/%D0%A2%D0%9E%D0%91%D0%94/data/recipes_sample.csv", sep=",", parse_dates=["submitted"])
reviews = pd.read_csv(r"https://raw.githubusercontent.com/Cat-in-box/FA/main/3%20%D0%BA%D1%83%D1%80%D1%81/%D0%A2%D0%9E%D0%91%D0%94/data/reviews_sample.csv", sep=",", index_col=[0], parse_dates=["date"])
reviews
# Out:
#             user_id  ...                                             review
# 370476        21752  ...  Last week whole sides of frozen salmon fillet ...
# 624300       431813  ...  So simple and so tasty!  I used a yellow capsi...
# 187037       400708  ...  Very nice breakfast HH, easy to make and yummy...
# 706134   2001852463  ...  These are a favorite for the holidays and so e...
# 312179        95810  ...  Excellent soup!  The tomato flavor is just gre...
# ...             ...  ...                                                ...
# 1013457     1270706  ...  This recipe was great! I made it last night. I...
# 158736      2282344  ...  This recipe is outstanding. I followed the rec...
# 1059834      689540  ...  Well, we were not a crowd but it was a fabulou...
# 453285   2000242659  ...  I have been a steak eater and dedicated BBQ gr...
# 691207       463435  ...  Wonderful and simple to prepare seasoning blen...
#
# [126696 rows x 5 columns]

# %%
def f_A():
  sum_rating = 0
  counter = 0

  for index, row in reviews.iterrows():
    if row.date.year == 2010:
      sum_rating += row.rating
      counter += 1

  print(sum_rating/counter)

# %time f_A()
# Out:
# 4.4544402182900615
# CPU times: user 11.9 s, sys: 54.2 ms, total: 12 s
# Wall time: 12.2 s

# %%
def f_B():
  reviews_2010 = reviews[reviews['date'].dt.year == 2010]
  sum_rating = 0

  for index, row in reviews_2010.iterrows():
      sum_rating += row.rating

  print(sum_rating/reviews_2010.shape[0])

# %time f_B()
# Out:
# 4.4544402182900615
# CPU times: user 1.15 s, sys: 3.61 ms, total: 1.15 s
# Wall time: 1.16 s

# %%
# %time reviews[reviews['date'].dt.year == 2010]['rating'].mean()
# Out:
# CPU times: user 22.1 ms, sys: 0 ns, total: 22.1 ms
# Wall time: 28.5 ms
# 4.4544402182900615

# %% [markdown]
# 2. Какая из созданных функций выполняется медленнее? Что наиболее сильно влияет на скорость выполнения? Для ответа использовать профайлер `line_profiler`. Сохраните результаты работы профайлера в отдельную текстовую ячейку и прокомментируйте результаты его работы.
#
# (*). Сможете ли вы ускорить работу функции 1Б, отказавшись от использования метода `iterrows`, но не используя метод `mean`?

# %%
# %lprun -f f_A f_A()
# Out:
# 4.4544402182900615

# %% [markdown]
# Timer unit: 1e-06 s
#
# Total time: 31.4813 s
#
# File: ipython-input-72-eeb22a6359df
#
# Function: f_A at line 1
#
# Line №      Hits         Time  Per Hit   % Time  Line Contents
# ______________________________________________________________
#      1                                           def f_A():
#      2         1          3.0      3.0      0.0    sum_rating = 0
#      3         1          1.0      1.0      0.0    counter = 0
#      4
#      5    126697   27523904.0    217.2     87.4    for index, row in reviews.iterrows():
#      6    126696    3666066.0     28.9     11.6      if row.date.year == 2010:
#      7     12094     279640.0     23.1      0.9        sum_rating += row.rating
#      8     12094      10937.0      0.9      0.0        counter += 1
#      9
#     10         1        721.0    721.0      0.0    print(sum_rating/counter)

# %%
def f_B_upd():
  reviews_2010 = reviews[reviews['date'].dt.year == 2010]

  print(reviews_2010['rating'].sum()/reviews_2010.shape[0])

# %time f_B_upd()
# Out:
# 4.4544402182900615
# CPU times: user 22.5 ms, sys: 0 ns, total: 22.5 ms
# Wall time: 29.6 ms

# %% [markdown]
# 3. Вам предлагается воспользоваться функцией, которая собирает информацию, сколько отзывов содержат то или иное слово. Измерьте время выполнения этой функции. Сможете ли вы найти узкие места в коде, используя профайлер? Выпишите (словами), что в имеющемся коде реализовано неоптимально. Оптимизируйте функцию и добейтесь значительного прироста в скорости выполнения.

# %%
def get_word_reviews_count(df):
    word_reviews = {}
    for _, row in df.dropna(subset=['review']).iterrows():
        recipe_id, review = row['recipe_id'], row['review']
        words = review.split(' ')
        for word in words:
            if word not in word_reviews:
                word_reviews[word] = []
            word_reviews[word].append(recipe_id)
    
    word_reviews_count = {}
    for _, row in df.dropna(subset=['review']).iterrows():
        review = row['review']
        words = review.split(' ')
        for word in words:
            word_reviews_count[word] = len(word_reviews[word])
    return word_reviews_count

# %%
print(get_word_reviews_count(reviews))
# Out:
# {'Last': 94, 'week': 804, 'whole': 5628, 'sides': 312, 'of': 109029, 'frozen': 2647, 'salmon': 729, 'fillet': 60, 'was': 88781, 'on': 34583, 'sale': 149, 'in': 61539, 'my': 44144, 'local': 561, 'supermarket,': 10, 'so': 46090, 'I': 285147, 'bought': 1369, 'tons': 161, '(okay,': 5, 'only': 13965, '3,': 48, 'but': 42513, 'total': 381, 'weight': 160, 'over': 9065, '10': 2303, 'pounds).': 2, '': 214145, 'This': 39448, 'recipe': 41098, 'is': 55075, 'perfect': 4398, 'for': 121224, 'fillet,': 14, 'even': 7878, 'though': 2314, 'it': 111175, 'calls': 520, 'steaks.': 93, 'cut': 6688, 'up': 13585, 'the': 266050, 'into': 7031, 'individual': 314, 'portions': 156, 'and': 217849, 'followed': 4859, 'instructions': 731, 'exactly.': 571, "I'm": 7145, 'one': 15086, 'those': 2287, 'food': 2413, 'combining': 74, 'diets,': 5, 'left': 4690, 'out': 23644, 'white': 3425, 'wine': 1256, 'added': 21710, 'just': 24944, 'a': 166136, 'dash': 532, 'vinegar': 1272, 'instead': 10395, '(just': 273, 'little': 16319, 'bit,': 316, 'not': 22907, 'enough': 4440, 'to': 131471, 'change': 4146, 'taste': 8026, 'dish).': 20, 'Super': 840, 'yummy,': 366, 'leftovers': 1497, 'lunch': 1593, 'today': 1034, '(lucky': 3, 'me)!': 5, 'So': 4319, 'simple': 3947, 'tasty!': 994, 'used': 44849, 'yellow': 782, 'capsicum': 45, 'place': 2012, 'green': 4470, 'because': 11390, "that's": 1563, 'what': 7462, 'had': 26362, 'hand.': 1416, 'came': 5263, 'together': 3268, 'fast.': 178, 'Perfect': 755, 'meal': 1891, 'if': 7326, 'you': 24475, "don't": 6183, 'have': 35190, 'lot': 3186, 'time.': 4010, 'Easy,': 288, 'healthy': 1282, 'tasty.': 1986, 'Thanks': 26556, 'Stardustannie!': 4, 'Made': 12801, 'PAC': 1488, 'Fall': 737, '2007.': 85, 'Very': 8691, 'nice': 8168, 'breakfast': 1398, 'HH,': 1, 'easy': 17222, 'make': 32124, 'yummy': 2111, 'with': 58374, 'fresh': 7670, 'hot': 3578, 'coffe.': 2, 'Instead': 860, 'toast': 449, 'served': 6449, '#97694': 1, 'by': 6592, 'Paula': 121, 'G': 13, 'that': 36984, 'made': 38087, 'earlier': 167, 'turned': 6368, 'great.': 3686, 'will': 23985, 'be': 25032, 'regular': 2988, 'our': 6879, 'house': 1246, '-': 12000, 'DH': 3796, 'loved': 13755, 'them.': 3663, 'These': 8371, 'are': 15518, 'favorite': 2587, 'holidays': 123, 'children': 356, 'We': 12585, 'also': 14466, 'use': 16905, 'Rolo': 6, 'candies': 59, 'kisses.': 14, 'Excellent': 1550, 'soup!': 456, 'The': 25720, 'tomato': 2136, 'flavor': 7690, 'this': 87057, 'freezer': 874, 'tag': 808, 'soup': 4437, 'froze': 645, 'beautifully.': 305, 'prepared': 935, 'as': 35493, 'directed': 720, 'then': 8440, 'allowed': 225, 'cool': 953, 'container.': 46, 'thawed': 211, 'fridge': 922, 'reheated': 222, 'stovetop.': 38, 'Worked': 251, 'perfectly!': 158, 'forgot': 1290, 'add': 12987, 'skim': 409, 'milk': 3759, 'still': 6693, 'tasted': 4119, 'pretty': 3499, 'good!': 3887, 'Dancer!': 17, 'dinner': 3882, 'excellent,': 186, 'finally': 513, 'found': 5067, 'tuna': 488, 'casserole': 798, 'we': 12841, 'enjoy,': 11, 'thanks.': 123, 'When': 1630, 'snapped': 9, 'picture,': 61, 'review': 1142, 'recipe.': 14337, 'toasted': 775, 'pecans': 624, 'dish,': 801, 'at': 15362, 'party': 1243, 'Prime': 23, 'Rib.': 4, 'Ten': 16, 'stars': 2070, 'Lennie': 29, '!!': 334, 'good': 16106, 'combination': 1801, 'flavors': 2212, 'reduce': 910, 'rice': 3664, 'cilantro': 731, 'next': 10082, 'time,': 2236, 'thanks': 3197, 'sharing': 6196, 'hon!...Kitten': 9, 'Oh': 1335, 'Bergy!': 61, 'wonderful': 5681, 'cakes': 433, 'awesome.': 550, 'Fast': 83, 'put': 8578, 'together.': 1445, 'get': 6753, 'fish': 1128, 'where': 971, 'live': 435, '(yuck).': 5, 'am': 6191, 'tired': 147, 'trying': 1847, 'new': 2765, 'recipes': 2819, 'help': 761, 'lack': 174, 'quality.': 62, 'But': 2588, 'recipe,': 5129, 'problem.': 194, 'did': 17358, '3': 4472, 'cloves': 897, 'garlic,': 1029, 'seasoned': 776, 'bread': 5904, 'crumbs': 801, 'Smash': 3, 'Seasoning(318441).': 1, 'It': 19417, 'has': 4861, 'no': 5863, 'salt!\nI': 1, 'tartar': 77, 'sauce': 11425, 'go': 3691, '(56860).\nThank': 1, 'great': 19166, ' ...

# %%
# %lprun -f get_word_reviews_count get_word_reviews_count(reviews)

# %% [markdown]
# 4. Напишите несколько версий функции `MAPE` (см. [MAPE](https://en.wikipedia.org/wiki/Mean_absolute_percentage_error)) для расчета среднего процентного отклонения значения рейтинга для отзыва от среднего значения рейтинга для этого отзыва.
#     1. Без использования массивов `numpy` и `numba`
#     2. Без использования массивов `numpy`, но с использованием `numba`
#     3. С использованием массивов `numpy`, но без использования `numba`
#     4. C использованием массивов `numpy` и `numba`
#
# Измерьте время выполнения каждой из реализаций.
#
# Замечание: удалите из выборки отзывы с нулевым рейтингом.
